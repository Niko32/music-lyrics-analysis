# %%
import os
import lyricsgenius
from dotenv import load_dotenv
import yaml
import tomllib
import numpy as np
from typing import List
import sys

root = "../../.."

sys.path.append(os.path.abspath(f"{root}/src"))
from utils import get_main_tag, shrink_genius_tag, song_to_csv, artists_list_to_string

load_dotenv()

genius = lyricsgenius.Genius()
public_api = lyricsgenius.PublicAPI()

with open(f"{root}/config.toml", "rb") as f:
    config = tomllib.load(f)

def get_song_tags(song_id: int):
    song = public_api.song(song_id)['song']
    return song['tags']

# %%
for genre in ["blues", "electronic", "experimental", "folk", "jazz"]:

    multilabel_file = f"{root}/{config['multilabel_data_dir']}/songs/{genre}.yml"
    song_file = f"{root}/{config['id_data_dir']}/songs.csv"
    index_file = "05-index.txt"

    with open(multilabel_file, "r") as f:
        songs = yaml.safe_load(f)

    start_index = 0
    if os.path.exists(index_file):
        with open(index_file, "r") as f:
                start_index = int(f.read())

    # TODO: Search every id to get the songs language
    csv_strings = []
    for i, song in enumerate(songs[start_index:]):

        if song["id"] == -1:
            continue

        # print(f"Saving song {song['title']} with id {song['id']}")

        language = None
        while not language:
             try:
                language = genius.song(song["id"])["song"]["language"]

                if not language:
                    language = ""
                    break
             except Exception:
                print(f"❌ Failed to get song for id {song['id']}")

        song["language"] = language
        song["artists"] = artists_list_to_string(song["artists"])

        csv_strings.append(song_to_csv(song))

        # File save for every 10th song
        if i % 10 == 0:

            with open(song_file, "a", encoding="utf-8") as f:
                f.writelines(csv_strings)

            with open(index_file, "w") as f:
                f.write(str(start_index + i + 1))

            csv_strings = []

            print(f"✅ Saved {start_index + i + 1}th song for genre {genre}")

    with open(index_file, "w") as f:
        f.write('0')

    print(f"Saved songs from {genre} genre")
# Out:
# ✅ Saved 912th song for genre blues
# ✅ Saved 922th song for genre blues
# ✅ Saved 932th song for genre blues
# ✅ Saved 942th song for genre blues
# ✅ Saved 952th song for genre blues
# ✅ Saved 962th song for genre blues
# ✅ Saved 972th song for genre blues
# ✅ Saved 982th song for genre blues
# ❌ Failed to get song for id 2949128
# ✅ Saved 992th song for genre blues
# Saved songs from blues genre
# ✅ Saved 1th song for genre electronic
# ✅ Saved 11th song for genre electronic
# ✅ Saved 21th song for genre electronic
# ✅ Saved 31th song for genre electronic
# ✅ Saved 41th song for genre electronic
# ✅ Saved 51th song for genre electronic
# ✅ Saved 61th song for genre electronic
# ✅ Saved 71th song for genre electronic
# ✅ Saved 81th song for genre electronic
# ✅ Saved 91th song for genre electronic
# ✅ Saved 101th song for genre electronic
# ✅ Saved 111th song for genre electronic
# ✅ Saved 121th song for genre electronic
# ✅ Saved 131th song for genre electronic
# ✅ Saved 141th song for genre electronic
# ✅ Saved 151th song for genre electronic
# ✅ Saved 161th song for genre electronic
# ✅ Saved 171th song for genre electronic
# ✅ Saved 181th song for genre electronic
# ✅ Saved 191th song for genre electronic
# ❌ Failed to get song for id 4271772
# ✅ Saved 201th song for genre electronic
# ✅ Saved 211th song for genre electronic
# ✅ Saved 221th song for genre electronic
# ✅ Saved 231th song for genre electronic
# ✅ Saved 241th song for genre electronic
# ✅ Saved 251th song for genre electronic
# ✅ Saved 261th song for genre electronic
# ✅ Saved 271th song for genre electronic
# ✅ Saved 281th song for genre electronic
# ✅ Saved 291th song for genre electronic
# ✅ Saved 301th song for genre electronic
# ✅ Saved 311th song for genre electronic
# ✅ Saved 321th song for genre electronic
# ✅ Saved 331th song for genre electronic
# ✅ Saved 341th song for genre electronic
# ✅ Saved 351th song for genre electronic
# ✅ Saved 361th song for genre electronic
# ✅ Saved 371th song for genre electronic
# ✅ Saved 381th song for genre electronic
# ✅ Saved 391th song for genre electronic
# ✅ Saved 401th song for genre electronic
# ✅ Saved 411th song for genre electronic
# ✅ Saved 421th song for genre electronic
# ✅ Saved 431th song for genre electronic
# ✅ Saved 441th song for genre electronic
# ✅ Saved 451th song for genre electronic
# ✅ Saved 461th song for genre electronic
# ✅ Saved 471th song for genre electronic
# ✅ Saved 481th song for genre electronic
# ✅ Saved 491th song for genre electronic
# ✅ Saved 501th song for genre electronic
# ✅ Saved 511th song for genre electronic
# ✅ Saved 521th song for genre electronic
# ✅ Saved 531th song for genre electronic
# ✅ Saved 541th song for genre electronic
# ✅ Saved 551th song for genre electronic
# ✅ Saved 561th song for genre electronic
# ✅ Saved 571th song for genre electronic
# ✅ Saved 581th song for genre electronic
# ✅ Saved 591th song for genre electronic
# ✅ Saved 601th song for genre electronic
# ❌ Failed to get song for id 235729
# ✅ Saved 611th song for genre electronic
# ✅ Saved 621th song for genre electronic
# ✅ Saved 631th song for genre electronic
# ❌ Failed to get song for id 235729
# ✅ Saved 641th song for genre electronic
# ✅ Saved 651th song for genre electronic
# ✅ Saved 661th song for genre electronic
# ✅ Saved 671th song for genre electronic
# ✅ Saved 681th song for genre electronic
# ✅ Saved 691th song for genre electronic
# ✅ Saved 701th song for genre electronic
# ✅ Saved 711th song for genre electronic
# ✅ Saved 721th song for genre electronic
# ✅ Saved 731th song for genre electronic
# ✅ Saved 741th song for genre electronic
# ✅ Saved 751th song for genre electronic
# ✅ Saved 761th song for genre electronic
# ✅ Saved 771th song for genre electronic
# ✅ Saved 781th song for genre electronic
# ✅ Saved 791th song for genre electronic
# ✅ Saved 801th song for genre electronic
# ✅ Saved 811th song for genre electronic
# ✅ Saved 821th song for genre electronic
# ✅ Saved 831th song for genre electronic
# ✅ Saved 841th song for genre electronic
# ✅ Saved 851th song for genre electronic
# ✅ Saved 861th song for genre electronic
# ✅ Saved 871th song for genre electronic
# ✅ Saved 881th song for genre electronic
# ✅ Saved 891th song for genre electronic
# ✅ Saved 901th song for genre electronic
# ✅ Saved 911th song for genre electronic
# ❌ Failed to get song for id 43
# ❌ Failed to get song for id 43
# ✅ Saved 921th song for genre electronic
# ✅ Saved 931th song for genre electronic
# ✅ Saved 941th song for genre electronic
# ✅ Saved 951th song for genre electronic
# ✅ Saved 961th song for genre electronic
# ✅ Saved 971th song for genre electronic
# ✅ Saved 981th song for genre electronic
# ✅ Saved 991th song for genre electronic
# Saved songs from electronic genre
# ✅ Saved 1th song for genre experimental
# ❌ Failed to get song for id 158615
# ✅ Saved 11th song for genre experimental
# ❌ Failed to get song for id 235729
# ✅ Saved 21th song for genre experimental
# ✅ Saved 31th song for genre experimental
# ❌ Failed to get song for id 235729
# ✅ Saved 41th song for genre experimental
# ✅ Saved 51th song for genre experimental
# ✅ Saved 61th song for genre experimental
# ✅ Saved 71th song for genre experimental
# ✅ Saved 81th song for genre experimental
# ✅ Saved 91th song for genre experimental
# ❌ Failed to get song for id 235729
# ❌ Failed to get song for id 235729
# ✅ Saved 101th song for genre experimental
# ✅ Saved 111th song for genre experimental
# ✅ Saved 121th song for genre experimental
# ✅ Saved 131th song for genre experimental
# ✅ Saved 141th song for genre experimental
# ✅ Saved 151th song for genre experimental
# ✅ Saved 161th song for genre experimental
# ✅ Saved 171th song for genre experimental
# ✅ Saved 181th song for genre experimental
# ✅ Saved 191th song for genre experimental
# ✅ Saved 201th song for genre experimental
# ✅ Saved 211th song for genre experimental
# ✅ Saved 221th song for genre experimental
# ✅ Saved 231th song for genre experimental
# ✅ Saved 241th song for genre experimental
# ✅ Saved 251th song for genre experimental
# ✅ Saved 261th song for genre experimental
# ❌ Failed to get song for id 235729
# ✅ Saved 271th song for genre experimental
# ❌ Failed to get song for id 181598
# ✅ Saved 281th song for genre experimental
# ✅ Saved 291th song for genre experimental
# ✅ Saved 301th song for genre experimental
# ✅ Saved 311th song for genre experimental
# ❌ Failed to get song for id 2989266
# ❌ Failed to get song for id 235729
# ✅ Saved 321th song for genre experimental
# ✅ Saved 331th song for genre experimental
# ✅ Saved 341th song for genre experimental
# ✅ Saved 351th song for genre experimental
# ❌ Failed to get song for id 235729
# ✅ Saved 361th song for genre experimental
# ✅ Saved 371th song for genre experimental
# ✅ Saved 381th song for genre experimental
# ❌ Failed to get song for id 3958196
# ✅ Saved 391th song for genre experimental
# ✅ Saved 401th song for genre experimental
# ✅ Saved 411th song for genre experimental
# ✅ Saved 421th song for genre experimental
# ✅ Saved 431th song for genre experimental
# ✅ Saved 441th song for genre experimental
# ❌ Failed to get song for id 2845980
# ❌ Failed to get song for id 5832126
# ✅ Saved 451th song for genre experimental
# ✅ Saved 461th song for genre experimental
# ✅ Saved 471th song for genre experimental
# ✅ Saved 481th song for genre experimental
# ✅ Saved 491th song for genre experimental
# ❌ Failed to get song for id 235729
# ❌ Failed to get song for id 235729
# ✅ Saved 501th song for genre experimental
# ✅ Saved 511th song for genre experimental
# ❌ Failed to get song for id 3003630
# ❌ Failed to get song for id 3003630
# ✅ Saved 521th song for genre experimental
# ✅ Saved 531th song for genre experimental
# ✅ Saved 541th song for genre experimental
# ✅ Saved 551th song for genre experimental
# ✅ Saved 561th song for genre experimental
# ✅ Saved 571th song for genre experimental
# ✅ Saved 581th song for genre experimental
# ✅ Saved 591th song for genre experimental
# ✅ Saved 611th song for genre experimental
# ✅ Saved 621th song for genre experimental
# ✅ Saved 631th song for genre experimental
# ✅ Saved 641th song for genre experimental
# ✅ Saved 651th song for genre experimental
# ✅ Saved 661th song for genre experimental
# ✅ Saved 671th song for genre experimental
# ✅ Saved 681th song for genre experimental
# ✅ Saved 691th song for genre experimental
# ✅ Saved 701th song for genre experimental
# ✅ Saved 711th song for genre experimental
# ✅ Saved 721th song for genre experimental
# ✅ Saved 731th song for genre experimental
# ✅ Saved 741th song for genre experimental
# ❌ Failed to get song for id 2949128
# ❌ Failed to get song for id 2949128
# ❌ Failed to get song for id 2949128
# ✅ Saved 751th song for genre experimental
# ❌ Failed to get song for id 2400811
# ❌ Failed to get song for id 2400811
# ❌ Failed to get song for id 2400811
# ✅ Saved 761th song for genre experimental
# ✅ Saved 771th song for genre experimental
# ✅ Saved 781th song for genre experimental
# ✅ Saved 791th song for genre experimental
# ✅ Saved 801th song for genre experimental
# ✅ Saved 811th song for genre experimental
# ✅ Saved 821th song for genre experimental
# ✅ Saved 831th song for genre experimental
# ❌ Failed to get song for id 1063
# ✅ Saved 841th song for genre experimental
# ✅ Saved 851th song for genre experimental
# ✅ Saved 861th song for genre experimental
# ✅ Saved 871th song for genre experimental
# ✅ Saved 881th song for genre experimental
# ✅ Saved 891th song for genre experimental
# ✅ Saved 901th song for genre experimental
# ✅ Saved 911th song for genre experimental
# ❌ Failed to get song for id 3315890
# ❌ Failed to get song for id 3315890
# ✅ Saved 921th song for genre experimental
# ✅ Saved 931th song for genre experimental
# ✅ Saved 941th song for genre experimental
# ✅ Saved 951th song for genre experimental
# ✅ Saved 961th song for genre experimental
# ✅ Saved 971th song for genre experimental
# ✅ Saved 981th song for genre experimental
# ✅ Saved 991th song for genre experimental
# Saved songs from experimental genre
# ✅ Saved 1th song for genre folk
# ✅ Saved 11th song for genre folk
# ✅ Saved 21th song for genre folk
# ❌ Failed to get song for id 235729
# ❌ Failed to get song for id 235729
# ✅ Saved 31th song for genre folk
# ✅ Saved 41th song for genre folk
# ❌ Failed to get song for id 1237
# ✅ Saved 51th song for genre folk
# ✅ Saved 61th song for genre folk
# ✅ Saved 71th song for genre folk
# ✅ Saved 81th song for genre folk
# ✅ Saved 91th song for genre folk
# ✅ Saved 101th song for genre folk
# ❌ Failed to get song for id 90473
# ✅ Saved 111th song for genre folk
# ✅ Saved 121th song for genre folk
# ✅ Saved 131th song for genre folk
# ✅ Saved 141th song for genre folk
# ✅ Saved 151th song for genre folk
# ✅ Saved 161th song for genre folk
# ✅ Saved 171th song for genre folk
# ✅ Saved 181th song for genre folk
# ✅ Saved 191th song for genre folk
# ✅ Saved 201th song for genre folk
# ✅ Saved 211th song for genre folk
# ✅ Saved 221th song for genre folk
# ✅ Saved 231th song for genre folk
# ✅ Saved 241th song for genre folk
# ✅ Saved 251th song for genre folk
# ✅ Saved 261th song for genre folk
# ✅ Saved 271th song for genre folk
# ✅ Saved 281th song for genre folk
# ✅ Saved 291th song for genre folk
# ✅ Saved 301th song for genre folk
# ✅ Saved 311th song for genre folk
# ✅ Saved 321th song for genre folk
# ✅ Saved 331th song for genre folk
# ✅ Saved 341th song for genre folk
# ✅ Saved 351th song for genre folk
# ✅ Saved 361th song for genre folk
# ✅ Saved 371th song for genre folk
# ✅ Saved 381th song for genre folk
# ✅ Saved 391th song for genre folk
# ✅ Saved 401th song for genre folk
# ✅ Saved 411th song for genre folk
# ✅ Saved 421th song for genre folk
# ✅ Saved 431th song for genre folk
# ✅ Saved 441th song for genre folk
# ✅ Saved 451th song for genre folk
# ✅ Saved 461th song for genre folk
# ✅ Saved 471th song for genre folk
# ✅ Saved 481th song for genre folk
# ✅ Saved 491th song for genre folk
# ✅ Saved 501th song for genre folk
# ✅ Saved 511th song for genre folk
# ✅ Saved 521th song for genre folk
# ✅ Saved 531th song for genre folk
# ✅ Saved 541th song for genre folk
# ✅ Saved 551th song for genre folk
# ✅ Saved 561th song for genre folk
# ✅ Saved 571th song for genre folk
# ✅ Saved 581th song for genre folk
# ✅ Saved 591th song for genre folk
# ✅ Saved 601th song for genre folk
# ✅ Saved 611th song for genre folk
# ✅ Saved 621th song for genre folk
# ❌ Failed to get song for id 1063
# ✅ Saved 631th song for genre folk
# ✅ Saved 641th song for genre folk
# ✅ Saved 651th song for genre folk
# ✅ Saved 661th song for genre folk
# ✅ Saved 671th song for genre folk
# ✅ Saved 681th song for genre folk
# ✅ Saved 691th song for genre folk
# ✅ Saved 701th song for genre folk
# ✅ Saved 711th song for genre folk
# ✅ Saved 721th song for genre folk
# ✅ Saved 731th song for genre folk
# ✅ Saved 741th song for genre folk
# ✅ Saved 751th song for genre folk
# ✅ Saved 761th song for genre folk
# ✅ Saved 771th song for genre folk
# ✅ Saved 781th song for genre folk
# ❌ Failed to get song for id 1063
# ❌ Failed to get song for id 1063
# ❌ Failed to get song for id 1063
# ❌ Failed to get song for id 1063
# ✅ Saved 791th song for genre folk
# ✅ Saved 801th song for genre folk
# ✅ Saved 811th song for genre folk
# ✅ Saved 821th song for genre folk
# ❌ Failed to get song for id 2845980
# ✅ Saved 831th song for genre folk
# ✅ Saved 841th song for genre folk
# ✅ Saved 851th song for genre folk
# ✅ Saved 861th song for genre folk
# ✅ Saved 871th song for genre folk
# ❌ Failed to get song for id 235729
# ❌ Failed to get song for id 235729
# ✅ Saved 881th song for genre folk
# ✅ Saved 891th song for genre folk
# ✅ Saved 901th song for genre folk
# ✅ Saved 911th song for genre folk
# ✅ Saved 921th song for genre folk
# ✅ Saved 931th song for genre folk
# ✅ Saved 941th song for genre folk
# ✅ Saved 951th song for genre folk
# ✅ Saved 961th song for genre folk
# ✅ Saved 971th song for genre folk
# ✅ Saved 981th song for genre folk
# ✅ Saved 991th song for genre folk
# Saved songs from folk genre
# ✅ Saved 1th song for genre jazz
# ❌ Failed to get song for id 104942
# ❌ Failed to get song for id 104942
# ✅ Saved 11th song for genre jazz
# ✅ Saved 21th song for genre jazz
# ✅ Saved 31th song for genre jazz
# ✅ Saved 41th song for genre jazz
# ✅ Saved 51th song for genre jazz
# ❌ Failed to get song for id 235729
# ✅ Saved 61th song for genre jazz
# ✅ Saved 71th song for genre jazz
# ✅ Saved 81th song for genre jazz
# ✅ Saved 91th song for genre jazz
# ✅ Saved 101th song for genre jazz
# ✅ Saved 111th song for genre jazz
# ✅ Saved 121th song for genre jazz
# ✅ Saved 131th song for genre jazz
# ❌ Failed to get song for id 444948
# ✅ Saved 141th song for genre jazz
# ✅ Saved 151th song for genre jazz
# ✅ Saved 161th song for genre jazz
# ✅ Saved 171th song for genre jazz
# ✅ Saved 181th song for genre jazz
# ✅ Saved 191th song for genre jazz
# ✅ Saved 201th song for genre jazz
# ✅ Saved 211th song for genre jazz
# ✅ Saved 221th song for genre jazz
# ✅ Saved 231th song for genre jazz
# ✅ Saved 241th song for genre jazz
# ✅ Saved 251th song for genre jazz
# ✅ Saved 261th song for genre jazz
# ✅ Saved 271th song for genre jazz
# ❌ Failed to get song for id 2398213
# ✅ Saved 281th song for genre jazz
# ✅ Saved 291th song for genre jazz
# ✅ Saved 301th song for genre jazz
# ✅ Saved 311th song for genre jazz
# ✅ Saved 321th song for genre jazz
# ✅ Saved 331th song for genre jazz
# ✅ Saved 341th song for genre jazz
# ✅ Saved 351th song for genre jazz
# ✅ Saved 361th song for genre jazz
# ✅ Saved 371th song for genre jazz
# ✅ Saved 381th song for genre jazz
# ✅ Saved 391th song for genre jazz
# ✅ Saved 401th song for genre jazz
# ✅ Saved 411th song for genre jazz
# ✅ Saved 421th song for genre jazz
# ✅ Saved 431th song for genre jazz
# ✅ Saved 441th song for genre jazz
# ✅ Saved 451th song for genre jazz
# ✅ Saved 461th song for genre jazz
# ❌ Failed to get song for id 1237
# ✅ Saved 471th song for genre jazz
# ✅ Saved 481th song for genre jazz
# ✅ Saved 491th song for genre jazz
# ✅ Saved 501th song for genre jazz
# ✅ Saved 511th song for genre jazz
# ❌ Failed to get song for id 3003630
# ✅ Saved 521th song for genre jazz
# ✅ Saved 531th song for genre jazz
# ✅ Saved 541th song for genre jazz
# ✅ Saved 551th song for genre jazz
# ✅ Saved 561th song for genre jazz
# ❌ Failed to get song for id 67962
# ❌ Failed to get song for id 67962
# ✅ Saved 571th song for genre jazz
# ✅ Saved 581th song for genre jazz
# ✅ Saved 591th song for genre jazz
# ✅ Saved 601th song for genre jazz
# ✅ Saved 611th song for genre jazz
# ✅ Saved 621th song for genre jazz
# ✅ Saved 631th song for genre jazz
# ✅ Saved 641th song for genre jazz
# ✅ Saved 651th song for genre jazz
# ✅ Saved 671th song for genre jazz
# ✅ Saved 681th song for genre jazz
# ❌ Failed to get song for id 2949128
# ✅ Saved 691th song for genre jazz
# ✅ Saved 701th song for genre jazz
# ✅ Saved 711th song for genre jazz
# ✅ Saved 721th song for genre jazz
# ✅ Saved 731th song for genre jazz
# ✅ Saved 741th song for genre jazz
# ✅ Saved 751th song for genre jazz
# ✅ Saved 761th song for genre jazz
# ✅ Saved 771th song for genre jazz
# ✅ Saved 781th song for genre jazz
# ❌ Failed to get song for id 2949128
# ❌ Failed to get song for id 2949128
# ❌ Failed to get song for id 2949128
# ✅ Saved 791th song for genre jazz
# ✅ Saved 801th song for genre jazz
# ✅ Saved 811th song for genre jazz
# ✅ Saved 821th song for genre jazz
# ✅ Saved 831th song for genre jazz
# ❌ Failed to get song for id 204233
# ❌ Failed to get song for id 204233
# ❌ Failed to get song for id 204233
# ❌ Failed to get song for id 204233
# ❌ Failed to get song for id 204233
# ❌ Failed to get song for id 204233
# ❌ Failed to get song for id 204233
# ❌ Failed to get song for id 204233
# ❌ Failed to get song for id 204233
# ❌ Failed to get song for id 204233
# ❌ Failed to get song for id 204233
# ❌ Failed to get song for id 204233
# ❌ Failed to get song for id 204233
# ❌ Failed to get song for id 204233
# ❌ Failed to get song for id 204233
# ❌ Failed to get song for id 204233
# ❌ Failed to get song for id 204233
# ❌ Failed to get song for id 204233
# ❌ Failed to get song for id 204233
# ❌ Failed to get song for id 204233
# ❌ Failed to get song for id 204233
# ❌ Failed to get song for id 204233
# ❌ Failed to get song for id 204233
# ❌ Failed to get song for id 204233
# ❌ Failed to get song for id 204233
# ❌ Failed to get song for id 204233
# ❌ Failed to get song for id 204233
# ❌ Failed to get song for id 204233
# ❌ Failed to get song for id 204233
# ❌ Failed to get song for id 204233
# ❌ Failed to get song for id 204233
# ❌ Failed to get song for id 204233
# ❌ Failed to get song for id 204233
# ❌ Failed to get song for id 204233
# ❌ Failed to get song for id 204233
# ❌ Failed to get song for id 204233
# ❌ Failed to get song for id 204233
# ❌ Failed to get song for id 204233
# ❌ Failed to get song for id 204233
# ❌ Failed to get song for id 204233
# ❌ Failed to get song for id 204233
# ❌ Failed to get song for id 204233
# ❌ Failed to get song for id 204233
# ❌ Failed to get song for id 204233
# ❌ Failed to get song for id 204233
# ❌ Failed to get song for id 204233
# ❌ Failed to get song for id 204233
# ❌ Failed to get song for id 204233
# ❌ Failed to get song for id 204233
# ✅ Saved 841th song for genre jazz
# ✅ Saved 851th song for genre jazz
# ✅ Saved 861th song for genre jazz
# ✅ Saved 871th song for genre jazz
# ✅ Saved 881th song for genre jazz
# ✅ Saved 891th song for genre jazz
# ✅ Saved 901th song for genre jazz
# ✅ Saved 911th song for genre jazz
# ✅ Saved 921th song for genre jazz
# ✅ Saved 931th song for genre jazz
# ✅ Saved 941th song for genre jazz
# ✅ Saved 951th song for genre jazz
# ✅ Saved 961th song for genre jazz
# ✅ Saved 971th song for genre jazz
# ❌ Failed to get song for id 900939
# ❌ Failed to get song for id 900939
# ✅ Saved 981th song for genre jazz
# ✅ Saved 991th song for genre jazz
# Saved songs from jazz genre
