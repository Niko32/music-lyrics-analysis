# %%
from dotenv import load_dotenv
import os
import lyricsgenius
import yaml

# %%
# Get credentials for the api calls from the .env file
# Niko has the credentials if you need them
load_dotenv()
DATA_PATH = "../../data"
GENRES = ["pop", "rock", "r-b", "country", "rap", "blues", "jazz", "experimental", "folk", "classical-music", "electronic"]

# %%
genius = lyricsgenius.Genius()

# %%
# Scraping of all existing secondary tags on genius 
# has been done in src/notebooks/scrape-secondary-tags.ipynb
main_tags = ["country", "pop", "r-b", "rap", "rock"]
with open(DATA_PATH + "/secondary_genres.yaml", "r") as f:
    secondary_tags = yaml.safe_load(f)

main_tags, secondary_tags
# Out:
# (['country', 'pop', 'r-b', 'rap', 'rock'],
#  ['abstract-rap',
#   'a-cappella',
#   'acid-house',
#   'acid-jazz',
#   'acid-techno',
#   'acoustic',
#   'adult-alternative',
#   'adult-contemporary',
#   'afro-arab',
#   'afrobeat',
#   'afrobeats',
#   'afro-hip-hop',
#   'afro-house',
#   'afro-jazz',
#   'afrosoul',
#   'afroswing',
#   'afro-trap',
#   'albanian-folk',
#   'album-oriented-rock-aor',
#   'algerian-rai',
#   'algerian-rap',
#   'alternative',
#   'alternative-country',
#   'alternative-dance',
#   'alternative-metal',
#   'alternative-pop',
#   'alternative-rap',
#   'alternative-r-b',
#   'alternative-rock',
#   'amapiano',
#   'ambient',
#   'ambient-dub',
#   'ambient-pop',
#   'americana',
#   'american-folk',
#   'american-underground',
#   'anarcho-punk',
#   'anime-lo-fi',
#   'anime-rap',
#   'anthem',
#   'anti-folk',
#   'arabic-diss',
#   'arabic-instrumental',
#   'arabic-pop',
#   'arabic-rap',
#   'arabic-rock',
#   'arrocha',
#   'art-pop',
#   'art-punk',
#   'art-rock',
#   'ashiq-music',
#   'atmospheric-black-metal',
#   'atmospheric-sludge-metal',
#   'aussie-drill',
#   'aussie-grime',
#   'aussie-hip-hop',
#   'avant-folk',
#   'avant-garde',
#   'avant-garde-metal',
#   'avant-pop',
#   'avant-prog',
#   'axe',
#   'azerbaijani-jazz',
#   'azerbaijani-pop',
#   'azerbaijani-r-b',
#   'azerbaijani-rap',
#   'azerbaijani-rock',
#   'azonto',
#   'bachata',
#   'balada',
#   'banda',
#   'bangla-hip-hop',
#   'bangla-pop',
#   'barcardi',
#   'bard-song',
#   'baroque-pop',
#   'bashkir-rap',
#   'bass-house',
#   'bass-trap',
#   'bassline',
#   'bass-music',
#   'battle-rap',
#   'beatbox',
#   'beatdown-hardcore',
#   'bebop',
#   'bedroom-pop',
#   'bestial-black-metal',
#   'big-band',
#   'big-room',
#   'bitpop',
#   'blackened-death-metal',
#   'blackened-hardcore',
#   'blackened-screamo',
#   'blackened-sludge-metal',
#   'blackened-thrash-metal',
#   'blackgaze',
#   'black-metal',
#   'black-n-roll',
#   'bluegrass',
#   'blues',
#   'blues-rock',
#   'bolero',
#   'bongo-flava',
#   'boogie',
#   'boom-bap',
#   'bosanski-folk',
#   'bosanski-jazz',
#   'bosanski-pop',
#   'bosanski-r-b',
#   'bosanski-rap',
#   'bosanski-rock',
#   'bosanski-sevdah',
#   'bossa-nova',
#   'bounce',
#   'bouyon',
#   'boy-band',
#   'brass-band',
#   'brass-trap',
#   'breakbeat',
#   'breakcore',
#   'brega',
#   'brega-funk',
#   'brill-building',
#   'british-folk',
#   'british-rock',
#   'britpop',
#   'broadway',
#   'brutal-death-metal',
#   'brutal-horrorcore',
#   'bubblegum-bass',
#   'bubblegum-dance',
#   'bubblegum-pop',
#   'burru',
#   'calabrian-rap',
#   'calypso',
#   'cameroonian-rap',
#   'candombe',
#   'cantopop',
#   'canzone-napoletana',
#   'canzone-romana',
#   'canzone-siciliana',
#   'carimbo',
#   'carranga',
#   'cartel',
#   'catalan-drill',
#   'catalan-music',
#   'catalan-pop',
#   'catalan-r-b',
#   'catalan-rap',
#   'catalan-rock',
#   'catalan-urban',
#   'celtic-punk',
#   'cesky-pop',
#   'cesky-preklad',
#   'cesky-rap',
#   'cesky-rock',
#   'cesky-trap',
#   'chamber-folk',
#   'chamber-music',
#   'chamber-pop',
#   'champeta',
#   'chanson',
#   'chap-hop',
#   'chicago-blues',
#   'chicago-drill',
#   'chicago-house',
#   'chicago-rap',
#   'childrens-music',
#   'chill',
#   'chillhop',
#   'chill-house',
#   'chillout',
#   'chillstep',
#   'chinese-folk',
#   'chinese-hip-hop',
#   'chipmunk-soul',
#   'chiptune',
#   'chopped-and-screwed',
#   'choral-music',
#   'christian',
#   'christian-metal',
#   'christian-pop',
#   'christian-punk',
#   'christian-rap',
#   'christian-r-b',
#   'christian-rock',
#   'christmas',
#   'chutney',
#   'cinematic',
#   'city-pop',
#   'classical-crossover',
#   'classical-music',
#   'cloud-rap',
#   'coladera',
#   'college-rock',
#   'color-bass',
#   'comedy',
#   'complextro',
#   'conscious-hip-hop',
#   'contemporary-folk',
#   'contemporary-r-b',
#   'corrido',
#   'corridos-tumbados',
#   'country-pop',
#   'country-rap',
#   'country-rock',
#   'cowpunk',
#   'c-pop',
#   'crnogorski-folk',
#   'crnogorski-pop',
#   'crnogorski-r-b',
#   'crnogorski-rap',
#   'crnogorski-rock',
#   'crossover-thrash',
#   'crunk',
#   'crushed-trap',
#   'crust-punk',
#   'cuarteto',
#   'cumbia',
#   'cybergrind',
#   'cyprus-pop',
#   'cyprus-rap',
#   'cyprus-rock',
#   'dance',
#   'dancehall',
#   'dance-pop',
#   'dance-punk',
#   'dance-rock',
#   'dariacore',
#   'dark-ambient',
#   'dark-cabaret',
#   'dark-folk',
#   'dark-jazz',
#   'dark-plugg',
#   'dark-pop',
#   'dark-trap',
#   'dark-wave',
#   'd-beat',
#   'deathcore',
#   'death-doom',
#   'deathgrind',
#   'death-metal',
#   'deconstructed-club',
#   'deep-house',
#   'dembow',
#   'desi-hip-hop',
#   'deutscher-jersey-club',
#   'deutschsprachige-musicals',
#   'deutschsprachiger-drill',
#   'deutschsprachiger-hyperpop',
#   'deutschsprachiger-phonk',
#   'deutschsprachiger-pop',
#   'deutschsprachiger-r-b',
#   'deutschsprachiger-rap',
#   'deutschsprachiger-rock',
#   'deutschsprachiger-trap',
#   'deutschsprachiges-detroit',
#   'digital-hardcore',
#   'dipset',
#   'dirty-south',
#   'disco',
#   'disco-polo',
#   'diy-punk',
#   'djent',
#   'doom-metal',
#   'doo-wop',
#   'downtempo',
#   'drain',
#   'dream-pop',
#   'drift-phonk',
#   'drill',
#   'drill-brasileiro',
#   'drill-farsi',
#   'drone',
#   'drone-metal',
#   'drum-and-bass',
#   'drumstep',
#   'dsbm-depressive-suicidal-black-metal',
#   'dub',
#   'dubstep',
#   'dub-techno',
#   'dungeon-synth',
#   'dutch-drill',
#   'dutch-rap',
#   'easycore',
#   'easy-listening',
#   'ebm',
#   'edm',
#   'egyptian-drill',
#   'egyptian-pop',
#   'egyptian-rap',
#   'electric-blues',
#   'electro',
#   'electroclash',
#   'electro-funk',
#   'electro-hop',
#   'electro-house',
#   'electro-industrial',
#   'electronic',
#   'electronica',
#   'electronicore',
#   'electronic-rock',
#   'electronic-trap',
#   'electro-pop',
#   'electro-soul',
#   'electro-swing',
#   'emo',
#   'emocore',
#   'emo-pop',
#   'emo-rap',
#   'emo-revival',
#   'emo-trap',
#   'emoviolence',
#   'espana',
#   'euphoric-hardstyle',
#   'eurobeat',
#   'eurodance',
#   'eurodisco',
#   'euro-house',
#   'europop',
#   'euro-reggae',
#   'eurotrance',
#   'experimental',
#   'experimental-folk',
#   'experimental-pop',
#   'experimental-rap',
#   'experimental-rock',
#   'extreme-metal',
#   'fado',
#   'fanchant',
#   'fandango',
#   'farsi-rap',
#   'filk',
#   'flamenco',
#   'folk',
#   'folklore',
#   'folk-metal',
#   'folk-pop',
#   'folk-punk',
#   'folk-rock',
#   'folktronica',
#   'footwork',
#   'forro',
#   'freak-folk',
#   'free-jazz',
#   'freestyle',
#   'french-country',
#   'french-dancehall',
#   'french-house',
#   'french-pop',
#   'french-r-b',
#   'french-rap',
#   'french-reggae',
#   'french-rock',
#   'french-soul',
#   'frevo',
#   'funana',
#   'funeral-doom',
#   'funk',
#   'funk-melody',
#   'funk-nacional',
#   'funk-pop',
#   'funk-rock',
#   'funky-house',
#   'future-bass',
#   'future-bounce',
#   'future-funk',
#   'future-garage',
#   'future-house',
#   'future-rave',
#   'future-riddim',
#   'gabber',
#   'gaeilge',
#   'gangsta-rap',
#   'garage-house',
#   'garage-punk',
#   'garage-rock',
#   'garage-rock-revival',
#   'georgian-folk',
#   'georgian-pop',
#   'georgian-rap',
#   'georgian-rock',
#   'g-funk',
#   'ghetto-house',
#   'girl-group',
#   'glam-metal',
#   'glam-punk',
#   'glam-rock',
#   'glitch',
#   'glitch-hop',
#   'gnaoui',
#   'goa-trance',
#   'go-go',
#   'goregrind',
#   'gospel',
#   'gothic-metal',
#   'gothic-rock',
#   'gqom',
#   'grime',
#   'grime-brasileiro-brazilian-grime',
#   'grindcore',
#   'groove-metal',
#   'grunge',
#   'guaracha',
#   'guasca',
#   'happy-hardcore',
#   'hard-bass',
#   'hard-bop',
#   'hardcore',
#   'hardcore-edm',
#   'hardcore-punk',
#   'hardcore-rap',
#   'hard-dance',
#   'hard-drill',
#   'hard-house',
#   'hard-rock',
#   'hardstyle',
#   'hard-trance',
#   'hardwave',
#   'harsh-noise',
#   'hawaiian',
#   'heartland-rock',
#   'heavy-metal',
#   'hexd',
#   'highlife',
#   'hi-nrg',
#   'hip-hop',
#   'hip-hop-tuga',
#   'hip-hop-viet',
#   'hip-house',
#   'holiday',
#   'hong-kong-indie',
#   'hong-kong-rap',
#   'honky-tonk',
#   'hookah-rap',
#   'horrorcore',
#   'horror-punk',
#   'house',
#   'hrvatski-jazz',
#   'hrvatski-pop',
#   'hrvatski-r-b',
#   'hrvatski-rap',
#   'hrvatski-rock',
#   'hybrid-trap',
#   'hymn',
#   'hyperpop',
#   'hyperpunk',
#   'hyphy',
#   'idm',
#   'impressionism',
#   'indian-classical',
#   'indian-pop',
#   'indie',
#   'indie-electronic',
#   'indie-folk',
#   'indie-pop',
#   'indie-rap',
#   'indie-rock',
#   'industrial',
#   'industrial-hip-hop',
#   'industrial-metal',
#   'industrial-rock',
#   'industrial-techno',
#   'infantil',
#   'iranian-pop',
#   'iranian-rap',
#   'irish-drill',
#   'irish-folk',
#   'irish-rap',
#   'isicathamiya',
#   'islamic',
#   'island-music',
#   'israeli-children-songs',
#   'israeli-classic',
#   'israeli-country',
#   'israeli-drill',
#   'israeli-folk',
#   'israeli-funk',
#   'israeli-grundge',
#   'israeli-hip-hop',
#   'israeli-metal',
#   'israeli-music',
#   'israeli-pop',
#   'israeli-punk',
#   'israeli-r-b',
#   'israeli-rap',
#   'israeli-reggae',
#   'israeli-rock',
#   'israeli-soul',
#   'israeli-trap',
#   'israeli-yam-tichoni',
#   'italo-disco',
#   'ivona',
#   'jangle-pop',
#   'jazz',
#   'jazz-contrafact',
#   'jazz-funk',
#   'jazz-fusion',
#   'jazz-rap',
#   'jazz-rock',
#   'jersey-club',
#   'jewish',
#   'joik',
#   'j-pop',
#   'j-rap',
#   'j-rock',
#   'jump-blues',
#   'jumpstyle',
#   'jungle',
#   'kazakh-rap',
#   'k-ballad',
#   'k-chinese',
#   'k-hip-hop',
#   'k-idon-hip-hop',
#   'k-indie',
#   'kizomba',
#   'k-japanese',
#   'k-ost',
#   'k-pop',
#   'k-r-b',
#   'krautrock',
#   'k-rock',
#   'k-solo',
#   'kuduro',
#   'kultura-w-rapie',
#   'kuwaiti-rap',
#   'kwaito',
#   'kwela',
#   'lambada',
#   'latin-drill',
#   'latin-freestyle-edm',
#   'latin-house',
#   'latin-jazz',
#   'latin-music',
#   'latin-pop',
#   'latin-r-b',
#   'latin-rap',
#   'latin-reggae',
#   'latin-rock',
#   'latin-trap',
#   'latin-urban',
#   'lebanese-rap',
#   'liquid-drum-and-bass',
#   'liscio',
#   'lo-fi',
#   'lok-dohori',
#   'lok-geet',
#   'louisiana-blues',
#   'lounge',
#   'lovers-rock',
#   'lowercase',
#   'lullaby',
#   'macedonian-folk',
#   'macedonian-pop',
#   'macedonian-r-b',
#   'macedonian-rap',
#   'macedonian-rock',
#   'madchester',
#   'magyar-drill',
#   'magyar-rap',
#   'mahraganat',
#   'makina',
#   'malaysian-dangdut',
#   'malaysian-rap',
#   'mambo',
#   'mandopop',
#   'manele',
#   'mantra',
#   'marabi',
#   'marchinha',
#   'mariachi',
#   'maskhandi',
#   'mathcore',
#   'math-metal',
#   'math-rock',
#   'mbaganga',
#   'melbourne-bounce',
#   'melodic-death-metal',
#   'melodic-dubstep',
#   'melodic-hardcore',
#   'melodic-house',
#   'melodic-metalcore',
#   'melodic-riddim',
#   'melodic-techno',
#   'meme-rap',
#   'mental-health',
#   'mento',
#   'merengue',
#   'merengue-tipico',
#   'metal',
#   'metalcore',
#   'meykhana',
#   'miami-bass',
#   'midtempo',
#   'midwest-emo',
#   'minimalism',
#   'minimal-techno',
#   'modern-classical',
#   'moldovan-pop',
#   'moombahton',
#   'morna',
#   'moroccan-rap',
#   'mortuary',
#   'motown',
#   'motswako',
#   'mpb-musica-popular-brasileira',
#   'mugham',
#   'murder-ballad',
#   'murga',
#   'musicals',
#   'musik-fur-kinder',
#   'musique-concrete',
#   'muzik-popullore',
#   'mystic',
#   'nasheed',
#   'neocrust',
#   'neofolk',
#   'neomelodica',
#   'neoperreo',
#   'neo-psychedelia',
#   'neo-soul',
#   'nep-hop',
#   'nerdcore',
#   'neue-deutsche-harte',
#   'neue-deutsche-welle',
#   'new-age',
#   'new-jack-swing',
#   'new-orleans-r-b',
#   'new-wave',
#   'new-york-drill',
#   'nigerian-rap',
#   'nightcore',
#   'nintendocore',
#   'noise',
#   'noisecore',
#   'noise-pop',
#   'noise-rock',
#   'norsk-country',
#   'norsk-julemusikk',
#   'norsk-pop',
#   'norsk-r-b',
#   'norsk-rap',
#   'norsk-rock',
#   'nortena',
#   'no-wave',
#   'nu-disco',
#   'nueva-cancion',
#   'nueva-trova',
#   'nu-jazz',
#   'nu-metal',
#   'nu-rave',
#   'oi',
#   'opera',
#   'operetta',
#   'opm',
#   'orchestral',
#   'otaku-music',
#   'otaku-rap',
#   'otaku-trap',
#   'outlaw-country',
#   'outsider-music',
#   'pagode',
#   'pagode-baiano',
#   'pakistani-pop',
#   'palestinian-rap',
#   'parody',
#   'partyschlager',
#   'persian-rock',
#   'persian-traditional-music',
#   'p-funk',
#   'phonk',
#   'piano',
#   'piano-house',
#   'piano-rock',
#   'pink-noise',
#   'pinoy-hip-hop',
#   'pirate-metal',
#   'piseiro',
#   'planete-rap',
#   'plena-uruguaya',
#   'plunderphonics',
#   'plugg',
#   'pluggnb',
#   'polka',
#   'polskie-disco-polo',
#   'polski-folk',
#   'polski-freestyle',
#   'polski-pop',
#   'polski-rap',
#   'polski-rock',
#   'polynesian-reggae',
#   'pop-italiano',
#   'pop-melayu',
#   'pop-punk',
#   'pop-r-b',
#   'pop-rap',
#   'pop-reggae',
#   'pop-rock',
#   'posse-cut',
#   'post-black-metal',
#   'post-bop',
#   'post-britpop',
#   'post-dubstep',
#   'post-grunge',
#   'post-hardcore',
#   'post-metal',
#   'post-minimalism',
#   'post-punk',
#   'post-punk-revival',
#   'post-rap',
#   'post-rock',
#   'post-screamo',
#   'power-metal',
#   'power-pop',
#   'powerviolence',
#   'p-pop',
#   'progressive-death-metal',
#   'progressive-electronic',
#   'progressive-house',
#   'progressive-metal',
#   'progressive-metalcore',
#   'progressive-pop',
#   'progressive-rock',
#   'progressive-trance',
#   'proto-manele',
#   'proto-punk',
#   'psychedelic',
#   'psychedelic-rock',
#   'psychedelic-soul',
#   'psychedelic-trance',
#   'psychobilly',
#   'punk-pathetique',
#   'punk-revival',
#   'punk-rock',
#   'qawwali',
#   'q-pop',
#   'queercore',
#   'raga-rock',
#   'rage',
#   'ragga',
#   'ragtime',
#   'rai',
#   'ranchera',
#   'r-b-viet',
#   'rapcore',
#   'rap-italiano',
#   'rap-metal',
#   'rap-napoletano',
#   'rap-rock',
#   'rastafarian',
#   'rawstyle',
#   'red-dirt',
#   'reggae',
#   'reverse-bass',
#   'reggae-rock',
#   'reggaeton',
#   'regional-mexicano',
#   'reparterismo',
#   'retro',
#   'rhythm-and-grime',
#   'riddim',
#   'riot-grrrl',
#   'ritual-rap',
#   'rkt',
#   'road-rap',
#   'rockabilly',
#   'rock-gaucho',
#   'rocksteady',
#   'rock-viet',
#   'romanian-drill',
#   'romansh',
#   'roots',
#   'roots-reggae',
#   'rub-a-dub',
#   'rumba',
#   'russemusikk',
#   'russian-battle-rap',
#   'russian-chanson',
#   'russian-country',
#   'russian-drill',
#   'russian-grime',
#   'russian-hyperpop',
#   'russian-jazz',
#   'russian-pop',
#   'russian-punk-rock',
#   'russian-r-b',
#   'russian-rap',
#   'russian-rave',
#   'russian-reggae',
#   'russian-rock',
#   'russian-trap',
#   'russian-underground',
#   'sab-hop',
#   'salsa',
#   'samba',
#   'samba-reggae',
#   'samba-rock',
#   'saudi-rap',
#   'scam-rap',
#   'scandipop',
#   'scenecore',
#   'schlager',
#   'scottish-folk',
#   'screamo',
#   'sea-shanty',
#   'semba',
#   'sertenejo',
#   'shaabi',
#   'shibuya-kei',
#   'shoegaze',
#   'sicilian-rap',
#   'sierreno',
#   'sindicat',
#   'sinogrime',
#   'sigilkore',
#   'ska',
#   'skacore',
#   'ska-punk',
#   'skate-punk',
#   'skhanda-rap',
#   'slam-metal',
#   'slap-house',
#   'slay',
#   'slovenian-pop',
#   'slovenian-rap',
#   'slovenian-rock',
#   'slovensky-pop',
#   'slovensky-rap',
#   'slowcore',
#   'slowed-and-reverb',
#   'sludge-metal',
#   'smooth-jazz',
#   'soca',
#   'soft-house',
#   'soft-rock',
#   'sophisti-pop',
#   'soul',
#   'soul-jazz',
#   'soul-pop',
#   'soul-rap',
#   'sound-collage',
#   'southern-rock',
#   'soviet-estrada',
#   'soviet-jazz',
#   'soviet-rap',
#   'soviet-rock',
#   'soviet-samizdat',
#   'space-rock',
#   'spanish-drill',
#   'spanish-pop',
#   'spanish-r-b',
#   'spanish-rap',
#   'spanish-rock',
#   'spanish-urban',
#   'sped-up',
#   'speedcore',
#   'speed-metal',
#   'spiritual',
#   'spiritual-jazz',
#   'srpski-folk',
#   'srpski-jazz',
#   'srpski-pop',
#   'srpski-r-b',
#   'srpski-rap',
#   'srpski-rock',
#   'steampunk',
#   'stomp-and-holler',
#   'stoner-metal',
#   'stoner-rock',
#   'sto-pro-rap',
#   'straightedge',
#   'street-punk',
#   'sunshine-pop',
#   'suomi-drill',
#   'suomi-pop',
#   'suomi-rap',
#   'suomirock',
#   'suomi-underground-rap',
#   'supertrap',
#   'surf',
#   'surf-punk',
#   'surf-rock',
#   'surge',
#   'svensk-country',
#   'svensk-pop',
#   'svensk-r-b',
#   'svensk-rap',
#   'svensk-rock',
#   'swedish-folk',
#   'swing',
#   'symphonic-black-metal',
#   'symphonic-metal',
#   'symphonic-power-metal',
#   'symphonic-rock',
#   'synth-funk',
#   'synth-pop',
#   'synth-punk',
#   'synth-rock',
#   'synthwave',
#   'tai-pop',
#   'tango',
#   'taqwacore',
#   'tarraxinha',
#   'tech-house',
#   'technical-death-metal',
#   'technical-thrash-metal',
#   'techno',
#   'techno-rap',
#   'tecnobrega',
#   'teen-pop',
#   'thai-pop',
#   'thai-rap',
#   'third-stream',
#   'thrash-metal',
#   'time-lord-rock-trock',
#   'toasting',
#   'togo-pop',
#   'togo-rap',
#   'togo-trap',
#   'tontipop',
#   'traditional-folk',
#   'trallpunk',
#   'trance',
#   'trap',
#   'trap-dancehall',
#   'trap-metal',
#   'trap-rock',
#   'trapwave',
#   'tread',
#   'tribal',
#   'trip-hop',
#   'tropical-house',
#   'trot',
#   'trova',
#   'tunisian-rap',
#   'turkce-alternatif',
#   'turkce-drill',
#   'turkce-folk',
#   'turkce-pop',
#   'turkce-r-b',
#   'turkce-rap',
#   'turkce-rock',
#   'turkce-trap',
#   'two-tone',
#   'uk-drill',
#   'uk-funky',
#   'uk-garage',
#   'uk-pop',
#   'ukrainian-drill',
#   'ukrainian-pop',
#   'ukrainian-rap',
#   'ukrainian-rock',
#   'ukrainian-trap',
#   'uk-r-b',
#   'uk-rap',
#   'ukulele',
#   'underground-rap',
#   'underground-soul',
#   'vallenato',
#   'valsa',
#   'vaporwave',
#   'variete-francaise',
#   'via',
#   'viking-metal',
#   'vise-visa',
#   'vispop',
#   'vocaloid',
#   'volksmusik',
#   'v-pop',
#   'weirdcore',
#   'western-swing',
#   'witch-house',
#   'wizard-rock-wrock',
#   'worship',
#   'xote',
#   'yacht-rock',
#   'yiddish',
#   'yu-mex',
#   'zouk',
#   'z-pop',
#   'zydeco',
#   'atlanta-rap',
#   'bay-area-rap',
#   'chicago-rap',
#   'detroit-rap',
#   'dmv-rap',
#   'florida-rap',
#   'memphis-rap',
#   'new-york',
#   'quebec-rap',
#   'texas-rap',
#   'afghanistan',
#   'albania',
#   'algeria',
#   'andorra',
#   'angola',
#   'arabia',
#   'argentina',
#   'armenia',
#   'aruba',
#   ...])

# %%
# Try to find all songs for a specified genre
abstract_rap_songs = genius.tag("abstract-rap")["hits"]

# %%
# These are appearently not all songs yet
len(abstract_rap_songs)
# Out:
# 20

# %%
feel_good_inc = abstract_rap_songs[2]
feel_good_inc
# Out:
# {'url': 'https://genius.com/Gorillaz-feel-good-inc-lyrics',
#  'title_with_artists': 'Feel Good Inc. by Gorillaz (Ft. De La Soul)',
#  'title': 'Feel Good Inc.',
#  'artists': ['Gorillaz'],
#  'featured_artists': ['De La Soul']}

# %%
# Print the lyrics for a specific song
print(genius.lyrics(song_url=feel_good_inc["url"]))
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# File c:\Users\nikok\Repos\Uni\music-lyrics-analysis\venv\Lib\site-packages\urllib3\connectionpool.py:536, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     535 try:
# --> 536     response = conn.getresponse()
#     537 except (BaseSSLError, OSError) as e:
#
# File c:\Users\nikok\Repos\Uni\music-lyrics-analysis\venv\Lib\site-packages\urllib3\connection.py:461, in HTTPConnection.getresponse(self)
#     460 # Get the response from http.client.HTTPConnection
# --> 461 httplib_response = super().getresponse()
#     463 try:
#
# File c:\python311\Lib\http\client.py:1374, in HTTPConnection.getresponse(self)
#    1373 try:
# -> 1374     response.begin()
#    1375 except ConnectionError:
#
# File c:\python311\Lib\http\client.py:318, in HTTPResponse.begin(self)
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#
# File c:\python311\Lib\http\client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#
# File c:\python311\Lib\socket.py:706, in SocketIO.readinto(self, b)
#     705 try:
# --> 706     return self._sock.recv_into(b)
#     707 except timeout:
#
# File c:\python311\Lib\ssl.py:1278, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1275         raise ValueError(
#    1276           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1277           self.__class__)
# -> 1278     return self.read(nbytes, buffer)
#    1279 else:
#
# File c:\python311\Lib\ssl.py:1134, in SSLSocket.read(self, len, buffer)
#    1133 if buffer is not None:
# -> 1134     return self._sslobj.read(len, buffer)
#    1135 else:
#
# TimeoutError: The read operation timed out
#
# The above exception was the direct cause of the following exception:
#
# ReadTimeoutError                          Traceback (most recent call last)
# File c:\Users\nikok\Repos\Uni\music-lyrics-analysis\venv\Lib\site-packages\requests\adapters.py:486, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     485 try:
# --> 486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#     489         body=request.body,
#     490         headers=request.headers,
#     491         redirect=False,
#     492         assert_same_host=False,
#     493         preload_content=False,
#     494         decode_content=False,
#     495         retries=self.max_retries,
#     496         timeout=timeout,
#     497         chunked=chunked,
#     498     )
#     500 except (ProtocolError, OSError) as err:
#
# File c:\Users\nikok\Repos\Uni\music-lyrics-analysis\venv\Lib\site-packages\urllib3\connectionpool.py:844, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     842     new_e = ProtocolError("Connection aborted.", new_e)
# --> 844 retries = retries.increment(
#     845     method, url, error=new_e, _pool=self, _stacktrace=sys.exc_info()[2]
#     846 )
#     847 retries.sleep()
#
# File c:\Users\nikok\Repos\Uni\music-lyrics-analysis\venv\Lib\site-packages\urllib3\util\retry.py:470, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     469 if read is False or method is None or not self._is_method_retryable(method):
# --> 470     raise reraise(type(error), error, _stacktrace)
#     471 elif read is not None:
#
# File c:\Users\nikok\Repos\Uni\music-lyrics-analysis\venv\Lib\site-packages\urllib3\util\util.py:39, in reraise(tp, value, tb)
#      38         raise value.with_traceback(tb)
# ---> 39     raise value
#      40 finally:
#
# File c:\Users\nikok\Repos\Uni\music-lyrics-analysis\venv\Lib\site-packages\urllib3\connectionpool.py:790, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     789 # Make the request on the HTTPConnection object
# --> 790 response = self._make_request(
#     791     conn,
#     792     method,
#     793     url,
#     794     timeout=timeout_obj,
#     795     body=body,
#     796     headers=headers,
#     797     chunked=chunked,
#     798     retries=retries,
#     799     response_conn=response_conn,
#     800     preload_content=preload_content,
#     801     decode_content=decode_content,
#     802     **response_kw,
#     803 )
#     805 # Everything went great!
#
# File c:\Users\nikok\Repos\Uni\music-lyrics-analysis\venv\Lib\site-packages\urllib3\connectionpool.py:538, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     537 except (BaseSSLError, OSError) as e:
# --> 538     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#     539     raise
#
# File c:\Users\nikok\Repos\Uni\music-lyrics-analysis\venv\Lib\site-packages\urllib3\connectionpool.py:370, in HTTPConnectionPool._raise_timeout(self, err, url, timeout_value)
#     369 if isinstance(err, SocketTimeout):
# --> 370     raise ReadTimeoutError(
#     371         self, url, f"Read timed out. (read timeout={timeout_value})"
#     372     ) from err
#     374 # See the above comment about EAGAIN in Python 3.
#
# ReadTimeoutError: HTTPSConnectionPool(host='genius.com', port=443): Read timed out. (read timeout=5)
#
# During handling of the above exception, another exception occurred:
#
# ReadTimeout                               Traceback (most recent call last)
# File c:\Users\nikok\Repos\Uni\music-lyrics-analysis\venv\Lib\site-packages\lyricsgenius\api\base.py:75, in Sender._make_request(self, path, method, params_, public_api, web, **kwargs)
#      74 try:
# ---> 75     response = self._session.request(method, uri,
#      76                                      timeout=self.timeout,
#      77                                      params=params_,
#      78                                      headers=header,
#      79                                      **kwargs)
#      80     response.raise_for_status()
#
# File c:\Users\nikok\Repos\Uni\music-lyrics-analysis\venv\Lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File c:\Users\nikok\Repos\Uni\music-lyrics-analysis\venv\Lib\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#
# File c:\Users\nikok\Repos\Uni\music-lyrics-analysis\venv\Lib\site-packages\requests\adapters.py:532, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     531 elif isinstance(e, ReadTimeoutError):
# --> 532     raise ReadTimeout(e, request=request)
#     533 elif isinstance(e, _InvalidHeader):
#
# ReadTimeout: HTTPSConnectionPool(host='genius.com', port=443): Read timed out. (read timeout=5)
#
# During handling of the above exception, another exception occurred:
#
# Timeout                                   Traceback (most recent call last)
# Cell In[8], line 2
#       1 # Print the lyrics for a specific song
# ----> 2 print(genius.lyrics(song_url=feel_good_inc["url"]))
#
# File c:\Users\nikok\Repos\Uni\music-lyrics-analysis\venv\Lib\site-packages\lyricsgenius\genius.py:132, in Genius.lyrics(self, song_id, song_url, remove_section_headers)
#     128     path = self.song(song_id)['song']['path'][1:]
#     130 # Scrape the song lyrics from the HTML
#     131 html = BeautifulSoup(
# --> 132     self._make_request(path, web=True).replace('<br/>', '\n'),
#     133     "html.parser"
#     134 )
#     136 # Determine the class of the div
#     137 div = html.find("div", class_=re.compile("^lyrics$|Lyrics__Root"))
#
# File c:\Users\nikok\Repos\Uni\music-lyrics-analysis\venv\Lib\site-packages\lyricsgenius\api\base.py:84, in Sender._make_request(self, path, method, params_, public_api, web, **kwargs)
#      82     error = "Request timed out:\n{e}".format(e=e)
#      83     if tries > self.retries:
# ---> 84         raise Timeout(error)
#      85 except HTTPError as e:
#      86     error = get_description(e)
#
# Timeout: Request timed out:
# HTTPSConnectionPool(host='genius.com', port=443): Read timed out. (read timeout=5)

# %%
abstract_rap_songs[:2]
# Out:
# [{'url': 'https://genius.com/Childish-gambino-iv-sweatpants-lyrics',
#   'title_with_artists': 'IV. Sweatpants by Childish Gambino',
#   'title': 'IV. Sweatpants',
#   'artists': ['Childish Gambino'],
#   'featured_artists': []},
#  {'url': 'https://genius.com/Tyler-the-creator-yonkers-lyrics',
#   'title_with_artists': 'Yonkers by Tyler, The Creator',
#   'title': 'Yonkers',
#   'artists': ['Tyler, The Creator'],
#   'featured_artists': []},
#  {'url': 'https://genius.com/Gorillaz-feel-good-inc-lyrics',
#   'title_with_artists': 'Feel Good Inc. by Gorillaz (Ft. De La Soul)',
#   'title': 'Feel Good Inc.',
#   'artists': ['Gorillaz'],
#   'featured_artists': ['De La Soul']}]

# %%
# The page feature can be used to find 20 more songs
genius.tag("abstract-rap", page=2)["hits"][:2]
# Out:
# [{'url': 'https://genius.com/Chance-the-rapper-acid-rain-lyrics',
#   'title_with_artists': 'Acid Rain by Chance the Rapper',
#   'title': 'Acid Rain',
#   'artists': ['Chance the Rapper'],
#   'featured_artists': []},
#  {'url': 'https://genius.com/A-ap-rocky-phoenix-lyrics',
#   'title_with_artists': 'Phoenix by A$AP Rocky',
#   'title': 'Phoenix',
#   'artists': ['A$AP Rocky'],
#   'featured_artists': []}]

# %%
# Download 1000 songs for the every genre
for genre in GENRES:

    # Iterate through pages of songs in genius
    titles = []
    lyrics = []
    all_songs = []
    for i in range(1, 51):
        pop_songs = genius.tag(genre, page=i)["hits"]
        for song in pop_songs:
            title = song["title_with_artists"]
            all_songs.append(song)
            print(f"Saved '{title}'")

    with open(f"{DATA_PATH}/songs/{genre}.yml", "w") as f:
        yaml.safe_dump(all_songs, f)
    print(f"Succsefffully saved {genre} songs")
# Out:
# Saved 'Closer by The Chainsmokers (Ft. Halsey)'
# Saved 'FRIENDS by Marshmello & Anne-Marie'
# Saved 'Get Lucky by Daft Punk (Ft. Nile Rodgers & Pharrell Williams)'
# Saved 'Something Just Like This by The Chainsmokers & Coldplay'
# Saved 'As It Was by Harry Styles'
# Saved 'Die For You by The Weeknd'
# Saved '​bad guy by Billie Eilish'
# Saved 'Nights by Frank Ocean'
# Saved 'Let Me Love You by DJ Snake (Ft. Justin Bieber)'
# Saved 'Happier by Marshmello & Bastille'
# Saved 'Feeling Myself by Nicki Minaj (Ft. Beyoncé)'
# Saved 'Poker Face by Lady Gaga'
# Saved 'Collard Greens by ScHoolboy Q (Ft. Kendrick Lamar)'
# Saved 'Heathens by ​twenty one pilots'
# Saved 'Baby by Justin Bieber (Ft. Ludacris)'
# Saved 'Blood On the Leaves by Kanye West'
# Saved 'SLOW DANCING IN THE DARK by Joji'
# Saved '​hot girl bummer by ​blackbear'
# Saved 'Slide by Calvin Harris (Ft. Frank Ocean & Migos)'
# Saved 'It Ain't Me by Kygo & Selena Gomez'
# Saved '​bury a friend by Billie Eilish'
# Saved 'Truffle Butter by Nicki Minaj (Ft. Drake & Lil Wayne)'
# Saved 'HIGHEST IN THE ROOM by Travis Scott'
# Saved 'Pyramids by Frank Ocean'
# Saved 'Heartbeat by Childish Gambino'
# Saved 'Without Me by Halsey'
# Saved 'Is It Over Now? (Taylor's Version) [From The Vault] by Taylor Swift'
# Saved 'Feel Good Inc. by Gorillaz (Ft. De La Soul)'
# Saved 'Needed Me by Rihanna'
# Saved 'Royals by Lorde'
# Saved 'Chandelier by Sia'
# Saved 'Instant Crush by Daft Punk (Ft. Julian Casablancas)'
# Saved 'Unholy by Sam Smith & Kim Petras'
# Saved 'Stay by Zedd & Alessia Cara'
# Saved 'Cruel Summer by Taylor Swift'
# Saved 'Faded by Alan Walker'
# Saved 'Thunder by Imagine Dragons'
# Saved 'Style by Taylor Swift'
# Saved 'Silence by Marshmello (Ft. Khalid)'
# Saved 'Mine by Bazzi'
# Saved 'The Middle by Zedd, Maren Morris & Grey'
# Saved 'Rockabye by Clean Bandit (Ft. Anne-Marie & Sean Paul)'
# Saved 'Scared to Be Lonely by Martin Garrix & Dua Lipa'
# Saved 'Swish Swish by Katy Perry (Ft. Nicki Minaj)'
# Saved 'Blank Space by Taylor Swift'
# Saved 'End Game by Taylor Swift (Ft. Ed Sheeran & Future)'
# Saved 'Way Back Home (Sam Feldt Edit) by SHAUN (숀) (Ft. Conor Maynard)'
# Saved 'As Long As You Love Me by Justin Bieber (Ft. Big Sean)'
# Saved 'Therefore I Am by Billie Eilish'
# Saved 'Stronger by Kanye West'
# Saved '"Slut!" (Taylor's Version) [From The Vault] by Taylor Swift'
# Saved 'Cold Water by Major Lazer (Ft. Justin Bieber & MØ)'
# Saved 'Rather Be by Clean Bandit (Ft. Jess Glynne)'
# Saved 'Bad Romance by Lady Gaga'
# Saved 'You're On Your Own, Kid by Taylor Swift'
# Saved 'How Deep Is Your Love by Calvin Harris & Disciples'
# Saved 'Shut Up by Stormzy'
# Saved '​yes, and? by Ariana Grande'
# Saved 'Bitch Lasagna by PewDiePie & Party in Backyard'
# Saved 'Wolves by Selena Gomez & Marshmello'
# Saved 'Wild for the Night by A$AP Rocky (Ft. Birdy Nam Nam & Skrillex)'
# Saved 'Back To You by Selena Gomez'
# Saved 'Feel It Still by Portugal. The Man'
# Saved 'Now That We Don't Talk (Taylor's Version) [From The Vault] by Taylor Swift'
# Saved 'Chlorine by ​twenty one pilots'
# Saved 'Heat Waves by Glass Animals'
# Saved '2002 by Anne-Marie'
# Saved 'Heartless by Kanye West'
# Saved 'IDGAF by Dua Lipa'
# Saved '​all the good girls go to hell by Billie Eilish'
# Saved 'Question...? by Taylor Swift'
# Saved 'Say Don't Go (Taylor's Version) [From The Vault] by Taylor Swift'
# Saved 'Diamonds by Rihanna'
# Saved 'Numb by Linkin Park'
# Saved 'Gold by Kiiara'
# Saved 'Habits (Stay High) by Tove Lo'
# Saved '​bellyache by Billie Eilish'
# Saved 'Paris by The Chainsmokers'
# Saved 'MIC Drop (Steve Aoki Remix) by BTS'
# Saved '​ilomilo by Billie Eilish'
# Saved 'Fade by Kanye West (Ft. Post Malone & Ty Dolla $ign)'
# Saved 'Hits Different by Taylor Swift'
# Saved '4 Morant (Better Luck Next Time) by Doja Cat'
# Saved 'In the Name of Love by Martin Garrix & Bebe Rexha'
# Saved 'Mastermind by Taylor Swift'
# Saved 'Bad Blood (Remix) by Taylor Swift (Ft. Kendrick Lamar)'
# Saved 'Karma by Taylor Swift'
# Saved 'Bad at Love by Halsey'
# Saved 'Would've, Could've, Should've by Taylor Swift'
# Saved 'Here Comes the Sun by The Beatles'
# Saved 'Sweet Dreams (Are Made of This) by Eurythmics'
# Saved 'Getaway Car by Taylor Swift'
# Saved 'Gorgeous by Taylor Swift'
# Saved 'More Than You Know by Axwell Λ Ingrosso'
# Saved 'Day ‘N’ Nite (Nightmare) by Kid Cudi'
# Saved 'Vigilante Shit by Taylor Swift'
# Saved 'Lean On by Major Lazer (Ft. DJ Snake & MØ)'
# Saved 'Daddy Issues (Remix) by The Neighbourhood & Syd'
# Saved 'Little Dark Age by MGMT'
# Saved '​bloodline by Ariana Grande'
# Saved 'First Love / Late Spring by Mitski'
# Saved 'On Sight by Kanye West'
# Saved 'Euphoria by BTS'
# Saved 'Solo by Clean Bandit (Ft. Demi Lovato)'
# Saved 'River by Bishop Briggs'
# Saved 'THE SCOTTS by THE SCOTTS, Travis Scott & Kid Cudi'
# Saved 'One Kiss by Calvin Harris & Dua Lipa'
# Saved 'Shutdown by Skepta'
# Saved '2U by David Guetta (Ft. Justin Bieber)'
# Saved 'Sky Walker by Miguel (Ft. Travis Scott)'
# Saved 'Heavydirtysoul by ​twenty one pilots'
# Saved 'I Did Something Bad by Taylor Swift'
# Saved 'Lavender Haze by Taylor Swift'
# Saved 'Blow by Beyoncé'
# Saved 'The Man by Taylor Swift'
# Saved 'Tear in My Heart by ​twenty one pilots'
# Saved 'Never Be Like You by Flume (Ft. ​kai)'
# Saved '​fake smile by Ariana Grande'
# Saved 'Do What U Want by Lady Gaga (Ft. R. Kelly)'
# Saved 'M To The B (Soph Aspin Send) by Millie B'
# Saved '​goodnight n go by Ariana Grande'
# Saved 'Cradles by Sub Urban'
# Saved 'Guilt Trip by Kanye West'
# Saved 'Come & Go by Juice WRLD & Marshmello'
# Saved 'Miss Americana & The Heartbreak Prince by Taylor Swift'
# Saved 'Spotlight by Marshmello & Lil Peep'
# Saved 'I Like Me Better by Lauv'
# Saved 'Futsal Shuffle 2020 by Lil Uzi Vert'
# Saved 'Mama by Jonas Blue (Ft. William Singe)'
# Saved 'London Boy by Taylor Swift'
# Saved 'Sweet Nothing by Taylor Swift'
# Saved 'King of My Heart by Taylor Swift'
# Saved 'Good Life by Kanye West (Ft. T-Pain)'
# Saved 'Alone by Marshmello'
# Saved 'So Far Away by Martin Garrix & David Guetta (Ft. Jamie Scott & Romy Dya)'
# Saved 'Fireflies by Owl City'
# Saved 'Bad Blood by Taylor Swift'
# Saved 'Saturnz Barz by Gorillaz (Ft. Popcaan)'
# Saved 'DNA by BTS'
# Saved 'Suburban Legends (Taylor's Version) [From The Vault] by Taylor Swift'
# Saved 'Cornelia Street by Taylor Swift'
# Saved 'Fergalicious by Fergie (Ft. ​will.i.am)'
# Saved 'Blow Your Mind (Mwah) by Dua Lipa'
# Saved '뚜두뚜두 (DDU-DU DDU-DU) by BLACKPINK'
# Saved 'Bigger Than The Whole Sky by Taylor Swift'
# Saved 'What's My Name? by Rihanna (Ft. Drake)'
# Saved 'Thiago Silva by Dave (Ft. AJ Tracey)'
# Saved '​bad idea by Ariana Grande'
# Saved 'My Blood by ​twenty one pilots'
# Saved '★ (Blackstar) by David Bowie'
# Saved 'Titanium by David Guetta (Ft. Sia)'
# Saved 'Climax by USHER'
# Saved 'Labyrinth by Taylor Swift'
# Saved 'Sexxx Dreams by Lady Gaga'
# Saved 'Sober by Childish Gambino'
# Saved 'This Could Be Us by Rae Sremmurd'
# Saved 'Get Into It (Yuh) by Doja Cat'
# Saved 'The Fox (What Does The Fox Say?) by Ylvis'
# Saved 'That's Not Me by Skepta (Ft. Jme)'
# Saved 'Same Ol' Mistakes by Rihanna'
# Saved 'Break My Heart by Dua Lipa'
# Saved 'Let Me by ZAYN'
# Saved 'Alarm by Anne-Marie'
# Saved 'Afterglow by Taylor Swift'
# Saved 'Where Are Ü Now by Skrillex, Justin Bieber & Diplo'
# Saved 'Blue (Da Ba Dee) by Eiffel 65'
# Saved 'Good for You by Selena Gomez (Ft. A$AP Rocky)'
# Saved 'The Great War by Taylor Swift'
# Saved 'Holding On To You by ​twenty one pilots'
# Saved 'Beauty and a Beat by Justin Bieber (Ft. Nicki Minaj)'
# Saved 'Darkside by Alan Walker (Ft. Au/Ra & Tomine Harket)'
# Saved 'All We Know by The Chainsmokers (Ft. Phoebe Ryan)'
# Saved 'Love$ick by ​Mura Masa (Ft. A$AP Rocky)'
# Saved 'Kill This Love by BLACKPINK'
# Saved 'Everyday by Logic & Marshmello'
# Saved 'Man Don't Care by Jme (Ft. Giggs)'
# Saved 'Tears by Clean Bandit (Ft. Louisa Johnson)'
# Saved 'El Chapo by The Game (Ft. Skrillex)'
# Saved 'Lost in the Fire by The Weeknd & Gesaffelstein'
# Saved 'Татарин (Tatar) by АИГЕЛ (AIGEL)'
# Saved 'Purple Lamborghini by Skrillex & Rick Ross'
# Saved 'Paper Rings by Taylor Swift'
# Saved 'Kiss and Make Up by Dua Lipa & BLACKPINK'
# Saved 'Alone by Halsey'
# Saved 'Roses by The Chainsmokers (Ft. ROZES)'
# Saved 'Levitate by ​twenty one pilots'
# Saved 'Be the One by Dua Lipa'
# Saved 'Kitchen Sink by ​twenty one pilots (Ft. Zack Joseph)'
# Saved 'Born This Way by Lady Gaga'
# Saved 'Angels by The xx'
# Saved 'II. Zealots of Stockholm [Free Information] by Childish Gambino'
# Saved 'Man Down by Rihanna'
# Saved 'Radioactive (Remix) by Imagine Dragons (Ft. Kendrick Lamar)'
# Saved 'Don't Let Me Down by The Chainsmokers (Ft. Daya)'
# Saved 'So It Goes... by Taylor Swift'
# Saved 'I Forgot That You Existed by Taylor Swift'
# Saved 'Radio Ga Ga by Queen'
# Saved 'Starving by Hailee Steinfeld & Grey (Ft. Zedd)'
# Saved '​bad guy by Billie Eilish & Justin Bieber'
# Saved 'I'm a Mess by Bebe Rexha'
# Saved 'Message Man by ​twenty one pilots'
# Saved 'Clarity by Zedd (Ft. Foxes)'
# Saved 'Scream & Shout by ​will.i.am (Ft. Britney Spears)'
# Saved 'Paris by Taylor Swift'
# Saved 'Cold by Maroon 5 (Ft. Future)'
# Saved 'In My Room by Frank Ocean'
# Saved 'This Feeling by The Chainsmokers (Ft. Kelsea Ballerini)'
# Saved 'Tamagotchi by TACONAFIDE'
# Saved 'Pretty Savage by BLACKPINK'
# Saved 'Legends Never Die by League of Legends & Against The Current'
# Saved '1979 by The Smashing Pumpkins'
# Saved 'Bon Appétit by Katy Perry (Ft. Migos)'
# Saved 'You Don't Know Me by Jax Jones (Ft. RAYE)'
# Saved 'These Days by Rudimental (Ft. Dan Caplen, Jess Glynne & Macklemore)'
# Saved 'Hold My Hand by Jess Glynne'
# Saved '​coffee by Miguel'
# Saved 'What About Us by P!nk'
# Saved 'Ciao Adios by Anne-Marie'
# Saved 'MIC Drop (Steve Aoki Remix) [Desiigner Remix] by BTS (Ft. Desiigner)'
# Saved 'High Infidelity by Taylor Swift'
# Saved 'Токсин (Toxin) by RAM'
# Saved 'G.U.Y. by Lady Gaga'
# Saved 'Tennis Court by Lorde'
# Saved 'Levitating (Remix) by Dua Lipa (Ft. DaBaby)'
# Saved 'Super Freaky Girl by Nicki Minaj'
# Saved 'La La La by Naughty Boy (Ft. Sam Smith)'
# Saved '​goodbye by Billie Eilish'
# Saved 'Work Bitch by Britney Spears'
# Saved 'Ganja Burn by Nicki Minaj'
# Saved 'Sick Boy by The Chainsmokers'
# Saved 'Buy a Heart by Nicki Minaj (Ft. Meek Mill)'
# Saved 'My Ordinary Life by The Living Tombstone'
# Saved 'Stolen Dance by Milky Chance'
# Saved 'Retrograde by James Blake'
# Saved 'II. Worldstar by Childish Gambino'
# Saved 'Middle by DJ Snake (Ft. Bipolar Sunshine)'
# Saved 'Waiting For Love by Avicii'
# Saved 'Lane Boy by ​twenty one pilots'
# Saved 'III. Life: The Biggest Troll [Andrew Auernheimer] by Childish Gambino'
# Saved 'Genius by LSD'
# Saved 'HEATED by Beyoncé'
# Saved 'Jackie Chan by Tiësto & Dzeko (Ft. Post Malone & Preme)'
# Saved 'Out Of The Woods by Taylor Swift'
# Saved 'Diamond Heart by Alan Walker (Ft. Sophia Somajo)'
# Saved 'LALISA by LISA'
# Saved 'Hey Mama by David Guetta (Ft. AFROJACK, Bebe Rexha & Nicki Minaj)'
# Saved 'I'll Show You by Justin Bieber'
# Saved 'Magic Shop by BTS'
# Saved 'A Sky Full of Stars by Coldplay'
# Saved 'Dear Reader by Taylor Swift'
# Saved 'Bezos I by Bo Burnham'
# Saved 'Never Really Over by Katy Perry'
# Saved 'Out of Time by The Weeknd'
# Saved 'Waka Waka (This Time for Africa) by Shakira (Ft. Freshlyground)'
# Saved 'Diamonds (Remix) by Rihanna (Ft. Kanye West)'
# Saved 'BREAK MY SOUL by Beyoncé'
# Saved 'Shelter by Porter Robinson & Madeon'
# Saved 'Ode To Sleep by ​twenty one pilots'
# Saved 'Big For Your Boots by Stormzy'
# Saved 'Mr. Morale by Kendrick Lamar & Tanna Leone'
# Saved 'Moth to a Flame by Swedish House Mafia & The Weeknd'
# Saved 'Chun Swae by Nicki Minaj (Ft. Swae Lee)'
# Saved 'Gooey by Glass Animals'
# Saved 'Provider by Frank Ocean'
# Saved 'What's Next by Drake'
# Saved 'Bury the Light by Casey Edwards & Victor Borba (Ft. Victor Borba)'
# Saved 'Судно (Борис Рыжий) [Bedpan (Boris Ryzhy)] by Молчат Дома (Molchat Doma)'
# Saved 'Kill V. Maim by Grimes'
# Saved 'Soap by Melanie Martinez'
# Saved 'Hacker by Death Grips'
# Saved 'Oxytocin by Billie Eilish'
# Saved 'LLC by Nicki Minaj'
# Saved 'TiK ToK by Kesha'
# Saved 'Ocean by Martin Garrix (Ft. Khalid)'
# Saved 'S&M by Rihanna'
# Saved 'Polarize by ​twenty one pilots'
# Saved 'Love Lockdown by Kanye West'
# Saved 'Welcome to the Party by Diplo (Ft. French Montana, Lil Pump & Zhavia Ward)'
# Saved 'Is There Someone Else? by The Weeknd'
# Saved 'Let Me Go by Hailee Steinfeld & Alesso (Ft. Florida Georgia Line & ​watt)'
# Saved 'All Eyes on Me by Bo Burnham'
# Saved 'Mad Hatter by Melanie Martinez'
# Saved 'Gasoline by The Weeknd'
# Saved 'Remind Me to Forget by Kygo & Miguel'
# Saved 'Touch by Daft Punk (Ft. Paul Williams)'
# Saved 'Poland by Lil Yachty'
# Saved 'Oblivion by Grimes'
# Saved 'There For You by Martin Garrix & Troye Sivan'
# Saved 'MODERN JAM by Travis Scott (Ft. Teezo Touchdown)'
# Saved 'Genesis by Grimes'
# Saved 'Ain't My Fault by Zara Larsson'
# Saved 'Bubble Butt by Major Lazer (Ft. 2 Chainz, Bruno Mars, Mystic & Tyga)'
# Saved 'Low Lights by Kanye West'
# Saved 'Don't Leave by Snakehips & MØ'
# Saved 'I Know There's Gonna Be (Good Times) by Jamie xx (Ft. Popcaan & Young Thug)'
# Saved 'New Romantics by Taylor Swift'
# Saved 'Неваляшка (Tumbler Toy) by Oxxxymiron'
# Saved 'Hard White by Nicki Minaj'
# Saved 'Happy Now by Zedd & Elley Duhé'
# Saved 'Sacrifice by The Weeknd'
# Saved 'Less Than Zero by The Weeknd'
# Saved 'Until I Bleed Out by The Weeknd'
# Saved 'Blood // Water by ​grandson'
# Saved 'Devil Eyes by Hippie Sabotage'
# Saved 'Mambo No. 5 (A Little Bit of...) by Lou Bega'
# Saved 'The Nights by Avicii'
# Saved 'Summer by Calvin Harris'
# Saved 'Black Widow by Iggy Azalea (Ft. Rita Ora)'
# Saved 'Paradise by Coldplay'
# Saved 'LOST FOREVER by Travis Scott (Ft. Westside Gunn)'
# Saved 'This Is What You Came For by Calvin Harris & Rihanna'
# Saved 'Maniac by Conan Gray'
# Saved 'Unstoppable by Sia'
# Saved 'Weak by AJR'
# Saved 'All for Us by Labrinth & Zendaya'
# Saved 'Pacify Her by Melanie Martinez'
# Saved 'Stole The Show by Kygo (Ft. Parson James)'
# Saved 'Filthy by Justin Timberlake'
# Saved 'Closer by Nine Inch Nails'
# Saved 'DEATH by Melanie Martinez'
# Saved 'BLACKPINK - Forever Young (Romanized) by Genius Romanizations'
# Saved 'Street Lights by Kanye West'
# Saved 'Ascension by Gorillaz (Ft. Vince Staples)'
# Saved 'Electric by Alina Baraz (Ft. Khalid)'
# Saved 'Now or Never by Halsey'
# Saved 'Quit by Cashmere Cat (Ft. Ariana Grande)'
# Saved '​cellophane by FKA twigs'
# Saved 'Liquorice by Azealia Banks'
# Saved '​you broke me first by Tate McRae'
# Saved 'Ocean Drive by Duke Dumont (Ft. Boy Matthews)'
# Saved 'Love is a Bitch by Two Feet'
# Saved 'Don't Stop the Music by Rihanna'
# Saved 'DARE by Gorillaz (Ft. Shaun Ryder)'
# Saved 'Baba O'Riley by The Who'
# Saved 'California Gurls by Katy Perry (Ft. Snoop Dogg)'
# Saved 'Milkshake by Kelis'
# Saved 'Done for Me by Charlie Puth (Ft. Kehlani)'
# Saved 'I Miss You by Clean Bandit (Ft. Julia Michaels)'
# Saved 'Venus by Lady Gaga'
# Saved 'Sandstorm by Darude'
# Saved 'Rockin' by The Weeknd'
# Saved 'Run Up by Major Lazer (Ft. Nicki Minaj & PARTYNEXTDOOR)'
# Saved 'Without You by Avicii (Ft. Sandro Cavazza)'
# Saved 'Guns for Hands by ​twenty one pilots'
# Saved 'Ode to the Mets by The Strokes'
# Saved 'Doubt by ​twenty one pilots'
# Saved '​money machine by 100 gecs'
# Saved 'Glitch by Taylor Swift'
# Saved 'Fire Drill by Melanie Martinez'
# Saved 'I Love It by Icona Pop (Ft. Charli XCX)'
# Saved 'Say You Will by Kanye West'
# Saved 'Giorgio by Moroder by Daft Punk (Ft. Giorgio Moroder)'
# Saved 'The Boys by Nicki Minaj & Cassie'
# Saved 'I Gotta Feeling by Black Eyed Peas'
# Saved 'Electric Feel by MGMT'
# Saved 'Lens by Frank Ocean'
# Saved 'I Knew You Were Trouble by Taylor Swift'
# Saved 'After Dark by Mr.Kitty'
# Saved 'Blue World by Mac Miller'
# Saved 'Eyes Closed by Halsey'
# Saved 'Party Rock Anthem by LMFAO (Ft. Lauren Bennett & Listenbee)'
# Saved 'On a Roll by Ashley O'
# Saved 'Runnin' (Lose It All) by Naughty Boy (Ft. Arrow Benjamin & Beyoncé)'
# Saved 'Lose Yourself to Dance by Daft Punk (Ft. Pharrell Williams)'
# Saved 'Say My Name by David Guetta, Bebe Rexha & J Balvin'
# Saved 'Tainted Love by Soft Cell'
# Saved 'E.T. (Remix Video Version) by Katy Perry (Ft. Kanye West)'
# Saved 'Stargazing by Kygo (Ft. Justin Jesso)'
# Saved 'Me by The 1975'
# Saved 'Electric Love by BØRNS'
# Saved 'Movements by Pham (Ft. The Yung Fusion)'
# Saved 'Alone, Pt. II by Alan Walker & Ava Max'
# Saved 'Telephone by Lady Gaga (Ft. Beyoncé)'
# Saved 'King by Olly Alexander'
# Saved 'Give Me Everything by Pitbull (Ft. AFROJACK, Nayer & Ne-Yo)'
# Saved 'SOS by Avicii (Ft. Aloe Blacc)'
# Saved 'High On Life by Martin Garrix (Ft. BONN)'
# Saved 'Capital Letters by Hailee Steinfeld & BloodPop®'
# Saved 'She Wolf by Shakira'
# Saved 'Welcome To The Cum Zone by OblivionFall After Dark'
# Saved 'Pity Party by Melanie Martinez'
# Saved 'I Didn't Change My Number by Billie Eilish'
# Saved 'No Love by Death Grips'
# Saved 'Мальчик на девятке (Boy on the Nine) by DEAD BLONDE'
# Saved 'DDU-DU DDU-DU (JP Ver.) by BLACKPINK'
# Saved 'Alejandro by Lady Gaga'
# Saved 'ALIEN SUPERSTAR by Beyoncé'
# Saved 'Company by Justin Bieber'
# Saved 'Only Girl (In The World) by Rihanna'
# Saved 'CUFF IT by Beyoncé'
# Saved 'Know No Better by Major Lazer (Ft. Camila Cabello, Quavo & Travis Scott)'
# Saved 'II. Earth: The Oldest Computer (The Last Night) by Childish Gambino (Ft. Azealia Banks)'
# Saved 'Girls Like by Tinie Tempah (Ft. Zara Larsson)'
# Saved 'Get Free by Major Lazer (Ft. Amber Coffman)'
# Saved 'Cotton Eye Joe by Rednex'
# Saved 'Cake by Melanie Martinez'
# Saved 'Sex by Cheat Codes & Kris Kross Amsterdam'
# Saved 'Hide and Seek by Imogen Heap'
# Saved 'Восточный Мордор (East Mordor) by Oxxxymiron'
# Saved '715 - CRΣΣKS by Bon Iver'
# Saved 'Without Me (Remix) by Halsey (Ft. Juice WRLD)'
# Saved 'Песенка Гремлина (Gremlin's Song) by Oxxxymiron'
# Saved 'Sober Up by AJR (Ft. Rivers Cuomo)'
# Saved 'Dance to This by Troye Sivan (Ft. Ariana Grande)'
# Saved 'Say It by Flume (Ft. Tove Lo)'
# Saved 'Know Me From by Stormzy'
# Saved 'Everything in Its Right Place by Radiohead'
# Saved 'Cebuana by Karencitta'
# Saved 'Bad Girls by M.I.A.'
# Saved 'Love Again by Dua Lipa'
# Saved 'Lonely Together by Avicii (Ft. Rita Ora)'
# Saved 'Parasite Eve by Bring Me The Horizon'
# Saved 'Me Rehúso by Danny Ocean'
# Saved 'Dirty Harry by Gorillaz (Ft. Bootie Brown)'
# Saved 'Alphabet Boy by Melanie Martinez'
# Saved 'The Way I Am by Charlie Puth'
# Saved 'Thoiry Remix by Achille Lauro (Ft. Gemitaiz, Puritano & Quentin40)'
# Saved 'Takeaway by The Chainsmokers & ILLENIUM (Ft. Lennon Stella)'
# Saved 'New by Daya'
# Saved 'Paranoid by Kanye West (Ft. Mr. Hudson)'
# Saved 'How Do I Make You Love Me? by The Weeknd'
# Saved '강남스타일 (Gangnam Style) by PSY'
# Saved 'Oh No! by MARINA'
# Saved 'On My Way by Alan Walker, Sabrina Carpenter & Farruko'
# Saved 'Genghis Khan by Miike Snow'
# Saved 'Talk by Yeat'
# Saved 'Spell It Out by The Lonely Island'
# Saved 'Down by Marian Hill'
# Saved 'All Falls Down by Alan Walker, Digital Farm Animals, Noah Cyrus & Juliander'
# Saved 'Detention by Melanie Martinez'
# Saved 'She’s My Collar by Gorillaz (Ft. Kali Uchis)'
# Saved 'Breathe by Lauv'
# Saved 'The Way I Are (Dance with Somebody) by Bebe Rexha (Ft. Lil Wayne)'
# Saved 'No Limit by USHER (Ft. Young Thug)'
# Saved 'Best Of Me by BTS'
# Saved 'Tammy's Song (Her Evils) by Kendrick Lamar'
# Saved 'Danger by Migos & Marshmello'
# Saved 'Cold Heart (PNAU Remix) by Elton John & Dua Lipa'
# Saved 'Something Different by Why Don't We'
# Saved 'Sail by AWOLNATION'
# Saved 'Teenage Dream by Katy Perry'
# Saved 'Not Today by BTS'
# Saved 'Tessellate by ​​alt-J'
# Saved 'Ride It by Regard'
# Saved 'Carousel by Melanie Martinez'
# Saved 'POP by Lil Uzi Vert'
# Saved 'Lone Digger by Caravan Palace'
# Saved 'Run the World (Girls) by Beyoncé'
# Saved 'On My Mind by Jorja Smith'
# Saved 'Makeba by Jain'
# Saved 'CIRCUS MAXIMUS by Travis Scott (Ft. Swae Lee & The Weeknd)'
# Saved 'GOLDWING by Billie Eilish'
# Saved 'Call Me Mother by RuPaul'
# Saved 'Safe and Sound by Capital Cities'
# Saved 'Idioteque by Radiohead'
# Saved 'Hotter Than Hell by Dua Lipa'
# Saved 'Rise by Katy Perry'
# Saved 'Water by Kanye West (Ft. Ant Clemons)'
# Saved 'Scream and Shout (Hit-Boy Remix) by ​will.i.am (Ft. Britney Spears, Diddy, Hit-Boy, Lil Wayne & Waka Flocka Flame)'
# Saved 'Fitter Happier by Radiohead'
# Saved 'Miku by Anamanaguchi (Ft. 初音ミク (Hatsune Miku))'
# Saved 'The Way I Are by Timbaland (Ft. D.O.E. (Rapper) & Keri Hilson)'
# Saved 'Goner by ​twenty one pilots'
# Saved 'Dynamite by Taio Cruz'
# Saved 'Thumbs by Sabrina Carpenter'
# Saved 'I Know Places by Taylor Swift'
# Saved '​looking for a star (CANT GET YOU OUT OF MY HEAD) by XXXTENTACION'
# Saved 'First Time by Kygo & Ellie Goulding'
# Saved 'WHEN I WAS OLDER by Billie Eilish'
# Saved 'The One by The Chainsmokers'
# Saved 'Read U Wrote U (Ellis Miah Mix) by RuPaul (Ft. Alaska Thunderfuck, The Cast of RuPaul's Drag Race: All Stars, Season 2, Detox Icunt, Katya Zamolodchikova & Roxxxy Andrews)'
# Saved 'WILD by Troye Sivan'
# Saved 'Safari by Serena'
# Saved 'Die For You by Joji'
# Saved 'Somebody's Watching Me by Rockwell (Ft. Jermaine Jackson & Michael Jackson)'
# Saved 'Prada by ​cassö, RAYE & D-Block Europe'
# Saved 'Look Who's Inside Again by Bo Burnham'
# Saved 'Cannibal by Kesha'
# Saved 'Airbag by Radiohead'
# Saved 'On Hold by The xx'
# Saved 'All You Had To Do Was Stay by Taylor Swift'
# Saved 'PYNK by Janelle Monáe (Ft. Grimes)'
# Saved 'Nightcall by Kavinsky (Ft. Lovefoxxx)'
# Saved 'Feel Good by Gryffin & ILLENIUM (Ft. Daya)'
# Saved 'If U Seek Amy by Britney Spears'
# Saved '33 “GOD” by Bon Iver'
# Saved 'Aura by Lady Gaga'
# Saved 'Donatella by Lady Gaga'
# Saved 'Hot N Cold by Katy Perry'
# Saved 'Class Fight by Melanie Martinez'
# Saved 'Hurt by Oliver Tree'
# Saved 'Worth It by Fifth Harmony (Ft. Kid Ink)'
# Saved 'BOOMBAYAH -Japanese Ver.- by BLACKPINK'
# Saved 'You by The 1975'
# Saved 'The Ultimate Showdown of Ultimate Destiny by Lemon Demon'
# Saved 'When You Die by MGMT'
# Saved 'You Reposted in the Wrong Neighborhood by SHOKK 青'
# Saved 'Just Hold On by Steve Aoki & Louis Tomlinson'
# Saved 'Yeah Right by Vince Staples (Ft. Kendrick Lamar & KUČKA)'
# Saved 'Started by Iggy Azalea'
# Saved 'Don't Stop by Megan Thee Stallion (Ft. Young Thug)'
# Saved 'In Cold Blood by ​​alt-J'
# Saved 'Ignite by K-391 (Ft. Alan Walker, Julie Bergan & Seungri (승리))'
# Saved 'A Different Way by DJ Snake (Ft. Lauv)'
# Saved 'Flesh Without Blood by Grimes'
# Saved 'Anywhere by Rita Ora'
# Saved 'Waiting Game by BANKS'
# Saved 'Call on Me by Starley'
# Saved 'Softcore by The Neighbourhood'
# Saved 'Make Me Feel by Janelle Monáe'
# Saved 'Rude Boy by Rihanna'
# Saved 'Close to Me by Ellie Goulding & Diplo (Ft. Swae Lee)'
# Saved 'Trees by ​twenty one pilots'
# Saved 'Don't Leave Me by BTS'
# Saved 'Boys by Charli XCX'
# Saved 'I'M THAT GIRL by Beyoncé'
# Saved 'Shanghai by Nicki Minaj'
# Saved 'Cookie Thumper! by Die Antwoord'
# Saved 'Forever Young by BLACKPINK'
# Saved 'La La La (Brazil 2014) by Shakira (Ft. Carlinhos Brown)'
# Saved 'Flames by David Guetta & Sia'
# Saved 'F.F.F. by Bebe Rexha (Ft. G-Eazy)'
# Saved 'Never Catch Me by Flying Lotus (Ft. Kendrick Lamar)'
# Saved 'Dawn FM by The Weeknd'
# Saved 'Feels by Kiiara'
# Saved 'Monëy so big by Yeat'
# Saved 'Ruin My Life by Zara Larsson'
# Saved 'Rehab by Rihanna (Ft. Justin Timberlake)'
# Saved 'Time to Pretend by MGMT'
# Saved 'Win Again by Nicki Minaj'
# Saved 'Keep It Mello by Marshmello (Ft. Omar LinX)'
# Saved 'OK by Robin Schulz (Ft. James Blunt)'
# Saved 'Boom, Boom, Boom, Boom!! by Vengaboys'
# Saved 'Take Me Back To London by Ed Sheeran (Ft. Stormzy)'
# Saved 'Woke the F*ck Up by Jon Bellion'
# Saved 'Nevermind by Dennis Lloyd'
# Saved '19-2000 by Gorillaz'
# Saved 'Don't Leave Me Alone by David Guetta (Ft. Anne-Marie)'
# Saved 'OverHeated by Billie Eilish'
# Saved 'Hell by A$AP Rocky (Ft. Santigold)'
# Saved '1539 N. Calvert by JPEGMAFIA'
# Saved 'I Wish You Would by Taylor Swift'
# Saved 'I'm Good (Blue) by David Guetta & Bebe Rexha'
# Saved 'She Loves Control by Camila Cabello'
# Saved 'Choker by ​twenty one pilots'
# Saved 'Big Fish by Vince Staples (Ft. Juicy J)'
# Saved 'Need by Taylor Swift'
# Saved 'Throne by Bring Me The Horizon'
# Saved 'CHURCH GIRL by Beyoncé'
# Saved 'The Mind Electric by Miracle Musical (Ft. Joe Hawley)'
# Saved 'Man by Skepta'
# Saved 'Emo Boy by Ayesha Erotica'
# Saved 'Fester Skank by Lethal Bizzle (Ft. Diztortion)'
# Saved 'Let Go by BTS'
# Saved 'Патимейкер (Partymaker) by Пика (Pika)'
# Saved 'Cruel by Snakehips (Ft. ZAYN)'
# Saved 'Change Your Life by Iggy Azalea (Ft. T.I.)'
# Saved 'Me Enamoré by Shakira'
# Saved 'Boom Boom Pow by Black Eyed Peas'
# Saved 'LOOOVE by Travis Scott (Ft. Kid Cudi)'
# Saved 'Gypsy by Lady Gaga'
# Saved 'Wasabi by Little Mix'
# Saved 'Omen by Disclosure (Ft. Sam Smith)'
# Saved 'I'm Sorry by Lil Uzi Vert'
# Saved '​home with you by FKA twigs'
# Saved 'I'm Sorry by Swell (Ft. Shiloh Dynasty)'
# Saved '8 (circle) by Bon Iver'
# Saved 'Alice by Lady Gaga'
# Saved 'Double Fantasy by The Weeknd (Ft. Future)'
# Saved 'Freed From Desire by Gala'
# Saved 'Road Rage (Freestyle) by Josh Tate (Little T)'
# Saved 'Dancing On My Own by Robyn'
# Saved '붐바야 (BOOMBAYAH) by BLACKPINK'
# Saved 'Salt by Ava Max'
# Saved 'You Might Think He Loves You for Your Money but I Know What He Really Loves You for It’s Your Brand New Leopard Skin Pillbox Hat by Death Grips'
# Saved 'Little Boy by KSI'
# Saved 'Here With Me by Marshmello (Ft. CHVRCHES)'
# Saved 'Hunger of the Pine by ​​alt-J'
# Saved 'I Knew You Were Trouble (Taylor's Version) by Taylor Swift'
# Saved 'II. No Exit by Childish Gambino'
# Saved 'Harder, Better, Faster, Stronger by Daft Punk'
# Saved 'Fake You Out by ​twenty one pilots'
# Saved 'Don't You Worry Child by Swedish House Mafia (Ft. John Martin)'
# Saved 'DoYaThing by Gorillaz (Ft. André 3000 & James Murphy)'
# Saved 'Disturbia by Rihanna'
# Saved 'Gemini Feed by BANKS'
# Saved 'I'm an Albatraoz by AronChupa'
# Saved 'Firestone by Kygo (Ft. Conrad Sewell)'
# Saved 'Smile by Katy Perry'
# Saved 'Rich Minion by Yeat'
# Saved 'BLACKPINK - 아니길 (Hope Not) (Romanized) by Genius Romanizations'
# Saved 'Super Freaky Girl (Roman Remix) by Nicki Minaj'
# Saved 'Her by Majid Jordan'
# Saved 'Yellow Flicker Beat by Lorde'
# Saved 'COZY by Beyoncé'
# Saved 'KSI's Little Brother by Miniminter'
# Saved 'Alone by Alan Walker'
# Saved 'Coco Chanel by Nicki Minaj (Ft. Foxy Brown)'
# Saved 'Only You by Cheat Codes & Little Mix'
# Saved 'Kid A by Radiohead'
# Saved 'Frail State of Mind by The 1975'
# Saved 'Где твоя любовь? (Where Is Your Love?) by Скриптонит (Skryptonite) (Ft. Major Lazer)'
# Saved 'Fight Back by NEFFEX'
# Saved 'Why by Sabrina Carpenter'
# Saved 'Girl Loves Me by David Bowie'
# Saved 'Magnets by Disclosure (Ft. Lorde)'
# Saved 'Burn by Ellie Goulding'
# Saved 'ENERGY by Beyoncé (Ft. BEAM)'
# Saved 'In My Mind by Dynoro & Gigi D'Agostino'
# Saved 'U by Jaden'
# Saved 'Borders by M.I.A.'
# Saved '에잇 (eight) by IU (아이유) (Ft. SUGA (슈가))'
# Saved 'Beggin for Thread by BANKS'
# Saved 'DOMINO (English Ver.) by Stray Kids'
# Saved 'Alaska by Maggie Rogers'
# Saved 'Meet Me Halfway by Black Eyed Peas'
# Saved 'Light Switch by Charlie Puth'
# Saved 'Literal Legend by Ayesha Erotica'
# Saved 'Liability (Reprise) by Lorde'
# Saved 'Texts Go Green by Drake'
# Saved 'Teddy Bear by Melanie Martinez'
# Saved 'Sunset by The xx'
# Saved 'End Credits by EDEN (Ft. Leah Kelly)'
# Saved 'Танцуй (Dance) [Remix 2018] by MORGENSHTERN'
# Saved 'One, Two Step by Ciara (Ft. Missy Elliott)'
# Saved 'Personal Jesus by Depeche Mode'
# Saved 'Rivals by USHER (Ft. Future)'
# Saved 'Turn Down For What by DJ Snake & Lil Jon'
# Saved 'Baby's on Fire by Die Antwoord'
# Saved '3:15 by Bazzi'
# Saved 'Manolo by Trip Lee (Ft. Lecrae)'
# Saved 'Creep On Me by GASHI (Ft. DJ Snake & French Montana)'
# Saved 'Cool For The Summer by Demi Lovato'
# Saved 'I Feel Like I'm Drowning by Two Feet'
# Saved 'Fake Happy by Paramore'
# Saved 'Say It Right by Nelly Furtado'
# Saved 'My Love by Majid Jordan (Ft. Drake)'
# Saved 'Sir by Nicki Minaj (Ft. Future)'
# Saved 'FU by Miley Cyrus (Ft. French Montana)'
# Saved 'REALLY REALLY by WINNER'
# Saved 'Venetia by Lil Uzi Vert'
# Saved 'Somebody by The Chainsmokers (Ft. Drew Love)'
# Saved 'BREAK MY SOUL (THE QUEENS REMIX) by Beyoncé & Madonna'
# Saved 'On & On by Cartoon & Jéja (Ft. Daniel Levi (EST))'
# Saved 'Everything Black by Unlike Pluto (Ft. Mike Taylor)'
# Saved 'Welcome to the Machine by Pink Floyd'
# Saved 'Soulmate by Mac Miller'
# Saved 'TUNNEL VISION by Melanie Martinez'
# Saved 'Vogue by Madonna'
# Saved 'Wish You Were Sober by Conan Gray'
# Saved 'Gët Busy by Yeat'
# Saved 'Best Friends by The Weeknd'
# Saved 'There Will Be Tears by Frank Ocean'
# Saved 'Nasty by Skepta'
# Saved 'Mad Love by Sean Paul & David Guetta (Ft. Becky G.)'
# Saved 'Freal Luv by Far East Movement & Marshmello (Ft. CHANYEOL & Tinashe)'
# Saved 'Forest by ​twenty one pilots'
# Saved 'Discord by The Living Tombstone (Ft. Eurobeat Brony)'
# Saved 'Party Girls by Ludacris (Ft. Cashmere Cat, Jeremih & Wiz Khalifa)'
# Saved 'At the Door by The Strokes'
# Saved '​anxiety by ​blackbear & FRND'
# Saved 'Amerika by Rammstein'
# Saved 'Everybody Hates Me by The Chainsmokers'
# Saved 'Gdzie jest biały węgorz? (Zejście) by Cypis'
# Saved 'The Night Is Still Young by Nicki Minaj'
# Saved 'Breathe by Jax Jones (Ft. Ina Wroldsen)'
# Saved 'Particula by Major Lazer & DJ Maphorisa (Ft. Ice Prince, Jidenna, Nasty C & Patoranking)'
# Saved 'Бесприданница (Dowry) by DEAD BLONDE'
# Saved 'Vacation Bible School by Ayesha Erotica'
# Saved 'Monster by Lady Gaga'
# Saved 'Fuck with Myself by BANKS'
# Saved 'Phantom Regret by Jim by The Weeknd'
# Saved 'E.T. by Katy Perry'
# Saved 'Take Me Back To London (Remix) by Ed Sheeran (Ft. Aitch, Jaykae & Stormzy)'
# Saved 'The Mother We Share by CHVRCHES'
# Saved 'Everytime We Touch by Cascada'
# Saved 'Lights by Ellie Goulding'
# Saved 'Bad Blood by NAO'
# Saved 'Nobody Gotta Know by Why Don't We'
# Saved 'Strangers by Sigrid'
# Saved 'Old Thing Back by Matoma & The Notorious B.I.G. (Ft. Ja Rule & Ralph Tresvant)'
# Saved 'Don't Trust Me by 3OH!3'
# Saved '29 #Strafford APTS by Bon Iver'
# Saved 'Just Wanna Rock by Lil Uzi Vert'
# Saved 'Fuego by Eleni Foureira'
# Saved 'Outro by M83'
# Saved 'I Heard You're Married by The Weeknd (Ft. Lil Wayne)'
# Saved 'The Ocean by Mike Perry (Ft. SHY Martin)'
# Saved 'Genesis by Dua Lipa'
# Saved 'Thought I Knew You by Nicki Minaj (Ft. The Weeknd)'
# Saved 'Don't You Want Me by The Human League'
# Saved 'My Girls by Animal Collective'
# Saved 'Sunset Lover by Petit Biscuit'
# Saved 'Boom Clap by Charli XCX'
# Saved 'Just Can't Get Enough by Black Eyed Peas'
# Saved 'Antisocial by ​tana (Ft. Slump6s)'
# Saved 'I Need Your Love by Calvin Harris (Ft. Ellie Goulding)'
# Saved 'Our Song by Anne-Marie & Niall Horan'
# Saved 'Swine by Lady Gaga'
# Saved 'Ayo Technology by 50 Cent (Ft. Justin Timberlake & Timbaland)'
# Saved 'Август (August) by Intelligency'
# Saved 'Future Nostalgia by Dua Lipa'
# Saved 'Screen by ​twenty one pilots'
# Saved 'Pretty Please by Dua Lipa'
# Saved 'Karma (Remix) by Taylor Swift (Ft. Ice Spice)'
# Saved 'Hope by The Chainsmokers (Ft. Winona Oak)'
# Saved 'I Really Want to Stay at Your House by Rosa Walton & Hallie Coggins'
# Saved 'Grrrls by Lizzo'
# Saved 'Miss You by Cashmere Cat, Major Lazer & Tory Lanez'
# Saved 'Mary Jane Holland by Lady Gaga'
# Saved 'PS5 by ​salem ilese, TOMORROW X TOGETHER & Alan Walker'
# Saved 'You Owe Me by The Chainsmokers'
# Saved 'Everything Is AWESOME!!! by Tegan and Sara (Ft. The Lonely Island)'
# Saved 'Comedy by Bo Burnham'
# Saved '​start//end by EDEN'
# Saved 'The Very First Night (Taylor's Version) [From The Vault] by Taylor Swift'
# Saved 'Va Va Voom by Nicki Minaj'
# Saved 'My Universe by Coldplay & BTS'
# Saved 'In the Dark by Camila Cabello'
# Saved 'NintendHoe by Doja Cat'
# Saved 'Blue Monday by New Order'
# Saved 'суки я в шлеме (демо) [bitches I'm wearing a helmet (demo)] by прыгай киска (kiska)'
# Saved 'Russky Cockney by Oxxxymiron'
# Saved 'Semi-Automatic by ​twenty one pilots'
# Saved 'Call You Mine by The Chainsmokers & Bebe Rexha'
# Saved 'RAMSING by SIDxRAM'
# Saved 'Domino by Jessie J'
# Saved 'Stay With You by Cheat Codes & Cade'
# Saved 'SOLO by JENNIE'
# Saved 'Time Moves Slow by BADBADNOTGOOD (Ft. Samuel T. Herring)'
# Saved 'Audacity by Stormzy (Ft. Headie One)'
# Saved 'Miss the Rage by Mario Judah'
# Saved 'Let Me Hold You (Turn Me On) by Cheat Codes & Dante Klein'
# Saved 'Happy Now by Kygo & Sandro Cavazza'
# Saved 'Boş Gemiler by Yüzyüzeyken Konuşuruz'
# Saved 'It's Strange by Louis The Child (Ft. K.Flay)'
# Saved 'Нас не догонят (Nas ne dogonyat) by ​t.A.T.u.'
# Saved 'Something About Us by Daft Punk'
# Saved 'False Alarm by Matoma & Becky Hill'
# Saved 'Hopeless by Halsey (Ft. Cashmere Cat)'
# Saved 'Working for It by ZHU, Skrillex & THEY.'
# Saved 'Sorry Bout That by Yeat'
# Saved 'ARTPOP by Lady Gaga'
# Saved 'NEVER MET! by CMTEN (Ft. Glitch Gum)'
# Saved 'Scatman (Ski-Ba-Bop-Ba-Dop-Bop) by Scatman John'
# Saved 'I Don't Know Why by Imagine Dragons'
# Saved 'White Woman's Instagram by Bo Burnham'
# Saved 'Right Thru Me by Nicki Minaj'
# Saved 'STILL DISAPPOINTED by Stormzy'
# Saved '​hand crushed by a mallet by 100 gecs'
# Saved 'PURE/HONEY by Beyoncé'
# Saved '365 by Zedd & Katy Perry'
# Saved 'Make It Bun Dem by Skrillex (Ft. Damian Marley)'
# Saved 'Magenta Riddim by DJ Snake'
# Saved 'Sugar by Robin Schulz (Ft. Francesco Yates)'
# Saved 'Paracetamol by Declan McKenna'
# Saved 'Purge the Poison by MARINA'
# Saved 'Life Round Here (Remix) by James Blake (Ft. Chance the Rapper)'
# Saved 'GDFR by Flo Rida (Ft. Lookas & Sage The Gemini)'
# Saved 'Crazy by Lost Frequencies & Zonderling'
# Saved 'Born to Be Yours by Kygo & Imagine Dragons'
# Saved 'Pretty Cvnt by Sewerslvt'
# Saved 'Lost in Your Light by Dua Lipa (Ft. Miguel)'
# Saved 'Day 1 ◑ by HONNE'
# Saved 'Water Me by FKA twigs'
# Saved '​​​​stupid by Tate McRae'
# Saved 'Everything Now by Arcade Fire'
# Saved 'Leaders by Lil Uzi Vert (Ft. NAV)'
# Saved 'Every Angel is Terrifying by The Weeknd'
# Saved '​ocean eyes (Astronomyy Remix) by Billie Eilish'
# Saved 'Plastic 100°C by Sampha'
# Saved 'What's Up Danger by Blackway & Black Caviar'
# Saved 'THIQUE by Beyoncé'
# Saved 'Тает лёд (Ice’s Melting) by Грибы (Griby)'
# Saved 'Vroom Vroom by Charli XCX'
# Saved 'How You Get The Girl by Taylor Swift'
# Saved 'Let's Groove by Earth, Wind & Fire'
# Saved 'Good Night by Kanye West (Ft. Al Be Back & Yasiin Bey)'
# Saved 'Venus as a Boy by Björk'
# Saved 'Options by Doja Cat (Ft. JID)'
# Saved 'Pump Up the Jam by Technotronic (Ft. Ya Kid K)'
# Saved 'Heroes Tonight by Janji (Ft. Johnning)'
# Saved 'Young by The Chainsmokers'
# Saved 'Celebration Station by Lil Uzi Vert'
# Saved 'Midnight City by M83'
# Saved 'Confess by Logic (Ft. Killer Mike)'
# Saved 'Tattoo by Loreen'
# Saved 'Sexy and I Know It by LMFAO'
# Saved 'One Touch by Baauer (Ft. AlunaGeorge, Rae Sremmurd & Swae Lee)'
# Saved 'How to Be a Heartbreaker by MARINA'
# Saved '(No One Knows Me) Like the Piano by Sampha'
# Saved '17 by MK'
# Saved 'Straightjacket by Quinn XCII'
# Saved 'Flawlëss by Yeat (Ft. Lil Uzi Vert)'
# Saved 'Peanut Butter Jelly by Galantis'
# Saved 'Drop the Game by Flume & Chet Faker'
# Saved 'Bad Karma by Axel Thesleff'
# Saved 'Another Late Night by Drake (Ft. Lil Yachty)'
# Saved 'Everybody Gets High by MISSIO'
# Saved 'Funkytown by Lipps, Inc.'
# Saved '쩔어 (DOPE) by BTS'
# Saved 'Darling Nikki by Prince and the Revolution'
# Saved 'Breaking Me by Topic & A7S'
# Saved 'Sweet Nothing by Calvin Harris (Ft. Florence Welch)'
# Saved 'Houdini by Foster the People'
# Saved 'Pound The Alarm by Nicki Minaj'
# Saved 'MOVE by Beyoncé (Ft. Grace Jones & Tems)'
# Saved 'In For It by Tory Lanez'
# Saved 'MANiCURE by Lady Gaga'
# Saved '1999 by Charli XCX & Troye Sivan'
# Saved 'REALiTi by Grimes'
# Saved 'Head in the Clouds by 88rising & Joji'
# Saved '22 (OVER S∞∞N) by Bon Iver'
# Saved 'TRRST by IC3PEAK (Ft. ZillaKami)'
# Saved '(I Just) Died in Your Arms by Cutting Crew'
# Saved 'Rich Girl by Gwen Stefani (Ft. Eve)'
# Saved 'Anathema by ​twenty one pilots'
# Saved 'Tired by Alan Walker (Ft. Gavin James)'
# Saved 'I Fink U Freeky by Die Antwoord'
# Saved 'There There by Radiohead'
# Saved '#SELFIE by The Chainsmokers'
# Saved ''Tis a Pity She Was a Whore by David Bowie'
# Saved 'Implicit Demand for Proof by ​twenty one pilots'
# Saved 'Bravado by Lorde'
# Saved '@ (trailer) by ​chillwagon'
# Saved 'Fatty Boom Boom by Die Antwoord'
# Saved 'Violence by Grimes & i_o'
# Saved 'Cherry by Rina Sawayama'
# Saved 'I'm Not Her by Clara Mae'
# Saved 'Star (Voice English Ver.) by LOONA'
# Saved 'Dance Yrself Clean by LCD Soundsystem'
# Saved 'Honest by The Chainsmokers'
# Saved 'Superhero by Unknown Brain (Ft. Chris Linton)'
# Saved 'Cool Girl by Tove Lo'
# Saved 'Up My Sleeves by Death Grips'
# Saved 'Don't Break My Heart by The Weeknd'
# Saved 'Shout by Tears for Fears'
# Saved 'IDOL by BTS'
# Saved 'I Got You by Bebe Rexha'
# Saved 'Talk That Talk by Rihanna (Ft. JAY-Z)'
# Saved '​2 soon by ​keshi'
# Saved 'Reality by Lost Frequencies (Ft. Janieck)'
# Saved 'Space Ghost Coast to Coast by Glass Animals'
# Saved 'Give It 2 U (Remix) by Robin Thicke (Ft. 2 Chainz & Kendrick Lamar)'
# Saved 'VIRGO'S GROOVE by Beyoncé'
# Saved 'Team by Iggy Azalea'
# Saved 'Around the World by Daft Punk'
# Saved 'My Way by Calvin Harris'
# Saved 'Scream by Michael Jackson (Ft. Janet Jackson)'
# Saved 'Complicated by Dimitri Vegas & Like Mike & David Guetta (Ft. Kiiara)'
# Saved 'Myself by Bazzi'
# Saved 'Hustle Bones by Death Grips'
# Saved 'Audio by LSD'
# Saved 'Only The Young by Taylor Swift'
# Saved 'Bring the Noize by M.I.A.'
# Saved 'Beyond by Daft Punk'
# Saved 'JE TE VOGLIO BENE ASSAJE by LIBERATO'
# Saved 'Left Brain, Right Brain by Bo Burnham'
# Saved 'Brain Power by NOMA (JPN)'
# Saved 'Jump by Rihanna (Ft. Kevin Cossom)'
# Saved 'Antisocial 2 by ​tana (Ft. Slump6s, ​SSGKobe, Xhulooo & Yung Fazo)'
# Saved '96 Fuckries by Jme'
# Saved 'I Just Had Sex by The Lonely Island (Ft. Akon)'
# Saved 'Busted and Blue by Gorillaz'
# Saved 'Location Unknown ◐ by HONNE (Ft. Georgia)'
# Saved 'Massive by Drake'
# Saved 'Out of Touch by Daryl Hall & John Oates'
# Saved 'Enigma by Lady Gaga'
# Saved 'BATTLE OF THE LARYNX by Melanie Martinez'
# Saved 'Where Them Girls At by David Guetta (Ft. Flo Rida & Nicki Minaj)'
# Saved 'I Really Like You by Carly Rae Jepsen'
# Saved 'Everybody's Free (To Wear Sunscreen) by Baz Luhrmann (Ft. Lee Perry (Narrator))'
# Saved 'NFS Underground by GSPD'
# Saved 'Just One Yesterday by Fall Out Boy (Ft. Foxes)'
# Saved 'The Run and Go by ​twenty one pilots'
# Saved 'Angel by Fifth Harmony'
# Saved 'This Town by Kygo (Ft. Sasha Alex Sloan)'
# Saved 'After The Afterparty by Charli XCX (Ft. Lil Yachty)'
# Saved 'Brain by BANKS'
# Saved 'Because by The Beatles'
# Saved 'Fearless, Pt. II by Lost Sky (Ft. Chris Linton)'
# Saved 'I Can't Give Everything Away by David Bowie'
# Saved 'A Tale By Quincy by The Weeknd'
# Saved 'Madness by Muse'
# Saved '불장난 (PLAYING WITH FIRE) by BLACKPINK'
# Saved '​mary magdalene by FKA twigs'
# Saved 'I'm The Best by Nicki Minaj'
# Saved 'Baby, I'm Jealous by Bebe Rexha (Ft. Doja Cat)'
# Saved 'Be Together by Major Lazer (Ft. Wild Belle)'
# Saved 'And the Snakes Start to Sing by Bring Me The Horizon'
# Saved 'SUMMER RENAISSANCE by Beyoncé'
# Saved 'Someone That Loves You by HONNE & Izzy Bizu'
# Saved 'Shine by Olly Alexander'
# Saved 'Maniac by Michael Sembello'
# Saved 'Starry Eyes by The Weeknd'
# Saved 'Did Somebody Say (Just Eat) by Katy Perry'
# Saved 'Life Round Here by James Blake'
# Saved '​disco tits by Tove Lo'
# Saved 'Dreamer by Axwell Λ Ingrosso (Ft. Trevor Guthrie)'
# Saved 'Gone by Charli XCX & Christine and the Queens'
# Saved 'Save ME by BTS'
# Saved 'Good Things Fall Apart by ILLENIUM (Ft. Jon Bellion)'
# Saved 'LA Confidential by Tory Lanez'
# Saved 'The National Anthem by Radiohead'
# Saved 'Остров (Island) by МЫ (WE) (Ft. Mirèle)'
# Saved 'Bad Decisions by ​benny blanco, BTS & Snoop Dogg'
# Saved 'Pagan Poetry by Björk'
# Saved 'Holy Ground by Davido (Ft. Nicki Minaj)'
# Saved 'Everybody Knows by Leonard Cohen'
# Saved 'Glory Box by Portishead'
# Saved 'Jenny (I Wanna Ruin Our Friendship) by Studio Killers'
# Saved '3-Way (The Golden Rule) by The Lonely Island (Ft. Justin Timberlake & Lady Gaga)'
# Saved 'Sing Me to Sleep by Alan Walker'
# Saved 'A Moment Apart by ODESZA'
# Saved '​holy terrain by FKA twigs (Ft. Future)'
# Saved 'Shit by Bo Burnham'
# Saved 'Jealous by Eyedress'
# Saved 'Frozen by Madonna'
# Saved 'Ruby by ​twenty one pilots'
# Saved 'Swing Lynn by Harmless'
# Saved 'Thief by Ansel Elgort'
# Saved 'No Excuses by Meghan Trainor'
# Saved 'Gimme More by Britney Spears'
# Saved 'Skin by Rihanna'
# Saved 'Nights With You by MØ'
# Saved 'Don't Stay in School by Boyinaband'
# Saved 'Revolution by Diplo (Ft. Faustix, Imanos & ​kai)'
# Saved 'Check It Out by Nicki Minaj & will.i.am'
# Saved '불타오르네 (Burning Up) (Fire) by BTS'
# Saved 'YOLO by The Lonely Island (Ft. Adam Levine & Kendrick Lamar)'
# Saved 'Integrity by Jme'
# Saved 'Both Ways by Liam Payne'
# Saved 'This is What It Feels Like by BANKS'
# Saved 'Dooo It! by Miley Cyrus'
# Saved '1x1 by Bring Me The Horizon (Ft. Nova Twins)'
# Saved 'Dirty Sexy Money by David Guetta & AFROJACK (Ft. Charli XCX & French Montana)'
# Saved 'MOON CYCLE by Melanie Martinez'
# Saved 'Come Up and Get Me by Death Grips'
# Saved 'Crack Baby by Mitski'
# Saved 'Any Colour You Like by Pink Floyd'
# Saved 'Habits of My Heart by Jaymes Young'
# Saved '666 ʇ by Bon Iver'
# Saved 'Y.A.L.A. by M.I.A.'
# Saved 'Do My Thang by Miley Cyrus'
# Saved 'Glad You Came by The Wanted'
# Saved 'New Divide by Linkin Park'
# Saved '​stupid horse by 100 gecs'
# Saved 'Dorak Gai - دورك جي by Wegz - ويجز'
# Saved 'Outside by Calvin Harris (Ft. Ellie Goulding)'
# Saved 'Dímelo by Snakehips & Tory Lanez'
# Saved 'Bang Bang by ​will.i.am'
# Saved 'Ameno by ERA'
# Saved '​sex money feelings die by Lykke Li'
# Saved 'A Keeper by Drake'
# Saved 'Miss You by Oliver Tree & Robin Schulz'
# Saved 'Flicker by Porter Robinson'
# Saved 'Lighter by Nathan Dawe (Ft. KSI)'
# Saved 'On the Run by Pink Floyd'
# Saved 'Head.Cars.Bending by The 1975'
# Saved 'Lotus Flower by Radiohead'
# Saved 'IN THE SUMMER by 嵐 (ARASHI)'
# Saved 'Lovely by ​twenty one pilots'
# Saved 'Big Enough by Kirin J Callinan (Ft. Alex Cameron, Jimmy Barnes & Molly Lewis)'
# Saved 'Watch This by Lil Uzi Vert'
# Saved 'SMOKE IT OFF! by Lumi Athena & jnhygs'
# Saved 'Someone New by BANKS'
# Saved 'Play by K-391, Alan Walker & Martin Tungevaag (Ft. Mangoo)'
# Saved 'Akasaka Sad by Rina Sawayama'
# Saved 'Break Up Song by Little Mix'
# Saved 'Save Me by Nicki Minaj'
# Saved 'Cut My Hair by Mounika. (Ft. Cavetown)'
# Saved 'Die Trying by Michl'
# Saved 'Mitsubishi Sony by Frank Ocean'
# Saved 'Whip It by Nicki Minaj'
# Saved 'Runaway (U & I) by Galantis'
# Saved 'You & Me (Flume Remix) by Disclosure (Ft. ELIZA)'
# Saved 'PLASTIC OFF THE SOFA by Beyoncé'
# Saved 'Goodnight Gotham by Rihanna'
# Saved 'Don't Play by Anne-Marie, KSI & Digital Farm Animals'
# Saved '​moment by Vierre Cloud'
# Saved 'Dawn Chorus by Thom Yorke'
# Saved 'Секс (Sex) by Lida'
# Saved 'Winaloto by Tommy Cash'
# Saved 'Then by Anne-Marie'
# Saved 'Can’t Get You Out Of My Head by Kylie Minogue'
# Saved 'Fashion! by Lady Gaga'
# Saved 'Make Me Fade by K.Flay'
# Saved 'BLACKPINK - Really (English Translation) by Genius English Translations'
# Saved 'West End Girls by Pet Shop Boys'
# Saved 'Don't Kill My Vibe by Sigrid'
# Saved 'Overgrown by James Blake'
# Saved '​psychofreak by Camila Cabello (Ft. WILLOW)'
# Saved 'These Girls by Why Don't We'
# Saved '​bitches by Tove Lo'
# Saved 'I Dare You by The xx'
# Saved 'All Of Me by Big Gigantic (Ft. Logic & ROZES)'
# Saved 'Supplies by Justin Timberlake'
# Saved 'Астронавт (Astronaut) by ATL'
# Saved 'No Drama by Tinashe (Ft. Offset)'
# Saved 'Summertime by Vince Staples'
# Succsefffully saved electronic songs

# %%
# Download lyrics for all the songs

for genre in GENRES:

    # Create an output folder
    if not os.path.exists(f"{DATA_PATH}/lyrics/{genre}"):
        os.mkdir(f"{DATA_PATH}/lyrics/{genre}")

    # Get the song list for one genre
    with open(f"{DATA_PATH}/songs/{genre}.yml", "r") as f:
        songs = yaml.safe_load(f)

    # The API call for lyrics often times out
    # We repeat it every time it has timed out
    error = True
    while error:
        error = False 

        try:
            # Check the already saved songs
            saved_songs = os.listdir(DATA_PATH + "/lyrics/" + genre)
            n_saved_songs = 0 if len(saved_songs) == 0 else max([int(song[:4]) for song in saved_songs])

            # Download the song lyrics
            for i, song in enumerate(songs[n_saved_songs:]):
                title, url = song
                title: str

                # A Page "Behind The Lyrics" appeared in the country songs
                # This is not a song and is filtered out
                if title.startswith("Behind The Lyrics"):
                    continue

                # The title sometimes has invalid chars for a file name
                # Remove these here
                scary_chars = "\"/?*|"
                for char in scary_chars:
                    title = title.replace(char, "")
                if len(title) > 150:
                    title = title[:150]

                lyrics: str = genius.lyrics(song_url=url)

                # The downlaoded lyrics have a header in the first line and
                # a number + "Embed" on the last line
                # These need to be removed
                lyrics = "\n".join(lyrics.splitlines()[1:])[:-5]
                
                # Skip emtpy lyrics
                if len(lyrics) == 0:
                    continue

                # Remove "Embed" + number from the end
                if lyrics[-1] == 'K':
                    lyrics = lyrics[:-3]
                while lyrics[-1].isdigit():
                    lyrics = lyrics[:-1]

                with open(f"{DATA_PATH}/lyrics/{genre}/{(n_saved_songs + i):04d}_{title}.txt", "w", encoding="utf-8") as f:
                    f.write(lyrics)
                print(f"✅ Saved {n_saved_songs + i}: {title}")
        except Exception as e:
            print(f"❌ {e}")
            error = True
# Out:
# ✅ Saved 998: ​making the bed by Olivia Rodrigo
# ✅ Saved 999: Civil War by Guns N' Roses
# ✅ Saved 999: Chivalry Is Dead by Trevor Wesley
# ✅ Saved 994: Hello Beautiful by Noah Schnacky
# ✅ Saved 31: Without Me by Eminem
# ✅ Saved 32: Alexander Hamilton by Leslie Odom, Jr., Anthony Ramos, Daveed Diggs, Okieriete Onaodowan, Lin-Manuel Miranda, Phillipa Soo, Christopher Jackson & Orig
# ✅ Saved 33: The Real Slim Shady by Eminem
# ✅ Saved 34: XXX. by Kendrick Lamar (Ft. U2)
# ❌ Request timed out:
# HTTPSConnectionPool(host='genius.com', port=443): Read timed out. (read timeout=5)
# ✅ Saved 34: XXX. by Kendrick Lamar (Ft. U2)
# ❌ Request timed out:
# HTTPSConnectionPool(host='genius.com', port=443): Read timed out. (read timeout=5)
# ✅ Saved
# ✅ Saved 326: Cleanin' Out My Closet by Eminem
# ✅ Saved 327: U With Me by Drake
# ✅ Saved 328: I spoke to the devil in miami, he said everything would be fine by XXXTENTACION
# ✅ Saved 329: 90210 by Travis Scott (Ft. Kacy Hill)
# ✅ Saved 330: I'm Different by 2 Chainz
# ✅ Saved 331: Taki Taki by DJ Snake (Ft. Cardi B, Ozuna & Selena Gomez)
# ✅ Saved 332: Apparently by J. Cole
# ✅ Saved 333: Non-Stop by Leslie Odom, Jr., Lin-Manuel Miranda, Phillipa Soo, Christopher Jackson, Original Broadway Cast of Hamilton & Renée Elise Goldsberry
# ✅ Saved 334: Ransom by Lil Tecca
# ✅ Saved 335: No Guidance by Chris Brown (Ft. Drake)
# ✅ Saved 336: We Own It (Fast & Furious) by 2 Chainz & Wiz Khalifa
# ✅ Saved 337: Cabinet Battle #1 by Christopher Jackson, Daveed Diggs, Lin-Manuel Miranda & Okieriete Onaodowan
# ✅ Saved 338: Recognize by PARTYNEXTDOOR (Ft. Drake)
# ✅ Saved 339: Devil In a New Dress by Kanye West (Ft. Rick Ross)
# ✅ Saved 340: Beautiful by Eminem
# ✅ Saved 341: Not Afraid by Eminem
# ✅ Saved 342: Shabba by A$AP Ferg (Ft. A$AP Rocky)
# ✅ Saved 343: Keep Ya Head Up by 2Pac
# ✅ Saved 344: Down in the DM by Yo Gotti
# ✅ Saved 345: Saint Pablo by Kanye West (Ft. Sampha)
# ✅ Saved 346: Pt. 2 by Kanye West (Ft. Desiigner)
# ✅ Saved 347: Veleno 6 by MadMan (Ft. Gemitaiz)
# ✅ Saved 348: Dark Fantasy by Kanye West
# ✅ Saved 349: Let You Down by NF
# ✅ Saved 350: About The Money by T.I. (Ft. Young Thug)
# ✅ Saved 351: Ric Flair Drip by Offset & Metro Boomin
# ✅ Saved 352: Helpless by Phillipa Soo & Original Broadway Cast of Hamilton
# ✅ Saved 353: Crew Love by Drake (Ft. The Weeknd)
# ✅ Saved 354: For Free by DJ Khaled (Ft. Drake)
# ✅ Saved 355: Do Not Disturb by Drake
# ✅ Saved 356: XXL Freshmen 2016 Cypher - Part 2 by XXL (Ft. 21 Savage, Denzel Curry, Kodak Black, Lil Uzi Vert & Lil Yachty)
# ✅ Saved 357: Own It by Drake
# ✅ Saved 358: Город под подошвой (City Under the Sole) by Oxxxymiron
# ✅ Saved 359: Flawless Remix by Beyoncé (Ft. Nicki Minaj)
# ✅ Saved 360: Praise the Lord (Da Shine) by A$AP Rocky (Ft. Skepta)
# ✅ Saved 361: Goldie by A$AP Rocky
# ✅ Saved 362: FML by Kanye West (Ft. The Weeknd)
# ✅ Saved 363: Waves by Kanye West (Ft. Chris Brown)
# ✅ Saved 364: Doing It Wrong by Drake
# ✅ Saved 365: Drip Too Hard by Lil Baby & Gunna
# ✅ Saved 366: Look What You've Done by Drake
# ✅ Saved 367: All of the Lights by Kanye West
# ✅ Saved 368: ​u by Kendrick Lamar
# ✅ Saved 369: Wu-Tang Forever by Drake
# ✅ Saved 370: Hold My Liquor by Kanye West
# ✅ Saved 618: Space Bound by Eminem
# ✅ Saved 619: 03' Adolescence by J. Cole
# ✅ Saved 620: Jungle by A Boogie wit da Hoodie
# ✅ Saved 621: Drugs You Should Try It by Travis Scott
# ✅ Saved 622: Paris by $UICIDEBOY$
# ✅ Saved 623: Diamonds Dancing by Drake & Future
# ✅ Saved 624: 9 by Drake
# ✅ Saved 625: Renegade by JAY-Z (Ft. Eminem)
# ✅ Saved 626: Comin Out Strong by Future (Ft. The Weeknd)
# ✅ Saved 627: Forbidden Fruit by J. Cole (Ft. Kendrick Lamar)
# ✅ Saved 628: Say No to This by Jasmine Cephas-Jones, Leslie Odom, Jr., Lin-Manuel Miranda, Sydney James Harcourt & Original Broadway Cast of Hamilton
# ✅ Saved 629: 30 Hours by Kanye West
# ✅ Saved 630: Heartless by Kanye West
# ✅ Saved 631: Pusha ManParanoia by Chance the Rapper (Ft. Lili K & Nate Fox)
# ✅ Saved 632: I Know by Big Sean (Ft. Jhené Aiko)
# ✅ Saved 633: Need to Know by Doja Cat
# ✅ Saved 634: Dance with the Devil by Immortal Technique
# ✅ Saved 635: Where Ya At by Future (Ft. Drake)
# ✅ Saved 636: L$D by A$AP Rocky
# ✅ Saved 637: The Greatest by Sia (Ft. Kendrick Lamar)
# ✅ Saved 638: Feu de bois by Damso
# ✅ Saved 639: 911  Mr. Lonely by Tyler, The Creator (Ft. Frank Ocean & Steve Lacy)
# ✅ Saved 640: Carry On by XXXTENTACION
# ✅ Saved 641: Go Flex by Post Malone
# ✅ Saved 642: Love Scars by Trippie Redd
# ✅ Saved 643: Days in the East by Drake
# ✅ Saved 644: Tú No Metes Cabra by Bad Bunny
# ✅ Saved 645: Benz Truck (Гелик) by Lil Peep
# ✅ Saved 646: Unaccommodating by Eminem (Ft. Young M.A)
# ✅ Saved 647: Only You Freestyle by Headie One & Drake
# ✅ Saved 648: Myself by NAV
# ✅ Saved 649: Close Friends by Lil Baby
# ✅ Saved 650: RAPSTAR by Polo G
# ✅ Saved 651: Yikes by Kanye West
# ✅ Saved 652: Who Do You Love by YG (Ft. Drake)
# ✅ Saved 653: 99 Problems by JAY-Z
# ✅ Saved 654: Au DD by PNL
# ✅ Saved 655: ICY GRL by Saweetie
# ✅ Saved 656: Try Me by DeJ Loaf
# ✅ Saved 657: ZEZE by Kodak Black (Ft. Offset & Travis Scott)
# ✅ Saved 658: Flashing Lights by Kanye West (Ft. Dwele)
# ✅ Saved 659: 100 by The Game (Ft. Drake)
# ✅ Saved 660: Best Friend by Yelawolf (Ft. Eminem)
# ✅ Saved 661: Tuesday by ​iLoveMakonnen (Ft. Drake)
# ✅ Saved 662: Redemption by Drake
# ✅ Saved 663: Way 2 Sexy by Drake (Ft. Future & Young Thug)
# ✅ Saved 664: Long Live A$AP by A$AP Rocky
# ✅ Saved 665: Signs by Drake
# ✅ Saved 666: Glorious by Macklemore (Ft. Skylar Grey)
# ✅ Saved 667: Work Out by J. Cole
# ✅ Saved 668: For Free (Interlude) by Kendrick Lamar
# ❌ Request timed out:
# HTTPSConnectionPool(host='genius.com', port=443): Read timed out. (read timeout=5)
# ✅ Saved 759: GOD. by Kendrick Lamar
# ✅ Saved 760: It Wasn't Me by Shaggy (Ft. Rikrok)
# ✅ Saved 761: Bandana by Big Baby Tape & kizaru
# ✅ Saved 762: FRIENDS by THE CARTERS
# ✅ Saved 763: Fuck Up Some Commas by Future
# ...
# ✅ Saved 716: Russky Cockney by Oxxxymiron
# ✅ Saved 717: Semi-Automatic by ​twenty one pilots
# ✅ Saved 718: Call You Mine by The Chainsmokers & Bebe Rexha
# ✅ Saved 719: RAMSING by SIDxRAM
# ✅ Saved 720: Karma (Remix) by Taylor Swift (Ft. Ice Spice)
# ✅ Saved 721: Stay With You by Cheat Codes & Cade
# ✅ Saved 722: SOLO by JENNIE
# ✅ Saved 723: Time Moves Slow by BADBADNOTGOOD (Ft. Samuel T. Herring)
# ✅ Saved 724: Audacity by Stormzy (Ft. Headie One)
# ✅ Saved 725: Miss the Rage by Mario Judah
# ✅ Saved 726: Let Me Hold You (Turn Me On) by Cheat Codes & Dante Klein
# ✅ Saved 727: Happy Now by Kygo & Sandro Cavazza
# ✅ Saved 728: Boş Gemiler by Yüzyüzeyken Konuşuruz
# ✅ Saved 729: It's Strange by Louis The Child (Ft. K.Flay)
# ✅ Saved 730: Нас не догонят (Nas ne dogonyat) by ​t.A.T.u.
# ✅ Saved 731: False Alarm by Matoma & Becky Hill
# ✅ Saved 732: Hopeless by Halsey (Ft. Cashmere Cat)
# ✅ Saved 733: Working for It by ZHU, Skrillex & THEY.
# ✅ Saved 734: Sorry Bout That by Yeat
# ✅ Saved 735: ARTPOP by Lady Gaga
# ✅ Saved 736: NEVER MET! by CMTEN (Ft. Glitch Gum)
# ✅ Saved 737: Scatman (Ski-Ba-Bop-Ba-Dop-Bop) by Scatman John
# ✅ Saved 738: I Don't Know Why by Imagine Dragons
# ✅ Saved 739: White Woman's Instagram by Bo Burnham
# ✅ Saved 740: STILL DISAPPOINTED by Stormzy
# ✅ Saved 741: ​hand crushed by a mallet by 100 gecs
# ❌ Request timed out:
# HTTPSConnectionPool(host='genius.com', port=443): Read timed out. (read timeout=5)
# ✅ Saved 741: ​hand crushed by a mallet by 100 gecs
# ✅ Saved 742: Something About Us by Daft Punk
# ✅ Saved 743: Right Thru Me by Nicki Minaj
# ✅ Saved 744: PUREHONEY by Beyoncé
# ✅ Saved 745: 365 by Zedd & Katy Perry
# ✅ Saved 746: Make It Bun Dem by Skrillex (Ft. Damian Marley)
# ✅ Saved 747: Magenta Riddim by DJ Snake
# ✅ Saved 748: Sugar by Robin Schulz (Ft. Francesco Yates)
# ✅ Saved 749: Paracetamol by Declan McKenna
# ✅ Saved 750: Purge the Poison by MARINA
# ✅ Saved 751: Life Round Here (Remix) by James Blake (Ft. Chance the Rapper)
# ✅ Saved 752: Crazy by Lost Frequencies & Zonderling
# ✅ Saved 753: Born to Be Yours by Kygo & Imagine Dragons
# ✅ Saved 754: Day 1 ◑ by HONNE
# ✅ Saved 755: Water Me by FKA twigs
# ✅ Saved 756: Lost in Your Light by Dua Lipa (Ft. Miguel)
# ✅ Saved 757: ​​​​stupid by Tate McRae
# ✅ Saved 758: Everything Now by Arcade Fire
# ✅ Saved 759: GDFR by Flo Rida (Ft. Lookas & Sage The Gemini)
# ✅ Saved 760: Leaders by Lil Uzi Vert (Ft. NAV)
# ✅ Saved 761: Every Angel is Terrifying by The Weeknd
# ✅ Saved 762: ​ocean eyes (Astronomyy Remix) by Billie Eilish
# ✅ Saved 763: Plastic 100°C by Sampha
# ✅ Saved 764: What's Up Danger by Blackway & Black Caviar
# ✅ Saved 765: THIQUE by Beyoncé
# ✅ Saved 766: Тает лёд (Ice’s Melting) by Грибы (Griby)
# ✅ Saved 767: Vroom Vroom by Charli XCX
# ✅ Saved 768: How You Get The Girl by Taylor Swift
# ✅ Saved 769: Let's Groove by Earth, Wind & Fire
# ✅ Saved 770: Good Night by Kanye West (Ft. Al Be Back & Yasiin Bey)
# ✅ Saved 771: Venus as a Boy by Björk
# ✅ Saved 772: Options by Doja Cat (Ft. JID)
# ❌ Request timed out:
# HTTPSConnectionPool(host='genius.com', port=443): Read timed out. (read timeout=5)
# ✅ Saved 772: Options by Doja Cat (Ft. JID)
# ✅ Saved 773: Pump Up the Jam by Technotronic (Ft. Ya Kid K)
# ✅ Saved 774: Heroes Tonight by Janji (Ft. Johnning)
# ✅ Saved 775: Young by The Chainsmokers
# ✅ Saved 776: Celebration Station by Lil Uzi Vert
# ✅ Saved 777: Midnight City by M83
# ✅ Saved 778: Confess by Logic (Ft. Killer Mike)
# ✅ Saved 779: Tattoo by Loreen
# ✅ Saved 780: Sexy and I Know It by LMFAO
# ✅ Saved 781: One Touch by Baauer (Ft. AlunaGeorge, Rae Sremmurd & Swae Lee)
# ✅ Saved 782: How to Be a Heartbreaker by MARINA
# ✅ Saved 783: (No One Knows Me) Like the Piano by Sampha
# ✅ Saved 784: 17 by MK
# ✅ Saved 785: Straightjacket by Quinn XCII
# ✅ Saved 786: Flawlëss by Yeat (Ft. Lil Uzi Vert)
# ✅ Saved 787: Peanut Butter Jelly by Galantis
# ✅ Saved 788: Drop the Game by Flume & Chet Faker
# ✅ Saved 789: Bad Karma by Axel Thesleff
# ✅ Saved 790: Another Late Night by Drake (Ft. Lil Yachty)
# ✅ Saved 791: Everybody Gets High by MISSIO
# ❌ Request timed out:
# HTTPSConnectionPool(host='genius.com', port=443): Read timed out. (read timeout=5)
# ✅ Saved 791: Everybody Gets High by MISSIO
# ❌ Request timed out:
# HTTPSConnectionPool(host='genius.com', port=443): Read timed out. (read timeout=5)
# ✅ Saved 791: Everybody Gets High by MISSIO
# ✅ Saved 792: Funkytown by Lipps, Inc.
# ✅ Saved 793: 쩔어 (DOPE) by BTS
# ✅ Saved 794: Darling Nikki by Prince and the Revolution
# ✅ Saved 795: Breaking Me by Topic & A7S
# ✅ Saved 796: Sweet Nothing by Calvin Harris (Ft. Florence Welch)
# ✅ Saved 797: Houdini by Foster the People
# ✅ Saved 798: MOVE by Beyoncé (Ft. Grace Jones & Tems)
# ✅ Saved 799: Pound The Alarm by Nicki Minaj
# ✅ Saved 800: In For It by Tory Lanez
# ✅ Saved 801: MANiCURE by Lady Gaga
# ❌ Request timed out:
# HTTPSConnectionPool(host='genius.com', port=443): Read timed out. (read timeout=5)
# ✅ Saved 801: MANiCURE by Lady Gaga
# ✅ Saved 802: 1999 by Charli XCX & Troye Sivan
# ✅ Saved 803: REALiTi by Grimes
# ✅ Saved 804: Head in the Clouds by 88rising & Joji
# ✅ Saved 805: 22 (OVER S∞∞N) by Bon Iver
# ✅ Saved 806: TRRST by IC3PEAK (Ft. ZillaKami)
# ❌ Request timed out:
# HTTPSConnectionPool(host='genius.com', port=443): Read timed out. (read timeout=5)
# ✅ Saved 806: TRRST by IC3PEAK (Ft. ZillaKami)
# ❌ Request timed out:
# HTTPSConnectionPool(host='genius.com', port=443): Read timed out. (read timeout=5)
# ✅ Saved 806: TRRST by IC3PEAK (Ft. ZillaKami)
# ✅ Saved 807: (I Just) Died in Your Arms by Cutting Crew
# ✅ Saved 808: Rich Girl by Gwen Stefani (Ft. Eve)
# ✅ Saved 809: Anathema by ​twenty one pilots
# ✅ Saved 810: Tired by Alan Walker (Ft. Gavin James)
# ✅ Saved 811: I Fink U Freeky by Die Antwoord
# ✅ Saved 812: There There by Radiohead
# ✅ Saved 813: #SELFIE by The Chainsmokers
# ✅ Saved 814: 'Tis a Pity She Was a Whore by David Bowie
# ✅ Saved 815: Implicit Demand for Proof by ​twenty one pilots
# ✅ Saved 816: Bravado by Lorde
# ✅ Saved 817: @ (trailer) by ​chillwagon
# ✅ Saved 818: Fatty Boom Boom by Die Antwoord
# ✅ Saved 819: Violence by Grimes & i_o
# ✅ Saved 820: Cherry by Rina Sawayama
# ✅ Saved 821: I'm Not Her by Clara Mae
# ✅ Saved 822: Star (Voice English Ver.) by LOONA
# ✅ Saved 823: Dance Yrself Clean by LCD Soundsystem
# ✅ Saved 824: Honest by The Chainsmokers
# ✅ Saved 825: Superhero by Unknown Brain (Ft. Chris Linton)
# ✅ Saved 826: Cool Girl by Tove Lo
# ✅ Saved 827: Up My Sleeves by Death Grips
# ✅ Saved 828: Don't Break My Heart by The Weeknd
# ❌ Request timed out:
# HTTPSConnectionPool(host='genius.com', port=443): Read timed out. (read timeout=5)
# ✅ Saved 828: Don't Break My Heart by The Weeknd
# ❌ Request timed out:
# HTTPSConnectionPool(host='genius.com', port=443): Read timed out. (read timeout=5)
# ✅ Saved 828: Don't Break My Heart by The Weeknd
# ✅ Saved 829: Shout by Tears for Fears
# ✅ Saved 830: IDOL by BTS
# ✅ Saved 831: I Got You by Bebe Rexha
# ✅ Saved 832: Talk That Talk by Rihanna (Ft. JAY-Z)
# ✅ Saved 833: ​2 soon by ​keshi
# ✅ Saved 834: Reality by Lost Frequencies (Ft. Janieck)
# ✅ Saved 835: Space Ghost Coast to Coast by Glass Animals
# ✅ Saved 836: Give It 2 U (Remix) by Robin Thicke (Ft. 2 Chainz & Kendrick Lamar)
# ✅ Saved 837: VIRGO'S GROOVE by Beyoncé
# ✅ Saved 838: Team by Iggy Azalea
# ❌ Request timed out:
# HTTPSConnectionPool(host='genius.com', port=443): Read timed out. (read timeout=5)
# ✅ Saved 838: Team by Iggy Azalea
# ✅ Saved 839: Around the World by Daft Punk
# ✅ Saved 840: My Way by Calvin Harris
# ❌ Request timed out:
# HTTPSConnectionPool(host='genius.com', port=443): Read timed out. (read timeout=5)
# ✅ Saved 840: My Way by Calvin Harris
# ✅ Saved 841: Scream by Michael Jackson (Ft. Janet Jackson)
# ✅ Saved 842: Complicated by Dimitri Vegas & Like Mike & David Guetta (Ft. Kiiara)
# ✅ Saved 843: Myself by Bazzi
# ✅ Saved 844: Hustle Bones by Death Grips
# ✅ Saved 845: Audio by LSD
# ✅ Saved 846: Only The Young by Taylor Swift
# ✅ Saved 847: Bring the Noize by M.I.A.
# ✅ Saved 848: Beyond by Daft Punk
# ✅ Saved 849: JE TE VOGLIO BENE ASSAJE by LIBERATO
# ✅ Saved 850: Left Brain, Right Brain by Bo Burnham
# ✅ Saved 851: Brain Power by NOMA (JPN)
# ✅ Saved 852: Jump by Rihanna (Ft. Kevin Cossom)
# ✅ Saved 853: 96 Fuckries by Jme
# ✅ Saved 854: I Just Had Sex by The Lonely Island (Ft. Akon)
# ✅ Saved 855: Busted and Blue by Gorillaz
# ✅ Saved 856: Antisocial 2 by ​tana (Ft. Slump6s, ​SSGKobe, Xhulooo & Yung Fazo)
# ✅ Saved 857: Location Unknown ◐ by HONNE (Ft. Georgia)
# ❌ Request timed out:
# HTTPSConnectionPool(host='genius.com', port=443): Read timed out. (read timeout=5)
# ✅ Saved 857: Location Unknown ◐ by HONNE (Ft. Georgia)
# ✅ Saved 858: Massive by Drake
# ❌ Request timed out:
# HTTPSConnectionPool(host='genius.com', port=443): Read timed out. (read timeout=5)
# ✅ Saved 858: Massive by Drake
# ✅ Saved 859: Out of Touch by Daryl Hall & John Oates
# ✅ Saved 860: Enigma by Lady Gaga
# ✅ Saved 861: I Really Like You by Carly Rae Jepsen
# ✅ Saved 862: Everybody's Free (To Wear Sunscreen) by Baz Luhrmann (Ft. Lee Perry (Narrator))
# ✅ Saved 863: NFS Underground by GSPD
# ✅ Saved 864: Just One Yesterday by Fall Out Boy (Ft. Foxes)
# ✅ Saved 865: The Run and Go by ​twenty one pilots
# ✅ Saved 866: Angel by Fifth Harmony
# ✅ Saved 867: This Town by Kygo (Ft. Sasha Alex Sloan)
# ✅ Saved 868: After The Afterparty by Charli XCX (Ft. Lil Yachty)
# ✅ Saved 869: Brain by BANKS
# ✅ Saved 870: Because by The Beatles
# ✅ Saved 871: Fearless, Pt. II by Lost Sky (Ft. Chris Linton)
# ✅ Saved 872: I Can't Give Everything Away by David Bowie
# ✅ Saved 873: A Tale By Quincy by The Weeknd
# ✅ Saved 874: Madness by Muse
# ✅ Saved 875: 불장난 (PLAYING WITH FIRE) by BLACKPINK
# ✅ Saved 876: ​mary magdalene by FKA twigs
# ✅ Saved 877: Baby, I'm Jealous by Bebe Rexha (Ft. Doja Cat)
# ✅ Saved 878: Be Together by Major Lazer (Ft. Wild Belle)
# ✅ Saved 879: And the Snakes Start to Sing by Bring Me The Horizon
# ✅ Saved 880: SUMMER RENAISSANCE by Beyoncé
# ✅ Saved 881: Someone That Loves You by HONNE & Izzy Bizu
# ✅ Saved 882: Shine by Olly Alexander
# ❌ Request timed out:
# HTTPSConnectionPool(host='genius.com', port=443): Read timed out. (read timeout=5)
# ✅ Saved 882: Shine by Olly Alexander
# ✅ Saved 883: Maniac by Michael Sembello
# ✅ Saved 884: Starry Eyes by The Weeknd
# ✅ Saved 885: Did Somebody Say (Just Eat) by Katy Perry
# ✅ Saved 886: Where Them Girls At by David Guetta (Ft. Flo Rida & Nicki Minaj)
# ✅ Saved 887: Life Round Here by James Blake
# ✅ Saved 888: ​disco tits by Tove Lo
# ✅ Saved 889: I'm The Best by Nicki Minaj
# ✅ Saved 890: Dreamer by Axwell Λ Ingrosso (Ft. Trevor Guthrie)
# ✅ Saved 891: Gone by Charli XCX & Christine and the Queens
# ✅ Saved 892: Save ME by BTS
# ✅ Saved 893: Good Things Fall Apart by ILLENIUM (Ft. Jon Bellion)
# ✅ Saved 894: LA Confidential by Tory Lanez
# ✅ Saved 895: BATTLE OF THE LARYNX by Melanie Martinez
# ✅ Saved 896: Остров (Island) by МЫ (WE) (Ft. Mirèle)
# ✅ Saved 897: Bad Decisions by ​benny blanco, BTS & Snoop Dogg
# ✅ Saved 898: Pagan Poetry by Björk
# ✅ Saved 899: Holy Ground by Davido (Ft. Nicki Minaj)
# ✅ Saved 900: Everybody Knows by Leonard Cohen
# ✅ Saved 901: Glory Box by Portishead
# ✅ Saved 902: Jenny (I Wanna Ruin Our Friendship) by Studio Killers
# ✅ Saved 903: 3-Way (The Golden Rule) by The Lonely Island (Ft. Justin Timberlake & Lady Gaga)
# ✅ Saved 904: Sing Me to Sleep by Alan Walker
# ✅ Saved 905: The National Anthem by Radiohead
# ✅ Saved 906: A Moment Apart by ODESZA
# ✅ Saved 907: ​holy terrain by FKA twigs (Ft. Future)
# ✅ Saved 908: Shit by Bo Burnham
# ✅ Saved 909: Jealous by Eyedress
# ❌ Request timed out:
# HTTPSConnectionPool(host='genius.com', port=443): Read timed out. (read timeout=5)
# ✅ Saved 909: Jealous by Eyedress
# ✅ Saved 910: Frozen by Madonna
# ✅ Saved 911: Ruby by ​twenty one pilots
# ✅ Saved 912: Swing Lynn by Harmless
# ✅ Saved 913: Thief by Ansel Elgort
# ✅ Saved 914: No Excuses by Meghan Trainor
# ✅ Saved 915: Gimme More by Britney Spears
# ✅ Saved 916: Skin by Rihanna
# ❌ Request timed out:
# HTTPSConnectionPool(host='genius.com', port=443): Read timed out. (read timeout=5)
# ✅ Saved 916: Skin by Rihanna
# ✅ Saved 917: Nights With You by MØ
# ✅ Saved 918: Don't Stay in School by Boyinaband
# ✅ Saved 919: Revolution by Diplo (Ft. Faustix, Imanos & ​kai)
# ✅ Saved 920: 불타오르네 (Burning Up) (Fire) by BTS
# ✅ Saved 921: YOLO by The Lonely Island (Ft. Adam Levine & Kendrick Lamar)
# ✅ Saved 922: Integrity by Jme
# ✅ Saved 923: Check It Out by Nicki Minaj & will.i.am
# ✅ Saved 924: Both Ways by Liam Payne
# ✅ Saved 925: This is What It Feels Like by BANKS
# ✅ Saved 926: Dooo It! by Miley Cyrus
# ✅ Saved 927: 1x1 by Bring Me The Horizon (Ft. Nova Twins)
# ✅ Saved 928: Dirty Sexy Money by David Guetta & AFROJACK (Ft. Charli XCX & French Montana)
# ✅ Saved 929: Come Up and Get Me by Death Grips
# ✅ Saved 930: Crack Baby by Mitski
# ✅ Saved 932: Habits of My Heart by Jaymes Young
# ✅ Saved 933: 666 ʇ by Bon Iver
# ✅ Saved 934: Domino by Jessie J
# ✅ Saved 935: Y.A.L.A. by M.I.A.
# ✅ Saved 936: Pretty Cvnt by Sewerslvt
# ✅ Saved 937: Do My Thang by Miley Cyrus
# ❌ Request timed out:
# HTTPSConnectionPool(host='genius.com', port=443): Read timed out. (read timeout=5)
# ✅ Saved 937: Do My Thang by Miley Cyrus
# ✅ Saved 938: Glad You Came by The Wanted
# ✅ Saved 939: New Divide by Linkin Park
# ✅ Saved 940: ​stupid horse by 100 gecs
# ✅ Saved 941: Dorak Gai - دورك جي by Wegz - ويجز
# ✅ Saved 942: BLACKPINK - 아니길 (Hope Not) (Romanized) by Genius Romanizations
# ✅ Saved 943: Outside by Calvin Harris (Ft. Ellie Goulding)
# ✅ Saved 944: Dímelo by Snakehips & Tory Lanez
# ✅ Saved 945: Bang Bang by ​will.i.am
# ✅ Saved 946: Ameno by ERA
# ✅ Saved 947: ​sex money feelings die by Lykke Li
# ✅ Saved 948: A Keeper by Drake
# ✅ Saved 949: Miss You by Oliver Tree & Robin Schulz
# ✅ Saved 950: Flicker by Porter Robinson
# ✅ Saved 951: Lighter by Nathan Dawe (Ft. KSI)
# ✅ Saved 952: On the Run by Pink Floyd
# ✅ Saved 953: Head.Cars.Bending by The 1975
# ✅ Saved 954: Lotus Flower by Radiohead
# ✅ Saved 955: IN THE SUMMER by 嵐 (ARASHI)
# ✅ Saved 956: Lovely by ​twenty one pilots
# ✅ Saved 957: Big Enough by Kirin J Callinan (Ft. Alex Cameron, Jimmy Barnes & Molly Lewis)
# ✅ Saved 958: Watch This by Lil Uzi Vert
# ✅ Saved 959: SMOKE IT OFF! by Lumi Athena & jnhygs
# ✅ Saved 960: Someone New by BANKS
# ✅ Saved 961: Akasaka Sad by Rina Sawayama
# ✅ Saved 962: Break Up Song by Little Mix
# ✅ Saved 963: Play by K-391, Alan Walker & Martin Tungevaag (Ft. Mangoo)
# ✅ Saved 964: Cut My Hair by Mounika. (Ft. Cavetown)
# ✅ Saved 965: Die Trying by Michl
# ✅ Saved 966: Mitsubishi Sony by Frank Ocean
# ✅ Saved 967: Whip It by Nicki Minaj
# ✅ Saved 968: Save Me by Nicki Minaj
# ✅ Saved 969: Runaway (U & I) by Galantis
# ✅ Saved 970: You & Me (Flume Remix) by Disclosure (Ft. ELIZA)
# ✅ Saved 971: PLASTIC OFF THE SOFA by Beyoncé
# ✅ Saved 972: Goodnight Gotham by Rihanna
# ✅ Saved 973: Don't Play by Anne-Marie, KSI & Digital Farm Animals
# ✅ Saved 974: ​moment by Vierre Cloud
# ✅ Saved 975: Dawn Chorus by Thom Yorke
# ✅ Saved 976: Winaloto by Tommy Cash
# ✅ Saved 977: Then by Anne-Marie
# ❌ Request timed out:
# HTTPSConnectionPool(host='genius.com', port=443): Read timed out. (read timeout=5)
# ✅ Saved 977: Then by Anne-Marie
# ❌ Request timed out:
# HTTPSConnectionPool(host='genius.com', port=443): Read timed out. (read timeout=5)
# ✅ Saved 977: Then by Anne-Marie
# ✅ Saved 978: Can’t Get You Out Of My Head by Kylie Minogue
# ✅ Saved 979: Fashion! by Lady Gaga
# ✅ Saved 980: Make Me Fade by K.Flay
# ✅ Saved 981: BLACKPINK - Really (English Translation) by Genius English Translations
# ✅ Saved 982: West End Girls by Pet Shop Boys
# ✅ Saved 983: Don't Kill My Vibe by Sigrid
# ✅ Saved 984: Overgrown by James Blake
# ✅ Saved 985: ​psychofreak by Camila Cabello (Ft. WILLOW)
# ✅ Saved 986: These Girls by Why Don't We
# ✅ Saved 987: ​bitches by Tove Lo
# ✅ Saved 988: I Dare You by The xx
# ✅ Saved 989: All Of Me by Big Gigantic (Ft. Logic & ROZES)
# ✅ Saved 990: Supplies by Justin Timberlake
# ✅ Saved 991: Астронавт (Astronaut) by ATL
# ✅ Saved 992: No Drama by Tinashe (Ft. Offset)
# ✅ Saved 993: Summertime by Vince Staples
# ✅ Saved 994: Been You by Justin Bieber
# ✅ Saved 995: Content by Bo Burnham
# ✅ Saved 996: Poppin by Yeat
# ✅ Saved 997: In Here Somewhere by Frank Ocean
# ✅ Saved 998: Грустная сука (Sad Bitch) by IC3PEAK
# ✅ Saved 999: Love Is Gone by SLANDER (Ft. Dylan Matthew)
