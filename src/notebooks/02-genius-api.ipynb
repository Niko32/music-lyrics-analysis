# %%
from dotenv import load_dotenv
import os
import lyricsgenius
import yaml
import tomllib

# %%
# Get credentials for the api calls from the .env file
# Niko has the credentials if you need them
load_dotenv()

# Get config entries
with open("../../config.toml", "rb") as f:
    config = tomllib.load(f)

# %%
genius = lyricsgenius.Genius()

# %%
# Scraping of all existing secondary tags on genius 
# has been done in src/notebooks/scrape-secondary-tags.ipynb
main_tags = ["country", "pop", "r-b", "rap", "rock"]
with open(config["data_dir"] + "/secondary_genres.yaml", "r") as f:
    secondary_tags = yaml.safe_load(f)

main_tags, secondary_tags
# Out:
# (['country', 'pop', 'r-b', 'rap', 'rock'],
#  ['abstract-rap',
#   'a-cappella',
#   'acid-house',
#   'acid-jazz',
#   'acid-techno',
#   'acoustic',
#   'adult-alternative',
#   'adult-contemporary',
#   'afro-arab',
#   'afrobeat',
#   'afrobeats',
#   'afro-hip-hop',
#   'afro-house',
#   'afro-jazz',
#   'afrosoul',
#   'afroswing',
#   'afro-trap',
#   'albanian-folk',
#   'album-oriented-rock-aor',
#   'algerian-rai',
#   'algerian-rap',
#   'alternative',
#   'alternative-country',
#   'alternative-dance',
#   'alternative-metal',
#   'alternative-pop',
#   'alternative-rap',
#   'alternative-r-b',
#   'alternative-rock',
#   'amapiano',
#   'ambient',
#   'ambient-dub',
#   'ambient-pop',
#   'americana',
#   'american-folk',
#   'american-underground',
#   'anarcho-punk',
#   'anime-lo-fi',
#   'anime-rap',
#   'anthem',
#   'anti-folk',
#   'arabic-diss',
#   'arabic-instrumental',
#   'arabic-pop',
#   'arabic-rap',
#   'arabic-rock',
#   'arrocha',
#   'art-pop',
#   'art-punk',
#   'art-rock',
#   'ashiq-music',
#   'atmospheric-black-metal',
#   'atmospheric-sludge-metal',
#   'aussie-drill',
#   'aussie-grime',
#   'aussie-hip-hop',
#   'avant-folk',
#   'avant-garde',
#   'avant-garde-metal',
#   'avant-pop',
#   'avant-prog',
#   'axe',
#   'azerbaijani-jazz',
#   'azerbaijani-pop',
#   'azerbaijani-r-b',
#   'azerbaijani-rap',
#   'azerbaijani-rock',
#   'azonto',
#   'bachata',
#   'balada',
#   'banda',
#   'bangla-hip-hop',
#   'bangla-pop',
#   'barcardi',
#   'bard-song',
#   'baroque-pop',
#   'bashkir-rap',
#   'bass-house',
#   'bass-trap',
#   'bassline',
#   'bass-music',
#   'battle-rap',
#   'beatbox',
#   'beatdown-hardcore',
#   'bebop',
#   'bedroom-pop',
#   'bestial-black-metal',
#   'big-band',
#   'big-room',
#   'bitpop',
#   'blackened-death-metal',
#   'blackened-hardcore',
#   'blackened-screamo',
#   'blackened-sludge-metal',
#   'blackened-thrash-metal',
#   'blackgaze',
#   'black-metal',
#   'black-n-roll',
#   'bluegrass',
#   'blues',
#   'blues-rock',
#   'bolero',
#   'bongo-flava',
#   'boogie',
#   'boom-bap',
#   'bosanski-folk',
#   'bosanski-jazz',
#   'bosanski-pop',
#   'bosanski-r-b',
#   'bosanski-rap',
#   'bosanski-rock',
#   'bosanski-sevdah',
#   'bossa-nova',
#   'bounce',
#   'bouyon',
#   'boy-band',
#   'brass-band',
#   'brass-trap',
#   'breakbeat',
#   'breakcore',
#   'brega',
#   'brega-funk',
#   'brill-building',
#   'british-folk',
#   'british-rock',
#   'britpop',
#   'broadway',
#   'brutal-death-metal',
#   'brutal-horrorcore',
#   'bubblegum-bass',
#   'bubblegum-dance',
#   'bubblegum-pop',
#   'burru',
#   'calabrian-rap',
#   'calypso',
#   'cameroonian-rap',
#   'candombe',
#   'cantopop',
#   'canzone-napoletana',
#   'canzone-romana',
#   'canzone-siciliana',
#   'carimbo',
#   'carranga',
#   'cartel',
#   'catalan-drill',
#   'catalan-music',
#   'catalan-pop',
#   'catalan-r-b',
#   'catalan-rap',
#   'catalan-rock',
#   'catalan-urban',
#   'celtic-punk',
#   'cesky-pop',
#   'cesky-preklad',
#   'cesky-rap',
#   'cesky-rock',
#   'cesky-trap',
#   'chamber-folk',
#   'chamber-music',
#   'chamber-pop',
#   'champeta',
#   'chanson',
#   'chap-hop',
#   'chicago-blues',
#   'chicago-drill',
#   'chicago-house',
#   'chicago-rap',
#   'childrens-music',
#   'chill',
#   'chillhop',
#   'chill-house',
#   'chillout',
#   'chillstep',
#   'chinese-folk',
#   'chinese-hip-hop',
#   'chipmunk-soul',
#   'chiptune',
#   'chopped-and-screwed',
#   'choral-music',
#   'christian',
#   'christian-metal',
#   'christian-pop',
#   'christian-punk',
#   'christian-rap',
#   'christian-r-b',
#   'christian-rock',
#   'christmas',
#   'chutney',
#   'cinematic',
#   'city-pop',
#   'classical-crossover',
#   'classical-music',
#   'cloud-rap',
#   'coladera',
#   'college-rock',
#   'color-bass',
#   'comedy',
#   'complextro',
#   'conscious-hip-hop',
#   'contemporary-folk',
#   'contemporary-r-b',
#   'corrido',
#   'corridos-tumbados',
#   'country-pop',
#   'country-rap',
#   'country-rock',
#   'cowpunk',
#   'c-pop',
#   'crnogorski-folk',
#   'crnogorski-pop',
#   'crnogorski-r-b',
#   'crnogorski-rap',
#   'crnogorski-rock',
#   'crossover-thrash',
#   'crunk',
#   'crushed-trap',
#   'crust-punk',
#   'cuarteto',
#   'cumbia',
#   'cybergrind',
#   'cyprus-pop',
#   'cyprus-rap',
#   'cyprus-rock',
#   'dance',
#   'dancehall',
#   'dance-pop',
#   'dance-punk',
#   'dance-rock',
#   'dariacore',
#   'dark-ambient',
#   'dark-cabaret',
#   'dark-folk',
#   'dark-jazz',
#   'dark-plugg',
#   'dark-pop',
#   'dark-trap',
#   'dark-wave',
#   'd-beat',
#   'deathcore',
#   'death-doom',
#   'deathgrind',
#   'death-metal',
#   'deconstructed-club',
#   'deep-house',
#   'dembow',
#   'desi-hip-hop',
#   'deutscher-jersey-club',
#   'deutschsprachige-musicals',
#   'deutschsprachiger-drill',
#   'deutschsprachiger-hyperpop',
#   'deutschsprachiger-phonk',
#   'deutschsprachiger-pop',
#   'deutschsprachiger-r-b',
#   'deutschsprachiger-rap',
#   'deutschsprachiger-rock',
#   'deutschsprachiger-trap',
#   'deutschsprachiges-detroit',
#   'digital-hardcore',
#   'dipset',
#   'dirty-south',
#   'disco',
#   'disco-polo',
#   'diy-punk',
#   'djent',
#   'doom-metal',
#   'doo-wop',
#   'downtempo',
#   'drain',
#   'dream-pop',
#   'drift-phonk',
#   'drill',
#   'drill-brasileiro',
#   'drill-farsi',
#   'drone',
#   'drone-metal',
#   'drum-and-bass',
#   'drumstep',
#   'dsbm-depressive-suicidal-black-metal',
#   'dub',
#   'dubstep',
#   'dub-techno',
#   'dungeon-synth',
#   'dutch-drill',
#   'dutch-rap',
#   'easycore',
#   'easy-listening',
#   'ebm',
#   'edm',
#   'egyptian-drill',
#   'egyptian-pop',
#   'egyptian-rap',
#   'electric-blues',
#   'electro',
#   'electroclash',
#   'electro-funk',
#   'electro-hop',
#   'electro-house',
#   'electro-industrial',
#   'electronic',
#   'electronica',
#   'electronicore',
#   'electronic-rock',
#   'electronic-trap',
#   'electro-pop',
#   'electro-soul',
#   'electro-swing',
#   'emo',
#   'emocore',
#   'emo-pop',
#   'emo-rap',
#   'emo-revival',
#   'emo-trap',
#   'emoviolence',
#   'espana',
#   'euphoric-hardstyle',
#   'eurobeat',
#   'eurodance',
#   'eurodisco',
#   'euro-house',
#   'europop',
#   'euro-reggae',
#   'eurotrance',
#   'experimental',
#   'experimental-folk',
#   'experimental-pop',
#   'experimental-rap',
#   'experimental-rock',
#   'extreme-metal',
#   'fado',
#   'fanchant',
#   'fandango',
#   'farsi-rap',
#   'filk',
#   'flamenco',
#   'folk',
#   'folklore',
#   'folk-metal',
#   'folk-pop',
#   'folk-punk',
#   'folk-rock',
#   'folktronica',
#   'footwork',
#   'forro',
#   'freak-folk',
#   'free-jazz',
#   'freestyle',
#   'french-country',
#   'french-dancehall',
#   'french-house',
#   'french-pop',
#   'french-r-b',
#   'french-rap',
#   'french-reggae',
#   'french-rock',
#   'french-soul',
#   'frevo',
#   'funana',
#   'funeral-doom',
#   'funk',
#   'funk-melody',
#   'funk-nacional',
#   'funk-pop',
#   'funk-rock',
#   'funky-house',
#   'future-bass',
#   'future-bounce',
#   'future-funk',
#   'future-garage',
#   'future-house',
#   'future-rave',
#   'future-riddim',
#   'gabber',
#   'gaeilge',
#   'gangsta-rap',
#   'garage-house',
#   'garage-punk',
#   'garage-rock',
#   'garage-rock-revival',
#   'georgian-folk',
#   'georgian-pop',
#   'georgian-rap',
#   'georgian-rock',
#   'g-funk',
#   'ghetto-house',
#   'girl-group',
#   'glam-metal',
#   'glam-punk',
#   'glam-rock',
#   'glitch',
#   'glitch-hop',
#   'gnaoui',
#   'goa-trance',
#   'go-go',
#   'goregrind',
#   'gospel',
#   'gothic-metal',
#   'gothic-rock',
#   'gqom',
#   'grime',
#   'grime-brasileiro-brazilian-grime',
#   'grindcore',
#   'groove-metal',
#   'grunge',
#   'guaracha',
#   'guasca',
#   'happy-hardcore',
#   'hard-bass',
#   'hard-bop',
#   'hardcore',
#   'hardcore-edm',
#   'hardcore-punk',
#   'hardcore-rap',
#   'hard-dance',
#   'hard-drill',
#   'hard-house',
#   'hard-rock',
#   'hardstyle',
#   'hard-trance',
#   'hardwave',
#   'harsh-noise',
#   'hawaiian',
#   'heartland-rock',
#   'heavy-metal',
#   'hexd',
#   'highlife',
#   'hi-nrg',
#   'hip-hop',
#   'hip-hop-tuga',
#   'hip-hop-viet',
#   'hip-house',
#   'holiday',
#   'hong-kong-indie',
#   'hong-kong-rap',
#   'honky-tonk',
#   'hookah-rap',
#   'horrorcore',
#   'horror-punk',
#   'house',
#   'hrvatski-jazz',
#   'hrvatski-pop',
#   'hrvatski-r-b',
#   'hrvatski-rap',
#   'hrvatski-rock',
#   'hybrid-trap',
#   'hymn',
#   'hyperpop',
#   'hyperpunk',
#   'hyphy',
#   'idm',
#   'impressionism',
#   'indian-classical',
#   'indian-pop',
#   'indie',
#   'indie-electronic',
#   'indie-folk',
#   'indie-pop',
#   'indie-rap',
#   'indie-rock',
#   'industrial',
#   'industrial-hip-hop',
#   'industrial-metal',
#   'industrial-rock',
#   'industrial-techno',
#   'infantil',
#   'iranian-pop',
#   'iranian-rap',
#   'irish-drill',
#   'irish-folk',
#   'irish-rap',
#   'isicathamiya',
#   'islamic',
#   'island-music',
#   'israeli-children-songs',
#   'israeli-classic',
#   'israeli-country',
#   'israeli-drill',
#   'israeli-folk',
#   'israeli-funk',
#   'israeli-grundge',
#   'israeli-hip-hop',
#   'israeli-metal',
#   'israeli-music',
#   'israeli-pop',
#   'israeli-punk',
#   'israeli-r-b',
#   'israeli-rap',
#   'israeli-reggae',
#   'israeli-rock',
#   'israeli-soul',
#   'israeli-trap',
#   'israeli-yam-tichoni',
#   'italo-disco',
#   'ivona',
#   'jangle-pop',
#   'jazz',
#   'jazz-contrafact',
#   'jazz-funk',
#   'jazz-fusion',
#   'jazz-rap',
#   'jazz-rock',
#   'jersey-club',
#   'jewish',
#   'joik',
#   'j-pop',
#   'j-rap',
#   'j-rock',
#   'jump-blues',
#   'jumpstyle',
#   'jungle',
#   'kazakh-rap',
#   'k-ballad',
#   'k-chinese',
#   'k-hip-hop',
#   'k-idon-hip-hop',
#   'k-indie',
#   'kizomba',
#   'k-japanese',
#   'k-ost',
#   'k-pop',
#   'k-r-b',
#   'krautrock',
#   'k-rock',
#   'k-solo',
#   'kuduro',
#   'kultura-w-rapie',
#   'kuwaiti-rap',
#   'kwaito',
#   'kwela',
#   'lambada',
#   'latin-drill',
#   'latin-freestyle-edm',
#   'latin-house',
#   'latin-jazz',
#   'latin-music',
#   'latin-pop',
#   'latin-r-b',
#   'latin-rap',
#   'latin-reggae',
#   'latin-rock',
#   'latin-trap',
#   'latin-urban',
#   'lebanese-rap',
#   'liquid-drum-and-bass',
#   'liscio',
#   'lo-fi',
#   'lok-dohori',
#   'lok-geet',
#   'louisiana-blues',
#   'lounge',
#   'lovers-rock',
#   'lowercase',
#   'lullaby',
#   'macedonian-folk',
#   'macedonian-pop',
#   'macedonian-r-b',
#   'macedonian-rap',
#   'macedonian-rock',
#   'madchester',
#   'magyar-drill',
#   'magyar-rap',
#   'mahraganat',
#   'makina',
#   'malaysian-dangdut',
#   'malaysian-rap',
#   'mambo',
#   'mandopop',
#   'manele',
#   'mantra',
#   'marabi',
#   'marchinha',
#   'mariachi',
#   'maskhandi',
#   'mathcore',
#   'math-metal',
#   'math-rock',
#   'mbaganga',
#   'melbourne-bounce',
#   'melodic-death-metal',
#   'melodic-dubstep',
#   'melodic-hardcore',
#   'melodic-house',
#   'melodic-metalcore',
#   'melodic-riddim',
#   'melodic-techno',
#   'meme-rap',
#   'mental-health',
#   'mento',
#   'merengue',
#   'merengue-tipico',
#   'metal',
#   'metalcore',
#   'meykhana',
#   'miami-bass',
#   'midtempo',
#   'midwest-emo',
#   'minimalism',
#   'minimal-techno',
#   'modern-classical',
#   'moldovan-pop',
#   'moombahton',
#   'morna',
#   'moroccan-rap',
#   'mortuary',
#   'motown',
#   'motswako',
#   'mpb-musica-popular-brasileira',
#   'mugham',
#   'murder-ballad',
#   'murga',
#   'musicals',
#   'musik-fur-kinder',
#   'musique-concrete',
#   'muzik-popullore',
#   'mystic',
#   'nasheed',
#   'neocrust',
#   'neofolk',
#   'neomelodica',
#   'neoperreo',
#   'neo-psychedelia',
#   'neo-soul',
#   'nep-hop',
#   'nerdcore',
#   'neue-deutsche-harte',
#   'neue-deutsche-welle',
#   'new-age',
#   'new-jack-swing',
#   'new-orleans-r-b',
#   'new-wave',
#   'new-york-drill',
#   'nigerian-rap',
#   'nightcore',
#   'nintendocore',
#   'noise',
#   'noisecore',
#   'noise-pop',
#   'noise-rock',
#   'norsk-country',
#   'norsk-julemusikk',
#   'norsk-pop',
#   'norsk-r-b',
#   'norsk-rap',
#   'norsk-rock',
#   'nortena',
#   'no-wave',
#   'nu-disco',
#   'nueva-cancion',
#   'nueva-trova',
#   'nu-jazz',
#   'nu-metal',
#   'nu-rave',
#   'oi',
#   'opera',
#   'operetta',
#   'opm',
#   'orchestral',
#   'otaku-music',
#   'otaku-rap',
#   'otaku-trap',
#   'outlaw-country',
#   'outsider-music',
#   'pagode',
#   'pagode-baiano',
#   'pakistani-pop',
#   'palestinian-rap',
#   'parody',
#   'partyschlager',
#   'persian-rock',
#   'persian-traditional-music',
#   'p-funk',
#   'phonk',
#   'piano',
#   'piano-house',
#   'piano-rock',
#   'pink-noise',
#   'pinoy-hip-hop',
#   'pirate-metal',
#   'piseiro',
#   'planete-rap',
#   'plena-uruguaya',
#   'plunderphonics',
#   'plugg',
#   'pluggnb',
#   'polka',
#   'polskie-disco-polo',
#   'polski-folk',
#   'polski-freestyle',
#   'polski-pop',
#   'polski-rap',
#   'polski-rock',
#   'polynesian-reggae',
#   'pop-italiano',
#   'pop-melayu',
#   'pop-punk',
#   'pop-r-b',
#   'pop-rap',
#   'pop-reggae',
#   'pop-rock',
#   'posse-cut',
#   'post-black-metal',
#   'post-bop',
#   'post-britpop',
#   'post-dubstep',
#   'post-grunge',
#   'post-hardcore',
#   'post-metal',
#   'post-minimalism',
#   'post-punk',
#   'post-punk-revival',
#   'post-rap',
#   'post-rock',
#   'post-screamo',
#   'power-metal',
#   'power-pop',
#   'powerviolence',
#   'p-pop',
#   'progressive-death-metal',
#   'progressive-electronic',
#   'progressive-house',
#   'progressive-metal',
#   'progressive-metalcore',
#   'progressive-pop',
#   'progressive-rock',
#   'progressive-trance',
#   'proto-manele',
#   'proto-punk',
#   'psychedelic',
#   'psychedelic-rock',
#   'psychedelic-soul',
#   'psychedelic-trance',
#   'psychobilly',
#   'punk-pathetique',
#   'punk-revival',
#   'punk-rock',
#   'qawwali',
#   'q-pop',
#   'queercore',
#   'raga-rock',
#   'rage',
#   'ragga',
#   'ragtime',
#   'rai',
#   'ranchera',
#   'r-b-viet',
#   'rapcore',
#   'rap-italiano',
#   'rap-metal',
#   'rap-napoletano',
#   'rap-rock',
#   'rastafarian',
#   'rawstyle',
#   'red-dirt',
#   'reggae',
#   'reverse-bass',
#   'reggae-rock',
#   'reggaeton',
#   'regional-mexicano',
#   'reparterismo',
#   'retro',
#   'rhythm-and-grime',
#   'riddim',
#   'riot-grrrl',
#   'ritual-rap',
#   'rkt',
#   'road-rap',
#   'rockabilly',
#   'rock-gaucho',
#   'rocksteady',
#   'rock-viet',
#   'romanian-drill',
#   'romansh',
#   'roots',
#   'roots-reggae',
#   'rub-a-dub',
#   'rumba',
#   'russemusikk',
#   'russian-battle-rap',
#   'russian-chanson',
#   'russian-country',
#   'russian-drill',
#   'russian-grime',
#   'russian-hyperpop',
#   'russian-jazz',
#   'russian-pop',
#   'russian-punk-rock',
#   'russian-r-b',
#   'russian-rap',
#   'russian-rave',
#   'russian-reggae',
#   'russian-rock',
#   'russian-trap',
#   'russian-underground',
#   'sab-hop',
#   'salsa',
#   'samba',
#   'samba-reggae',
#   'samba-rock',
#   'saudi-rap',
#   'scam-rap',
#   'scandipop',
#   'scenecore',
#   'schlager',
#   'scottish-folk',
#   'screamo',
#   'sea-shanty',
#   'semba',
#   'sertenejo',
#   'shaabi',
#   'shibuya-kei',
#   'shoegaze',
#   'sicilian-rap',
#   'sierreno',
#   'sindicat',
#   'sinogrime',
#   'sigilkore',
#   'ska',
#   'skacore',
#   'ska-punk',
#   'skate-punk',
#   'skhanda-rap',
#   'slam-metal',
#   'slap-house',
#   'slay',
#   'slovenian-pop',
#   'slovenian-rap',
#   'slovenian-rock',
#   'slovensky-pop',
#   'slovensky-rap',
#   'slowcore',
#   'slowed-and-reverb',
#   'sludge-metal',
#   'smooth-jazz',
#   'soca',
#   'soft-house',
#   'soft-rock',
#   'sophisti-pop',
#   'soul',
#   'soul-jazz',
#   'soul-pop',
#   'soul-rap',
#   'sound-collage',
#   'southern-rock',
#   'soviet-estrada',
#   'soviet-jazz',
#   'soviet-rap',
#   'soviet-rock',
#   'soviet-samizdat',
#   'space-rock',
#   'spanish-drill',
#   'spanish-pop',
#   'spanish-r-b',
#   'spanish-rap',
#   'spanish-rock',
#   'spanish-urban',
#   'sped-up',
#   'speedcore',
#   'speed-metal',
#   'spiritual',
#   'spiritual-jazz',
#   'srpski-folk',
#   'srpski-jazz',
#   'srpski-pop',
#   'srpski-r-b',
#   'srpski-rap',
#   'srpski-rock',
#   'steampunk',
#   'stomp-and-holler',
#   'stoner-metal',
#   'stoner-rock',
#   'sto-pro-rap',
#   'straightedge',
#   'street-punk',
#   'sunshine-pop',
#   'suomi-drill',
#   'suomi-pop',
#   'suomi-rap',
#   'suomirock',
#   'suomi-underground-rap',
#   'supertrap',
#   'surf',
#   'surf-punk',
#   'surf-rock',
#   'surge',
#   'svensk-country',
#   'svensk-pop',
#   'svensk-r-b',
#   'svensk-rap',
#   'svensk-rock',
#   'swedish-folk',
#   'swing',
#   'symphonic-black-metal',
#   'symphonic-metal',
#   'symphonic-power-metal',
#   'symphonic-rock',
#   'synth-funk',
#   'synth-pop',
#   'synth-punk',
#   'synth-rock',
#   'synthwave',
#   'tai-pop',
#   'tango',
#   'taqwacore',
#   'tarraxinha',
#   'tech-house',
#   'technical-death-metal',
#   'technical-thrash-metal',
#   'techno',
#   'techno-rap',
#   'tecnobrega',
#   'teen-pop',
#   'thai-pop',
#   'thai-rap',
#   'third-stream',
#   'thrash-metal',
#   'time-lord-rock-trock',
#   'toasting',
#   'togo-pop',
#   'togo-rap',
#   'togo-trap',
#   'tontipop',
#   'traditional-folk',
#   'trallpunk',
#   'trance',
#   'trap',
#   'trap-dancehall',
#   'trap-metal',
#   'trap-rock',
#   'trapwave',
#   'tread',
#   'tribal',
#   'trip-hop',
#   'tropical-house',
#   'trot',
#   'trova',
#   'tunisian-rap',
#   'turkce-alternatif',
#   'turkce-drill',
#   'turkce-folk',
#   'turkce-pop',
#   'turkce-r-b',
#   'turkce-rap',
#   'turkce-rock',
#   'turkce-trap',
#   'two-tone',
#   'uk-drill',
#   'uk-funky',
#   'uk-garage',
#   'uk-pop',
#   'ukrainian-drill',
#   'ukrainian-pop',
#   'ukrainian-rap',
#   'ukrainian-rock',
#   'ukrainian-trap',
#   'uk-r-b',
#   'uk-rap',
#   'ukulele',
#   'underground-rap',
#   'underground-soul',
#   'vallenato',
#   'valsa',
#   'vaporwave',
#   'variete-francaise',
#   'via',
#   'viking-metal',
#   'vise-visa',
#   'vispop',
#   'vocaloid',
#   'volksmusik',
#   'v-pop',
#   'weirdcore',
#   'western-swing',
#   'witch-house',
#   'wizard-rock-wrock',
#   'worship',
#   'xote',
#   'yacht-rock',
#   'yiddish',
#   'yu-mex',
#   'zouk',
#   'z-pop',
#   'zydeco',
#   'atlanta-rap',
#   'bay-area-rap',
#   'chicago-rap',
#   'detroit-rap',
#   'dmv-rap',
#   'florida-rap',
#   'memphis-rap',
#   'new-york',
#   'quebec-rap',
#   'texas-rap',
#   'afghanistan',
#   'albania',
#   'algeria',
#   'andorra',
#   'angola',
#   'arabia',
#   'argentina',
#   'armenia',
#   'aruba',
#   ...])

# %%
# Try to find all songs for a specified genre
abstract_rap_songs = genius.tag("abstract-rap")["hits"]

# %%
# These are appearently not all songs yet
len(abstract_rap_songs)
# Out:
# 20

# %%
feel_good_inc = abstract_rap_songs[2]
feel_good_inc
# Out:
# {'url': 'https://genius.com/Gorillaz-feel-good-inc-lyrics',
#  'title_with_artists': 'Feel Good Inc. by Gorillaz (Ft. De La Soul)',
#  'title': 'Feel Good Inc.',
#  'artists': ['Gorillaz'],
#  'featured_artists': ['De La Soul']}

# %%
# Print the lyrics for a specific song
print(genius.lyrics(song_url=feel_good_inc["url"]))
# Out:
# 348 ContributorsTranslationsPolskiItalianoNederlandsFeel Good Inc. Lyrics[Intro: Maseo & 2-D]
# Hahahahahahahahahahahahahahahahaha
# Feel good
# Sha, sha-ba-da, sha-ba-da-ca; feel good
# Sha, sha-ba-da, sha-ba-da-ca; feel good
# Sha, sha-ba-da, sha-ba-da-ca; feel good
# Sha, sha-ba-da, sha-ba-da-ca; feel good
# Sha, sha-ba-da, sha-ba-da-ca; feel good
# Sha, sha-ba-da, sha-ba-da-ca; feel good
# (Change, change, change, change)
# Sha, sha-ba-da, sha-ba-da-ca; feel good
# (Change, change, change, change)
# Sha, sha-ba-da, sha-ba-da-ca; feel good
#
# [Verse 1: 2-D]
# City's breaking down on a camel's back
# They just have to go, 'cause they don't know wack
# So while you fill the streets, it's appealing to see
# And you won't get out the county 'cause you're damned and free
# You got a new horizon, its ephemeral style
# A melancholy town where we never smile
# And all I wanna hear is the message beep
# My dreams, they've got to kiss me 'cause I don't get to sleep, no
# (Beep)
#
# [Chorus: 2-D]
# Windmill, windmill for the land
# Turn forever, hand in hand
# Take it all in on your stride
# It is ticking, falling down
# Love forever, love is free
# Let's turn forever, you and me
# Windmill, windmill for the land
# Is everybody in?
# You might also like[Verse 2: Trugoy the Dove]
# Laughin' gas, these hazmats, fast cats
# Linin' 'em up like ass cracks
# Play these ponies at the track
# It's my chocolate attack
# Shit, I'm steppin' in the heart of this here (Yeah)
# Care Bear repping in harder this year (Yeah)
# Watch me as I gravitate, ha-ha-ha-ha-ha!
# Yo, we gon' ghost town this Motown
# With yo' sound, you in the blink
# Gon' bite the dust, can't fight with us
# With yo' sound, you kill the Inc
# So don't stop, get it, get it (Get it)
# Until you're cheddar headed
# And watch the way I navigate, hahahahaha
# (Ha! Haha! Haha! Haha! Ha!)
#
# [Refrain: 2-D]
# Sha, sha-ba-da, sha-ba-da-ca; feel good
# Sha, sha-ba-da, sha-ba-da-ca; feel good
# Sha, sha-ba-da, sha-ba-da-ca; feel good
# Sha, sha-ba-da, sha-ba-da-ca; feel good
#
# [Chorus: 2-D]
# Windmill, windmill for the land
# Turn forever, hand in hand
# Take it all in on your stride
# It is ticking, falling down
# Love forever, love is free
# Let's turn forever, you and me
# Windmill, windmill for the land
# Is everybody in?
# [Outro: Trugoy the Dove & 2-D]
# Don't stop, get it, get it, peep how your captain's in it
# (Sha, sha-ba-da, sha-ba-da-ca; feel good)
# Steady, watch me navigate, ha-ha-ha-ha-ha!
# (Sha, sha-ba-da, sha-ba-da-ca; feel good)
# Don't stop, get it, get it, peep how your captain's in it
# (Sha, sha-ba-da, sha-ba-da-ca; feel good)
# Steady, watch me navigate, ha-ha-ha-ha-ha!
# (Sha, sha-ba-da, sha-ba-da-ca; feel good)
# Sha, sha-ba-da, sha-ba-da-ca; feel good (Hahaha!)
# Sha, sha-ba-da, sha-ba-da-ca; feel good (Hahaha!)
# Sha, sha-ba-da, sha-ba-da-ca; feel good (Hahaha!)
# Sha, sha-ba-da, sha-ba-da-ca; feel good (Hahahahahaha!)303Embed

# %%
abstract_rap_songs[:2]
# Out:
# [{'url': 'https://genius.com/Childish-gambino-iv-sweatpants-lyrics',
#   'title_with_artists': 'IV. Sweatpants by Childish Gambino',
#   'title': 'IV. Sweatpants',
#   'artists': ['Childish Gambino'],
#   'featured_artists': []},
#  {'url': 'https://genius.com/Tyler-the-creator-yonkers-lyrics',
#   'title_with_artists': 'Yonkers by Tyler, The Creator',
#   'title': 'Yonkers',
#   'artists': ['Tyler, The Creator'],
#   'featured_artists': []},
#  {'url': 'https://genius.com/Gorillaz-feel-good-inc-lyrics',
#   'title_with_artists': 'Feel Good Inc. by Gorillaz (Ft. De La Soul)',
#   'title': 'Feel Good Inc.',
#   'artists': ['Gorillaz'],
#   'featured_artists': ['De La Soul']}]

# %%
# The page feature can be used to find 20 more songs
genius.tag("abstract-rap", page=2)["hits"][:2]
# Out:
# [{'url': 'https://genius.com/Chance-the-rapper-acid-rain-lyrics',
#   'title_with_artists': 'Acid Rain by Chance the Rapper',
#   'title': 'Acid Rain',
#   'artists': ['Chance the Rapper'],
#   'featured_artists': []},
#  {'url': 'https://genius.com/A-ap-rocky-phoenix-lyrics',
#   'title_with_artists': 'Phoenix by A$AP Rocky',
#   'title': 'Phoenix',
#   'artists': ['A$AP Rocky'],
#   'featured_artists': []}]

# %%
# Download 1000 songs for the every genre
for genre in config["genres"]:

    # Iterate through pages of songs in genius
    titles = []
    lyrics = []
    all_songs = []
    for i in range(1, 51):
        songs_on_page = genius.tag(genre, page=i)["hits"]
        for song in songs_on_page:
            title = song["title_with_artists"]

            # A Page "Behind The Lyrics" appeared in the country songs
            # This is not a song and is filtered out
            if title.startswith("Behind The Lyrics"):
                continue

            all_songs.append(song)
            print(f"Saved '{title}'")

    with open(f"{config['multilabel_data_dir']}/songs/{genre}.yml", "w") as f:
        yaml.safe_dump(all_songs, f)
    print(f"Succsefffully saved {genre} songs")
# Out:
# Saved 'Despacito (Remix) by Luis Fonsi & Daddy Yankee (Ft. Justin Bieber)'
# Saved 'Shape of You by Ed Sheeran'
# Saved 'The Hills by The Weeknd'
# Saved 'Bohemian Rhapsody by Queen'
# Saved 'God's Plan by Drake'
# Saved '​thank u, next by Ariana Grande'
# Saved 'Drunk in Love by Beyoncé (Ft. JAY-Z)'
# Saved 'Starboy by The Weeknd (Ft. Daft Punk)'
# Saved '1-800-273-8255 by Logic (Ft. Alessia Cara & Khalid)'
# Saved 'Work by Rihanna (Ft. Drake)'
# Saved 'SAD! by XXXTENTACION'
# Saved 'Too Good at Goodbyes by Sam Smith'
# Saved '7 rings by Ariana Grande'
# Saved 'In My Feelings by Drake'
# Saved 'Trap Queen by Fetty Wap'
# Saved '​​rockstar by Post Malone (Ft. 21 Savage)'
# Saved 'Hotline Bling by Drake'
# Saved 'Perfect by Ed Sheeran'
# Saved 'Closer by The Chainsmokers (Ft. Halsey)'
# Saved 'Believer by Imagine Dragons'
# Saved '​i​ hate u, i love u by ​gnash (Ft. Olivia O'Brien)'
# Saved 'Swimming Pools (Drank) by Kendrick Lamar'
# Saved 'Money Trees by Kendrick Lamar (Ft. Jay Rock)'
# Saved 'Formation by Beyoncé'
# Saved 'One Dance by Drake (Ft. Kyla & Wizkid)'
# Saved 'Old Town Road (Remix) by Lil Nas X (Ft. Billy Ray Cyrus)'
# Saved 'FRIENDS by Marshmello & Anne-Marie'
# Saved 'Hold On, We're Going Home by Drake (Ft. Majid Jordan)'
# Saved 'I'm the One by DJ Khaled (Ft. Chance the Rapper, Justin Bieber, Lil Wayne & Quavo)'
# Saved 'Hello by Adele'
# Saved 'This Is America by Childish Gambino'
# Saved 'The Twelve Days of Christmas by Christmas Songs'
# Saved 'All of Me by John Legend'
# Saved 'Father Stretch My Hands, Pt. 1 by Kanye West (Ft. Kid Cudi)'
# Saved 'Bitch, Don't Kill My Vibe by Kendrick Lamar'
# Saved 'The Monster by Eminem (Ft. Rihanna)'
# Saved 'Caroline by Aminé'
# Saved 'Thrift Shop by Macklemore & Ryan Lewis (Ft. Wanz)'
# Saved '​iSpy by KYLE (Ft. Lil Yachty)'
# Saved 'Blurred Lines by Robin Thicke (Ft. Pharrell Williams & T.I.)'
# Saved 'Poetic Justice by Kendrick Lamar (Ft. Drake)'
# Saved 'Fly Me to the Moon by Frank Sinatra & Count Basie'
# Saved 'Say You Won't Let Go by James Arthur'
# Saved 'New Rules by Dua Lipa'
# Saved 'Ultralight Beam by Kanye West (Ft. Chance the Rapper, Kelly Price, Kirk Franklin & The-Dream)'
# Saved 'See You Again by Wiz Khalifa (Ft. Charlie Puth)'
# Saved 'Love Yourself by Justin Bieber'
# Saved 'Can't Feel My Face by The Weeknd'
# Saved '​drivers license by Olivia Rodrigo'
# Saved 'Bound 2 by Kanye West'
# Saved '679 by Fetty Wap (Ft. Monty, P-Dice & Remy Boyz)'
# Saved 'City of Stars by Ryan Gosling & Emma Stone'
# Saved '​lovely by Billie Eilish & Khalid'
# Saved 'Mirrors by Justin Timberlake'
# Saved 'All Too Well (10 Minute Version) (Taylor's Version) [From The Vault] by Taylor Swift'
# Saved 'White Iverson by Post Malone'
# Saved 'Can't Hold Us by Macklemore & Ryan Lewis (Ft. Ray Dalton)'
# Saved 'Jingle Bells by Christmas Songs'
# Saved 'Dynamite by BTS'
# Saved 'Get Lucky by Daft Punk (Ft. Nile Rodgers & Pharrell Williams)'
# Saved 'Sign of the Times by Harry Styles'
# Saved 'Havana by Camila Cabello (Ft. Young Thug)'
# Saved 'Attention by Charlie Puth'
# Saved 'Despacito by Luis Fonsi (Ft. Daddy Yankee)'
# Saved 'Running Up That Hill (A Deal with God) by Kate Bush'
# Saved 'Something Just Like This by The Chainsmokers & Coldplay'
# Saved 'A Million Dreams by Ziv Zaifman, Hugh Jackman & Michelle Williams'
# Saved '​when the party's over by Billie Eilish'
# Saved '7 Years by Lukas Graham'
# Saved 'Dusk Till Dawn by ZAYN (Ft. Sia)'
# Saved 'Thinkin Bout You by Frank Ocean'
# Saved 'As It Was by Harry Styles'
# Saved 'Happier Than Ever by Billie Eilish'
# Saved 'Die For You by The Weeknd'
# Saved 'Revenge by XXXTENTACION'
# Saved 'All Too Well (10 Minute Version) (Taylor's Version) [Live Acoustic] by Taylor Swift'
# Saved 'V. 3005 by Childish Gambino'
# Saved '​bad guy by Billie Eilish'
# Saved 'Psycho by Post Malone (Ft. Ty Dolla $ign)'
# Saved 'Issues by Julia Michaels'
# Saved 'Butter by BTS'
# Saved 'Nights by Frank Ocean'
# Saved 'The Box by Roddy Ricch'
# Saved 'Rewrite the Stars by Zac Efron & Zendaya'
# Saved 'Someone You Loved by Lewis Capaldi'
# Saved 'Girls Like You (Remix) by Maroon 5 (Ft. Cardi B)'
# Saved 'Reminder by The Weeknd'
# Saved 'Revenge by CaptainSparklez (Ft. TryHardNinja)'
# Saved 'Let Me Love You by DJ Snake (Ft. Justin Bieber)'
# Saved 'Cupid (Twin Version) by FIFTY FIFTY (피프티피프티)'
# Saved 'Papaoutai by Stromae'
# Saved 'Mo Bamba by Sheck Wes'
# Saved '​God is a woman by Ariana Grande'
# Saved '​everything i wanted by Billie Eilish'
# Saved 'Partition by Beyoncé'
# Saved 'Happier by Marshmello & Bastille'
# Saved 'Call Out My Name by The Weeknd'
# Saved 'River by Eminem (Ft. Ed Sheeran)'
# Saved '藤井 風 (Fujii Kaze) - 死ぬのがいいわ (Shinunoga E-Wa) (Romanized) by Genius Romanizations'
# Saved 'Him & I by G-Eazy & Halsey'
# Saved '​cardigan by Taylor Swift'
# Saved 'Can't Help Falling in Love by Elvis Presley'
# Saved 'Passionfruit by Drake'
# Saved 'Poker Face by Lady Gaga'
# Saved '​changes by XXXTENTACION (Ft. PnB Rock)'
# Saved 'Nice For What by Drake'
# Saved 'Side To Side by Ariana Grande (Ft. Nicki Minaj)'
# Saved 'ELEMENT. by Kendrick Lamar'
# Saved 'Heathens by ​twenty one pilots'
# Saved 'Sunflower by Post Malone & Swae Lee'
# Saved 'That's What I Like by Bruno Mars'
# Saved 'Stressed Out by ​twenty one pilots'
# Saved 'Baby by Justin Bieber (Ft. Ludacris)'
# Saved 'Look at Me Now by Chris Brown (Ft. Busta Rhymes & Lil Wayne)'
# Saved 'Lose You To Love Me by Selena Gomez'
# Saved 'Berzerk by Eminem'
# Saved '​idontwannabeyouanymore by Billie Eilish'
# Saved 'Self Control by Frank Ocean'
# Saved 'Señorita by Shawn Mendes & Camila Cabello'
# Saved '​​no tears left to cry by Ariana Grande'
# Saved 'Up by Cardi B'
# Saved 'SLOW DANCING IN THE DARK by Joji'
# Saved '​hot girl bummer by ​blackbear'
# Saved '34+35 by Ariana Grande'
# Saved 'Slide by Calvin Harris (Ft. Frank Ocean & Migos)'
# Saved 'Runaway by Kanye West (Ft. Pusha T)'
# Saved 'Young Dumb & Broke by Khalid'
# Saved 'O Holy Night by Christmas Songs'
# Saved 'Easy On Me by Adele'
# Saved 'I Fall Apart by Post Malone'
# Saved 'Too Good by Drake (Ft. Rihanna)'
# Saved 'Chanel by Frank Ocean'
# Saved 'It Ain't Me by Kygo & Selena Gomez'
# Saved 'Ivy by Frank Ocean'
# Saved '​deja vu by Olivia Rodrigo'
# Saved 'Pink Matter by Frank Ocean (Ft. André 3000)'
# Saved 'Blinding Lights by The Weeknd'
# Saved 'This Is Me by Keala Settle & The Greatest Showman Ensemble'
# Saved '​i (Album Version) by Kendrick Lamar'
# Saved 'Your Song by Elton John'
# Saved '​good 4 u by Olivia Rodrigo'
# Saved 'Finesse (Remix) by Bruno Mars (Ft. Cardi B)'
# Saved 'Stay With Me by Sam Smith'
# Saved 'All Star by Smash Mouth'
# Saved 'Me, Myself & I by G-Eazy & Bebe Rexha'
# Saved 'Cocoa Butter Kisses by Chance the Rapper (Ft. Twista & VIC MENSA)'
# Saved 'Sorry by Justin Bieber'
# Saved '​bury a friend by Billie Eilish'
# Saved 'Never Gonna Give You Up by Rick Astley'
# Saved 'Love the Way You Lie by Eminem (Ft. Rihanna)'
# Saved 'Often by The Weeknd'
# Saved 'Pumped Up Kicks by Foster the People'
# Saved 'Halo by Beyoncé'
# Saved '​exile by Taylor Swift (Ft. Bon Iver)'
# Saved 'Old Town Road by Lil Nas X'
# Saved 'MONTERO (Call Me By Your Name) by Lil Nas X'
# Saved 'Gangsta's Paradise by Coolio (Ft. L.V. (South Central Cartel))'
# Saved 'The Schuyler Sisters by Phillipa Soo, Jasmine Cephas-Jones, Leslie Odom, Jr., Original Broadway Cast of "Hamilton" & Renée Elise Goldsberry'
# Saved 'There's Nothing Holdin' Me Back by Shawn Mendes'
# Saved 'I Will Always Love You by Whitney Houston'
# Saved 'The Greatest Show by Hugh Jackman, Keala Settle, Zac Efron, Zendaya & The Greatest Showman Ensemble'
# Saved 'Famous by Kanye West (Ft. Rihanna)'
# Saved 'Come and See Me by PARTYNEXTDOOR (Ft. Drake)'
# Saved '​break up with your girlfriend, i'm bored by Ariana Grande'
# Saved 'Feels by Calvin Harris (Ft. Big Sean, Katy Perry & Pharrell Williams)'
# Saved 'Gone by ROSÉ'
# Saved 'Everybody Wants to Rule the World by Tears for Fears'
# Saved 'Pyramids by Frank Ocean'
# Saved 'Bad Things by ​mgk & Camila Cabello'
# Saved 'You'll Be Back by Jonathan Groff & Original Broadway Cast of "Hamilton"'
# Saved 'Lover by Taylor Swift'
# Saved 'Without Me by Halsey'
# Saved 'All I Want for Christmas Is You by Mariah Carey'
# Saved 'Nikes by Frank Ocean'
# Saved 'Te Boté (Remix) by Nio García, Casper Mágico & Bad Bunny (Ft. Darell, Nicky Jam & Ozuna)'
# Saved '​vampire by Olivia Rodrigo'
# Saved 'Kill Bill by SZA'
# Saved 'Sorry Not Sorry by Demi Lovato'
# Saved 'Heartless by The Weeknd'
# Saved 'Be Careful by Cardi B'
# Saved '松原みき (Miki Matsubara) - 真夜中のドア / Stay With Me (Mayonaka no Door) (Romanized) by Genius Romanizations'
# Saved 'Love on the Brain by Rihanna'
# Saved 'INDUSTRY BABY by Lil Nas X & Jack Harlow'
# Saved 'Dance Monkey by Tones and I'
# Saved 'Is It Over Now? (Taylor's Version) [From The Vault] by Taylor Swift'
# Saved 'Feel Good Inc. by Gorillaz (Ft. De La Soul)'
# Saved '​the 1 by Taylor Swift'
# Saved 'Wolves by Kanye West (Ft. Sia & VIC MENSA)'
# Saved 'Riptide by Vance Joy'
# Saved '​​death bed (coffee for your head) by Powfu & beabadoobee'
# Saved 'Real Friends by Kanye West (Ft. Ty Dolla $ign)'
# Saved 'Needed Me by Rihanna'
# Saved 'All The Stars by Kendrick Lamar & SZA'
# Saved 'See You Again by Tyler, The Creator (Ft. Kali Uchis)'
# Saved 'Gold Digger by Kanye West (Ft. Jamie Foxx)'
# Saved '​august by Taylor Swift'
# Saved 'Royals by Lorde'
# Saved '​i love you by Billie Eilish'
# Saved 'I Feel It Coming by The Weeknd (Ft. Daft Punk)'
# Saved 'SpongeBob SquarePants Theme Song by SpongeBob SquarePants'
# Saved 'Circles by Post Malone'
# Saved 'Happy by Pharrell Williams'
# Saved 'Wicked Games by The Weeknd'
# Saved 'Anaconda by Nicki Minaj'
# Saved 'You Are The Reason by Calum Scott'
# Saved 'If I Were a Boy by Beyoncé'
# Saved 'Watermelon Sugar by Harry Styles'
# Saved 'Castle On The Hill by Ed Sheeran'
# Saved 'BTS – 봄날 (Spring Day) (English Translation) by Genius English Translations'
# Saved 'Super Rich Kids by Frank Ocean (Ft. Earl Sweatshirt)'
# Saved 'Freaky Friday by Lil Dicky (Ft. Chris Brown)'
# Saved 'Sweater Weather by The Neighbourhood'
# Saved 'Total Eclipse of the Heart by Bonnie Tyler'
# Saved 'Truth Hurts by Lizzo'
# Saved 'Happier by Ed Sheeran'
# Saved 'Somebody That I Used To Know by Gotye (Ft. Kimbra)'
# Saved 'After Hours by The Weeknd'
# Saved 'Chandelier by Sia'
# Saved 'Versace on the Floor by Bruno Mars'
# Saved 'Never Enough by Loren Allred'
# Saved 'Thinking Out Loud by Ed Sheeran'
# Saved 'Instant Crush by Daft Punk (Ft. Julian Casablancas)'
# Saved 'My Way by Frank Sinatra'
# Saved 'Unholy by Sam Smith & Kim Petras'
# Saved 'Stay by Zedd & Alessia Cara'
# Saved '​​breathin by Ariana Grande'
# Saved 'White Ferrari by Frank Ocean'
# Saved 'Look What You Made Me Do by Taylor Swift'
# Saved 'Pink + White by Frank Ocean'
# Saved 'Yummy by Justin Bieber'
# Saved 'YOASOBI - アイドル (Idol) (Romanized) by Genius Romanizations'
# Saved 'Never Be The Same by Camila Cabello'
# Saved 'Burn by Phillipa Soo'
# Saved 'Silent Night by Christmas Songs'
# Saved 'Supermarket Flowers by Ed Sheeran'
# Saved 'Leave The Door Open by Silk Sonic'
# Saved 'Bad Religion by Frank Ocean'
# Saved 'Cruel Summer by Taylor Swift'
# Saved 'Stand By Me by Ben E. King'
# Saved 'Earth by Lil Dicky'
# Saved 'NEW MAGIC WAND by Tyler, The Creator'
# Saved 'Faded by Alan Walker'
# Saved 'Someone Like You by Adele'
# Saved 'Perfect Duet by Ed Sheeran & Beyoncé'
# Saved 'Hey Ya! by OutKast'
# Saved 'Controlla by Drake'
# Saved 'ROCKSTAR by DaBaby (Ft. Roddy Ricch)'
# Saved 'Young and Beautiful by Lana Del Rey'
# Saved 'Your Power by Billie Eilish'
# Saved 'U With Me? by Drake'
# Saved 'Stuck with U by Ariana Grande & Justin Bieber'
# Saved '​positions by Ariana Grande'
# Saved '90210 by Travis Scott (Ft. Kacy Hill)'
# Saved 'A Thousand Years by Christina Perri'
# Saved 'Taki Taki by DJ Snake (Ft. Cardi B, Ozuna & Selena Gomez)'
# Saved 'Non-Stop by Leslie Odom, Jr., Lin-Manuel Miranda, Phillipa Soo, Christopher Jackson, Original Broadway Cast of "Hamilton" & Renée Elise Goldsberry'
# Saved 'Mine by Beyoncé (Ft. Drake)'
# Saved 'No Guidance by Chris Brown (Ft. Drake)'
# Saved 'Not Afraid by Eminem'
# Saved 'I Took a Pill in Ibiza by Mike Posner'
# Saved 'Teenage Fever by Drake'
# Saved 'Devil In a New Dress by Kanye West (Ft. Rick Ross)'
# Saved 'Let You Down by NF'
# Saved 'Speechless (Full) by Naomi Scott'
# Saved '​champagne problems by Taylor Swift'
# Saved 'The Sound of Silence by Simon & Garfunkel'
# Saved 'Saint Pablo by Kanye West (Ft. Sampha)'
# Saved 'Save Your Tears by The Weeknd'
# Saved 'Dark Fantasy by Kanye West'
# Saved 'Flowers by Miley Cyrus'
# Saved 'Tuyo by Rodrigo Amarante'
# Saved 'Helpless by Phillipa Soo & Original Broadway Cast of "Hamilton"'
# Saved 'Thunder by Imagine Dragons'
# Saved 'Style by Taylor Swift'
# Saved 'Falling by Harry Styles'
# Saved 'Flawless Remix by Beyoncé (Ft. Nicki Minaj)'
# Saved 'Goldie by A$AP Rocky'
# Saved 'FML by Kanye West (Ft. The Weeknd)'
# Saved 'How Far I'll Go by Auli'i Cravalho'
# Saved 'Waves by Kanye West (Ft. Chris Brown)'
# Saved 'Party Monster by The Weeknd'
# Saved 'Stay by Rihanna (Ft. Mikky Ekko)'
# Saved 'All of the Lights by Kanye West'
# Saved 'Get You by Daniel Caesar (Ft. Kali Uchis)'
# Saved 'Billie Jean by Michael Jackson'
# Saved 'Silence by Marshmello (Ft. Khalid)'
# Saved 'Gorgeous by Kanye West (Ft. Kid Cudi & Raekwon)'
# Saved 'Somebody Else by The 1975'
# Saved 'No Scrubs (With Rap) by TLC'
# Saved 'DUCKWORTH. by Kendrick Lamar'
# Saved 'Eastside by ​benny blanco, Halsey & Khalid'
# Saved 'Born in the U.S.A. by Bruce Springsteen'
# Saved 'Mine by Bazzi'
# Saved 'Swalla by Jason Derulo (Ft. Nicki Minaj & Ty Dolla $ign)'
# Saved 'Still into You by Paramore'
# Saved 'The Middle by Zedd, Maren Morris & Grey'
# Saved 'I Have Nothing by Whitney Houston'
# Saved '​wish you were gay by Billie Eilish'
# Saved 'No Time To Die by Billie Eilish'
# Saved 'Galway Girl by Ed Sheeran'
# Saved 'YOSEMITE by Travis Scott (Ft. Gunna & NAV)'
# Saved 'Better by Khalid'
# Saved 'Rockabye by Clean Bandit (Ft. Anne-Marie & Sean Paul)'
# Saved 'Scared to Be Lonely by Martin Garrix & Dua Lipa'
# Saved 'Mask by Dream'
# Saved 'Memories by Maroon 5'
# Saved 'Kiss from a Rose by Seal'
# Saved 'I'm Still Standing by Elton John'
# Saved 'Anti-Hero by Taylor Swift'
# Saved 'Swish Swish by Katy Perry (Ft. Nicki Minaj)'
# Saved 'You’re Losing Me (From The Vault) by Taylor Swift'
# Saved 'Bom Diggy by Zack Knight & Jasmin Walia'
# Saved 'Better Now by Post Malone'
# Saved 'Here by Alessia Cara'
# Saved 'Lost On You by LP'
# Saved 'Teenage Dirtbag by Wheatus'
# Saved 'High Hopes by Panic! at the Disco'
# Saved 'BTS - Magic Shop (English Translation) by Genius English Translations'
# Saved 'Sweet but Psycho by Ava Max'
# Saved '​​ocean eyes by Billie Eilish'
# Saved 'Super Bass by Nicki Minaj'
# Saved 'Blank Space by Taylor Swift'
# Saved '​my tears ricochet by Taylor Swift'
# Saved 'Earned It by The Weeknd'
# Saved 'Way Back Home (Sam Feldt Edit) by SHAUN (숀) (Ft. Conor Maynard)'
# Saved 'The Cuppycake Song by Buddy Castle (Ft. Amy Castle)'
# Saved 'End Game by Taylor Swift (Ft. Ed Sheeran & Future)'
# Saved 'Feel No Ways by Drake'
# Saved 'Titibo-tibo by Moira Dela Torre'
# Saved 'Strip That Down by Liam Payne (Ft. Quavo)'
# Saved 'Let Her Go by Passenger'
# Saved 'As Long As You Love Me by Justin Bieber (Ft. Big Sean)'
# Saved '​tolerate it by Taylor Swift'
# Saved 'Photograph by Ed Sheeran'
# Saved '24K Magic by Bruno Mars'
# Saved 'Back To You by Louis Tomlinson (Ft. Bebe Rexha & Digital Farm Animals)'
# Saved 'Therefore I Am by Billie Eilish'
# Saved 'You're Welcome by Dwayne Johnson'
# Saved 'The Other Side by Hugh Jackman & Zac Efron'
# Saved 'Sofia the First Main Title Theme by Cast of Sofia the First (Ft. Ariel Winter)'
# Saved 'We Are Young by ​fun. (Ft. Janelle Monáe)'
# Saved 'Smooth Criminal by Michael Jackson'
# Saved 'What Lovers Do by Maroon 5 (Ft. SZA)'
# Saved 'BTS - FAKE LOVE (English Translation) by Genius English Translations'
# Saved 'Emotionless by Drake'
# Saved 'BTS - 전하지 못한 진심 (The Truth Untold) ft. Steve Aoki (English Translation) by Genius English Translations'
# Saved 'We Don't Talk Anymore by Charlie Puth (Ft. Selena Gomez)'
# Saved 'Team by Lorde'
# Saved 'HiiiPoWeR by Kendrick Lamar'
# Saved 'Best Friend by Rex Orange County'
# Saved 'Ms. Jackson by OutKast'
# Saved 'Summertime Sadness by Lana Del Rey'
# Saved 'Don't Stop Me Now by Queen'
# Saved '...Ready for It? by Taylor Swift'
# Saved 'Where Is the Love? by Black Eyed Peas (Ft. Justin Timberlake)'
# Saved 'No Diggity by Blackstreet (Ft. Dr. Dre & Queen Pen)'
# Saved 'Wonderwall by Oasis'
# Saved 'Don't Start Now by Dua Lipa'
# Saved 'Amorfoda by Bad Bunny'
# Saved 'Favorite Song by Chance the Rapper (Ft. Childish Gambino)'
# Saved 'Yellow by Coldplay'
# Saved 'Luis Fonsi & Daddy Yankee - Despacito (Remix) ft. Justin Bieber (English Translation) by Genius English Translations'
# Saved 'NO by Meghan Trainor'
# Saved 'Dernière Danse by Indila'
# Saved 'In My Blood by Shawn Mendes'
# Saved 'Little Einsteins Theme Song by Billy Straus'
# Saved 'Adore You by Harry Styles'
# Saved 'I Don't Care by Ed Sheeran & Justin Bieber'
# Saved 'I'm Yours by Jason Mraz'
# Saved 'Treat You Better by Shawn Mendes'
# Saved 'A Whole New World by Lea Salonga & Brad Kane'
# Saved 'Counting Stars by OneRepublic'
# Saved '​imagine by Ariana Grande'
# Saved '​willow by Taylor Swift'
# Saved 'Lemonade by Internet Money, Gunna & Don Toliver (Ft. NAV)'
# Saved 'Stronger by Kanye West'
# Saved '​pov by Ariana Grande'
# Saved '10,000 Hours by Dan + Shay & Justin Bieber'
# Saved 'Wasted Times by The Weeknd'
# Saved 'Promiscuous by Nelly Furtado (Ft. Timbaland)'
# Saved 'FourFiveSeconds by Rihanna, Kanye West & Paul McCartney'
# Saved '"Slut!" (Taylor's Version) [From The Vault] by Taylor Swift'
# Saved 'Boyfriend by Ariana Grande & Social House'
# Saved 'Zona Nyaman by Fourtwnty'
# Saved 'Tell Your Friends by The Weeknd'
# Saved 'Falling Down by Lil Peep & XXXTENTACION'
# Saved 'You Need To Calm Down by Taylor Swift'
# Saved 'Say So by Doja Cat'
# Saved 'Sunflower by Rex Orange County'
# Saved 'My Love Mine All Mine by Mitski'
# Saved 'L-O-V-E by Nat "King" Cole'
# Saved 'Kiss Me More by Doja Cat (Ft. SZA)'
# Saved 'Mi Gente by J Balvin & Willy William'
# Saved 'Peaches by Justin Bieber (Ft. Daniel Caesar & GIVĒON)'
# Saved 'Say Something by A Great Big World & Christina Aguilera'
# Saved 'FEEL. by Kendrick Lamar'
# Saved 'Cold Water by Major Lazer (Ft. Justin Bieber & MØ)'
# Saved 'Dive by Ed Sheeran'
# Saved 'ME! by Taylor Swift (Ft. Brendon Urie)'
# Saved 'Before You Go by Lewis Capaldi'
# Saved 'Rather Be by Clean Bandit (Ft. Jess Glynne)'
# Saved 'Downtown by Macklemore & Ryan Lewis (Ft. Eric Nally, Grandmaster Caz, Grandmaster Melle Mel & Kool Moe Dee)'
# Saved 'Sucker for Pain by Lil Wayne, Wiz Khalifa, Imagine Dragons, Logic & Ty Dolla $ign (Ft. X Ambassadors)'
# Saved 'Ayo by Chris Brown & Tyga'
# Saved 'BAD! by XXXTENTACION'
# Saved '​needy by Ariana Grande'
# Saved 'The Morning by The Weeknd'
# Saved 'Take On Me by ​a-ha'
# Saved 'Solo by Frank Ocean'
# Saved 'Kailash Kher - Saiyyan (Romanized) by Genius Romanizations'
# Saved 'Bad Romance by Lady Gaga'
# Saved 'Lemon by N.E.R.D & Rihanna'
# Saved 'Bang Bang by Jessie J, Ariana Grande & Nicki Minaj'
# Saved 'You're On Your Own, Kid by Taylor Swift'
# Saved 'How Deep Is Your Love by Calvin Harris & Disciples'
# Saved 'Arms Around You by XXXTENTACION & Lil Pump (Ft. Maluma & Swae Lee)'
# Saved 'Maroon by Taylor Swift'
# Saved 'Everyday by A$AP Rocky (Ft. Mark Ronson, Miguel & Rod Stewart)'
# Saved '​ghostin by Ariana Grande'
# Saved 'All Too Well by Taylor Swift'
# Saved '​yes, and? by Ariana Grande'
# Saved '​Tous les mêmes by Stromae'
# Saved 'American Boy by Estelle (Ft. Kanye West)'
# Saved '​my future by Billie Eilish'
# Saved 'Bitch Lasagna by PewDiePie & Party in Backyard'
# Saved '마지막처럼 (AS IF IT'S YOUR LAST) by BLACKPINK'
# Saved 'Forrest Gump by Frank Ocean'
# Saved 'Wolves by Selena Gomez & Marshmello'
# Saved 'Swang by Rae Sremmurd'
# Saved 'Colors by Halsey'
# Saved 'Back To You by Selena Gomez'
# Saved 'Until I Found You by Stephen Sanchez'
# Saved 'Feel It Still by Portugal. The Man'
# Saved 'I Want It That Way by Backstreet Boys'
# Saved '​happier by Olivia Rodrigo'
# Saved '​in my head by Ariana Grande'
# Saved 'SugarCrash! by ElyOtto'
# Saved '​invisible string by Taylor Swift'
# Saved 'Glimpse of Us by Joji'
# Saved 'BLACKPINK - 뚜두뚜두 (DDU-DU DDU-DU) (Romanized) by Genius Romanizations'
# Saved 'Cheap Thrills by Sia'
# Saved 'When I Was Your Man by Bruno Mars'
# Saved 'Ride by ​twenty one pilots'
# Saved '​seven by Taylor Swift'
# Saved 'Can't Take My Eyes Off You by Frankie Valli'
# Saved 'What Do You Mean? by Justin Bieber'
# Saved 'BTS - 작은 것들을 위한 시 (Boy With Luv) ft. Halsey (Romanized) by Genius Romanizations'
# Saved 'Work It by Missy Elliott'
# Saved 'Agora Hills by Doja Cat'
# Saved 'Demons by Imagine Dragons'
# Saved 'Over the Rainbow by Judy Garland'
# Saved 'Barbie Girl by Aqua'
# Saved 'Now That We Don't Talk (Taylor's Version) [From The Vault] by Taylor Swift'
# Saved 'Need To Know by Doja Cat'
# Saved 'Juice by Chance the Rapper'
# Saved 'Uptown Funk by Mark Ronson (Ft. Bruno Mars)'
# Saved 'Fetish by Selena Gomez (Ft. Gucci Mane)'
# Saved 'Seigfried by Frank Ocean'
# Saved 'Ice Cream by BLACKPINK & Selena Gomez'
# Saved 'Fix You by Coldplay'
# Saved 'Youngblood by 5 Seconds of Summer'
# Saved 'Bennie and the Jets by Elton John'
# Saved 'Chlorine by ​twenty one pilots'
# Saved 'KONSTRUKT by Booking Machine (Ft. JEEMBO, Loqiemean, Markul, May Wave$, Oxxxymiron, PORCHY, SOULOUD, Thomas Mraz & TVETH)'
# Saved 'Only One by Kanye West (Ft. Paul McCartney)'
# Saved 'Heather by Conan Gray'
# Saved 'Wait a Minute! by WILLOW'
# Saved 'Heat Waves by Glass Animals'
# Saved 'Keep the Family Close by Drake'
# Saved '2002 by Anne-Marie'
# Saved 'The Fairly Oddparents Theme Song by The Fairly Odd Parents'
# Saved 'Kahit Ayaw Mo Na by This Band'
# Saved 'BTS - Pied Piper (English Translation) by Genius English Translations'
# Saved '9 by Drake'
# Saved '​the last great american dynasty by Taylor Swift'
# Saved 'PILLOWTALK by ZAYN'
# Saved 'Say No to This by Jasmine Cephas-Jones, Leslie Odom, Jr., Lin-Manuel Miranda, Sydney James Harcourt & Original Broadway Cast of "Hamilton"'
# Saved 'FAKE LOVE by BTS'
# Saved 'You're a Mean One, Mr. Grinch by Thurl Ravenscroft'
# Saved 'Heartless by Kanye West'
# Saved 'Pusha Man/Paranoia by Chance the Rapper (Ft. Lili K & Nate Fox)'
# Saved 'L$D by A$AP Rocky'
# Saved 'The Greatest by Sia (Ft. Kendrick Lamar)'
# Saved 'Go Flex by Post Malone'
# Saved 'All I Want by Olivia Rodrigo'
# Saved '​traitor by Olivia Rodrigo'
# Saved 'Delicate by Taylor Swift'
# Saved 'American Pie by Don McLean'
# Saved 'Blem by Drake'
# Saved 'Locked Out Of Heaven by Bruno Mars'
# Saved 'We Belong Together by Mariah Carey'
# Saved 'Whatever It Takes by Imagine Dragons'
# Saved 'RAPSTAR by Polo G'
# Saved 'STAY by The Kid LAROI & Justin Bieber'
# Saved 'Call It What You Want by Taylor Swift'
# Saved 'A&W by Lana Del Rey'
# Saved 'IDGAF by Dua Lipa'
# Saved 'Flashing Lights by Kanye West (Ft. Dwele)'
# Saved 'Perfect Symphony by Ed Sheeran & Andrea Bocelli'
# Saved 'Beautiful by Katie Ladner, Alice Lee, Jessica Keenan Wynn, Barrett Wilbert Weed, & Elle McLemore'
# Saved 'Under Pressure by Queen & David Bowie'
# Saved 'Hey Jude by The Beatles'
# Saved '​pete davidson by Ariana Grande'
# Saved '​this is me trying by Taylor Swift'
# Saved 'Legacy by Eminem'
# Saved 'Glorious by Macklemore (Ft. Skylar Grey)'
# Saved 'Don't by Ed Sheeran'
# Saved 'Perfect Strangers by Jonas Blue (Ft. JP Cooper)'
# Saved 'BTS - Life Goes On (English Translation) by Genius English Translations'
# Saved 'Space Oddity by David Bowie'
# Saved 'Good News by Mac Miller'
# Saved 'I’m Not The Only One by Sam Smith'
# Saved '​all the good girls go to hell by Billie Eilish'
# Saved '​illicit affairs by Taylor Swift'
# Saved 'BTS - Euphoria (English Translation) by Genius English Translations'
# Saved 'Fashion Killa by A$AP Rocky'
# Saved '​happiness by Taylor Swift'
# Saved 'YAH. by Kendrick Lamar'
# Saved 'Scars to Your Beautiful by Alessia Cara'
# Saved 'The A Team by Ed Sheeran'
# Saved 'Main Title (From "Family Guy") by Family Guy'
# Saved '​xanny by Billie Eilish'
# Saved 'Wannabe by Spice Girls'
# Saved 'King of the Fall by The Weeknd'
# Saved 'Question...? by Taylor Swift'
# Saved 'In the Night by The Weeknd'
# Saved 'Regular (English Ver.) by NCT 127'
# Saved 'One More Light by Linkin Park'
# Saved 'Pursuit of Happiness (Nightmare) by Kid Cudi (Ft. MGMT & Ratatat)'
# Saved '​you should see me in a crown by Billie Eilish'
# Saved 'How Far I'll Go by Alessia Cara'
# Saved '​do re mi by ​blackbear'
# Saved 'In Your Eyes by The Weeknd'
# Saved 'Lost in Japan by Shawn Mendes'
# Saved 'Don't Mind by Kent Jones'
# Saved '​ivy by Taylor Swift'
# Saved 'Fine Line by Harry Styles'
# Saved 'Burn by USHER'
# Saved '...Baby One More Time by Britney Spears'
# Saved '藤井風 (Fujii Kaze) - 死ぬのがいいわ (Shinunoga E-Wa) (English Translation) by Genius English Translations'
# Saved 'Levitating by Dua Lipa'
# Saved 'Say Don't Go (Taylor's Version) [From The Vault] by Taylor Swift'
# Saved 'Acquainted by The Weeknd'
# Saved 'Money for Nothing by Dire Straits'
# Saved 'Diamonds by Rihanna'
# Saved 'First Class by Jack Harlow'
# Saved 'Love Story by Taylor Swift'
# Saved 'If I Ain't Got You by Alicia Keys'
# Saved 'Let Me Love You by Ariana Grande (Ft. Lil Wayne)'
# Saved 'When We Were Young by Adele'
# Saved 'Highlights by Kanye West (Ft. The-Dream & Young Thug)'
# Saved 'Sanctuary by Joji'
# Saved 'Wanna Be Startin' Somethin' by Michael Jackson'
# Saved 'Goodbyes by Post Malone (Ft. Young Thug)'
# Saved 'Gold by Kiiara'
# Saved 'One Last Time by Ariana Grande'
# Saved 'Pokémon Theme (Gotta Catch ’Em All!) by Pokémon (Ft. Jason Paige)'
# Saved 'Skin by Sabrina Carpenter'
# Saved 'Formidable by Stromae'
# Saved 'Habits (Stay High) by Tove Lo'
# Saved 'Snow On The Beach by Taylor Swift (Ft. Lana Del Rey)'
# Saved 'Daddy Issues by The Neighbourhood'
# Saved '​bellyache by Billie Eilish'
# Saved 'Love by Lana Del Rey'
# Saved 'Video Games by Lana Del Rey'
# Saved 'Pills N Potions by Nicki Minaj'
# Saved 'Paris by The Chainsmokers'
# Saved 'BLACKPINK - Kill This Love (Romanized) by Genius Romanizations'
# Saved 'For You by Liam Payne & Rita Ora'
# Saved 'Godspeed by Frank Ocean'
# Saved 'MIA by Bad Bunny (Ft. Drake)'
# Saved '​sweetener by Ariana Grande'
# Saved 'MIC Drop (Steve Aoki Remix) by BTS'
# Saved 'Heavy by Linkin Park (Ft. Kiiara)'
# Saved 'Shake It Off by Taylor Swift'
# Saved 'Love It If We Made It by The 1975'
# Saved '​ilomilo by Billie Eilish'
# Saved 'What a Wonderful World by Louis Armstrong'
# Saved 'Fade by Kanye West (Ft. Post Malone & Ty Dolla $ign)'
# Saved 'BLOOD. by Kendrick Lamar'
# Saved 'Hits Different by Taylor Swift'
# Saved 'Payphone by Maroon 5 (Ft. Wiz Khalifa)'
# Saved '***Flawless by Beyoncé (Ft. Chimamanda Ngozi Adichie)'
# Saved 'Cake By The Ocean by DNCE'
# Saved 'In the Name of Love by Martin Garrix & Bebe Rexha'
# Saved 'Homecoming by Kanye West (Ft. Chris Martin)'
# Saved 'Real by Kendrick Lamar (Ft. Anna Wise)'
# Saved 'Purple Rain by Prince and the Revolution'
# Saved 'It Wasn't Me by Shaggy (Ft. Rikrok)'
# Saved 'Mastermind by Taylor Swift'
# Saved 'Build a Bitch by Bella Poarch'
# Saved 'Bad Blood (Remix) by Taylor Swift (Ft. Kendrick Lamar)'
# Saved 'Dark Horse by Katy Perry (Ft. Juicy J)'
# Saved 'Karma by Taylor Swift'
# Saved 'Bad at Love by Halsey'
# Saved 'Back to Black by Amy Winehouse'
# Saved 'Run This Town by JAY-Z (Ft. Kanye West & Rihanna)'
# Saved 'Bunny Girl - 不可思議のカルテ (Fukashigi No Karte) (Romanized) by Genius Romanizations'
# Saved 'Would've, Could've, Should've by Taylor Swift'
# Saved 'Bad Habits by Ed Sheeran'
# Saved '​listen before i go by Billie Eilish'
# Saved 'Here Comes the Sun by The Beatles'
# Saved 'House of Balloons / Glass Table Girls by The Weeknd'
# Saved 'Born To Die by Lana Del Rey'
# Saved 'Lust for Life by Lana Del Rey (Ft. The Weeknd)'
# Saved 'Barbie Tingz by Nicki Minaj'
# Saved 'Liability by Lorde'
# Saved '​my strange addiction by Billie Eilish'
# Saved 'Gasolina by Daddy Yankee'
# Saved 'Robbers by The 1975'
# Saved 'Yonaguni by Bad Bunny'
# Saved '​get him back! by Olivia Rodrigo'
# Saved 'Fancy by Iggy Azalea (Ft. Charli XCX)'
# Saved 'Akad by Payung Teduh'
# Saved 'They Don't Care About Us by Michael Jackson'
# Saved 'Rain On Me by Lady Gaga & Ariana Grande'
# Saved 'Be Alright by Dean Lewis'
# Saved 'BTS - Life Goes On (Romanized) by Genius Romanizations'
# Saved '​​the grudge by Olivia Rodrigo'
# Saved 'How to Save a Life by The Fray'
# Saved 'Carmen by Stromae'
# Saved 'Vienna by Billy Joel'
# Saved 'My Heart Will Go On by Céline Dion'
# Saved 'How Deep Is Your Love by Bee Gees'
# Saved '​R.E.M. by Ariana Grande'
# Saved 'Medicine by Harry Styles'
# Saved 'Sweet Dreams (Are Made of This) by Eurythmics'
# Saved 'Welcome to the Black Parade by My Chemical Romance'
# Saved 'Money Longer by Lil Uzi Vert'
# Saved 'Boy’s a liar Pt. 2 by PinkPantheress & Ice Spice'
# Saved 'High Fashion by Roddy Ricch (Ft. Mustard)'
# Saved 'Reggaetón Lento (Remix) by CNCO & Little Mix'
# Saved 'Maria I'm Drunk by Travis Scott (Ft. Justin Bieber & Young Thug)'
# Saved 'Panini by Lil Nas X'
# Saved 'GREECE by DJ Khaled (Ft. Drake)'
# Saved 'Thriller by Michael Jackson'
# Saved 'JENNIE - SOLO (Romanized) by Genius Romanizations'
# Saved '​greedy by Tate McRae'
# Saved 'Gotta Go My Own Way by High School Musical Cast'
# Saved 'Girls Like You by Maroon 5'
# Saved 'COPYCAT by Billie Eilish'
# Saved 'TAEYANG - 눈, 코, 입 (EYES, NOSE, LIPS) (Romanized) by Genius Romanizations'
# Saved 'Set Fire to the Rain by Adele'
# Saved 'Waves by Mr. Probz'
# Saved 'Bruises by Lewis Capaldi'
# Saved 'GONE, GONE / THANK YOU by Tyler, The Creator'
# Saved '​evermore by Taylor Swift (Ft. Bon Iver)'
# Saved 'BTS - 소우주 (Mikrokosmos) (English Translation) by Genius English Translations'
# Saved 'Symphony by Clean Bandit (Ft. Zara Larsson)'
# Saved 'Dream Song by Taylor Lautner (Ft. Lavagirl)'
# Saved 'Sa Ngalan Ng Pag-Ibig by December Avenue'
# Saved 'Getaway Car by Taylor Swift'
# Saved 'Suit & Tie by Justin Timberlake (Ft. JAY-Z)'
# Saved 'Praying by Kesha'
# Saved 'Malibu by Miley Cyrus'
# Saved 'Under the Bridge by Red Hot Chili Peppers'
# Saved 'Matilda by Harry Styles'
# Saved 'One More Night by Maroon 5'
# Saved 'Sugar by Maroon 5'
# Saved '​lacy by Olivia Rodrigo'
# Saved 'Swim Good by Frank Ocean'
# Saved 'Cherry by Harry Styles'
# Saved 'Nico And The Niners by ​twenty one pilots'
# Saved 'Wrecking Ball by Miley Cyrus'
# Saved 'Some Nights by ​fun.'
# Saved 'Dick by StarBoi3 (Ft. Doja Cat)'
# Saved 'Falling by Trevor Daniel'
# Saved 'We Are Never Ever Getting Back Together by Taylor Swift'
# Saved 'Thunderclouds by LSD'
# Saved 'Gorgeous by Taylor Swift'
# Saved 'More Than You Know by Axwell Λ Ingrosso'
# Saved 'Permission to Dance by BTS'
# Saved 'Get You the Moon by Kina (Ft. Snøw)'
# Saved 'Circle of Life by Carmen Twillie & Lebo M'
# Saved 'J'me tire by Gims'
# Saved 'Sucker by Jonas Brothers'
# Saved 'Don't Wanna Know by Maroon 5 (Ft. Kendrick Lamar)'
# Saved 'Roses by OutKast'
# Saved 'Umbrella by Rihanna (Ft. JAY-Z)'
# Saved '99 Luftballons by Nena'
# Saved 'Day ‘N’ Nite (Nightmare) by Kid Cudi'
# Saved 'Jaded by Drake'
# Saved 'Vigilante Shit by Taylor Swift'
# Saved 'I Don't Wanna Live Forever by ZAYN & Taylor Swift'
# Saved 'Bad Liar by Selena Gomez'
# Saved 'NASA by Ariana Grande'
# Saved 'Green Light by Lorde'
# Saved 'The Party & The After Party by The Weeknd'
# Saved 'Angel by The Weeknd'
# Saved 'Wouldn't Leave by Kanye West (Ft. PARTYNEXTDOOR)'
# Saved 'Lean On by Major Lazer (Ft. DJ Snake & MØ)'
# Saved 'Waterfalls by TLC'
# Saved '​gold rush by Taylor Swift'
# Saved '봄날 (Spring Day) by BTS'
# Saved 'Let Me Love You by Mario'
# Saved ''Di Na Muli by Janine Teñoso'
# Saved 'Something by The Beatles'
# Saved 'Informer by Snow (Ft. MC Shan)'
# Saved '​peace by Taylor Swift'
# Saved 'Don't Blame Me by Taylor Swift'
# Saved 'If The World Was Ending by JP Saxe (Ft. Julia Michaels)'
# Saved 'All I Want by Kodaline'
# Saved 'Show Yourself by Idina Menzel & Evan Rachel Wood'
# Saved 'Dilemma by Nelly (Ft. Kelly Rowland)'
# Saved 'Daddy Issues (Remix) by The Neighbourhood & Syd'
# Saved 'Party in the U.S.A. by Miley Cyrus'
# Saved 'KANA-BOON - Silhouette (Romanized) by Genius Romanizations'
# Saved 'Apocalypse by Cigarettes After Sex'
# Saved 'Slow Hands by Niall Horan'
# Saved 'Try Me by The Weeknd'
# Saved 'Love Like You by Rebecca Sugar'
# Saved 'With You by Drake (Ft. PARTYNEXTDOOR)'
# Saved 'Yeah! by USHER (Ft. Lil Jon & Ludacris)'
# Saved 'Little Dark Age by MGMT'
# Saved 'I Was Never There by The Weeknd & Gesaffelstein'
# Saved 'Hollywood's Bleeding by Post Malone'
# Saved 'Каждый раз (Every Time) by Монеточка (Monetochka)'
# Saved 'Perfect by One Direction'
# Saved 'BTS - Answer: Love Myself (English Translation) by Genius English Translations'
# Saved 'Car Radio by ​twenty one pilots'
# Saved 'Shameless by The Weeknd'
# Saved 'Lights Up by Harry Styles'
# Saved '​bloodline by Ariana Grande'
# Saved 'Rolling Stone by The Weeknd'
# Saved 'It's Quiet Uptown by Lin-Manuel Miranda, Phillipa Soo, Original Broadway Cast of "Hamilton" & Renée Elise Goldsberry'
# Saved 'Runaway by AURORA'
# Saved 'Midnight Rain by Taylor Swift'
# Saved 'Holy by Justin Bieber (Ft. Chance the Rapper)'
# Saved '​imase - NIGHT DANCER (Romanized) by Genius Romanizations'
# Saved 'Chained To The Rhythm by Katy Perry (Ft. Skip Marley)'
# Saved 'First Love / Late Spring by Mitski'
# Saved 'How Long by Charlie Puth'
# Saved 'Euphoria by BTS'
# Saved 'Norman fucking Rockwell by Lana Del Rey'
# Saved 'Say So (Remix) by Doja Cat (Ft. Nicki Minaj)'
# Saved 'Di Matamu by Sufian Suhaimi'
# Saved 'The Archer by Taylor Swift'
# Saved 'STFU by Pink Guy'
# Saved 'Solo by Clean Bandit (Ft. Demi Lovato)'
# Saved 'BTS - Blue & Grey (English Translation) by Genius English Translations'
# Saved 'Radioactive by Imagine Dragons'
# Saved 'River by Bishop Briggs'
# Saved '1950 by King Princess'
# Saved 'Privilege by The Weeknd'
# Saved '​brutal by Olivia Rodrigo'
# Saved 'Winter Bear by V (뷔)'
# Saved 'Lost by Chance the Rapper (Ft. Noname)'
# Saved 'Reborn by KIDS SEE GHOSTS'
# Saved 'Used To Be Young by Miley Cyrus'
# Saved '전하지 못한 진심 (The Truth Untold) by BTS (Ft. Steve Aoki)'
# Saved 'Shankar Mahadevan - Breathless (Romanized) by Genius Romanizations'
# Saved 'Careless Whisper by George Michael'
# Saved '​all-american bitch by Olivia Rodrigo'
# Saved '​favorite crime by Olivia Rodrigo'
# Saved 'It Will Rain by Bruno Mars'
# Saved 'No Surprises by Radiohead'
# Saved 'Love of My Life by Queen'
# Saved 'Eleanor Rigby by The Beatles'
# Saved 'Futura Free by Frank Ocean'
# Saved 'The Knife Game Song by Rusty Cage'
# Saved 'Whopper Whopper by Burger King'
# Saved 'Jealous by Labrinth'
# Saved 'Dress by Taylor Swift'
# Saved 'One Kiss by Calvin Harris & Dua Lipa'
# Saved 'Starman by David Bowie'
# Saved 'On The Ground by ROSÉ'
# Saved 'All I Ask by Adele'
# Saved 'Auntie Diaries by Kendrick Lamar'
# Saved 'Say My Name by Original Broadway Cast of Beetlejuice (Ft. Alex Brightman, Kerry Butler, Rob McClure & Sophia Anne Caruso)'
# Saved 'Snowman by Sia'
# Saved 'No Me Conoce (Remix) by Jhay Cortez, J Balvin & Bad Bunny'
# Saved 'Felaket by Ezhel'
# Saved 'Bella Ciao by Manu Pilas'
# Saved 'Body by Loud Luxury (Ft. ​brando)'
# Saved 'Into You by Ariana Grande'
# Saved 'Don't Matter to Me by Drake & Michael Jackson'
# Saved 'Replay by Iyaz'
# Saved 'Talk by Khalid'
# Saved '2U by David Guetta (Ft. Justin Bieber)'
# Saved 'Globglogabgalab by Tony Halstead'
# Saved 'Story of My Life by One Direction'
# Saved '​mad woman by Taylor Swift'
# Saved 'Sky Walker by Miguel (Ft. Travis Scott)'
# Saved 'Twenty Eight by The Weeknd'
# Saved 'Don't Hurt Yourself by Beyoncé (Ft. Jack White)'
# Saved '​hope is a dangerous thing for a woman like me to have - but i have it by Lana Del Rey'
# Saved '​hostage by Billie Eilish'
# Saved 'What Was I Made For? by Billie Eilish'
# Saved 'Dear Theodosia by Lin-Manuel Miranda & Leslie Odom, Jr.'
# Saved 'Odio by Romeo Santos (Ft. Drake)'
# Saved 'La vie en rose by Édith Piaf'
# Saved 'Hymn For The Weekend by Coldplay (Ft. Beyoncé)'
# Saved 'Safaera by Bad Bunny, Jowell & Randy & Ñengo Flow'
# Saved 'Anuv Jain - Husn (Romanized) by Genius Romanizations'
# Saved 'Nightmare by Halsey'
# Saved 'BROWN SKIN GIRL by Blue Ivy, SAINt JHN, Beyoncé & Wizkid'
# Saved 'Daylight by Taylor Swift'
# Saved 'Heavydirtysoul by ​twenty one pilots'
# Saved 'All Time Low by Jon Bellion (Ft. Travis Mendes)'
# Saved 'I Did Something Bad by Taylor Swift'
# Saved 'Bella by Gims'
# Saved 'Joy to the World by Christmas Songs'
# Saved 'CAROUSEL by Travis Scott (Ft. Frank Ocean)'
# Saved 'Deja Vu by Post Malone (Ft. Justin Bieber)'
# Saved '​no body, no crime by Taylor Swift (Ft. HAIM)'
# Saved 'Lavender Haze by Taylor Swift'
# Saved 'Blow by Beyoncé'
# Saved 'Escape From LA by The Weeknd'
# Saved 'I don't even speak spanish lol by XXXTENTACION (Ft. Carlos Andrez, Judah Amar & Rio Santana)'
# Saved 'Seven (Clean Ver.) by Jung Kook (정국) (Ft. Latto)'
# Saved 'Stitches by Shawn Mendes'
# Saved 'What Makes You Beautiful by One Direction'
# Saved 'Pray by Sam Smith'
# Saved 'The Man by Taylor Swift'
# Saved '​hoax by Taylor Swift'
# Saved '​watch by Billie Eilish'
# Saved 'Come Alive by Hugh Jackman, Keala Settle, Daniel Everidge, Zendaya & The Greatest Showman Ensemble'
# Saved 'MONOPOLY by Ariana Grande & Victoria Monét'
# Saved 'Wake Me Up by Avicii'
# Saved 'Always Remember Us This Way by Lady Gaga'
# Saved 'Tear in My Heart by ​twenty one pilots'
# Saved 'Golden by Harry Styles'
# Saved 'Dark Knight Dummo by Trippie Redd (Ft. Travis Scott)'
# Saved 'Mood by 24kGoldn (Ft. ​iann dior)'
# Saved 'Biking by Frank Ocean (Ft. JAY-Z & Tyler, The Creator)'
# Saved 'Lucky Ali - O Sanam (Romanized) by Genius Romanizations'
# Saved 'Super Far by LANY'
# Saved 'Never Be Like You by Flume (Ft. ​kai)'
# Saved 'Rocket by Beyoncé'
# Saved 'Another Day of Sun by La La Land Cast (Ft. Angela Parrish, Briana Lee, Marius de Vries, Nicholai Baxter & Sam Stone)'
# Saved 'Toda (Remix) by Alex Rose, Rauw Alejandro, Lenny Tavárez, Cazzu & Lyanno'
# Saved '​jealousy, jealousy by Olivia Rodrigo'
# Saved 'Snowchild by The Weeknd'
# Saved 'Loft Music by The Weeknd'
# Saved '​fake smile by Ariana Grande'
# Saved 'Mystery of Love by Sufjan Stevens'
# Saved 'Friends by Justin Bieber & BloodPop®'
# Saved 'Kahit Maputi Na Ang Buhok Ko by Rey Valera'
# Saved 'Échame la Culpa by Luis Fonsi & Demi Lovato'
# Saved 'Juicy by Doja Cat'
# Saved 'I Wonder by Kanye West'
# Saved 'All the Small Things by ​​blink-182'
# Saved 'Do What U Want by Lady Gaga (Ft. R. Kelly)'
# Saved 'Thru Your Phone by Cardi B'
# Saved 'SKELETONS by Travis Scott (Ft. Pharrell Williams, Tame Impala & The Weeknd)'
# Saved 'Lost Boy by Ruth B.'
# Saved 'Mariners Apartment Complex by Lana Del Rey'
# Saved 'Initiation by The Weeknd'
# Saved 'Hurt You by The Weeknd & Gesaffelstein'
# Saved 'Feeling Good by Nina Simone'
# Saved 'Lo Que Siento by Cuco'
# Saved '​goodnight n go by Ariana Grande'
# Saved 'Sorry by Halsey'
# Saved 'Shiritsu Morimori Gakuen Seishun Boys / Yarichin Bitch Club - Touch You (Romanized) by Genius Romanizations'
# Saved 'Girls by Rita Ora (Ft. Bebe Rexha, Cardi B & Charli XCX)'
# Saved 'Drag Me Down by One Direction'
# Saved 'Wildest Dreams by Taylor Swift'
# Saved 'Faith by The Weeknd'
# Saved 'Moon by Kanye West (Ft. Don Toliver & Kid Cudi)'
# Saved 'Rät by Penelope Scott'
# Saved 'Cradles by Sub Urban'
# Saved 'Let It Go by Idina Menzel'
# Saved 'Sour Candy by Lady Gaga & BLACKPINK'
# Saved 'BTS - 친구 (Friends) (English Translation) by Genius English Translations'
# Saved 'DÁKITI by Bad Bunny & Jhay Cortez'
# Saved 'Cherry by Lana Del Rey'
# Saved 'No Brainer by DJ Khaled (Ft. Chance the Rapper, Justin Bieber & Quavo)'
# Saved '​epiphany by Taylor Swift'
# Saved 'Paper Planes by M.I.A.'
# Saved 'Candy Store by Jessica Keenan Wynn, Alice Lee, & Elle McLemore'
# Saved 'Fade Into You by Mazzy Star'
# Saved 'Sweet Life by Frank Ocean'
# Saved 'Let It Happen by Tame Impala'
# Saved 'Dollhouse by Melanie Martinez'
# Saved 'I Can See You (Taylor's Version) [From The Vault] by Taylor Swift'
# Saved 'Starships by Nicki Minaj'
# Saved 'Let Me Down Slowly by Alec Benjamin'
# Saved 'Talk Dirty by Jason Derulo (Ft. 2 Chainz)'
# Saved 'Come & Go by Juice WRLD & Marshmello'
# Saved 'Let It Go by James Bay'
# Saved 'Bejeweled by Taylor Swift'
# Saved 'Carmen by Lana Del Rey'
# Saved 'If I Can't Have You by Shawn Mendes'
# Saved 'Doin' Time by Lana Del Rey'
# Saved 'BTS - FAKE LOVE (Romanized) by Genius Romanizations'
# Saved 'Miss Americana & The Heartbreak Prince by Taylor Swift'
# Saved 'Mercy by Shawn Mendes'
# Saved 'Your Reality by Dan Salvato (Ft. Jillian Ashcraft)'
# Saved 'Chocolate by The 1975'
# Saved 'South Of The Border by Ed Sheeran (Ft. Camila Cabello & Cardi B)'
# Saved 'Natural by Imagine Dragons'
# Saved 'Belle by Emma Watson'
# Saved 'Lovesick Girls by BLACKPINK'
# Saved 'Hallelujah by Jeff Buckley'
# Saved 'Spotlight by Marshmello & Lil Peep'
# Saved 'Lost In the World by Kanye West (Ft. Bon Iver)'
# Saved '​the light is coming by Ariana Grande (Ft. Nicki Minaj)'
# Saved 'Secret Love Song by Little Mix (Ft. Jason Derulo)'
# Saved 'From Now On by Hugh Jackman & The Greatest Showman Ensemble'
# Saved 'Young, Wild & Free by Snoop Dogg & Wiz Khalifa (Ft. Bruno Mars)'
# Saved 'High By The Beach by Lana Del Rey'
# Saved 'Prisoner by The Weeknd (Ft. Lana Del Rey)'
# Saved 'Landslide by Fleetwood Mac'
# Saved 'Look At Her Now by Selena Gomez'
# Saved 'Tsuyu - Renai Circulation (Romanized) by Genius Romanizations'
# Saved 'Intentions by Justin Bieber (Ft. Quavo)'
# Saved 'Promises by Calvin Harris & Sam Smith (Ft. Jessie Reyez)'
# Saved 'K. by Cigarettes After Sex'
# Saved 'Welcome to the Internet by Bo Burnham'
# Saved 'How Does a Moment Last Forever by Céline Dion'
# Saved 'Sandcastles by Beyoncé'
# Saved 'True Colors by The Weeknd'
# Saved 'Part of Your World (Soundtrack Version) by Jodi Benson'
# Saved 'Low by Flo Rida (Ft. T-Pain)'
# Saved 'False Alarm by The Weeknd'
# Saved '​bad vibes forever by XXXTENTACION (Ft. PnB Rock & Trippie Redd)'
# Saved 'Night Changes by One Direction'
# Saved 'I Like Me Better by Lauv'
# Saved 'SUGAR by BROCKHAMPTON'
# Saved 'Lonely by Justin Bieber & benny blanco'
# Saved '​ballad of a homeschooled girl by Olivia Rodrigo'
# Saved '1 step forward, 3 steps back by Olivia Rodrigo'
# Saved 'Mama by Jonas Blue (Ft. William Singe)'
# Saved 'London Boy by Taylor Swift'
# Saved 'Sweet Nothing by Taylor Swift'
# Saved 'Leaves From The Vine (Little Soldier Boy) by Avatar: The Last Airbender (Ft. General Iroh)'
# Saved '​the lakes by Taylor Swift'
# Saved 'Majesty by Nicki Minaj & Labrinth (Ft. Eminem)'
# Saved 'You should be sad by Halsey'
# Saved 'Wake Up in the Sky by Gucci Mane, Bruno Mars & Kodak Black'
# Saved 'Calm Down by Rema'
# Saved 'Ultraviolence by Lana Del Rey'
# Saved 'Lay Me Down by Sam Smith'
# Saved 'ROXANNE by Arizona Zervas'
# Saved 'One Day by Tate McRae'
# Saved 'King of My Heart by Taylor Swift'
# Saved 'Good Life by Kanye West (Ft. T-Pain)'
# Saved 'National Anthem by Lana Del Rey'
# Saved 'Canceled by Larray'
# Saved 'Dark Times by The Weeknd (Ft. Ed Sheeran)'
# Saved 'Cinnamon Girl by Lana Del Rey'
# Saved '7/11 by Beyoncé'
# Saved 'Sincerity Is Scary by The 1975'
# Saved 'Home by Machine Gun Kelly, X Ambassadors & Bebe Rexha'
# Saved 'All About That Bass by Meghan Trainor'
# Saved 'Take What You Want by Post Malone (Ft. Ozzy Osbourne & Travis Scott)'
# Saved 'Alone by Marshmello'
# Saved 'Count Me Out by Kendrick Lamar'
# Saved 'So Far Away by Martin Garrix & David Guetta (Ft. Jamie Scott & Romy Dya)'
# Saved '6 Inch by Beyoncé (Ft. The Weeknd)'
# Saved 'Please Me by Cardi B & Bruno Mars'
# Saved 'A Day in the Life by The Beatles'
# Saved 'Pompeii by Bastille'
# Saved 'BTS - Intro: Serendipity (세렌디피티) (English Translation) by Genius English Translations'
# Saved 'Fireflies by Owl City'
# Saved 'BTS - 작은 것들을 위한 시 (Boy With Luv) ft. Halsey (English Translation) by Genius English Translations'
# Saved 'Dream - Mask (Official Sus Remix) by We The Sus Music'
# Saved 'YOASOBI - 夜に駆ける (Yoru Ni Kakeru/Racing Into The Night) (Romanized) by Genius Romanizations'
# Saved 'Alag Aasmaan by Anuv Jain'
# Saved 'Bad Blood by Taylor Swift'
# Saved 'Saturnz Barz by Gorillaz (Ft. Popcaan)'
# Saved 'Down Under by Men at Work'
# Saved 'I Love You by Barney'
# Saved 'Jordan Belfort by Wes Walker & Dyl'
# Saved 'I Won't Give Up by Jason Mraz'
# Saved 'New Year's Day by Taylor Swift'
# Saved 'DNA by BTS'
# Saved 'Just the Way You Are by Bruno Mars'
# Saved 'Monster by Shawn Mendes & Justin Bieber'
# Saved 'All Of The Girls You Loved Before by Taylor Swift'
# Saved 'Suburban Legends (Taylor's Version) [From The Vault] by Taylor Swift'
# Saved 'Grenade by Bruno Mars'
# Saved '​making the bed by Olivia Rodrigo'
# Saved 'Cornelia Street by Taylor Swift'
# Saved 'Like I'm Gonna Lose You by Meghan Trainor (Ft. John Legend)'
# Saved 'She Looks So Perfect by 5 Seconds of Summer'
# Saved 'Спать с тобой (To Sleep With You) by Пошлая Молли (Poshlaya Molly)'
# Saved 'Two Weeks by FKA twigs'
# Saved 'Two Ghosts by Harry Styles'
# Saved 'Wellerman by The Longest Johns'
# Saved '​cowboy like me by Taylor Swift'
# Saved 'The Boys of Summer by Don Henley'
# Saved 'Girl On Fire by Alicia Keys'
# Saved 'Crying In The Club by Camila Cabello'
# Saved 'Fergalicious by Fergie (Ft. ​will.i.am)'
# Saved 'Sweet Creature by Harry Styles'
# Saved 'Blow Your Mind (Mwah) by Dua Lipa'
# Saved 'Corduroy Dreams by Rex Orange County'
# Saved '​my boy by Billie Eilish'
# Saved 'Strange Fruit by Billie Holiday'
# Saved 'Did you know that there's a tunnel under Ocean Blvd by Lana Del Rey'
# Saved 'Bukti by Virgoun'
# Saved '뚜두뚜두 (DDU-DU DDU-DU) by BLACKPINK'
# Saved 'Twerk It Like Miley by Brandon Beal (Ft. Christopher)'
# Saved 'Save Your Tears (Remix) by The Weeknd & Ariana Grande'
# Saved 'Stargirl Interlude by The Weeknd (Ft. Lana Del Rey)'
# Saved 'Kathang Isip by Ben&Ben'
# Saved 'Line Without a Hook by Ricky Montgomery'
# Saved 'I Wish by Skee-Lo'
# Succsefffully saved pop songs
# Saved 'Bohemian Rhapsody by Queen'
# Saved 'Shallow by Lady Gaga & Bradley Cooper'
# Saved 'Believer by Imagine Dragons'
# Saved 'Hallelujah by Leonard Cohen'
# Saved 'Do I Wanna Know? by Arctic Monkeys'
# Saved 'Take Me to Church by Hozier'
# Saved 'Get Lucky by Daft Punk (Ft. Nile Rodgers & Pharrell Williams)'
# Saved 'Sign of the Times by Harry Styles'
# Saved 'Something Just Like This by The Chainsmokers & Coldplay'
# Saved 'As It Was by Harry Styles'
# Saved 'Happier Than Ever by Billie Eilish'
# Saved 'Revenge by XXXTENTACION'
# Saved 'Mr. Brightside by The Killers'
# Saved 'All Too Well (10 Minute Version) (Taylor's Version) [Live Acoustic] by Taylor Swift'
# Saved 'Viva La Vida by Coldplay'
# Saved 'I Miss You by ​​blink-182'
# Saved 'River by Eminem (Ft. Ed Sheeran)'
# Saved 'Killing in the Name by Rage Against the Machine'
# Saved 'Don't Stop Believin' by Journey'
# Saved 'What's Up? by 4 Non Blondes'
# Saved 'Hotel California by Eagles'
# Saved 'Berzerk by Eminem'
# Saved 'Smells Like Teen Spirit by Nirvana'
# Saved 'Black Skinhead by Kanye West'
# Saved 'Your Song by Elton John'
# Saved '​good 4 u by Olivia Rodrigo'
# Saved 'All Star by Smash Mouth'
# Saved 'Pumped Up Kicks by Foster the People'
# Saved 'Yesterday by The Beatles'
# Saved '​exile by Taylor Swift (Ft. Bon Iver)'
# Saved 'Everybody Wants to Rule the World by Tears for Fears'
# Saved '​vampire by Olivia Rodrigo'
# Saved 'Ghost Town by Kanye West (Ft. PARTYNEXTDOOR)'
# Saved 'POWER by Kanye West'
# Saved 'Creep by Radiohead'
# Saved 'Blinded by the Light by Manfred Mann's Earth Band'
# Saved 'Feel Good Inc. by Gorillaz (Ft. De La Soul)'
# Saved 'Riptide by Vance Joy'
# Saved 'Wish You Were Here by Pink Floyd'
# Saved 'In the End by Linkin Park'
# Saved 'TK from Ling tosite sigure - unravel (Romanized) by Genius Romanizations'
# Saved 'Circles by Post Malone'
# Saved 'Watermelon Sugar by Harry Styles'
# Saved 'Castle On The Hill by Ed Sheeran'
# Saved 'Zombie by The Cranberries'
# Saved 'The House of the Rising Sun by The Animals'
# Saved 'Sweater Weather by The Neighbourhood'
# Saved 'Total Eclipse of the Heart by Bonnie Tyler'
# Saved 'Thinking Out Loud by Ed Sheeran'
# Saved 'Instant Crush by Daft Punk (Ft. Julian Casablancas)'
# Saved 'Stairway to Heaven by Led Zeppelin'
# Saved 'I Took a Pill in Ibiza by Mike Posner'
# Saved 'Beautiful by Eminem'
# Saved 'We Didn't Start the Fire by Billy Joel'
# Saved 'The Sound of Silence by Simon & Garfunkel'
# Saved '505 by Arctic Monkeys'
# Saved 'Given - 冬のはなし (Fuyunohanashi) (Romanized) by Genius Romanizations'
# Saved 'The Scientist by Coldplay'
# Saved 'Born in the U.S.A. by Bruce Springsteen'
# Saved 'Still into You by Paramore'
# Saved 'Wishing Well by Juice WRLD'
# Saved 'Imagine by John Lennon'
# Saved 'The Less I Know the Better by Tame Impala'
# Saved 'Let It Be by The Beatles'
# Saved 'I'm Still Standing by Elton John'
# Saved 'Africa by Toto'
# Saved 'Anti-Hero by Taylor Swift'
# Saved 'Lost On You by LP'
# Saved 'Teenage Dirtbag by Wheatus'
# Saved 'Say It Ain't So by Weezer'
# Saved 'Fast Car by Tracy Chapman'
# Saved 'We Are Young by ​fun. (Ft. Janelle Monáe)'
# Saved 'Californication by Red Hot Chili Peppers'
# Saved 'Don't Stop Me Now by Queen'
# Saved 'Wonderwall by Oasis'
# Saved 'Yellow by Coldplay'
# Saved 'In My Blood by Shawn Mendes'
# Saved 'I'm Yours by Jason Mraz'
# Saved 'Counting Stars by OneRepublic'
# Saved 'Breezeblocks by ​​alt-J'
# Saved 'Sunflower by Rex Orange County'
# ...
# Saved 'Tequila by Dan + Shay'
# Saved 'Old Town Road (Young Thug & Mason Ramsey Remix) by Lil Nas X (Ft. Billy Ray Cyrus, Mason Ramsey & Young Thug)'
# Saved 'Oh Ana by Mother Mother'
# Saved 'Red (Taylor's Version) by Taylor Swift'
# Saved 'You're Still the One by Shania Twain'
# Saved 'Willin' by Little Feat'
# Saved '16 CARRIAGES by Beyoncé'
# Saved 'Try That In A Small Town by Jason Aldean'
# Saved 'Our Song by Taylor Swift'
# Saved 'Greensleeves by Traditional Transcriptions'
# Saved 'Big Iron by Marty Robbins'
# Saved 'Botella Tras Botella by Gera MX & Christian Nodal'
# Saved 'Sparks Fly by Taylor Swift'
# Saved 'Wasted on You by Morgan Wallen'
# Saved 'Ours by Taylor Swift'
# Saved 'Take Your Time by Sam Hunt'
# Saved 'Innocent by Taylor Swift'
# Saved 'Picture to Burn by Taylor Swift'
# Saved 'Drinkin' Problem by Midland'
# Saved 'Life Is a Highway by Rascal Flatts'
# Saved 'Wild Horses by The Rolling Stones'
# Saved 'Fearless by Taylor Swift'
# Saved 'Last Night by Morgan Wallen'
# Saved 'What Ifs by Kane Brown (Ft. Lauren Alaina)'
# Saved 'অপরাধী (Oporadhi) by Ankur Mahamud (Ft. Arman Alif)'
# Saved 'The Git Up by Blanco Brown'
# Saved 'Run (Taylor's Version) [From The Vault] by Taylor Swift (Ft. Ed Sheeran)'
# Saved 'Forever After All by Luke Combs'
# Saved 'Tim McGraw by Taylor Swift'
# Saved 'Need You Now by Lady A'
# Saved 'Caledonia by Dougie Maclean'
# Saved 'Hound Dog by Elvis Presley'
# Saved 'Ella by Junior H'
# Saved 'Girl Crush by Little Big Town'
# Saved 'Maybe It's Time by Bradley Cooper'
# Saved 'Beautiful Crazy by Luke Combs'
# Saved 'Islands in the Stream by Kenny Rogers & Dolly Parton'
# Saved 'Crazy by Patsy Cline'
# Saved 'Mercy by Brett Young'
# Saved 'Woman by Kesha (Ft. The Dap-Kings Horns)'
# Saved 'Yoü and I by Lady Gaga'
# Saved 'Teardrops On My Guitar by Taylor Swift'
# Saved 'Sen Gel Diyorsun (Öf Öf) by Cem Adrian'
# Saved 'Old Town Road (Seoul Town Road Remix) by Lil Nas X (Ft. RM)'
# Saved 'Jackson by Johnny Cash & June Carter Cash'
# Saved 'Whitehouse Road by Tyler Childers'
# Saved 'Gesi Bağları by Selda Bağcan'
# Saved 'The Last Time by Taylor Swift (Ft. Gary Lightbody)'
# Saved 'Fifteen by Taylor Swift'
# Saved 'Whiskey in the Jar by The Dubliners'
# Saved 'Starting Over by Chris Stapleton'
# Saved 'In Case You Didn't Know by Brett Young'
# Saved 'Cruise (Remix) by Florida Georgia Line (Ft. Nelly)'
# Saved 'Famous by Mason Ramsey'
# Saved 'Haunted by Taylor Swift'
# Saved 'The Way I Loved You by Taylor Swift'
# Saved 'Hurricane by Luke Combs'
# Saved 'LADY GAGA by Peso Pluma, Gabito Ballesteros & Junior H'
# Saved 'The Very First Night (Taylor's Version) [From The Vault] by Taylor Swift'
# Saved 'Tourniquet by Zach Bryan'
# Saved 'Going to California by Led Zeppelin'
# Saved 'The Lucky One by Taylor Swift'
# Saved 'Broken Arrows by Avicii (Ft. Zac Brown Band)'
# Saved 'Picture by Kid Rock (Ft. Sheryl Crow)'
# Saved 'All Your'n by Tyler Childers'
# Saved 'Kaifi Khalil - Kahani Suno 2.0 (Romanized) by Genius Romanizations'
# Saved 'TQM by Fuerza Regida'
# Saved 'Black Velvet by Alannah Myles'
# Saved 'When I Look at You by Miley Cyrus'
# Saved 'Hey Driver by Zach Bryan (Ft. The War and Treaty)'
# Saved 'Fire and Rain by James Taylor'
# Saved 'My My, Hey Hey (Out of the Blue) by Neil Young'
# Saved 'Sad Beautiful Tragic by Taylor Swift'
# Saved 'Unshaken by D'Angelo'
# Saved 'Die a Happy Man by Thomas Rhett'
# Saved 'Cover Me Up by Morgan Wallen'
# Saved 'Roadkill by The 1975'
# Saved 'This Land Is Your Land by Woody Guthrie'
# Saved 'Wagon Wheel by Darius Rucker'
# Saved 'American You by Yelawolf'
# Saved 'Either Way by Chris Stapleton'
# Saved 'Never Grow Up by Taylor Swift'
# Saved 'All Summer Long by Kid Rock'
# Saved 'I Almost Do by Taylor Swift'
# Saved 'Joanne by Lady Gaga'
# Saved 'Kendine İyi Bak by Ahmet Kaya'
# Saved 'Beautiful Thing by Grace VanderWaal'
# Saved 'Fire Away by Chris Stapleton'
# Saved 'Me and Bobby McGee by Kris Kristofferson'
# Saved 'Sleeping on the Blacktop by Colter Wall'
# Saved 'TEXAS HOLD ’EM by Beyoncé'
# Saved 'White is Right by Pink Guy'
# Saved 'Blue Ain't Your Color by Keith Urban'
# Saved 'Suspicious Minds by Elvis Presley'
# Saved 'You Were Meant For Me by Jewel'
# Saved 'Somebody's Problem by Morgan Wallen'
# Saved 'The Man Comes Around by Johnny Cash'
# Saved 'Friends in Low Places (Live) by Garth Brooks'
# Saved 'The Thunder Rolls by Garth Brooks'
# Saved 'Unwell by Matchbox Twenty'
# Saved 'Terrapin Station by The Grateful Dead'
# Saved 'Knockin’ on Heaven’s Door by Bob Dylan'
# Saved 'Marry Me by Thomas Rhett'
# Saved 'Don't You (Taylor's Version) [From the Vault] by Taylor Swift'
# Saved 'That's When (Taylor's Version) [From the Vault] by Taylor Swift (Ft. Keith Urban)'
# Saved 'Amor Tumbado by Natanael Cano'
# Saved 'Not Fair by Lily Allen'
# Saved 'I Hope by Gabby Barrett'
# Saved 'The Night They Drove Old Dixie Down by The Band'
# Saved 'You Broke Up with Me by Walker Hayes'
# Saved 'Treacherous by Taylor Swift'
# Saved 'Babe (Taylor's Version) [From The Vault] by Taylor Swift'
# Saved 'Pontoon by Little Big Town'
# Saved 'Disfruto Lo Malo by Natanael Cano & Junior H'
# Saved 'Like a Farmer (Remix) by Lil Tracy (Ft. Lil Uzi Vert)'
# Saved 'You Proof by Morgan Wallen'
# Saved 'The Night the Lights Went Out in Georgia by Reba McEntire'
# Saved 'El Gordo Trae El Mando by Chino Pacas'
# Saved 'Butterflies by Kacey Musgraves'
# Saved 'Speak Now by Taylor Swift'
# Saved 'Fear & Fridays (Poem) by Zach Bryan'
# Saved 'Rich by Maren Morris'
# Saved 'Chico Enamorado by El Ezequiel'
# Saved 'Eslabon Armado - Jugaste y Sufrí ft. DannyLux (English Translation) by Genius English Translations'
# Saved 'February 28, 2016 by Koe Wetzel'
# Saved 'Here Comes Santa Claus (Down Santa Claus Lane) by Gene Autry'
# Saved 'Babe by Sugarland (Ft. Taylor Swift)'
# Saved 'Greatest Love Story by LANCO'
# Saved 'Cry Pretty by Carrie Underwood'
# Saved 'Come Back... Be Here by Taylor Swift'
# Saved 'Can I Get It by Adele'
# Saved 'I'm Only Me When I'm With You by Taylor Swift'
# Saved 'Vampire Empire by Big Thief'
# Saved 'Unlove You by Jennifer Nettles'
# Saved 'LUNA by Peso Pluma & Junior H'
# Saved 'Müzik Kutusu by Emir Can İğrek'
# Saved 'In the Blood by John Mayer'
# Saved 'If I Can Dream by Elvis Presley'
# Saved 'Lady May by Tyler Childers'
# Saved 'Up Down by Morgan Wallen (Ft. Florida Georgia Line)'
# Saved 'When It Rains It Pours by Luke Combs'
# Saved 'We Were Happy (Taylor's Version) [From the Vault] by Taylor Swift'
# Saved 'The Moment I Knew by Taylor Swift'
# Saved 'White Horse by Taylor Swift'
# Saved 'Paper Doll by John Mayer'
# Saved 'Big Enough by Kirin J Callinan (Ft. Alex Cameron, Jimmy Barnes & Molly Lewis)'
# Saved 'Seeing Blind by Niall Horan & Maren Morris'
# Saved 'Streets of London by Ralph McTell'
# Saved 'Picture to Burn (Original Version) by Taylor Swift'
# Saved 'Lake of Fire by Nirvana'
# Saved 'Friends in Low Places by Garth Brooks'
# Saved 'Wichita Lineman by Glen Campbell'
# Saved 'Holler Boys by Upchurch'
# Saved 'Şafak Türküsü by Ahmet Kaya'
# Saved 'You Should Probably Leave by Chris Stapleton'
# Saved 'Love by Koe Wetzel (Ft. Parker McCollum)'
# Saved 'I Can't Make You Love Me by Bonnie Raitt'
# Saved 'Bye Bye Baby (Taylor's Version) [From the Vault] by Taylor Swift'
# Saved 'Broken Halos by Chris Stapleton'
# Saved 'The Red Army Choir — National Anthem Of The USSR (Romanized) by Genius Romanizations'
# Saved 'Annie's Song by John Denver'
# Saved 'Ask Me How I Know by Garth Brooks'
# Saved 'Life Changes by Thomas Rhett'
# Saved 'VVS by Peso Pluma, Edgardo Nuñez & Los Dareyes De La Siera'
# Saved 'Cocaine Blues (At Folsom Prison) by Johnny Cash'
# Saved 'That Don't Impress Me Much by Shania Twain'
# Saved 'Younger Now by Miley Cyrus'
# Saved 'Flower Shops by ERNEST (Ft. Morgan Wallen)'
# Saved 'Accidental Racist by Brad Paisley (Ft. LL Cool J)'
# Saved 'Golden Hour by Kacey Musgraves'
# Saved 'All I Have to Do Is Dream by ​The Everly Brothers'
# Saved 'Still Goin Down by Morgan Wallen'
# Saved 'Smaller Acts by Zach Bryan'
# Saved 'Starlight by Taylor Swift'
# Saved 'You Make It Easy by Jason Aldean'
# Saved 'Cheeseburger in Paradise by Jimmy Buffett'
# Saved 'Slow Burn by Kacey Musgraves'
# Saved 'Forever & Always by Taylor Swift'
# Saved 'One Thing Right by Marshmello & Kane Brown'
# Saved 'The Joke by Brandi Carlile'
# Saved 'Breaking Up Slowly by Lana Del Rey (Ft. Nikki Lane)'
# Saved 'Mağusa Limanı by Grup Abdal'
# Saved 'Mary's Song (Oh My My My) by Taylor Swift'
# Saved 'Sixteen Tons by Tennessee Ernie Ford'
# Saved 'Red River Valley by Gene Autry'
# Saved 'Wanted by Hunter Hayes'
# Saved 'Heaven by Kane Brown'
# Saved 'East Side of Sorrow by Zach Bryan'
# Saved 'Plateau by Nirvana'
# Saved 'This Is How We Roll by Florida Georgia Line (Ft. Luke Bryan)'
# Saved 'Gönül Dağı by Neşet Ertaş'
# Saved 'ONE BEER by HARDY (Ft. Devin Dawson & Lauren Alaina)'
# Saved 'If We Were Vampires by Jason Isbell and the 400 Unit'
# Saved 'Life in the Fast Lane by Eagles'
# Saved 'God Bless America by Kate Smith'
# Saved 'Ronan by Taylor Swift'
# Saved 'Hey, Good Lookin' by Hank Williams'
# Saved 'Should've Said No by Taylor Swift'
# Saved 'God's Gonna Cut You Down by Johnny Cash'
# Saved 'Angel of the Morning by Juice Newton (Ft. Merrilee Rush)'
# Saved 'Shake the Frost by Tyler Childers (Ft. The Highwall)'
# Saved 'Yup (On My Tractor) by Fly Rich Double'
# Saved 'Best Shot by Jimmie Allen'
# Saved 'Breathe by Taylor Swift (Ft. Colbie Caillat)'
# Saved 'I Went to the Store One Day by Father John Misty'
# Saved 'Craving You by Thomas Rhett (Ft. Maren Morris)'
# Saved 'The Best Day by Taylor Swift'
# Saved 'I Am a Man of Constant Sorrow by The Soggy Bottom Boys (Ft. Dan Tyminski)'
# Saved 'Unforgettable by Thomas Rhett'
# Saved '​rap music by Lil Darkie'
# Saved 'Cold as You by Taylor Swift'
# Saved 'El Chivo by Berner (Ft. T3R Elemento)'
# Saved 'Cowboy by Kid Rock'
# Saved 'Most People Are Good by Luke Bryan'
# Saved 'Inspired by Miley Cyrus'
# Saved 'Nose on the Grindstone by Tyler Childers'
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 9
#       7 all_songs = []
#       8 for i in range(1, 51):
# ----> 9     pop_songs = genius.tag(genre, page=i)["hits"]
#      10     for song in pop_songs:
#      11         title = song["title_with_artists"]
#
# File c:\Users\nikok\Repos\Uni\music-lyrics-analysis\venv\Lib\site-packages\lyricsgenius\genius.py:698, in Genius.tag(self, name, page)
#     695 path = 'tags/{}/all'.format(name)
#     696 params = {'page': page}
#     697 soup = BeautifulSoup(
# --> 698     self._make_request(path, params_=params, web=True),
#     699     'html.parser'
#     700 )
#     701 hits = []
#     703 ul = soup.find('ul', class_='song_list')
#
# File c:\Users\nikok\Repos\Uni\music-lyrics-analysis\venv\Lib\site-packages\lyricsgenius\api\base.py:75, in Sender._make_request(self, path, method, params_, public_api, web, **kwargs)
#      73 tries += 1
#      74 try:
# ---> 75     response = self._session.request(method, uri,
#      76                                      timeout=self.timeout,
#      77                                      params=params_,
#      78                                      headers=header,
#      79                                      **kwargs)
#      80     response.raise_for_status()
#      81 except Timeout as e:
#
# File c:\Users\nikok\Repos\Uni\music-lyrics-analysis\venv\Lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File c:\Users\nikok\Repos\Uni\music-lyrics-analysis\venv\Lib\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File c:\Users\nikok\Repos\Uni\music-lyrics-analysis\venv\Lib\site-packages\requests\adapters.py:486, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     483     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     485 try:
# --> 486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#     489         body=request.body,
#     490         headers=request.headers,
#     491         redirect=False,
#     492         assert_same_host=False,
#     493         preload_content=False,
#     494         decode_content=False,
#     495         retries=self.max_retries,
#     496         timeout=timeout,
#     497         chunked=chunked,
#     498     )
#     500 except (ProtocolError, OSError) as err:
#     501     raise ConnectionError(err, request=request)
#
# File c:\Users\nikok\Repos\Uni\music-lyrics-analysis\venv\Lib\site-packages\urllib3\connectionpool.py:790, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     787 response_conn = conn if not release_conn else None
#     789 # Make the request on the HTTPConnection object
# --> 790 response = self._make_request(
#     791     conn,
#     792     method,
#     793     url,
#     794     timeout=timeout_obj,
#     795     body=body,
#     796     headers=headers,
#     797     chunked=chunked,
#     798     retries=retries,
#     799     response_conn=response_conn,
#     800     preload_content=preload_content,
#     801     decode_content=decode_content,
#     802     **response_kw,
#     803 )
#     805 # Everything went great!
#     806 clean_exit = True
#
# File c:\Users\nikok\Repos\Uni\music-lyrics-analysis\venv\Lib\site-packages\urllib3\connectionpool.py:536, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     534 # Receive the response from the server
#     535 try:
# --> 536     response = conn.getresponse()
#     537 except (BaseSSLError, OSError) as e:
#     538     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File c:\Users\nikok\Repos\Uni\music-lyrics-analysis\venv\Lib\site-packages\urllib3\connection.py:461, in HTTPConnection.getresponse(self)
#     458 from .response import HTTPResponse
#     460 # Get the response from http.client.HTTPConnection
# --> 461 httplib_response = super().getresponse()
#     463 try:
#     464     assert_header_parsing(httplib_response.msg)
#
# File c:\python311\Lib\http\client.py:1374, in HTTPConnection.getresponse(self)
#    1372 try:
#    1373     try:
# -> 1374         response.begin()
#    1375     except ConnectionError:
#    1376         self.close()
#
# File c:\python311\Lib\http\client.py:318, in HTTPResponse.begin(self)
#     316 # read until we get a non-100 response
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#     320         break
#
# File c:\python311\Lib\http\client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#     281         raise LineTooLong("status line")
#
# File c:\python311\Lib\socket.py:706, in SocketIO.readinto(self, b)
#     704 while True:
#     705     try:
# --> 706         return self._sock.recv_into(b)
#     707     except timeout:
#     708         self._timeout_occurred = True
#
# File c:\python311\Lib\ssl.py:1278, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1274     if flags != 0:
#    1275         raise ValueError(
#    1276           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1277           self.__class__)
# -> 1278     return self.read(nbytes, buffer)
#    1279 else:
#    1280     return super().recv_into(buffer, nbytes, flags)
#
# File c:\python311\Lib\ssl.py:1134, in SSLSocket.read(self, len, buffer)
#    1132 try:
#    1133     if buffer is not None:
# -> 1134         return self._sslobj.read(len, buffer)
#    1135     else:
#    1136         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
# Download lyrics for all the songs

for genre in config["genres"]:

    # Create an output folder
    if not os.path.exists(f"{config['multilabel_data_dir']}/lyrics/{genre}"):
        os.mkdir(f"{config['multilabel_data_dir']}/lyrics/{genre}")

    # Get the song list for one genre
    with open(f"{config['multilabel_data_dir']}/songs/{genre}.yml", "r") as f:
        songs = yaml.safe_load(f)

    # The API call for lyrics often times out
    # We repeat it every time it has timed out
    error = True
    while error:
        error = False 

        try:
            # Check the already saved songs
            saved_songs = os.listdir(config["multilabel_data_dir"] + "/lyrics/" + genre)
            n_saved_songs = 0 if len(saved_songs) == 0 else max([int(song[:4]) for song in saved_songs])

            # Download the song lyrics
            for i, song in enumerate(songs[n_saved_songs:]):
                title: str = song["title"]
                url: str = song["url"]

                # The title sometimes has invalid chars for a file name
                # Remove these here
                scary_chars = "\"/?*|"
                for char in scary_chars:
                    title = title.replace(char, "")
                if len(title) > 150:
                    title = title[:150]

                lyrics: str = genius.lyrics(song_url=url)

                # The downlaoded lyrics have a header in the first line and
                # a number + "Embed" on the last line
                # These need to be removed
                lyrics = "\n".join(lyrics.splitlines()[1:])[:-5]
                
                # Skip emtpy lyrics
                if len(lyrics) == 0:
                    continue

                # Remove "Embed" + number from the end
                if lyrics[-1] == 'K':
                    lyrics = lyrics[:-3]
                while lyrics[-1].isdigit():
                    lyrics = lyrics[:-1]

                with open(f"{config['multilabel_data_dir']}/lyrics/{genre}/{(n_saved_songs + i):04d}_{title}.txt", "w", encoding="utf-8") as f:
                    f.write(lyrics)
                print(f"✅ Saved {genre} {n_saved_songs + i}: {title}")
        except Exception as e:
            print(f"❌ {e}")
            error = True
# Out:
# ✅ Saved pop 998: I Wish
# ✅ Saved rock 999: ​we think too much
# ✅ Saved r-b 999: WEST DISTRICT
# ✅ Saved rap 999: All My Friends
# ✅ Saved blues 998: Hesitation Blues
# ✅ Saved jazz 998: Midnight Blue
# ✅ Saved experimental 996: Eat, Sleep, Wake (Nothing But You)
# ✅ Saved folk 999: Young & Free
# ✅ Saved classical-music 998: Blackout
# ✅ Saved electronic 999: Summertime
