# %%
from dotenv import load_dotenv
import os
import lyricsgenius
import yaml

# %%
# Get credentials for the api calls from the .env file
# Niko has the credentials if you need them
load_dotenv()
DATA_PATH = "../../data"

# %%
genius = lyricsgenius.Genius()

# %%
# Scraping of all existing secondary tags on genius 
# has been done in src/notebooks/scrape-secondary-tags.ipynb
main_tags = ["country", "pop", "r-b", "rap", "rock"]
with open(DATA_PATH + "/secondary_genres.yaml", "r") as f:
    secondary_tags = yaml.safe_load(f)

main_tags, secondary_tags
# Out:
# (['country', 'pop', 'r-b', 'rap', 'rock'],
#  ['abstract-rap',
#   'a-cappella',
#   'acid-house',
#   'acid-jazz',
#   'acid-techno',
#   'acoustic',
#   'adult-alternative',
#   'adult-contemporary',
#   'afro-arab',
#   'afrobeat',
#   'afrobeats',
#   'afro-hip-hop',
#   'afro-house',
#   'afro-jazz',
#   'afrosoul',
#   'afroswing',
#   'afro-trap',
#   'albanian-folk',
#   'album-oriented-rock-aor',
#   'algerian-rai',
#   'algerian-rap',
#   'alternative',
#   'alternative-country',
#   'alternative-dance',
#   'alternative-metal',
#   'alternative-pop',
#   'alternative-rap',
#   'alternative-r-b',
#   'alternative-rock',
#   'amapiano',
#   'ambient',
#   'ambient-dub',
#   'ambient-pop',
#   'americana',
#   'american-folk',
#   'american-underground',
#   'anarcho-punk',
#   'anime-lo-fi',
#   'anime-rap',
#   'anthem',
#   'anti-folk',
#   'arabic-diss',
#   'arabic-instrumental',
#   'arabic-pop',
#   'arabic-rap',
#   'arabic-rock',
#   'arrocha',
#   'art-pop',
#   'art-punk',
#   'art-rock',
#   'ashiq-music',
#   'atmospheric-black-metal',
#   'atmospheric-sludge-metal',
#   'aussie-drill',
#   'aussie-grime',
#   'aussie-hip-hop',
#   'avant-folk',
#   'avant-garde',
#   'avant-garde-metal',
#   'avant-pop',
#   'avant-prog',
#   'axe',
#   'azerbaijani-jazz',
#   'azerbaijani-pop',
#   'azerbaijani-r-b',
#   'azerbaijani-rap',
#   'azerbaijani-rock',
#   'azonto',
#   'bachata',
#   'balada',
#   'banda',
#   'bangla-hip-hop',
#   'bangla-pop',
#   'barcardi',
#   'bard-song',
#   'baroque-pop',
#   'bashkir-rap',
#   'bass-house',
#   'bass-trap',
#   'bassline',
#   'bass-music',
#   'battle-rap',
#   'beatbox',
#   'beatdown-hardcore',
#   'bebop',
#   'bedroom-pop',
#   'bestial-black-metal',
#   'big-band',
#   'big-room',
#   'bitpop',
#   'blackened-death-metal',
#   'blackened-hardcore',
#   'blackened-screamo',
#   'blackened-sludge-metal',
#   'blackened-thrash-metal',
#   'blackgaze',
#   'black-metal',
#   'black-n-roll',
#   'bluegrass',
#   'blues',
#   'blues-rock',
#   'bolero',
#   'bongo-flava',
#   'boogie',
#   'boom-bap',
#   'bosanski-folk',
#   'bosanski-jazz',
#   'bosanski-pop',
#   'bosanski-r-b',
#   'bosanski-rap',
#   'bosanski-rock',
#   'bosanski-sevdah',
#   'bossa-nova',
#   'bounce',
#   'bouyon',
#   'boy-band',
#   'brass-band',
#   'brass-trap',
#   'breakbeat',
#   'breakcore',
#   'brega',
#   'brega-funk',
#   'brill-building',
#   'british-folk',
#   'british-rock',
#   'britpop',
#   'broadway',
#   'brutal-death-metal',
#   'brutal-horrorcore',
#   'bubblegum-bass',
#   'bubblegum-dance',
#   'bubblegum-pop',
#   'burru',
#   'calabrian-rap',
#   'calypso',
#   'cameroonian-rap',
#   'candombe',
#   'cantopop',
#   'canzone-napoletana',
#   'canzone-romana',
#   'canzone-siciliana',
#   'carimbo',
#   'carranga',
#   'cartel',
#   'catalan-drill',
#   'catalan-music',
#   'catalan-pop',
#   'catalan-r-b',
#   'catalan-rap',
#   'catalan-rock',
#   'catalan-urban',
#   'celtic-punk',
#   'cesky-pop',
#   'cesky-preklad',
#   'cesky-rap',
#   'cesky-rock',
#   'cesky-trap',
#   'chamber-folk',
#   'chamber-music',
#   'chamber-pop',
#   'champeta',
#   'chanson',
#   'chap-hop',
#   'chicago-blues',
#   'chicago-drill',
#   'chicago-house',
#   'chicago-rap',
#   'childrens-music',
#   'chill',
#   'chillhop',
#   'chill-house',
#   'chillout',
#   'chillstep',
#   'chinese-folk',
#   'chinese-hip-hop',
#   'chipmunk-soul',
#   'chiptune',
#   'chopped-and-screwed',
#   'choral-music',
#   'christian',
#   'christian-metal',
#   'christian-pop',
#   'christian-punk',
#   'christian-rap',
#   'christian-r-b',
#   'christian-rock',
#   'christmas',
#   'chutney',
#   'cinematic',
#   'city-pop',
#   'classical-crossover',
#   'classical-music',
#   'cloud-rap',
#   'coladera',
#   'college-rock',
#   'color-bass',
#   'comedy',
#   'complextro',
#   'conscious-hip-hop',
#   'contemporary-folk',
#   'contemporary-r-b',
#   'corrido',
#   'corridos-tumbados',
#   'country-pop',
#   'country-rap',
#   'country-rock',
#   'cowpunk',
#   'c-pop',
#   'crnogorski-folk',
#   'crnogorski-pop',
#   'crnogorski-r-b',
#   'crnogorski-rap',
#   'crnogorski-rock',
#   'crossover-thrash',
#   'crunk',
#   'crushed-trap',
#   'crust-punk',
#   'cuarteto',
#   'cumbia',
#   'cybergrind',
#   'cyprus-pop',
#   'cyprus-rap',
#   'cyprus-rock',
#   'dance',
#   'dancehall',
#   'dance-pop',
#   'dance-punk',
#   'dance-rock',
#   'dariacore',
#   'dark-ambient',
#   'dark-cabaret',
#   'dark-folk',
#   'dark-jazz',
#   'dark-plugg',
#   'dark-pop',
#   'dark-trap',
#   'dark-wave',
#   'd-beat',
#   'deathcore',
#   'death-doom',
#   'deathgrind',
#   'death-metal',
#   'deconstructed-club',
#   'deep-house',
#   'dembow',
#   'desi-hip-hop',
#   'deutscher-jersey-club',
#   'deutschsprachige-musicals',
#   'deutschsprachiger-drill',
#   'deutschsprachiger-hyperpop',
#   'deutschsprachiger-phonk',
#   'deutschsprachiger-pop',
#   'deutschsprachiger-r-b',
#   'deutschsprachiger-rap',
#   'deutschsprachiger-rock',
#   'deutschsprachiger-trap',
#   'deutschsprachiges-detroit',
#   'digital-hardcore',
#   'dipset',
#   'dirty-south',
#   'disco',
#   'disco-polo',
#   'diy-punk',
#   'djent',
#   'doom-metal',
#   'doo-wop',
#   'downtempo',
#   'drain',
#   'dream-pop',
#   'drift-phonk',
#   'drill',
#   'drill-brasileiro',
#   'drill-farsi',
#   'drone',
#   'drone-metal',
#   'drum-and-bass',
#   'drumstep',
#   'dsbm-depressive-suicidal-black-metal',
#   'dub',
#   'dubstep',
#   'dub-techno',
#   'dungeon-synth',
#   'dutch-drill',
#   'dutch-rap',
#   'easycore',
#   'easy-listening',
#   'ebm',
#   'edm',
#   'egyptian-drill',
#   'egyptian-pop',
#   'egyptian-rap',
#   'electric-blues',
#   'electro',
#   'electroclash',
#   'electro-funk',
#   'electro-hop',
#   'electro-house',
#   'electro-industrial',
#   'electronic',
#   'electronica',
#   'electronicore',
#   'electronic-rock',
#   'electronic-trap',
#   'electro-pop',
#   'electro-soul',
#   'electro-swing',
#   'emo',
#   'emocore',
#   'emo-pop',
#   'emo-rap',
#   'emo-revival',
#   'emo-trap',
#   'emoviolence',
#   'espana',
#   'euphoric-hardstyle',
#   'eurobeat',
#   'eurodance',
#   'eurodisco',
#   'euro-house',
#   'europop',
#   'euro-reggae',
#   'eurotrance',
#   'experimental',
#   'experimental-folk',
#   'experimental-pop',
#   'experimental-rap',
#   'experimental-rock',
#   'extreme-metal',
#   'fado',
#   'fanchant',
#   'fandango',
#   'farsi-rap',
#   'filk',
#   'flamenco',
#   'folk',
#   'folklore',
#   'folk-metal',
#   'folk-pop',
#   'folk-punk',
#   'folk-rock',
#   'folktronica',
#   'footwork',
#   'forro',
#   'freak-folk',
#   'free-jazz',
#   'freestyle',
#   'french-country',
#   'french-dancehall',
#   'french-house',
#   'french-pop',
#   'french-r-b',
#   'french-rap',
#   'french-reggae',
#   'french-rock',
#   'french-soul',
#   'frevo',
#   'funana',
#   'funeral-doom',
#   'funk',
#   'funk-melody',
#   'funk-nacional',
#   'funk-pop',
#   'funk-rock',
#   'funky-house',
#   'future-bass',
#   'future-bounce',
#   'future-funk',
#   'future-garage',
#   'future-house',
#   'future-rave',
#   'future-riddim',
#   'gabber',
#   'gaeilge',
#   'gangsta-rap',
#   'garage-house',
#   'garage-punk',
#   'garage-rock',
#   'garage-rock-revival',
#   'georgian-folk',
#   'georgian-pop',
#   'georgian-rap',
#   'georgian-rock',
#   'g-funk',
#   'ghetto-house',
#   'girl-group',
#   'glam-metal',
#   'glam-punk',
#   'glam-rock',
#   'glitch',
#   'glitch-hop',
#   'gnaoui',
#   'goa-trance',
#   'go-go',
#   'goregrind',
#   'gospel',
#   'gothic-metal',
#   'gothic-rock',
#   'gqom',
#   'grime',
#   'grime-brasileiro-brazilian-grime',
#   'grindcore',
#   'groove-metal',
#   'grunge',
#   'guaracha',
#   'guasca',
#   'happy-hardcore',
#   'hard-bass',
#   'hard-bop',
#   'hardcore',
#   'hardcore-edm',
#   'hardcore-punk',
#   'hardcore-rap',
#   'hard-dance',
#   'hard-drill',
#   'hard-house',
#   'hard-rock',
#   'hardstyle',
#   'hard-trance',
#   'hardwave',
#   'harsh-noise',
#   'hawaiian',
#   'heartland-rock',
#   'heavy-metal',
#   'hexd',
#   'highlife',
#   'hi-nrg',
#   'hip-hop',
#   'hip-hop-tuga',
#   'hip-hop-viet',
#   'hip-house',
#   'holiday',
#   'hong-kong-indie',
#   'hong-kong-rap',
#   'honky-tonk',
#   'hookah-rap',
#   'horrorcore',
#   'horror-punk',
#   'house',
#   'hrvatski-jazz',
#   'hrvatski-pop',
#   'hrvatski-r-b',
#   'hrvatski-rap',
#   'hrvatski-rock',
#   'hybrid-trap',
#   'hymn',
#   'hyperpop',
#   'hyperpunk',
#   'hyphy',
#   'idm',
#   'impressionism',
#   'indian-classical',
#   'indian-pop',
#   'indie',
#   'indie-electronic',
#   'indie-folk',
#   'indie-pop',
#   'indie-rap',
#   'indie-rock',
#   'industrial',
#   'industrial-hip-hop',
#   'industrial-metal',
#   'industrial-rock',
#   'industrial-techno',
#   'infantil',
#   'iranian-pop',
#   'iranian-rap',
#   'irish-drill',
#   'irish-folk',
#   'irish-rap',
#   'isicathamiya',
#   'islamic',
#   'island-music',
#   'israeli-children-songs',
#   'israeli-classic',
#   'israeli-country',
#   'israeli-drill',
#   'israeli-folk',
#   'israeli-funk',
#   'israeli-grundge',
#   'israeli-hip-hop',
#   'israeli-metal',
#   'israeli-music',
#   'israeli-pop',
#   'israeli-punk',
#   'israeli-r-b',
#   'israeli-rap',
#   'israeli-reggae',
#   'israeli-rock',
#   'israeli-soul',
#   'israeli-trap',
#   'israeli-yam-tichoni',
#   'italo-disco',
#   'ivona',
#   'jangle-pop',
#   'jazz',
#   'jazz-contrafact',
#   'jazz-funk',
#   'jazz-fusion',
#   'jazz-rap',
#   'jazz-rock',
#   'jersey-club',
#   'jewish',
#   'joik',
#   'j-pop',
#   'j-rap',
#   'j-rock',
#   'jump-blues',
#   'jumpstyle',
#   'jungle',
#   'kazakh-rap',
#   'k-ballad',
#   'k-chinese',
#   'k-hip-hop',
#   'k-idon-hip-hop',
#   'k-indie',
#   'kizomba',
#   'k-japanese',
#   'k-ost',
#   'k-pop',
#   'k-r-b',
#   'krautrock',
#   'k-rock',
#   'k-solo',
#   'kuduro',
#   'kultura-w-rapie',
#   'kuwaiti-rap',
#   'kwaito',
#   'kwela',
#   'lambada',
#   'latin-drill',
#   'latin-freestyle-edm',
#   'latin-house',
#   'latin-jazz',
#   'latin-music',
#   'latin-pop',
#   'latin-r-b',
#   'latin-rap',
#   'latin-reggae',
#   'latin-rock',
#   'latin-trap',
#   'latin-urban',
#   'lebanese-rap',
#   'liquid-drum-and-bass',
#   'liscio',
#   'lo-fi',
#   'lok-dohori',
#   'lok-geet',
#   'louisiana-blues',
#   'lounge',
#   'lovers-rock',
#   'lowercase',
#   'lullaby',
#   'macedonian-folk',
#   'macedonian-pop',
#   'macedonian-r-b',
#   'macedonian-rap',
#   'macedonian-rock',
#   'madchester',
#   'magyar-drill',
#   'magyar-rap',
#   'mahraganat',
#   'makina',
#   'malaysian-dangdut',
#   'malaysian-rap',
#   'mambo',
#   'mandopop',
#   'manele',
#   'mantra',
#   'marabi',
#   'marchinha',
#   'mariachi',
#   'maskhandi',
#   'mathcore',
#   'math-metal',
#   'math-rock',
#   'mbaganga',
#   'melbourne-bounce',
#   'melodic-death-metal',
#   'melodic-dubstep',
#   'melodic-hardcore',
#   'melodic-house',
#   'melodic-metalcore',
#   'melodic-riddim',
#   'melodic-techno',
#   'meme-rap',
#   'mental-health',
#   'mento',
#   'merengue',
#   'merengue-tipico',
#   'metal',
#   'metalcore',
#   'meykhana',
#   'miami-bass',
#   'midtempo',
#   'midwest-emo',
#   'minimalism',
#   'minimal-techno',
#   'modern-classical',
#   'moldovan-pop',
#   'moombahton',
#   'morna',
#   'moroccan-rap',
#   'mortuary',
#   'motown',
#   'motswako',
#   'mpb-musica-popular-brasileira',
#   'mugham',
#   'murder-ballad',
#   'murga',
#   'musicals',
#   'musik-fur-kinder',
#   'musique-concrete',
#   'muzik-popullore',
#   'mystic',
#   'nasheed',
#   'neocrust',
#   'neofolk',
#   'neomelodica',
#   'neoperreo',
#   'neo-psychedelia',
#   'neo-soul',
#   'nep-hop',
#   'nerdcore',
#   'neue-deutsche-harte',
#   'neue-deutsche-welle',
#   'new-age',
#   'new-jack-swing',
#   'new-orleans-r-b',
#   'new-wave',
#   'new-york-drill',
#   'nigerian-rap',
#   'nightcore',
#   'nintendocore',
#   'noise',
#   'noisecore',
#   'noise-pop',
#   'noise-rock',
#   'norsk-country',
#   'norsk-julemusikk',
#   'norsk-pop',
#   'norsk-r-b',
#   'norsk-rap',
#   'norsk-rock',
#   'nortena',
#   'no-wave',
#   'nu-disco',
#   'nueva-cancion',
#   'nueva-trova',
#   'nu-jazz',
#   'nu-metal',
#   'nu-rave',
#   'oi',
#   'opera',
#   'operetta',
#   'opm',
#   'orchestral',
#   'otaku-music',
#   'otaku-rap',
#   'otaku-trap',
#   'outlaw-country',
#   'outsider-music',
#   'pagode',
#   'pagode-baiano',
#   'pakistani-pop',
#   'palestinian-rap',
#   'parody',
#   'partyschlager',
#   'persian-rock',
#   'persian-traditional-music',
#   'p-funk',
#   'phonk',
#   'piano',
#   'piano-house',
#   'piano-rock',
#   'pink-noise',
#   'pinoy-hip-hop',
#   'pirate-metal',
#   'piseiro',
#   'planete-rap',
#   'plena-uruguaya',
#   'plunderphonics',
#   'plugg',
#   'pluggnb',
#   'polka',
#   'polskie-disco-polo',
#   'polski-folk',
#   'polski-freestyle',
#   'polski-pop',
#   'polski-rap',
#   'polski-rock',
#   'polynesian-reggae',
#   'pop-italiano',
#   'pop-melayu',
#   'pop-punk',
#   'pop-r-b',
#   'pop-rap',
#   'pop-reggae',
#   'pop-rock',
#   'posse-cut',
#   'post-black-metal',
#   'post-bop',
#   'post-britpop',
#   'post-dubstep',
#   'post-grunge',
#   'post-hardcore',
#   'post-metal',
#   'post-minimalism',
#   'post-punk',
#   'post-punk-revival',
#   'post-rap',
#   'post-rock',
#   'post-screamo',
#   'power-metal',
#   'power-pop',
#   'powerviolence',
#   'p-pop',
#   'progressive-death-metal',
#   'progressive-electronic',
#   'progressive-house',
#   'progressive-metal',
#   'progressive-metalcore',
#   'progressive-pop',
#   'progressive-rock',
#   'progressive-trance',
#   'proto-manele',
#   'proto-punk',
#   'psychedelic',
#   'psychedelic-rock',
#   'psychedelic-soul',
#   'psychedelic-trance',
#   'psychobilly',
#   'punk-pathetique',
#   'punk-revival',
#   'punk-rock',
#   'qawwali',
#   'q-pop',
#   'queercore',
#   'raga-rock',
#   'rage',
#   'ragga',
#   'ragtime',
#   'rai',
#   'ranchera',
#   'r-b-viet',
#   'rapcore',
#   'rap-italiano',
#   'rap-metal',
#   'rap-napoletano',
#   'rap-rock',
#   'rastafarian',
#   'rawstyle',
#   'red-dirt',
#   'reggae',
#   'reverse-bass',
#   'reggae-rock',
#   'reggaeton',
#   'regional-mexicano',
#   'reparterismo',
#   'retro',
#   'rhythm-and-grime',
#   'riddim',
#   'riot-grrrl',
#   'ritual-rap',
#   'rkt',
#   'road-rap',
#   'rockabilly',
#   'rock-gaucho',
#   'rocksteady',
#   'rock-viet',
#   'romanian-drill',
#   'romansh',
#   'roots',
#   'roots-reggae',
#   'rub-a-dub',
#   'rumba',
#   'russemusikk',
#   'russian-battle-rap',
#   'russian-chanson',
#   'russian-country',
#   'russian-drill',
#   'russian-grime',
#   'russian-hyperpop',
#   'russian-jazz',
#   'russian-pop',
#   'russian-punk-rock',
#   'russian-r-b',
#   'russian-rap',
#   'russian-rave',
#   'russian-reggae',
#   'russian-rock',
#   'russian-trap',
#   'russian-underground',
#   'sab-hop',
#   'salsa',
#   'samba',
#   'samba-reggae',
#   'samba-rock',
#   'saudi-rap',
#   'scam-rap',
#   'scandipop',
#   'scenecore',
#   'schlager',
#   'scottish-folk',
#   'screamo',
#   'sea-shanty',
#   'semba',
#   'sertenejo',
#   'shaabi',
#   'shibuya-kei',
#   'shoegaze',
#   'sicilian-rap',
#   'sierreno',
#   'sindicat',
#   'sinogrime',
#   'sigilkore',
#   'ska',
#   'skacore',
#   'ska-punk',
#   'skate-punk',
#   'skhanda-rap',
#   'slam-metal',
#   'slap-house',
#   'slay',
#   'slovenian-pop',
#   'slovenian-rap',
#   'slovenian-rock',
#   'slovensky-pop',
#   'slovensky-rap',
#   'slowcore',
#   'slowed-and-reverb',
#   'sludge-metal',
#   'smooth-jazz',
#   'soca',
#   'soft-house',
#   'soft-rock',
#   'sophisti-pop',
#   'soul',
#   'soul-jazz',
#   'soul-pop',
#   'soul-rap',
#   'sound-collage',
#   'southern-rock',
#   'soviet-estrada',
#   'soviet-jazz',
#   'soviet-rap',
#   'soviet-rock',
#   'soviet-samizdat',
#   'space-rock',
#   'spanish-drill',
#   'spanish-pop',
#   'spanish-r-b',
#   'spanish-rap',
#   'spanish-rock',
#   'spanish-urban',
#   'sped-up',
#   'speedcore',
#   'speed-metal',
#   'spiritual',
#   'spiritual-jazz',
#   'srpski-folk',
#   'srpski-jazz',
#   'srpski-pop',
#   'srpski-r-b',
#   'srpski-rap',
#   'srpski-rock',
#   'steampunk',
#   'stomp-and-holler',
#   'stoner-metal',
#   'stoner-rock',
#   'sto-pro-rap',
#   'straightedge',
#   'street-punk',
#   'sunshine-pop',
#   'suomi-drill',
#   'suomi-pop',
#   'suomi-rap',
#   'suomirock',
#   'suomi-underground-rap',
#   'supertrap',
#   'surf',
#   'surf-punk',
#   'surf-rock',
#   'surge',
#   'svensk-country',
#   'svensk-pop',
#   'svensk-r-b',
#   'svensk-rap',
#   'svensk-rock',
#   'swedish-folk',
#   'swing',
#   'symphonic-black-metal',
#   'symphonic-metal',
#   'symphonic-power-metal',
#   'symphonic-rock',
#   'synth-funk',
#   'synth-pop',
#   'synth-punk',
#   'synth-rock',
#   'synthwave',
#   'tai-pop',
#   'tango',
#   'taqwacore',
#   'tarraxinha',
#   'tech-house',
#   'technical-death-metal',
#   'technical-thrash-metal',
#   'techno',
#   'techno-rap',
#   'tecnobrega',
#   'teen-pop',
#   'thai-pop',
#   'thai-rap',
#   'third-stream',
#   'thrash-metal',
#   'time-lord-rock-trock',
#   'toasting',
#   'togo-pop',
#   'togo-rap',
#   'togo-trap',
#   'tontipop',
#   'traditional-folk',
#   'trallpunk',
#   'trance',
#   'trap',
#   'trap-dancehall',
#   'trap-metal',
#   'trap-rock',
#   'trapwave',
#   'tread',
#   'tribal',
#   'trip-hop',
#   'tropical-house',
#   'trot',
#   'trova',
#   'tunisian-rap',
#   'turkce-alternatif',
#   'turkce-drill',
#   'turkce-folk',
#   'turkce-pop',
#   'turkce-r-b',
#   'turkce-rap',
#   'turkce-rock',
#   'turkce-trap',
#   'two-tone',
#   'uk-drill',
#   'uk-funky',
#   'uk-garage',
#   'uk-pop',
#   'ukrainian-drill',
#   'ukrainian-pop',
#   'ukrainian-rap',
#   'ukrainian-rock',
#   'ukrainian-trap',
#   'uk-r-b',
#   'uk-rap',
#   'ukulele',
#   'underground-rap',
#   'underground-soul',
#   'vallenato',
#   'valsa',
#   'vaporwave',
#   'variete-francaise',
#   'via',
#   'viking-metal',
#   'vise-visa',
#   'vispop',
#   'vocaloid',
#   'volksmusik',
#   'v-pop',
#   'weirdcore',
#   'western-swing',
#   'witch-house',
#   'wizard-rock-wrock',
#   'worship',
#   'xote',
#   'yacht-rock',
#   'yiddish',
#   'yu-mex',
#   'zouk',
#   'z-pop',
#   'zydeco',
#   'atlanta-rap',
#   'bay-area-rap',
#   'chicago-rap',
#   'detroit-rap',
#   'dmv-rap',
#   'florida-rap',
#   'memphis-rap',
#   'new-york',
#   'quebec-rap',
#   'texas-rap',
#   'afghanistan',
#   'albania',
#   'algeria',
#   'andorra',
#   'angola',
#   'arabia',
#   'argentina',
#   'armenia',
#   'aruba',
#   ...])

# %%
# Try to find all songs for a specified genre
abstract_rap_songs = genius.tag("abstract-rap")["hits"]

# %%
# These are appearently not all songs yet
len(abstract_rap_songs)
# Out:
# 20

# %%
feel_good_inc = abstract_rap_songs[2]
feel_good_inc
# Out:
# {'url': 'https://genius.com/Gorillaz-feel-good-inc-lyrics',
#  'title_with_artists': 'Feel Good Inc. by Gorillaz (Ft. De La Soul)',
#  'title': 'Feel Good Inc.',
#  'artists': ['Gorillaz'],
#  'featured_artists': ['De La Soul']}

# %%
# Print the lyrics for a specific song
print(genius.lyrics(song_url=feel_good_inc["url"]))
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# File c:\Users\nikok\Repos\Uni\music-lyrics-analysis\venv\Lib\site-packages\urllib3\connectionpool.py:536, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     535 try:
# --> 536     response = conn.getresponse()
#     537 except (BaseSSLError, OSError) as e:
#
# File c:\Users\nikok\Repos\Uni\music-lyrics-analysis\venv\Lib\site-packages\urllib3\connection.py:461, in HTTPConnection.getresponse(self)
#     460 # Get the response from http.client.HTTPConnection
# --> 461 httplib_response = super().getresponse()
#     463 try:
#
# File c:\python311\Lib\http\client.py:1374, in HTTPConnection.getresponse(self)
#    1373 try:
# -> 1374     response.begin()
#    1375 except ConnectionError:
#
# File c:\python311\Lib\http\client.py:318, in HTTPResponse.begin(self)
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#
# File c:\python311\Lib\http\client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#
# File c:\python311\Lib\socket.py:706, in SocketIO.readinto(self, b)
#     705 try:
# --> 706     return self._sock.recv_into(b)
#     707 except timeout:
#
# File c:\python311\Lib\ssl.py:1278, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1275         raise ValueError(
#    1276           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1277           self.__class__)
# -> 1278     return self.read(nbytes, buffer)
#    1279 else:
#
# File c:\python311\Lib\ssl.py:1134, in SSLSocket.read(self, len, buffer)
#    1133 if buffer is not None:
# -> 1134     return self._sslobj.read(len, buffer)
#    1135 else:
#
# TimeoutError: The read operation timed out
#
# The above exception was the direct cause of the following exception:
#
# ReadTimeoutError                          Traceback (most recent call last)
# File c:\Users\nikok\Repos\Uni\music-lyrics-analysis\venv\Lib\site-packages\requests\adapters.py:486, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     485 try:
# --> 486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#     489         body=request.body,
#     490         headers=request.headers,
#     491         redirect=False,
#     492         assert_same_host=False,
#     493         preload_content=False,
#     494         decode_content=False,
#     495         retries=self.max_retries,
#     496         timeout=timeout,
#     497         chunked=chunked,
#     498     )
#     500 except (ProtocolError, OSError) as err:
#
# File c:\Users\nikok\Repos\Uni\music-lyrics-analysis\venv\Lib\site-packages\urllib3\connectionpool.py:844, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     842     new_e = ProtocolError("Connection aborted.", new_e)
# --> 844 retries = retries.increment(
#     845     method, url, error=new_e, _pool=self, _stacktrace=sys.exc_info()[2]
#     846 )
#     847 retries.sleep()
#
# File c:\Users\nikok\Repos\Uni\music-lyrics-analysis\venv\Lib\site-packages\urllib3\util\retry.py:470, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     469 if read is False or method is None or not self._is_method_retryable(method):
# --> 470     raise reraise(type(error), error, _stacktrace)
#     471 elif read is not None:
#
# File c:\Users\nikok\Repos\Uni\music-lyrics-analysis\venv\Lib\site-packages\urllib3\util\util.py:39, in reraise(tp, value, tb)
#      38         raise value.with_traceback(tb)
# ---> 39     raise value
#      40 finally:
#
# File c:\Users\nikok\Repos\Uni\music-lyrics-analysis\venv\Lib\site-packages\urllib3\connectionpool.py:790, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     789 # Make the request on the HTTPConnection object
# --> 790 response = self._make_request(
#     791     conn,
#     792     method,
#     793     url,
#     794     timeout=timeout_obj,
#     795     body=body,
#     796     headers=headers,
#     797     chunked=chunked,
#     798     retries=retries,
#     799     response_conn=response_conn,
#     800     preload_content=preload_content,
#     801     decode_content=decode_content,
#     802     **response_kw,
#     803 )
#     805 # Everything went great!
#
# File c:\Users\nikok\Repos\Uni\music-lyrics-analysis\venv\Lib\site-packages\urllib3\connectionpool.py:538, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     537 except (BaseSSLError, OSError) as e:
# --> 538     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#     539     raise
#
# File c:\Users\nikok\Repos\Uni\music-lyrics-analysis\venv\Lib\site-packages\urllib3\connectionpool.py:370, in HTTPConnectionPool._raise_timeout(self, err, url, timeout_value)
#     369 if isinstance(err, SocketTimeout):
# --> 370     raise ReadTimeoutError(
#     371         self, url, f"Read timed out. (read timeout={timeout_value})"
#     372     ) from err
#     374 # See the above comment about EAGAIN in Python 3.
#
# ReadTimeoutError: HTTPSConnectionPool(host='genius.com', port=443): Read timed out. (read timeout=5)
#
# During handling of the above exception, another exception occurred:
#
# ReadTimeout                               Traceback (most recent call last)
# File c:\Users\nikok\Repos\Uni\music-lyrics-analysis\venv\Lib\site-packages\lyricsgenius\api\base.py:75, in Sender._make_request(self, path, method, params_, public_api, web, **kwargs)
#      74 try:
# ---> 75     response = self._session.request(method, uri,
#      76                                      timeout=self.timeout,
#      77                                      params=params_,
#      78                                      headers=header,
#      79                                      **kwargs)
#      80     response.raise_for_status()
#
# File c:\Users\nikok\Repos\Uni\music-lyrics-analysis\venv\Lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File c:\Users\nikok\Repos\Uni\music-lyrics-analysis\venv\Lib\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#
# File c:\Users\nikok\Repos\Uni\music-lyrics-analysis\venv\Lib\site-packages\requests\adapters.py:532, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     531 elif isinstance(e, ReadTimeoutError):
# --> 532     raise ReadTimeout(e, request=request)
#     533 elif isinstance(e, _InvalidHeader):
#
# ReadTimeout: HTTPSConnectionPool(host='genius.com', port=443): Read timed out. (read timeout=5)
#
# During handling of the above exception, another exception occurred:
#
# Timeout                                   Traceback (most recent call last)
# Cell In[27], line 2
#       1 # Print the lyrics for a specific song
# ----> 2 print(genius.lyrics(song_url=feel_good_inc["url"]))
#
# File c:\Users\nikok\Repos\Uni\music-lyrics-analysis\venv\Lib\site-packages\lyricsgenius\genius.py:132, in Genius.lyrics(self, song_id, song_url, remove_section_headers)
#     128     path = self.song(song_id)['song']['path'][1:]
#     130 # Scrape the song lyrics from the HTML
#     131 html = BeautifulSoup(
# --> 132     self._make_request(path, web=True).replace('<br/>', '\n'),
#     133     "html.parser"
#     134 )
#     136 # Determine the class of the div
#     137 div = html.find("div", class_=re.compile("^lyrics$|Lyrics__Root"))
#
# File c:\Users\nikok\Repos\Uni\music-lyrics-analysis\venv\Lib\site-packages\lyricsgenius\api\base.py:84, in Sender._make_request(self, path, method, params_, public_api, web, **kwargs)
#      82     error = "Request timed out:\n{e}".format(e=e)
#      83     if tries > self.retries:
# ---> 84         raise Timeout(error)
#      85 except HTTPError as e:
#      86     error = get_description(e)
#
# Timeout: Request timed out:
# HTTPSConnectionPool(host='genius.com', port=443): Read timed out. (read timeout=5)

# %%
abstract_rap_songs[:2]
# Out:
# [{'url': 'https://genius.com/Childish-gambino-iv-sweatpants-lyrics',
#   'title_with_artists': 'IV. Sweatpants by Childish Gambino',
#   'title': 'IV. Sweatpants',
#   'artists': ['Childish Gambino'],
#   'featured_artists': []},
#  {'url': 'https://genius.com/Tyler-the-creator-yonkers-lyrics',
#   'title_with_artists': 'Yonkers by Tyler, The Creator',
#   'title': 'Yonkers',
#   'artists': ['Tyler, The Creator'],
#   'featured_artists': []},
#  {'url': 'https://genius.com/Gorillaz-feel-good-inc-lyrics',
#   'title_with_artists': 'Feel Good Inc. by Gorillaz (Ft. De La Soul)',
#   'title': 'Feel Good Inc.',
#   'artists': ['Gorillaz'],
#   'featured_artists': ['De La Soul']}]

# %%
# The page feature can be used to find 20 more songs
genius.tag("abstract-rap", page=2)["hits"][:2]
# Out:
# [{'url': 'https://genius.com/Chance-the-rapper-acid-rain-lyrics',
#   'title_with_artists': 'Acid Rain by Chance the Rapper',
#   'title': 'Acid Rain',
#   'artists': ['Chance the Rapper'],
#   'featured_artists': []},
#  {'url': 'https://genius.com/A-ap-rocky-phoenix-lyrics',
#   'title_with_artists': 'Phoenix by A$AP Rocky',
#   'title': 'Phoenix',
#   'artists': ['A$AP Rocky'],
#   'featured_artists': []}]

# %%
# Download 1000 songs for the every genre
for genre in ["pop", "rock", "r-b", "country", "rap", "blues", "jazz", "experimental", "folk", "classical-music", "electronic"]:

    # Iterate through pages of songs in genius
    titles = []
    lyrics = []
    all_songs = []
    for i in range(1, 51):
        pop_songs = genius.tag(genre, page=i)["hits"]
        for song in pop_songs:
            title = song["title_with_artists"]
            all_songs.append([title, song["url"]])
            print(f"Saved '{title}'")

    with open(f"{DATA_PATH}/songs/{genre}.yml", "w") as f:
        yaml.safe_dump(all_songs, f)
    print(f"Succsefffully saved {genre} songs")
# Out:
# Saved 'Time To Say Goodbye by Sarah Brightman'
# Saved 'We'll Meet Again by Vera Lynn'
# Saved 'Lacrimosa by Wolfgang Amadeus Mozart'
# Saved 'FACTS by Tom MacDonald (Ft. Ben Shapiro)'
# Saved 'Yeh Vaada Raha by Asha Bhosle (Ft. Kishore Kumar)'
# Saved 'La Donna E Mobile by Luciano Pavarotti'
# Saved 'All of the Lights (Interlude) by Kanye West'
# Saved 'Shatter Me by Lindsey Stirling (Ft. Lzzy Hale)'
# Saved 'Message to Harry Manback by Tool'
# Saved 'Wife by Mitski'
# Saved 'Fall on Me by Andrea Bocelli (Ft. Matteo Bocelli)'
# Saved 'Ode to Joy by Ludwig van Beethoven'
# Saved 'For The Beauty Of The Earth by John Rutter'
# Saved 'Ave Maria - Ellens dritter Gesang (Ellens Gesang III, D. 839, Op. 52, No. 6, 1825) by Franz Schubert'
# Saved 'E più ti penso by Andrea Bocelli & Ariana Grande'
# Saved 'Pearl Diver by Mitski'
# Saved 'Baker Street by Gerry Rafferty'
# Saved 'Après Moi by Regina Spektor'
# Saved 'Kishore Kumar - Aa Chal Ke Tujhe (Hindi Version) by Genius India'
# Saved 'Kishore Kumar - Chingari Koi Bhadke (Hindi Version) by Genius India'
# Saved 'Bring the Boys Back Home by Pink Floyd'
# Saved 'Dilbar Mere by Kishore Kumar (Ft. Anette Pinto)'
# Saved 'DO YOU DOUBT ME TRAITOR by Lingua Ignota'
# Saved 'Bag of Bones by Mitski'
# Saved 'Kuhu Kuhu Bole Koyalia by Lata Mangeshkar & Mohammed Rafi'
# Saved 'Sunrise by Coldplay'
# Saved 'Moner Manush by Anupam Roy, Satyaki Banerjee & Babul Supriyo (Ft. Babul Supriyo)'
# Saved 'The End (Music for Cars) by The 1975'
# Saved 'Now We Are Free by Hans Zimmer & Lisa Gerrard'
# Saved 'Drones by Muse'
# Saved 'Door by Mitski'
# Saved 'Uebok (Gotta Run) by Apashe (Ft. INSTASAMKA)'
# Saved 'La vaguelette by HOYO-MiX'
# Saved 'Look at the world by John Rutter'
# Saved 'Welcome To LA by Oliver Tree'
# Saved 'ətˈæk 0N tάɪtn (Attack On Titan) by 澤野弘之 (Hiroyuki Sawano) (Ft. 小林未郁 (Mika Kobayashi))'
# Saved 'This Is How It Feels by ‎‎d4vd & Laufey'
# Saved 'BUTCHER OF THE WORLD by Lingua Ignota'
# Saved 'Karma by Alicia Keys'
# Saved 'When I Need a Friend by Coldplay'
# Saved 'Nocturne in E-Flat Major Op. 9, No. 2 by Frédéric Chopin'
# Saved 'Cum Dederit by Armand Amar (Ft. Sandrine Piau)'
# Saved 'Candlelight Carol by John Rutter'
# Saved 'Two Men in Love by The Irrepressibles'
# Saved 'MAY FAILURE BE YOUR NOOSE by Lingua Ignota'
# Saved '13 Angels Standing Guard ’Round the Side of Your Bed by A Silver Mt. Zion'
# Saved 'Life Is But a Dream... by Avenged Sevenfold'
# Saved '7월 7일 (One Of These Nights) by Red Velvet (레드벨벳)'
# Saved 'Nemesis by Benjamin Clementine'
# Saved 'FRAGRANT IS MY MANY FLOWER'D CROWN by Lingua Ignota'
# Saved 'Tragedi Oktober by Awie'
# Saved 'O Fortuna (Fortuna Imperatrix Mundi) by Carl Orff'
# Saved 'FAITHFUL SERVANT FRIEND OF CHRIST by Lingua Ignota'
# Saved 'Waltz in E-Major, Op. 15 "Moon Waltz" by Cojum Dip (Ft. Joe Hawley)'
# Saved 'Buenas tardes amigo by Ween'
# Saved 'Woe to All (On the Day of My Wrath) by Lingua Ignota'
# Saved 'Black Diamond by Stratovarius'
# Saved 'IF THE POISON WON'T TAKE YOU MY DOGS WILL by Lingua Ignota'
# Saved '​avril 14th by Aphex Twin'
# Saved 'Prince Igor by The Rapsody (Ft. Sissel & Warren G)'
# Saved 'Conquer or Die! by Megadeth'
# Saved 'Space-Dye Vest by Dream Theater'
# Saved 'Six Degrees of Inner Turbulence by Dream Theater'
# Saved 'Make Me Cry by Jacob Collier'
# Saved 'This Is A Life by Son Lux (Ft. David Byrne & Mitski)'
# Saved 'SDSS14+13B (Zercon, A Flagpole Sitter) by Scott Walker'
# Saved 'IeuD by Igorrr'
# Saved 'Islands by King Crimson'
# Saved 'Lua by Jacob Collier (Ft. MARO)'
# Saved 'Mark's Theme by Black Country, New Road'
# Saved 'Starálfur by Sigur Rós'
# Saved 'All Bitches Die (Bitches All Die Here) by Lingua Ignota'
# Saved 'Hunting High and Low by Stratovarius'
# Saved 'Dawn of Victory by Rhapsody of Fire'
# Saved 'Last Rites / Loved to Deth by Megadeth'
# Saved 'Distance by Apashe (Ft. Geoffroy)'
# Saved 'With the Love in My Heart by Jacob Collier (Ft. Jules Buckley & Metropole Orkest)'
# Saved 'Jesus bleibet meine Freude by Johann Sebastian Bach'
# Saved 'Kao u snu (Acoustic) by Tony Cetinski'
# Saved 'The Day Begins by The Moody Blues'
# Saved 'Time To Rest Your Weary Head by Jacob Collier'
# Saved 'Little 15 by Depeche Mode'
# Saved 'Einstein on the Beach: Knee Play 1 by Philip Glass'
# Saved 'SORROW! SORROW! SORROW! by Lingua Ignota'
# Saved 'Do You Dream of Armageddon? by Architects'
# Saved 'The Odyssey by Symphony X'
# Saved 'Sabrina by Einstürzende Neubauten'
# Saved 'Ευτυχισμένες Ημέρες in C Minor by Beats Pliz (GRC) (Ft. LEX (GRC))'
# Saved 'Dream by Ugly God'
# Saved 'I AM THE BEAST by Lingua Ignota'
# Saved 'Dream a Little Dream of Me by Doris Day'
# Saved 'SPITE ALONE HOLDS ME ALOFT by Lingua Ignota'
# Saved 'A Nightingale Sang in Berkeley Square by Vera Lynn (Ft. The Ayoub Sisters)'
# Saved 'Work by Apashe (Ft. Vo Williams)'
# Saved 'Für Elise (Piano Version) by Ludwig van Beethoven'
# Saved 'Symphony No. 9 in D minor, Op. 125, 4th Movement (English translation) by Ludwig van Beethoven'
# Saved 'Rhapsody in Blue by George Gershwin'
# Saved 'Spöksonat by Ghost'
# Saved 'Der Leiermann by Franz Schubert'
# Saved 'Movie (Never Made) by A Silver Mt. Zion'
# Saved 'Tamizhi by Hiphop Tamizha (Ft. Anthony Daasan & Hiphop Tamizha)'
# Saved 'Orchestral Intro by Gorillaz (Ft. Sinfonia ViVA)'
# Saved 'Holy is the Name (Of My Ruthless Axe) by Lingua Ignota'
# Saved '(ocean) bloom by Radiohead (Ft. BBC Concert Orchestra & Hans Zimmer)'
# Saved 'High on a Rocky Ledge by Moondog'
# Saved 'Erlkönig by Franz Schubert'
# Saved 'Corps De Blah by Scott Walker'
# Saved 'Good News by Apashe'
# Saved 'Feel by Jacob Collier (Ft. Lianne La Havas)'
# Saved '(It's Gonna Be) Okay by The Piano Guys'
# Saved 'Gavi's Song by Lindsey Stirling'
# Saved 'Blood of the Rose by The Dear Hunter'
# Saved 'Cornerstone by Benjamin Clementine'
# Saved 'Capulets by SALEM'
# Saved 'Ocean Wide, Canyon Deep by Jacob Collier (Ft. Jules Buckley, Laura Mvula & Metropole Orkest)'
# Saved 'Clair de lune by Claude Debussy'
# Saved 'Did You Not Hear My Lady by Aled Jones'
# Saved 'Moonlight Kissed by Poets of the Fall'
# Saved 'The Road Home by Stephen Paulus'
# Saved 'Shak by Quf (Ft. Fadaei)'
# Saved 'Alone Together by Chet Baker'
# Saved 'A View from the Top of the World by Dream Theater'
# Saved 'Insane by Apashe (Ft. Tech N9ne)'
# Saved '(There’ll Be Bluebirds Over) The White Cliffs of Dover by Vera Lynn (Ft. Alexander Armstrong)'
# Saved 'Freefall by Björk'
# Saved 'Peaches Etude by FINNEAS'
# Saved 'I Want You Now by Depeche Mode'
# Saved 'Intro by Black Country, New Road'
# Saved 'FUCKING DEATHDEALER by Lingua Ignota'
# Saved 'Suite II Overture by Janelle Monáe'
# Saved 'The Devil's Triangle by King Crimson'
# Saved 'The Lake South by The Dear Hunter'
# Saved 'Once You by Jacob Collier (Ft. Jules Buckley, Metropole Orkest & Suzie Collier)'
# Saved 'Mundeya Dupatta Chad Mera by Noor Jehan (Ft. Nadeem)'
# Saved 'Symphony of the Night by DragonForce'
# Saved 'Here’s to You by Ennio Morricone (Ft. Joan Baez)'
# Saved 'Enough About Human Rights by Moondog'
# Saved 'God Gave Me No Name (No Thing Can Hide from My Flame) by Lingua Ignota'
# Saved 'Sword of Damocles by Rufus Wainwright'
# Saved 'Gute Nacht by Franz Schubert'
# Saved 'Message to Harry Manback II by Tool'
# Saved 'The Host of Seraphim by Dead Can Dance'
# Saved 'Hi by Laufey'
# Saved 'Sky Above by Jacob Collier'
# Saved 'Cara Mia Addio by Aperture Science Psychoacoustic Laboratories'
# Saved 'The Last Milestone by Leprous'
# Saved 'All God's People by Queen'
# Saved 'No More by The Alley (iSHi) (Ft. Ella Eyre)'
# Saved 'Dear Soulmate by Laufey'
# Saved 'Illumination Theory by Dream Theater'
# Saved 'Djesse by Jacob Collier (Ft. Jules Buckley & Metropole Orkest)'
# Saved 'Back to the Sky by Ólafur Arnalds (Ft. JFDR)'
# Saved 'Legend by Apashe & Slumberjack (Ft. Wasiu)'
# Saved 'It Don't Matter by Jacob Collier (Ft. JoJo)'
# Saved 'Pimpf by Depeche Mode'
# Saved 'Symphony 6: Fair Thee Well & The Requiem Mix by Emily Wells'
# Saved 'Violenza Domestica by Mr. Bungle'
# Saved 'Rebirth by Angra'
# Saved 'La Vita by Beverly Glenn-Copeland'
# Saved 'Gloomy Sunday (Hungarian Suicide Song) (Hungarian Version English Translation) by Rezső Seress'
# Saved 'Bel Piacere by George Frideric Handel'
# Saved 'It's in My Blood by Coil'
# Saved 'The Debt Collector by Blur'
# Saved 'Everlasting Motion by Jacob Collier (Ft. Hamid El Kasri, Jules Buckley & Metropole Orkest)'
# Saved 'Das Wandern by Franz Schubert'
# Saved 'Rain by Apashe (Ft. KROY)'
# Saved 'Moon River by Jacob Collier'
# Saved 'I'm Fine by Apashe & High Klassified (Ft. Cherry Lena)'
# Saved 'Minecraft by C418'
# Saved 'Xavier by Dead Can Dance'
# Saved 'The River North by The Dear Hunter'
# Saved 'Night Light by Laufey'
# Saved 'On the Nature of Daylight by Max Richter'
# Saved 'VIAGRA by Dycha & Masno'
# Saved 'The Bottom Line by Ólafur Arnalds (Ft. JOSIN)'
# Saved 'I Trawl the Megahertz by Paddy McAloon'
# Saved 'Auf Wiedersehen, Sweetheart by Vera Lynn'
# Saved 'Broken Chords Can Sing a Little by A Silver Mt. Zion'
# Saved 'Ain't by Neil Cicierega'
# Saved 'Lord & Master by Apashe'
# Saved 'In Holy Flux by Weyes Blood'
# Saved 'All Night Long by Jacob Collier (Ft. Jules Buckley, Metropole Orkest & Take 6)'
# Saved 'Undone by Ólafur Arnalds'
# Saved 'Sponch Bob (Губка Боб) by GLORY O'VISION (Ft. GUZAR)'
# Saved 'Gems (Interlude) by Little Simz'
# Saved 'Ten Times a Day, Every Day, a Stranger by The Body'
# Saved 'Could've Moved Mountains... by A Silver Mt. Zion'
# Saved 'The Divine Wings of Tragedy by Symphony X'
# Saved 'The Death and the Berth by The Dear Hunter'
# Saved 'Sawah - سواح by Abdel Halim Hafez - عبد الحليم حافظ'
# Saved 'Carry On by Angra'
# Saved 'Do Your Thing by Moondog'
# Saved 'Abschied by Nico'
# Saved 'Le Petit Chevalier by Nico'
# Saved 'Fathers' Eyes by The Piano Guys'
# Saved 'What Sweeter Music by John Rutter (Ft. The Cambridge Singers)'
# Saved 'The Ubiquitous Mr. Lovegrove by Dead Can Dance'
# Saved 'Forever by Stratovarius'
# Saved 'Built Then Burnt (Hurrah! Hurrah!) by A Silver Mt. Zion'
# Saved 'Marjan by Quf (Ft. Reveal)'
# Saved 'Everything I Know About Love by Laufey'
# Saved 'Walking in the Air by Nightwish'
# Saved 'The Last Sled by Tuomas Holopainen (Ft. Alan Reid, Johanna Iivanainen & Johanna Kurkela)'
# Saved 'Yulunga (Spirit Dance) by Dead Can Dance'
# Saved 'Nick's B. Danube by SpongeBob SquarePants'
# Saved 'Blown-Out Joy from Heaven's Mercied Hole by A Silver Mt. Zion'
# Saved 'Black Sun by Dead Can Dance'
# Saved 'All That Is My Own by Nico'
# Saved 'Nebaluyo by Jacob Collier (Ft. Oumou Sangaré)'
# Saved 'Pee Wee Inc by Neil Cicierega'
# Saved 'Apocalyptica - Not Strong Enough (Türkçe Çeviri) by Genius Türkçe Çeviri'
# Saved 'America by Laibach'
# Saved 'The Outsiders by Neil Cicierega'
# Saved 'Shadilay by Pepe the Frog'
# Saved 'In the Hall of the Mountain King by Edvard Grieg'
# Saved 'Dauðalogn by Sigur Rós (Ft. The Sixteen)'
# Saved 'When Vanishing by King Krule'
# Saved 'BridgetO'Malley by BONES'
# Saved 'The Triumph of Our Tired Eyes by A Silver Mt. Zion'
# Saved 'L'Internationale by Eugène Pottier'
# Saved 'I Know Why (And So Do You) by Glenn Miller and His Orchestra'
# Saved 'Cans and Brahms by Yes'
# Saved 'Sé lest by Sigur Rós'
# Saved 'I Heard You Singing by Jacob Collier (Ft. Becca Stevens & Chris Thile)'
# Saved 'Elysium by Hans Zimmer & Lisa Gerrard'
# Saved 'Act of Faythe by Dream Theater'
# Saved 'Path, Vol. 2 by Apocalyptica (Ft. Sandra Nasić)'
# Saved 'I'm Forever Blowing Bubbles by Vera Lynn'
# Saved 'The Fallen Priest by Freddie Mercury and Montserrat Caballé (Ft. Montserrat Caballé)'
# Saved 'Horizons by Genesis'
# Saved 'Dun Dun Ba Ba (Interlude) by Jacob Collier'
# Saved 'A New Beginning by Dream Theater'
# Saved 'Unraveling (Interlude) by Evanescence'
# Saved 'A Thousand Years by The Piano Guys'
# Saved 'Heroes of the Waterfalls' Kingdom by Rhapsody of Fire'
# Saved 'Mein Herz brennt (Piano Version by Sven Helbig) by Rammstein'
# Saved 'Elegy For Extinction by Enter Shikari'
# Saved 'Dear God (Remix) by B4Bonah (Ft. Sarkodie)'
# Saved 'Lavara & Balaclava in C Minor by Beats Pliz (GRC) (Ft. SADAM (GRC))'
# Saved 'The Wind That Shakes the Barley by Dead Can Dance'
# Saved 'Swan Lake by Dark Moor (Ft. Itea Benedicto)'
# Saved 'February Song by Josh Groban'
# Saved 'Baal's Hymn by David Bowie'
# Saved 'If Anyone Tells Me "It's Better to Have Loved and Lost Than to Never Have Loved at All" I Will Stab Them in the Face by Matt Elliott'
# Saved 'Anywhere Out of the World by Dead Can Dance'
# Saved 'Here Comes The Sun by Jacob Collier (Ft. ​dodie)'
# Saved 'Aristocrat's Symphony by Versailles'
# Saved 'Victoriam in F Minor by Beats Pliz (GRC) (Ft. Bloody Hawk)'
# Saved 'The Young Person's Guide to the Orchestra by Benjamin Britten'
# Saved 'The Garden (Interlude) by Little Simz'
# Saved 'Demonheart by Luca Turilli'
# Saved 'Eagleheart by Stratovarius'
# Saved 'So She Dances by Josh Groban'
# Saved 'Bakumbe by Jacob Collier (Ft. Sam Amidon)'
# Saved 'I've Never Been In Love Before by Laufey'
# Saved 'Daffy Duck's Rhapsody by Mel Blanc'
# Saved 'Davy Jones by Hans Zimmer'
# Saved 'Memento Vivere in F Minor by Beats Pliz (GRC) (Ft. WANG (GRC))'
# Saved 'I'm This, I'm That by Moondog'
# Saved 'Wet Hands by C418'
# Saved '​aisatsana [102] by Aphex Twin'
# Saved 'Moment of Betrayal by Dream Theater'
# Saved 'Enta Omry  - إنت عمري by Umm Kulthum - أم كلثوم'
# Saved 'Do You Feel Love by Jacob Collier (Ft. Steve Vai)'
# Saved 'Mice on Venus by C418'
# Saved 'Sweden by C418'
# Saved 'The Lamp Is Low by Laurindo Almeida'
# Saved 'Recital in D# Minor by Beats Pliz (GRC) (Ft. Ethismos)'
# Saved 'Memphisto by Depeche Mode'
# Saved 'Human by Apashe & Wasiu'
# Saved '​język ciała 2020 by Tymek (Ft. Pawbeats)'
# Saved 'La canzone dei vecchi amanti by Franco Battiato'
# Saved 'Sea of Lies by Symphony X'
# Saved 'Bad News by Apashe'
# Saved 'Brithoven by Neil Cicierega'
# Saved 'I'm Fine (IMANU Remix) by Apashe & High Klassified (Ft. Cherry Lena)'
# Saved 'Dies Irae by Wolfgang Amadeus Mozart'
# Saved 'Aria Math by C418'
# Saved 'Trio by King Crimson'
# Saved 'The In-Between (Piano Solo) by Evanescence'
# Saved 'Every Little Thing She Does Is Magic by Jacob Collier (Ft. Jules Buckley & Metropole Orkest)'
# Saved 'A Gaelic Blessing by John Rutter'
# Saved 'Stumble Then Rise on Some Awkward Morning by A Silver Mt. Zion'
# Saved 'Pole Position in D Minor by Beats Pliz (GRC) (Ft. Vlospa)'
# Saved 'Hallelujah by Brian Crain'
# Saved 'Song of the Caged Bird by Lindsey Stirling'
# Saved 'Field of Reeds by These New Puritans'
# Saved 'The Wizard's Last Rhymes by Rhapsody of Fire (Ft. Jay Lansford)'
# Saved 'The Drowned Girl by David Bowie'
# Saved 'Ravenskill by Dream Theater'
# Saved 'Home Is by Jacob Collier (Ft. VOCES8)'
# Saved 'And in the Darkness by Weyes Blood'
# Saved 'Persephone (The Gathering of Flowers) by Dead Can Dance'
# Saved 'Fake News by Apashe (Ft. GrandBuda)'
# Saved 'Part VII by Prequell (Ft. Cruel Youth)'
# Saved 'For Wanda by A Silver Mt. Zion'
# Saved 'Domine Jesu by Wolfgang Amadeus Mozart'
# Saved 'Promenade (Satellite Pictures at an Exhibition) by Neil Cicierega'
# Saved '​​​​​​fish in the pool by ​yeule'
# Saved 'My Last Farewell by Dream Theater'
# Saved 'The Road to Revolution by Dream Theater'
# Saved 'Darale Duaarey by Nandita & Ishaan'
# Saved 'Dance of the Knights by Сергей Прокофьев (Sergei Prokofiev)'
# Saved 'Горе не беда (GINAP) by Сергей Мавроди (Sergey Mavrody)'
# Saved 'A Tempting Offer by Dream Theater'
# Saved 'This Guy's in Love with You by These New Puritans'
# Saved 'A Beginning by The Beatles'
# Saved 'Flimsy by King Krule'
# Saved 'Dance With You Tonight by Laufey'
# Saved 'F.E.A.R. Transmission 3: As War Fades by Black Veil Brides'
# Saved 'The Fall of Efrafa by Fall of Efrafa'
# Saved 'The Path That Divides by Dream Theater'
# Saved 'The March of the Swordmaster by Rhapsody of Fire'
# Saved 'Cantara by Dead Can Dance'
# Saved 'F.E.A.R. Transmission 1: Stay Close by Black Veil Brides'
# Saved 'Alto Rhapsody, Op. 53 by Johannes Brahms'
# Saved 'Revenge of the Orchestra by Apashe (Ft. Magugu)'
# Saved '666 Photos of Nothing by Xiu Xiu'
# Saved 'Babylon Was Built on Fire / Starsnostars by A Silver Mt. Zion'
# Saved 'Symphony No. 9 in D minor, Op. 125, 4th Movement, Presto by Ludwig van Beethoven'
# Saved 'Silhouette by Opeth'
# Saved 'Paradise by Stratovarius'
# Saved 'Mountainside by Protest The Hero'
# Saved 'After the Flash by Squid'
# Saved 'Forever by Queen'
# Saved 'Colligere by Julia Holter'
# Saved 'November by Max Richter'
# Saved 'The Light in Your Name by These New Puritans'
# Saved 'In the Kingdom of the Blind the One-Eyed Are Kings by Dead Can Dance'
# Saved 'Heaven's Cove by Dream Theater'
# Saved 'Organ Eternal by These New Puritans'
# Saved 'Ascending to Infinity by Luca Turilli's Rhapsody'
# Saved 'Always With Me [Sheet Music] by 久石譲 (Joe Hisaishi)'
# Saved 'WHERE’ER YOU WALK by Lingua Ignota (Ft. Alexis Marshall)'
# Saved 'L'animale by Franco Battiato'
# Saved 'Πόλη Του Ατόφιου Κακού in E Minor by Beats Pliz (GRC) (Ft. Dani Gambino)'
# Saved 'Total Eclipse by The Alan Parsons Project (Ft. The English Chorale)'
# Saved 'Of Sins and Shadows by Symphony X'
# Saved 'Pigmy Pig by Moondog'
# Saved 'Star Carol by John Rutter'
# Saved 'Slow Down by Laufey'
# Saved 'Alpha by C418'
# Saved 'Questions For The Universe by Laufey'
# Saved 'His Theme by Toby Fox'
# Saved '보이지 않는 사랑 (Invisible Love) by 신승훈 (Shin Seung Hun)'
# Saved 'Let Me Fall (from Cirque du Soleil) by Josh Groban'
# Saved 'Summoning of the Muse by Dead Can Dance'
# Saved 'Tripper by Alex G'
# Saved 'Endlessly by Mercury Rev'
# Saved 'Eine Kleine by Cast of Total Drama World Tour (Ft. Carter Hayden, Emilie-Claire Barlow, Marco Grazzini, Megan Fahlenbock, Novie Edwards, Peter Oldring, Rachel Wilson, Scott McCord & Stephanie Anne Mills)'
# Saved 'The Secret Marriage by Sting'
# Saved 'Speed Of Light by Stratovarius'
# Saved 'Path by Apocalyptica'
# Saved 'Night by Pamela Dillard'
# Saved 'Six Degrees of Inner Turbulence: V. Goodnight Kiss by Dream Theater'
# Saved 'Step into the Light by Two Steps From Hell (Ft. C. C. White, Nick Phoenix & Úyanga Bold)'
# Saved 'Eve of Seduction by Symphony X'
# Saved 'Hillside by Protest The Hero'
# Saved 'Non Più Andrai (The Marriage Of Figaro) by Wolfgang Amadeus Mozart'
# Saved '9 to 5 by Still Time'
# Saved 'Hansta Hua Noorani Chehra by Lata Mangeshkar (Ft. Kamal Barot)'
# Saved 'Privilege of Being by Sprain'
# Saved 'Droopy Likes Ricochet by C418'
# Saved 'Vocalise by Dave Malloy (Ft. Nikki M. James & Preludes Original Cast)'
# Saved 'Labyrinth by Grouper'
# Saved 'God Save the King/Queen by John Bull'
# Saved 'The End Of The World (Outro) by Busta Rhymes'
# Saved 'Je te veux by Erik Satie'
# Saved 'Sibeling by Depeche Mode'
# Saved 'Enter Stage Right by GRIP'
# Saved 'Holofernes by Grouper'
# Saved 'Long, Long Ago by Thomas Haynes Bayly'
# Saved 'Woven Song by Ólafur Arnalds'
# Saved 'Whispers on the Wind by Dream Theater'
# Saved 'Angels Cry by Angra'
# Saved 'Sting of the Bumblebee by Manowar'
# Saved 'Green Crack by Apashe (Ft. ​​wifisfuneral)'
# Saved 'Moog City by C418'
# Saved 'Larkspur And Lazarus by Current 93'
# Saved 'Loom by Ólafur Arnalds (Ft. Bonobo)'
# Saved 'Hold Fast to Dreams by Louise Toppin'
# Saved 'Overture by Jacob Collier (Ft. Jules Buckley & Metropole Orkest)'
# Saved 'Candlelight Fantasia by Symphony X'
# Saved 'American Motor Over Smoldered Field by A Silver Mt. Zion'
# Saved 'F.E.A.R: Final Transmission by Black Veil Brides'
# Saved 'Toccata and Fugue in D Minor (BWV 565) by Johann Sebastian Bach'
# Saved 'De Novo Adagio by Alicia Keys'
# Saved 'Dies Irae (Amadeus) by Dark Moor'
# Saved 'Il Cigno Nero by Luca Turilli's Rhapsody'
# Saved 'Yours by Vera Lynn (Ft. The Squadronaires)'
# Saved 'Did I Make The Most Of Loving You by The Chamber Orchestra of London (Ft. Mary-jess)'
# Saved 'Fly To Paradise by Sarah Brightman'
# Saved 'Inferno (Unleash the Fire) by Symphony X'
# Saved 'Overture by Black Veil Brides'
# Saved 'The Lord Is My Shepherd by John Rutter (Ft. The Cambridge Singers)'
# Saved 'F.E.A.R. Transmission 2: Trust by Black Veil Brides'
# Saved 'O Fortuna (french version) by Carl Orff'
# Saved 'A Splintered Mind by Lord of the Lost'
# Saved 'The Accolade by Symphony X'
# Saved 'March of the Meanies by George Martin'
# Saved 'Uebok (YMIR Remix) by Apashe (Ft. INSTASAMKA)'
# Saved 'Remembering Marie A. by David Bowie'
# Saved 'The Dark Tower of Abyss by Rhapsody of Fire (Ft. Jay Lansford)'
# Saved 'Moon Trance by Lindsey Stirling'
# Saved 'One Ring to Rule Them All by Luca Turilli's Rhapsody (Ft. Bridget Fogle & Emilie Ragni)'
# Saved 'Sea of Monsters by George Martin'
# Saved 'Pièce De Resistance in D Minor by Beats Pliz (GRC) (Ft. Hawk (GRC))'
# Saved 'Without You by The Piano Guys'
# Saved 'I Wonder as I Wander by Audrey Assad'
# Saved 'Dirty Song by David Bowie'
# Saved '2285 Entr'acte by Dream Theater'
# Saved 'A King's Sunset by Ludwig Göransson'
# Saved 'Paramour (Die Leidenschaft Bringt Leiden) by Fleshgod Apocalypse'
# Saved 'Spirit by Dead Can Dance'
# Saved 'A One Ton Heart by Lord of the Lost'
# Saved 'Opus of the Night (Ghost Requiem) by Kamelot (Ft. Tina Guo)'
# Saved 'Spiral by These New Puritans'
# Saved 'Kung Fu Fighting (Celebration Time) by Shanghai Roxi Musical Studio Choirs & Metro Voices London'
# Saved 'The Kiss of Judas by Stratovarius'
# Saved 'Overture by Björk'
# Saved 'Queen of the Dark Horizons by Rhapsody of Fire'
# Saved 'Song of the Nile by Dead Can Dance'
# Saved 'In the Wake of Adversity by Dead Can Dance'
# Saved 'A New Tomorrow by Jonathan Antoine'
# Saved 'If A City ... by Current 93'
# Saved 'Jesus' Blood Never Failed Me Yet by Gavin Bryars (Ft. Tom Waits)'
# Saved 'Paula C by Rubén Blades'
# Saved 'To Be by The Irrepressibles'
# Saved 'Mitropolis in C# Minor by Beats Pliz (GRC) (Ft. Mikros Kleftis)'
# Saved 'Out of the Ashes by Symphony X'
# Saved 'Excalibur by Luca Turilli's Rhapsody'
# Saved 'Last but Not Least by Fall of Efrafa'
# Saved 'Geckos! by Animal Jam (Game) (Ft. Adam D. Hunter, Jaimee Christensen, Joshua F. Olmos & Maximo K. Olmos)'
# Saved 'From the Sun to the World (Boogie No. 1) by Electric Light Orchestra'
# Saved 'Lully, Lulla, Lullay by VOCES8'
# Saved 'À Noite (Interlude) by Jacob Collier'
# Saved 'Overture Piccante by Freddie Mercury and Montserrat Caballé (Ft. Montserrat Caballé)'
# Saved 'Even When We're Gone by The Next Step (Ft. James Alphonse)'
# Saved 'Aléjate by Josh Groban'
# Saved 'Pepperland Laid Waste by George Martin'
# Saved 'Wish Me Luck as You Wave Me Goodbye by Vera Lynn'
# Saved 'Tornado by Rhapsody of Fire'
# Saved 'What Are Words by The Piano Guys (Ft. Evynne Hollens & Peter Hollens)'
# Saved 'War Of The Universe by Luca Turilli'
# Saved 'Oon Manam by Hichkas'
# Saved 'Haggstrom by C418'
# Saved 'Prelude in G# Minor, Op. 32, No. 12 by Dave Malloy (Ft. Or Matias & Preludes Original Cast)'
# Saved 'Never Give up on Your Dreams by Two Steps From Hell'
# Saved 'Sisters! Brothers! Small Boats of Fire Are Falling From the Sky! by A Silver Mt. Zion'
# Saved 'Luna by Luca Turilli's Rhapsody (Ft. Sassy Bernert)'
# Saved 'Me Fern Brady by Fern Brady'
# Saved 'To Be Rich by Tuomas Holopainen (Ft. Johanna Iivanainen & Johanna Kurkela)'
# Saved 'O Happy Fault by Audrey Assad'
# Saved 'Ballade No. 4 in F Minor Op. 52 by Frédéric Chopin'
# Saved 'In Her Eyes by Josh Groban'
# Saved 'Dante’s Inferno by Luca Turilli's Rhapsody'
# Saved 'タタラ踏む女達－エボシ タタラうた－ (Tatara Women’s Song) by 久石譲 (Joe Hisaishi)'
# Saved 'Tempesta di Fuoco by Rhapsody of Fire'
# Saved 'Hymn to Vena by Gustav Holst'
# Saved 'Anthracite Flowers: IV. Flowers by Julia Wolfe (Ft. Bang on a Can All-Stars, Choir of Trinity Wall Street & Julian Wachner)'
# Saved 'Public Domain by Van Dyke Parks'
# Saved 'Prelude: Song of the Gulls by King Crimson'
# Saved 'Windfall by Dead Can Dance'
# Saved 'Dark Fate of Atlantis by Luca Turilli's Rhapsody'
# Saved '미운날 (Hate That I Miss You) Piano Ver. by Lee Hae Ri (이해리)'
# Saved 'The Arrival and the Reunion by Dead Can Dance'
# Saved 'Mr. Sandman by Nan Vernon'
# Saved 'Audio Secrecy by Stone Sour'
# Saved 'Hymn by Sarah Brightman'
# Saved 'Rediscovery (Part II) - The New Mythology by Symphony X'
# Saved 'X by Trivium'
# Saved 'Earth Anthem by The Turtles'
# Saved 'The Old Kind Of Summer by The Black Heart Procession'
# Saved 'Here Comes the Flood by Robert Fripp (Ft. Peter Gabriel)'
# Saved 'Dawn of the Iconoclast by Dead Can Dance'
# Saved 'Vampire by Versailles'
# Saved 'A Soul to Bear by Fall of Efrafa'
# Saved 'Interlude #3 by Depeche Mode'
# Saved 'Lord, Make Me an Instrument of Thy Peace by John Rutter'
# Saved 'Part XIV by Prequell (Ft. Rae Morris)'
# Saved 'King by Apashe (Ft. Busta Rhymes)'
# Saved 'The Chill of Death by Charles Mingus'
# Saved 'Nothing Else Matters by Apocalyptica'
# Saved 'Carry by Tori Amos'
# Saved 'Nothing Else by These New Puritans'
# Saved 'Trois Vierges by Epica (Ft. Roy Khan)'
# Saved 'Thanatos by 鷺巣詩郎 (Shiro Sagisu)'
# Saved 'Far Beyond The Sun by Yngwie Malmsteen'
# Saved 'Menace by Apashe & High Klassified (Ft. EARTHGANG)'
# Saved 'When You Wish Upon a Star by Vera Lynn'
# Saved 'Haunt Muskie by C418'
# Saved 'Amen & Attack (Orchestra Version) by Powerwolf'
# Saved 'Turning Back the Hands of Time by Neil Sedaka'
# Saved 'Ashes in the Snow by MONO (JPN)'
# Saved 'I Would Have Woken You With This Song by Matt Elliott'
# Saved 'I Don't Stand a Ghost of a Chance With You by Alfred Hitchcock'
# Saved 'Camilla by Nauts (남구민) (Ft. STARRYSKY)'
# Saved 'La Voce Del Silencio by Andrea Bocelli'
# Saved 'Heartache by Toby Fox'
# Saved 'Pharaoh by Symphony X'
# Saved 'It Is Time, Only Time by Current 93'
# Saved 'Follow Me by Sarah Brightman'
# Saved 'Before the Story by Toby Fox'
# Saved 'Tears of a Dying Angel by Rhapsody of Fire (Ft. Jay Lansford)'
# Saved 'I’ve Got My Eye on You by Hans Zimmer'
# Saved 'Lost in Mumbai by Apashe & Geoffroy'
# Saved 'Rosenkreuz (The Rose and the Cross) by Luca Turilli's Rhapsody (Ft. Emilie Ragni)'
# Saved 'Sacred Power of Raging Winds by Rhapsody of Fire (Ft. Christopher Lee)'
# Saved 'One Summer's Day [Sheet Music] by 久石譲 (Joe Hisaishi)'
# Saved 'Babi Yar by Дмитрий Шостакович (Dmitri Shostakovich)'
# Saved 'Night On Disco Mountain by David Shire'
# Saved 'Creatures That Kissed in Cold Mirrors by Cradle of Filth'
# Saved 'Painters of the Tempest (Part I): Wyrmholes by Ne Obliviscaris'
# Saved 'How Fortunate The Man With None by Dead Can Dance'
# Saved 'Uebok (VIP) by Apashe (Ft. INSTASAMKA)'
# Saved 'Graveyard of Empires by Evans Blue'
# Saved 'Living Mice by C418'
# Saved 'Pas de Deux by Chi-Chi (USA) (Ft. Cami-Cat, Lollia, McGwire, Reagan Murdock & UpgradedMoon)'
# Saved 'Stjärna by Depeche Mode'
# Saved 'The Carnival Is Over by Dead Can Dance'
# Saved 'A Winter's Dream - The Ascension (Part II) by Symphony X'
# Saved 'The Writing on My Father's Hand by Dead Can Dance'
# Saved 'Arte Povera Soundtrack in Gsus2 by Beats Pliz (GRC)'
# Saved 'Why Spend a Dark Night with Me by Moondog'
# Saved 'Dry Hands by C418'
# Saved 'Epipelagic by The Ocean Collective'
# Saved '​async by 坂本龍一 (Ryuichi Sakamoto)'
# Saved 'Battle of Trees by Tori Amos'
# Saved 'Hallelujah Junction - 1st movement - by Ralph van Raat'
# Saved 'Deep Blue by Angra'
# Saved 'A Resting Place (Intro) by Kings Kaleidoscope'
# Saved 'Edge of the Moon by Tori Amos'
# Saved 'Mondestrunken by Arnold Schoenberg'
# Saved 'Mourned Winter Then by Current 93 (Ft. ANOHNI)'
# Saved 'We Contain Multitudes by Ólafur Arnalds'
# Saved 'Seemann by Apocalyptica (Ft. Nina Hagen)'
# Saved 'You by Sarah Brightman'
# Saved 'Dinner at Deviant’s Palace by Cradle of Filth'
# Saved 'Dogstar by H Y B R I D (Ft. Perry Farrell)'
# Saved 'My Eternal Dream by Stratovarius'
# Saved 'Waltz in A-Flat Major Op. 69, No. 1 by Frédéric Chopin'
# Saved 'Shattering Sea by Tori Amos'
# Saved 'Night of Hunters by Tori Amos (Ft. Kelsey Dobyns)'
# Saved 'A Body by The Body'
# Saved 'Submission by The Irrepressibles (Ft. Jon Campbell)'
# Saved 'Intro (Schizophrenia) by Sepultura'
# Saved 'Fanfare by KISS'
# Saved 'Home to Stay by Josh Groban'
# Saved 'Painters of the Tempest (Part III): Reveries from the Stained Glass Womb by Ne Obliviscaris'
# Saved 'Intro by Jacob Collier (Ft. Kathryn Tickell)'
# Saved 'Over the Rainbow / Simple Gifts by The Piano Guys'
# Saved 'La canzone dell'amore perduto by Franco Battiato'
# Saved 'As Time Goes By by Vera Lynn'
# Saved 'Songs to the Dark Virgin by Robert Honeysucker'
# Saved 'Weep You No More, Sad Fountains by Sting (Ft. Edin Karamazov)'
# Saved 'Lucky for Me by Laufey'
# Saved 'Indus by Dead Can Dance'
# Saved 'Fearlessness by Tori Amos'
# Saved 'Song for a Failed Relationship by Matt Elliott'
# Saved 'Tormento e Passione by Luca Turilli's Rhapsody (Ft. Sassy Bernert)'
# Saved 'Opening by Philip Glass'
# Saved 'In the Dragon's Den by Symphony X'
# Saved 'Overture by Apashe'
# Saved 'Quarantine by Justin Hurwitz'
# Saved 'The Writing In The Sand by Theocracy'
# Saved 'Hear, Smith of Heavens by Varien'
# Saved 'Try by Patrick Brasca (Ft. 周杰倫 (Jay Chou))'
# Saved 'Ashes of the Modern World by Apocalyptica'
# Saved 'How Can I Go On (New Orchestrated Version) by Freddie Mercury (Ft. Montserrat Caballé)'
# Saved 'This Gentle Hearts Like Shot Bird's Fallen by A Silver Mt. Zion'
# Saved 'Gana El Hawa - جانا الهوى by Abdel Halim Hafez - عبد الحليم حافظ'
# Saved 'Wicked Games by Ramin Djawadi'
# Saved 'Faraway, Vol. 2 by Apocalyptica (Ft. Linda Sundblad)'
# Saved 'Symphony 1 In the Barrel of a Gun by Emily Wells'
# Saved 'Succession (Main Title Theme) [Extended Intro Version] by Nicholas Britell'
# Saved 'Entry of the Gladiators Op.68 by Julius Fučík'
# Saved 'Moog City 2 by C418'
# Saved 'Vaka (Live) by Sigur Rós'
# Saved 'Elegy by Fleshgod Apocalypse'
# Saved 'Il Tempo Degli Dei by Luca Turilli's Rhapsody (Ft. Emilie Ragni & Gustavo Adolfo Rol)'
# Saved 'Devour Me, Colossus (Part II): Contortions by Ne Obliviscaris'
# Saved 'The Damnation Game by Symphony X'
# Saved 'II. Air [ORCHESTRAL SUITE No. 3 in D Major, BWV. 1068] by Johann Sebastian Bach'
# Saved 'Tho You Are Gone I Still Often Walk w/You by A Silver Mt. Zion'
# Saved 'The Eyes of Medusa by Symphony X'
# Saved 'Never Understand by Angra (Ft. Dirk Schlächter, Kai Hansen & Sascha Paeth)'
# Saved 'In the Hot by Emily Wells'
# Saved 'The Charade by Serj Tankian'
# Saved 'Tonight We Love by Caterina Valente'
# Saved 'The Ballad of the Adventurers by David Bowie'
# Saved 'Yomi yori Kikoyu, Koukoku no Hi to Honoo no Shoujo. (Orchestral Ver.) by Imperial Circus Dead Decadence'
# Saved 'In Grandeur and Frankincense Devilment Stirs by Cradle of Filth'
# Saved 'Church of the Machine by Symphony X'
# Saved 'Caffé de la Paix by Franco Battiato'
# Saved 'A Winter's Dream - Prelude (Part I) by Symphony X'
# Saved 'The Edge of Forever by Symphony X'
# Saved 'Notturno by Luca Turilli's Rhapsody (Ft. Emilie Ragni)'
# Saved 'Job's Coffin by Tori Amos (Ft. Natashya Hawley)'
# Saved 'Door by C418'
# Saved 'Jupiter, the Bringer of Jollity by Gustav Holst'
# Saved 'Fight Song / Amazing Grace by The Piano Guys'
# Saved 'A Hundred Reasons by Ólafur Arnalds (Ft. Haukur Heiðar Hauksson)'
# Saved 'Black Star by Yngwie Malmsteen'
# Saved 'My Bonnie Lies Over the Ocean by Laura Wright (Ft. Barry Wordsworth, Laura Wright & Royal Philharmonic Orchestra)'
# Saved 'Your Ghost by Tori Amos'
# Saved 'King's Walk by Animal Collective'
# Saved 'Fine Knacks for Ladies by Sting (Ft. Edin Karamazov)'
# Saved 'Star Whisperer by Tori Amos'
# Saved 'Chant of Benevolence by 4everfreebrony (Ft. Chi-Chi (USA))'
# Saved 'Father Time by Stratovarius'
# Saved 'I Don't Think About You Anymore but, I Don't Think About You Anyless by Hungry Ghosts'
# Saved 'Act I, Scene 1: "The People Are the Heroes Now" by John Coolidge Adams'
# Saved 'Have You Seen the Bright Lily Grow by Sting (Ft. Edin Karamazov)'
# Saved 'The Shoes of the Fisherman’s Wife Are Some Jive Ass Slippers by Charles Mingus'
# Saved 'The Moon by Dark Moor'
# Saved 'The National Anthem by Jason Orbaum (Ft. Anna Louise Vincent & The NotGames Male Voice Choir)'
# Saved 'Un Giorno per Noi by Josh Groban'
# Saved 'Masquerade by Symphony X'
# Saved 'Sonata No.14 in C#m (Moonlight Sonata) by Depeche Mode'
# Saved 'Some by Nils Frahm'
# Saved 'La peregrinación (Huella pampeana) by Mercedes Sosa'
# Saved 'Minstrel Man by Pamela Dillard'
# Saved 'Nautical Twilight by Tori Amos'
# Saved 'Klaagzang by Sefa'
# Saved 'Barcelona - New Orchestrated Version by Freddie Mercury (Ft. Montserrat Caballé)'
# Saved 'The Victory Dance by Theocracy'
# Saved 'I’m in the World by Moondog'
# Saved 'Convocation by Yellowcard'
# Saved 'Cactus Practice by Tori Amos (Ft. Natashya Hawley)'
# Saved 'First Light (feat. Spencer Jones) by Cinematic Pop (Ft. Spencer Jones)'
# Saved 'Flying by The Next Step'
# Saved '1812 Overture, Op. 49 by Пётр Ильич Чайковский (Pyotr Ilyich Tchaikovsky)'
# Saved 'Evil Warning by Angra'
# Saved 'AGNUS DEI by Lingua Ignota'
# Saved 'The Loveliest Night of the Year by Vera Lynn'
# Saved 'F*ck Wagner by Dendemann (Ft. Chilly Gonzales & Kaiser Quartett)'
# Saved 'Duel & Cloudscapes by Tuomas Holopainen'
# Saved 'A Sky Full of Stars by The Piano Guys'
# Saved 'Nunquam Iterum, Op. 12 by Hatari (Ft. Friðrik Margrétar)'
# Saved 'Mountain by Theocracy'
# Saved 'Outro by Jacob Collier'
# Saved 'Stitched to My Heart by The Black Heart Procession'
# Saved 'L'ultima Notte by Josh Groban'
# Saved 'She said, "Don't make others  suffer for your personal hatred" by 鷺巣詩郎 (Shiro Sagisu)'
# Saved 'Prelude by Bernard Herrmann'
# Saved 'Please Please Please by Matt Elliott'
# Saved 'The Lord is a Man of War by George Frideric Handel'
# Saved 'The Seperation of HAQQ from HAEL by Liturgy'
# Saved 'Crusaders by Harry Gregson-Williams'
# Saved 'Snowblind by Tori Amos (Ft. Natashya Hawley)'
# Saved 'The Ashes of My Enemies by Heaven Shall Burn'
# Saved 'Seven Sisters by Tori Amos'
# Saved 'Follow the Map by MONO (JPN)'
# Saved 'Sympathy by Louise Toppin'
# Saved 'Bad Comments by Xlson137 (Ft. Vovenciii)'
# Saved 'Saltarello by Dead Can Dance'
# Saved 'Worlds Collide by Apocalyptica'
# Saved 'Spiral by Ólafur Arnalds'
# Saved 'Turtle Dreams (Waltz) by Meredith Monk (Ft. Andrea Goodman, Collin Walcott, Julius Eastman, Paul Langland, Robert Een & Steve Lockwood)'
# Saved 'For You [Classical] by Karma Fields'
# Saved 'Chaos by Ayreon'
# Saved 'How to Kill a Rose by Matt Elliott'
# Saved 'Don’t call my phone on no dumb shit by Mistr danny (Ft. Artshow OGK)'
# Saved 'Intro (End of Silence) by Red'
# Saved 'Classical Gas by Vanessa-Mae'
# Saved 'Legions by Stratovarius'
# Saved 'Truth by Versailles'
# Saved 'The Murder by Bernard Herrmann'
# Saved 'Black Realms' Majesty by Luca Turilli (Ft. Rannveig Sif Sigurdardottir)'
# Saved 'New Century's Tarantella by Luca Turilli'
# Saved 'Ooh-Poo-Pah-Doo by Ike & Tina Turner'
# Saved 'I glaub i geh jetzt by Wolfgang Ambros'
# Saved 'The Arrival of Kai by Hans Zimmer'
# Saved 'The Whole Universe Wants to Be Touched by Nils Frahm'
# Saved 'Skydiving onto the library roof by ​caroline'
# Saved 'The French Library by Franz Gordon'
# Saved 'Excuse by C418'
# Saved 'Cho Aski by Misagh (Ft. Kabin)'
# Saved 'Aska Me by Moondog'
# Saved 'My Immortal by Lindsey Stirling'
# Saved 'Piano Sonata No. 11 in A major, K. 331: III. Rondo alla turca by Wolfgang Amadeus Mozart'
# Saved 'Danny by C418'
# Saved 'Hope by Apocalyptica'
# Saved 'Dupree's Paradise by Frank Zappa'
# Saved 'I Walk To My Own Song by Stratovarius'
# Saved 'El Atlal - الأطلال by Umm Kulthum - أم كلثوم'
# Saved 'Odio Por Amor by Juanes'
# Saved 'Transient by Haywyre'
# Saved 'Pan’s Labyrinth Lullaby by Javier Navarrete'
# Saved 'Cymru Fach by Katherine Jenkins'
# Saved 'Rain by 坂本龍一 (Ryuichi Sakamoto)'
# Saved 'Hallelujah by André Rieu (Ft. Carla Maffioletti, Kimmy Skota, Mastreechter Staar, Mirusia Louwerse, The Platin Tenors & The Royal Choir Society)'
# Saved 'The Chase by Tori Amos (Ft. Natashya Hawley)'
# Saved 'Mars, the Bringer of War by Gustav Holst'
# Saved 'Concrete Halls by C418'
# Saved 'Intro by C418'
# Saved 'The Ash Grove by Laura Wright'
# Saved 'Habanera by Katherine Jenkins'
# Saved 'A Lesson Before Dying by Symphony X'
# Saved 'With My Sorrows by Black Tape for a Blue Girl'
# Saved 'Fast Company by Eagles'
# Saved 'Till I loved you by Plácido Domingo (Ft. Dionne Warwick)'
# Saved 'Unrequited Love and He Who Sleeps Beneath by Steampianist (Ft. GUMI (グミ))'
# Saved 'Ligeti : Requiem: II - Kyrie by György Ligeti'
# Saved 'Can She Excuse My Wrongs? by Sting (Ft. Edin Karamazov)'
# Saved 'En Route To Mayhem by Apocalyptica'
# Saved 'OIOION's Birth by Liturgy'
# Saved 'My Reverie by Larry Clinton'
# Saved 'Nierika by Dead Can Dance'
# Saved 'Dark Comet's Reign by Luca Turilli'
# Saved 'A Womb in Dark Chrysalis (Interlude) by The Black Dahlia Murder'
# Saved 'Anahata by Luca Turilli's Rhapsody (Ft. Bridget Fogle)'
# Saved 'Eleven by C418'
# Saved 'Voices of Spring by Moondog'
# Saved 'Now or Never by Josh Groban'
# Saved 'Rise by Apocalyptica'
# Saved 'The Witching Hour by Symphony X'
# Saved 'Jesus' Blood Never Failed Me Yet by Audrey Assad'
# Saved 'Theme From Trouble Man - Soundtrack Version by Marvin Gaye'
# Saved 'I'll Never Find Your Soul by Hania Rani'
# Saved 'Sarabande by George Frideric Handel'
# Saved 'Árbakkinn by Ólafur Arnalds (Ft. Einar Georg Einarsson)'
# Saved 'Blind Spots by C418'
# Saved 'Stop Texting Me (Intro) by JAYE (KE)'
# Saved 'Perfect by The Piano Guys'
# Saved 'Amal Hayaty - أمل حياتي by Umm Kulthum - أم كلثوم'
# Saved 'Kryptonite by Apashe (Ft. Lia Kurihara)'
# Saved 'Regyptian Strut by Frank Zappa'
# Saved 'Jesus bleibet meine Freude [Herz und Mund und Tat und Leben BWV. 147] by Johann Sebastian Bach'
# Saved 'Here’s to John Wesley Hardin by Moondog'
# Saved 'Ibelin by Harry Gregson-Williams'
# Saved 'Walpurgis Eve by Cradle of Filth'
# Saved 'The End of Words by Dead Can Dance'
# Saved 'An Open Door by Capstan'
# Saved 'Somewhere Around Nothing by Apocalyptica'
# Saved 'The Golden Boy (New Orchestrated Version) by Freddie Mercury (Ft. Montserrat Caballé)'
# Saved 'Sogni by Sarah Brightman (Ft. Vincent Niclo)'
# Saved 'Severance by Dead Can Dance'
# Saved 'Quiet As a Dead Friend by ​​do not resurrect'
# Saved 'Dance and Angela by Franz Waxman'
# Saved 'The Snake And The Moon by Dead Can Dance'
# Saved 'Lamento della ninfa by Claudio Monteverdi'
# Saved 'The Landing by Justin Hurwitz'
# Saved 'Choo Choo Lullaby by Moondog'
# Saved 'Electric Daisy Violin by Lindsey Stirling'
# Saved 'Devorzhum by Dead Can Dance'
# Saved 'Radar Maker by Mogwai'
# Saved '夢のスキマ (Gap of Dream) by 鷺巣詩郎 (Shiro Sagisu)'
# Saved 'Lasting Child by Angra'
# Saved 'Secret Garden by Angra (Ft. Simone Simons)'
# Saved 'Oogway's Legacy by Hans Zimmer'
# Saved 'Grace by Apocalyptica (Ft. 布袋寅泰 (Tomoyasu Hotei))'
# Saved 'The Cardinal Sin by Dead Can Dance'
# Saved 'Zero by Ólafur Arnalds'
# Saved 'Gloria in excelsis Deo by Joseph Haydn'
# Saved 'Insane (Kai Wachi Remix) by Apashe (Ft. Tech N9ne)'
# Saved 'Come Again by Sting (Ft. Edin Karamazov)'
# Saved 'The Womb of Winter by Swallow the Sun'
# Saved 'DNA by The Piano Guys'
# Saved 'Christmas In East Haven by Vinnie Penn'
# Saved 'In a Rainbow by Sweetwater'
# Saved 'La Souffleuse by Salvador Sobral'
# Saved 'As the Bell Rings the Maypole Spins by Dead Can Dance'
# Saved 'Miracle (Sarah's Version) by Sarah Brightman (Ft. YOSHIKI)'
# Saved 'Burial at Sea by MONO (JPN)'
# Saved 'RIP by Apashe & Vladimir Cauchemar'
# Saved 'Deck the Halls by Tarja (Ft. Naomi Cabuli Turunen)'
# Saved 'Blocks by C418'
# Saved 'The Ancient & Arcane by Varien'
# Saved 'Graveyard Symphony [The Undertaker] by Jim Johnston'
# Saved 'End by Clown Core'
# Saved 'Felix Culpa by Audrey Assad'
# Saved 'I’m Just a Hop Head by Moondog'
# Saved '23rd Psalm by 坂本龍一 (Ryuichi Sakamoto)'
# Saved 'Ballad of the Cats by C418'
# Saved 'New Grass by Ólafur Arnalds'
# Saved 'We Three Kings by Tarja'
# Saved 'Stabat Mater Dolorosa by Epica (Ft. Floor Jansen)'
# Saved 'Ullyses by Dead Can Dance'
# Saved 'Rise from the Sea of Flames by Rhapsody of Fire'
# Saved 'Close Your Eyes (Buffy/Angel Love Theme) by Christophe Beck'
# Saved 'We Played Some Open Chords and Rejoiced, for the Earth Had Circled the Sun Yet Another Year by A Winged Victory For The Sullen'
# Saved 'Succession (Main Title Theme) by Nicholas Britell'
# Saved 'The Simpsons Theme by Danny Elfman (Ft. The Simpsons)'
# Saved 'Bachegoone by Arman Vino (Ft. Ali Jaam)'
# Saved 'Chant of Oblivion by Possessed'
# Saved 'Burn by Apocalyptica'
# Saved 'Clear or Cloudy by Sting (Ft. Edin Karamazov)'
# Saved 'Closer by Sarah Brightman'
# Saved '閉塞の拡大 (Expansion of Blockade) by 鷺巣詩郎 (Shiro Sagisu)'
# Saved 'Sky And Sand by Sarah Brightman'
# Saved 'Oasis by Tarja'
# Saved 'She's Playing Piano by Toby Fox'
# Saved 'Beautiful by Apocalyptica'
# Saved 'Un Día Llegará by Josh Groban'
# Saved 'Hymn Overture by Sarah Brightman'
# Saved 'Doomsday Celebration by Morbid Angel'
# Saved 'Équinoxe by C418'
# Saved 'Viego, The Ruined King by League of Legends'
# Saved 'Perpetuum Mobile by Penguin Cafe Orchestra'
# Saved 'Clark by C418'
# Saved 'Corpseflower by Cradle of Filth'
# Saved 'Ansak - أنساك by Umm Kulthum - أم كلثوم'
# Saved 'The Abyss by Sepultura'
# Saved 'Radharc by Dead Can Dance'
# Saved 'The Song of the Sibyl by Dead Can Dance'
# Saved 'Unfeel by Lord of the Lost'
# Saved 'Paths by Be'lakor'
# Saved 'Enigma of the Absolute by Dead Can Dance'
# Saved 'Lost in a Heartbeat by Lord of the Lost'
# Saved 'Mutation by C418'
# Saved 'Gothic Vision by Luca Turilli's Dreamquest'
# Saved 'Every Void by April + VISTA'
# Saved 'Over The Waves by Juventino Rosas'
# Saved 'Night In WuTown by OUTLINE (Rapper) (Ft. Sol Stone)'
# Saved 'Closure by Evergrey'
# Saved 'In Darkness Let Me Dwell by Sting (Ft. Edin Karamazov)'
# Saved 'Pluto Projector (Cover) by ​d4vd'
# Saved 'Flow, My Tears (Lachrimae) by Sting (Ft. Edin Karamazov)'
# Saved 'Shelter by White Ward'
# Saved 'Dream Variation by Pamela Dillard'
# Saved 'Themes (From "Pirates of the Caribbean") by The Piano Guys'
# Saved 'Pie Jesu by Tarja'
# Saved 'Symphony No. 8 in E-flat major, Part I by Gustav Mahler'
# Saved 'Dressed to Kill by Symphony X'
# Saved 'Sugar Plum Fairy (Magical Christmas Mix) by Mariah Carey'
# Saved 'The Goldberg Variations, BWV 988: Aria by Johann Sebastian Bach'
# Saved 'Rei I by 鷺巣詩郎 (Shiro Sagisu)'
# Saved 'Transcendence by Lindsey Stirling'
# Saved 'Rolling in the Deep by The Piano Guys'
# Saved 'Symphony 4: America's Mercy War by Emily Wells'
# Saved 'Canta sobre Mí by Lorelei Tarón (Ft. Kike Pavón)'
# Saved 'Mai by Josh Groban'
# Saved 'Drill Clássico by Chico da Tina'
# Saved 'Tiffauges by Cradle of Filth'
# Saved 'Sad but True by Apocalyptica'
# Saved 'Anhedonia by Ne Obliviscaris'
# Saved 'Close to You by Vera Lynn'
# Saved 'The Eternal Diva by Nishiura Tomohito (Ft. 水樹奈々 (Nana Mizuki))'
# Saved '사뿐사뿐 (Like a Cat) + 단발머리 (Short Hair) by AOA Cream'
# Saved 'Kung Fu Fighting (The Vamps) by The Vamps'
# Saved 'Grandes Ilusiones by Salvador Sobral'
# Saved 'Masquerade '98 by Symphony X'
# Saved 'Adagio For Strings Op. 11 by Samuel Barber'
# Saved 'Over There by Billy Murray'
# Saved '退行への緊急避難 (Emergency Evacuation to Regression) by 鷺巣詩郎 (Shiro Sagisu)'
# Saved 'God Rest Ye Merry Gentlemen by Tarja'
# Saved 'Beyond the Stars by Apocalyptica'
# Saved 'Obuj Valobasha by Hridoy Khan'
# Saved 'Trolls in the Dark by Rhapsody of Fire'
# Saved 'Faraway by Apocalyptica'
# Saved 'Clair de Lune by Styx'
# Saved 'Jaago Piya (feat. Armeen Musa) by Berklee Indian Ensemble (Ft. Armeen Musa)'
# Saved 'Painting Flowers White Never Suited My Palette by Cradle of Filth'
# Saved 'Sailing by Vera Lynn'
# Saved 'At the Gates of Manala by Apocalyptica'
# Saved 'The Night Café by Clint Mansell'
# Saved 'Ice Dance by Danny Elfman'
# Saved 'Până când nu te iubeam by Maria Tănase'
# Saved 'The Fallen Priest - New Orchestrated Version by Freddie Mercury (Ft. Montserrat Caballé)'
# Saved 'The Seance by Matt Elliott'
# Saved 'Adagio Ma Non Troppo by Charles Mingus'
# Saved 'La Japonaise - New Orchestrated Version by Freddie Mercury (Ft. Montserrat Caballé)'
# Saved 'What’s the Most Exciting Thing? by Moondog'
# Saved 'Solo por ti by Josh Groban'
# Saved 'K.K. Aria by K.K. Slider'
# Saved 'Lost Virtue by Respire'
# Saved 'Nest by Hania Rani'
# Saved 'Better Is One Day by Sarah Brightman'
# Saved 'And Along Came the Rain by Elba (Piano)'
# Saved 'Impossible by Two Steps From Hell (Ft. Merethe Soltvedt)'
# Saved 'Are You There? by MONO (JPN)'
# Saved 'Clair de Lune (Adaptation) by Pitou'
# Saved 'Titanium / Pavane by The Piano Guys'
# Saved 'Last Hope by Apocalyptica (Ft. Dave Lombardo)'
# Saved 'Beginning 2 by C418'
# Saved 'Run Away to Mars - String Version by TALK'
# Saved 'Because We Believe by Jonathan Antoine'
# Saved 'The Raging Seasons by Symphony X'
# Saved 'The Lowest Trees Have Tops by Sting (Ft. Edin Karamazov)'
# Saved 'Dreamtime by Tuomas Holopainen'
# Saved 'Wilderness by Dead Can Dance'
# Saved 'Confutatis by Wolfgang Amadeus Mozart'
# Saved 'Cell-0 by Apocalyptica'
# Saved 'The Monstrous Sabbat (Summoning the Coven) by Cradle of Filth'
# Saved 'Emmeleia by Dead Can Dance'
# Saved 'Fade to Black by Apocalyptica'
# Saved 'Zunya by Lord of the Lost'
# Saved 'A New Moonlight by Andre Matos'
# Saved 'Wait a While (Live from Royal Albert Hall, 26th September 1999) by Deep Purple'
# Saved 'Call My Name by Apocalyptica'
# Saved 'Huh? (Intro) by Spiritualized'
# Saved 'The Battle of Chamdo by Gorguts'
# Saved 'Kyoto by C418'
# Saved 'Maestro by Behan the Scene'
# Saved 'Brotsjor by Ólafur Arnalds'
# Saved 'Red Hot by Vanessa-Mae'
# Saved 'Far Across The Land by Eurielle & Ryan Louder'
# Saved 'Blooding the Hounds of Hell by Cradle of Filth'
# Saved 'Silent Flight, Sleeping Dawn by MONO (JPN)'
# Saved 'Beginning by C418'
# Saved 'Pictured Within (Live from Royal Albert Hall, 26th September 1999) by Deep Purple'
# Saved 'The Garden of Zephirus by Dead Can Dance'
# Saved 'Alpha & Omega by Stratovarius'
# Saved 'The Battle of Legends by Hans Zimmer'
# Saved 'Tell Me About The Forest (You Once Called Home) by Dead Can Dance'
# Saved 'You Would Have Loved This by Tarja'
# Saved 'Hall of the Mountain King by Apocalyptica'
# Saved 'In Sorrow by Edu Falaschi'
# Saved 'Amazing Grace by Tarja'
# Saved 'My Tiny Butterfly by Moondog'
# Saved 'Sitting in a Dream (Live from Royal Albert Hall, 26th September 1999) by Deep Purple'
# Saved 'Scream For the Silent by Apocalyptica'
# Saved 'And I Shall Come To You Like a Stormtrooper In Drag Serving Imperial Realness by Sufjan Stevens, Timo Andres & Conor Hanick'
# Saved 'End by Matt Elliott'
# Saved 'Party by Xlson137 (Ft. Vovenciii)'
# Saved 'Advent by Dead Can Dance'
# Saved 'I, Too by Pamela Dillard'
# Saved 'Faust, Act III: "Ah, je ris de me voir" (Marguerite), CG 4 The Jewel Song by İnarə Babayeva'
# Saved 'Wilt Thou Unkind Thus Reave Me by Sting (Ft. Edin Karamazov)'
# Saved 'Swan Lake, Op. 20 – Scene, Act 2, #10 – Tchaikovsky ( A Cappella ) by The Agonist'
# Saved 'Dem Worlds by Emika'
# Saved 'Springtime by Robert Honeysucker'
# Saved 'Insano by MaYaN'
# Saved 'Rex tremendae by Wolfgang Amadeus Mozart'
# Saved '2010 by Apocalyptica (Ft. Dave Lombardo)'
# Saved 'Fikrimin İnce Gülü by Sertab Erener'
# Saved 'The Rite of Spring (Extract) by Игорь Стравинский (Igor Stravinsky)'
# Saved 'Who The Waves Are Roaring For (Hunted II) by Colin Stetson'
# Saved 'Prologue (The Turn of the Screw) by Benjamin Britten'
# Saved 'Deathzone by Apocalyptica'
# Saved 'Duo des fleurs by Étienne Cousineau (CAN)'
# Saved 'And We Walk After by Trevor Kowalski'
# Saved 'Lament by Fall of Efrafa'
# Saved 'Story of My Life by The Piano Guys'
# Saved 'Until It Sleeps by Apocalyptica'
# Saved 'Не жди меня (Do not wait for me) by Kriluna'
# Saved 'L'ombrello e la macchina da cucire by Franco Battiato'
# Saved 'The Firebird Suite by Игорь Стравинский (Igor Stravinsky)'
# Saved 'Fortune Presents Gifts Not According to the Book by Dead Can Dance'
# Saved 'El Rito by Gustavo Cerati'
# Saved 'Guide Me Home - New Orchestrated Version by Freddie Mercury (Ft. Montserrat Caballé)'
# Saved 'Chevaliers de Sangreal by Hans Zimmer'
# Saved 'La Diva by Céline Dion'
# Saved 'I Don't Know Ya by Sparkadiss (Ft. Leah Dazzio)'
# Saved 'Introduction by Fall of Efrafa'
# Saved 'In the Depths of Human Hearts by 鷺巣詩郎 (Shiro Sagisu)'
# Saved 'Song of Sophia by Dead Can Dance'
# Saved 'Come, Heavy Sleep by Sting (Ft. Edin Karamazov)'
# Saved 'Exodus by Ferrante & Teicher'
# Saved 'Det hev ei rose sprunge by Odd Nordstoga & Det Norske Kammerorkester (Ft. Frida Ånnevik)'
# Saved 'The Unforgiven by Apocalyptica'
# Saved 'Still / Sound by Ólafur Arnalds'
# Saved 'Symphony 3: The Story by Emily Wells (Ft. Count Bass D)'
# Saved 'Piece 1 by This Nude World (Ft. A Nude Japanese Orchestra)'
# Saved 'Energy by Luca Turilli's Dreamquest'
# Saved 'Theme from Tchaikovsky's Piano Concerto No. 1 in B-Flat Minor, Op. 23 by Caterina Valente'
# Saved 'Greensleeves by Jeff Beck Group'
# Saved 'Can't Stop Lovin U by Tina P'
# Saved 'Hungarian Dance No.5 In G Minor by Johannes Brahms'
# Saved 'Liza - ליזה by Hachaverim Shel Natasha - החברים של נטאשה (Ft. David D’Or - דוד ד’אור, Dudu Fisher - דודו פישר, Eran Tzur - ערן צור & Meir Banai - מאיר בנאי)'
# Saved 'Premonition by Symphony X'
# Saved 'Love's Dream by Rick Wakeman (Ft. Roger Daltrey)'
# Saved 'Music of the Spheres: Requiem Aeternam Part I by Becoming the Archetype'
# Saved 'Secrets by Hans Zimmer & Lisa Gerrard'
# Saved 'Fire & Ice by Apocalyptica'
# Saved 'O Come, O Come, Emmanuel by Tarja'
# Saved 'Der Hölle Rache kocht in meinem Herzen by Wolfgang Amadeus Mozart'
# Saved 'Le Nozze di Figaro Overture by Wolfgang Amadeus Mozart'
# ...
# Saved 'Manolo by Trip Lee (Ft. Lecrae)'
# Saved 'Creep On Me by GASHI (Ft. DJ Snake & French Montana)'
# Saved 'Cool For The Summer by Demi Lovato'
# Saved 'Teddy Bear by Melanie Martinez'
# Saved 'I Feel Like I'm Drowning by Two Feet'
# Saved 'Fake Happy by Paramore'
# Saved 'My Love by Majid Jordan (Ft. Drake)'
# Saved 'Sir by Nicki Minaj (Ft. Future)'
# Saved 'One, Two Step by Ciara (Ft. Missy Elliott)'
# Saved 'FU by Miley Cyrus (Ft. French Montana)'
# Saved 'REALLY REALLY by WINNER'
# Saved 'Venetia by Lil Uzi Vert'
# Saved 'Somebody by The Chainsmokers (Ft. Drew Love)'
# Saved 'BREAK MY SOUL (THE QUEENS REMIX) by Beyoncé & Madonna'
# Saved 'On & On by Cartoon & Jéja (Ft. Daniel Levi (EST))'
# Saved 'Everything Black by Unlike Pluto (Ft. Mike Taylor)'
# Saved 'Welcome to the Machine by Pink Floyd'
# Saved 'Soulmate by Mac Miller'
# Saved 'Wish You Were Sober by Conan Gray'
# Saved 'Gët Busy by Yeat'
# Saved 'Best Friends by The Weeknd'
# Saved 'Vogue by Madonna'
# Saved 'TUNNEL VISION by Melanie Martinez'
# Saved 'There Will Be Tears by Frank Ocean'
# Saved 'Nasty by Skepta'
# Saved 'Mad Love by Sean Paul & David Guetta (Ft. Becky G.)'
# Saved 'Forest by ​twenty one pilots'
# Saved 'Freal Luv by Far East Movement & Marshmello (Ft. CHANYEOL & Tinashe)'
# Saved 'Discord by The Living Tombstone (Ft. Eurobeat Brony)'
# Saved 'Party Girls by Ludacris (Ft. Cashmere Cat, Jeremih & Wiz Khalifa)'
# Saved 'At the Door by The Strokes'
# Saved '​anxiety by ​blackbear & FRND'
# Saved 'Amerika by Rammstein'
# Saved 'Everybody Hates Me by The Chainsmokers'
# Saved 'Gdzie jest biały węgorz? (Zejście) by Cypis'
# Saved 'Breathe by Jax Jones (Ft. Ina Wroldsen)'
# Saved 'Бесприданница (Dowry) by DEAD BLONDE'
# Saved 'Monster by Lady Gaga'
# Saved 'Fuck with Myself by BANKS'
# Saved 'Phantom Regret by Jim by The Weeknd'
# Saved 'Vacation Bible School (Original Version) by Ayesha Erotica'
# Saved 'E.T. by Katy Perry'
# Saved 'Particula by Major Lazer & DJ Maphorisa (Ft. Ice Prince, Jidenna, Nasty C & Patoranking)'
# Saved 'Take Me Back To London (Remix) by Ed Sheeran (Ft. Aitch, Jaykae & Stormzy)'
# Saved 'The Night Is Still Young by Nicki Minaj'
# Saved 'The Mother We Share by CHVRCHES'
# Saved 'Everytime We Touch by Cascada'
# Saved 'Lights by Ellie Goulding'
# Saved 'Bad Blood by NAO'
# Saved 'Nobody Gotta Know by Why Don't We'
# Saved 'Strangers by Sigrid'
# Saved 'Old Thing Back by Matoma & The Notorious B.I.G. (Ft. Ja Rule & Ralph Tresvant)'
# Saved 'Don't Trust Me by 3OH!3'
# Saved '29 #Strafford APTS by Bon Iver'
# Saved 'Just Wanna Rock by Lil Uzi Vert'
# Saved 'Fuego by Eleni Foureira'
# Saved 'Outro by M83'
# Saved 'I Heard You're Married by The Weeknd (Ft. Lil Wayne)'
# Saved 'The Ocean by Mike Perry (Ft. SHY Martin)'
# Saved 'Thought I Knew You by Nicki Minaj (Ft. The Weeknd)'
# Saved 'Genesis by Dua Lipa'
# Saved 'Don't You Want Me by The Human League'
# Saved 'My Girls by Animal Collective'
# Saved 'Sunset Lover by Petit Biscuit'
# Saved 'Boom Clap by Charli XCX'
# Saved 'Just Can't Get Enough by Black Eyed Peas'
# Saved 'Antisocial by ​tana (Ft. Slump6s)'
# Saved 'I Need Your Love by Calvin Harris (Ft. Ellie Goulding)'
# Saved 'Our Song by Anne-Marie & Niall Horan'
# Saved 'Swine by Lady Gaga'
# Saved 'Ayo Technology by 50 Cent (Ft. Justin Timberlake & Timbaland)'
# Saved 'Август (August) by Intelligency'
# Saved 'Future Nostalgia by Dua Lipa'
# Saved 'Screen by ​twenty one pilots'
# Saved 'Pretty Please by Dua Lipa'
# Saved 'Hope by The Chainsmokers (Ft. Winona Oak)'
# Saved 'Grrrls by Lizzo'
# Saved 'Miss You by Cashmere Cat, Major Lazer & Tory Lanez'
# Saved 'Mary Jane Holland by Lady Gaga'
# Saved 'PS5 by ​salem ilese, TOMORROW X TOGETHER & Alan Walker'
# Saved 'You Owe Me by The Chainsmokers'
# Saved 'I Really Want to Stay at Your House by Rosa Walton & Hallie Coggins'
# Saved 'Everything Is AWESOME!!! by Tegan and Sara (Ft. The Lonely Island)'
# Saved 'Comedy by Bo Burnham'
# Saved '​start//end by EDEN'
# Saved 'The Very First Night (Taylor's Version) [From The Vault] by Taylor Swift'
# Saved 'My Universe by Coldplay & BTS'
# Saved 'In the Dark by Camila Cabello'
# Saved 'NintendHoe by Doja Cat'
# Saved 'Va Va Voom by Nicki Minaj'
# Saved 'Blue Monday by New Order'
# Saved 'суки я в шлеме (демо) [bitches I'm wearing a helmet (demo)] by прыгай киска (kiska)'
# Saved 'Russky Cockney by Oxxxymiron'
# Saved 'Semi-Automatic by ​twenty one pilots'
# Saved 'Call You Mine by The Chainsmokers & Bebe Rexha'
# Saved 'RAMSING by SIDxRAM'
# Saved 'Karma (Remix) by Taylor Swift (Ft. Ice Spice)'
# Saved 'Stay With You by Cheat Codes & Cade'
# Saved 'SOLO by JENNIE'
# Saved 'Time Moves Slow by BADBADNOTGOOD (Ft. Samuel T. Herring)'
# Saved 'Audacity by Stormzy (Ft. Headie One)'
# Saved 'Miss the Rage by Mario Judah'
# Saved 'Let Me Hold You (Turn Me On) by Cheat Codes & Dante Klein'
# Saved 'Happy Now by Kygo & Sandro Cavazza'
# Saved 'Boş Gemiler by Yüzyüzeyken Konuşuruz'
# Saved 'It's Strange by Louis The Child (Ft. K.Flay)'
# Saved 'Нас не догонят (Nas ne dogonyat) by ​t.A.T.u.'
# Saved 'False Alarm by Matoma & Becky Hill'
# Saved 'Hopeless by Halsey (Ft. Cashmere Cat)'
# Saved 'Working for It by ZHU, Skrillex & THEY.'
# Saved 'Sorry Bout That by Yeat'
# Saved 'ARTPOP by Lady Gaga'
# Saved 'NEVER MET! by CMTEN (Ft. Glitch Gum)'
# Saved 'Scatman (Ski-Ba-Bop-Ba-Dop-Bop) by Scatman John'
# Saved 'I Don't Know Why by Imagine Dragons'
# Saved 'White Woman's Instagram by Bo Burnham'
# Saved 'STILL DISAPPOINTED by Stormzy'
# Saved '​hand crushed by a mallet by 100 gecs'
# Saved 'Something About Us by Daft Punk'
# Saved 'Right Thru Me by Nicki Minaj'
# Saved 'PURE/HONEY by Beyoncé'
# Saved '365 by Zedd & Katy Perry'
# Saved 'Make It Bun Dem by Skrillex (Ft. Damian Marley)'
# Saved 'Magenta Riddim by DJ Snake'
# Saved 'Sugar by Robin Schulz (Ft. Francesco Yates)'
# Saved 'Paracetamol by Declan McKenna'
# Saved 'Purge the Poison by MARINA'
# Saved 'Life Round Here (Remix) by James Blake (Ft. Chance the Rapper)'
# Saved 'Crazy by Lost Frequencies & Zonderling'
# Saved 'Born to Be Yours by Kygo & Imagine Dragons'
# Saved 'Day 1 ◑ by HONNE'
# Saved 'Water Me by FKA twigs'
# Saved 'Lost in Your Light by Dua Lipa (Ft. Miguel)'
# Saved '​​​​stupid by Tate McRae'
# Saved 'Everything Now by Arcade Fire'
# Saved 'GDFR by Flo Rida (Ft. Lookas & Sage The Gemini)'
# Saved 'Leaders by Lil Uzi Vert (Ft. NAV)'
# Saved 'Every Angel is Terrifying by The Weeknd'
# Saved '​ocean eyes (Astronomyy Remix) by Billie Eilish'
# Saved 'Plastic 100°C by Sampha'
# Saved 'What's Up Danger by Blackway & Black Caviar'
# Saved 'THIQUE by Beyoncé'
# Saved 'Тает лёд (Ice’s Melting) by Грибы (Griby)'
# Saved 'Vroom Vroom by Charli XCX'
# Saved 'How You Get The Girl by Taylor Swift'
# Saved 'Let's Groove by Earth, Wind & Fire'
# Saved 'Good Night by Kanye West (Ft. Al Be Back & Yasiin Bey)'
# Saved 'Venus as a Boy by Björk'
# Saved 'Options by Doja Cat (Ft. JID)'
# Saved 'Pump Up the Jam by Technotronic (Ft. Ya Kid K)'
# Saved 'Heroes Tonight by Janji (Ft. Johnning)'
# Saved 'Young by The Chainsmokers'
# Saved 'Celebration Station by Lil Uzi Vert'
# Saved 'Midnight City by M83'
# Saved 'Confess by Logic (Ft. Killer Mike)'
# Saved 'Tattoo by Loreen'
# Saved 'Sexy and I Know It by LMFAO'
# Saved 'One Touch by Baauer (Ft. AlunaGeorge, Rae Sremmurd & Swae Lee)'
# Saved 'How to Be a Heartbreaker by MARINA'
# Saved '(No One Knows Me) Like the Piano by Sampha'
# Saved '17 by MK'
# Saved 'Straightjacket by Quinn XCII'
# Saved 'Flawlëss by Yeat (Ft. Lil Uzi Vert)'
# Saved 'Peanut Butter Jelly by Galantis'
# Saved 'Drop the Game by Flume & Chet Faker'
# Saved 'Bad Karma by Axel Thesleff'
# Saved 'Another Late Night by Drake (Ft. Lil Yachty)'
# Saved 'Everybody Gets High by MISSIO'
# Saved 'Funkytown by Lipps, Inc.'
# Saved '쩔어 (DOPE) by BTS'
# Saved 'Darling Nikki by Prince and the Revolution'
# Saved 'Breaking Me by Topic & A7S'
# Saved 'Sweet Nothing by Calvin Harris (Ft. Florence Welch)'
# Saved 'Houdini by Foster the People'
# Saved 'MOVE by Beyoncé (Ft. Grace Jones & Tems)'
# Saved 'Pound The Alarm by Nicki Minaj'
# Saved 'In For It by Tory Lanez'
# Saved 'MANiCURE by Lady Gaga'
# Saved '1999 by Charli XCX & Troye Sivan'
# Saved 'REALiTi by Grimes'
# Saved 'Head in the Clouds by 88rising & Joji'
# Saved '22 (OVER S∞∞N) by Bon Iver'
# Saved 'TRRST by IC3PEAK (Ft. ZillaKami)'
# Saved '(I Just) Died in Your Arms by Cutting Crew'
# Saved 'Rich Girl by Gwen Stefani (Ft. Eve)'
# Saved 'Anathema by ​twenty one pilots'
# Saved 'Tired by Alan Walker (Ft. Gavin James)'
# Saved 'I Fink U Freeky by Die Antwoord'
# Saved 'There There by Radiohead'
# Saved '#SELFIE by The Chainsmokers'
# Saved ''Tis a Pity She Was a Whore by David Bowie'
# Saved 'Implicit Demand for Proof by ​twenty one pilots'
# Saved 'Bravado by Lorde'
# Saved '@ (trailer) by ​chillwagon'
# Saved 'Fatty Boom Boom by Die Antwoord'
# Saved 'Violence by Grimes & i_o'
# Saved 'Cherry by Rina Sawayama'
# Saved 'I'm Not Her by Clara Mae'
# Saved 'Star (Voice English Ver.) by LOONA'
# Saved 'Dance Yrself Clean by LCD Soundsystem'
# Saved 'Honest by The Chainsmokers'
# Saved 'Superhero by Unknown Brain (Ft. Chris Linton)'
# Saved 'Cool Girl by Tove Lo'
# Saved 'Up My Sleeves by Death Grips'
# Saved 'Don't Break My Heart by The Weeknd'
# Saved 'Shout by Tears for Fears'
# Saved 'IDOL by BTS'
# Saved 'I Got You by Bebe Rexha'
# Saved 'Talk That Talk by Rihanna (Ft. JAY-Z)'
# Saved '​2 soon by ​keshi'
# Saved 'Reality by Lost Frequencies (Ft. Janieck)'
# Saved 'Space Ghost Coast to Coast by Glass Animals'
# Saved 'Give It 2 U (Remix) by Robin Thicke (Ft. 2 Chainz & Kendrick Lamar)'
# Saved 'VIRGO'S GROOVE by Beyoncé'
# Saved 'Team by Iggy Azalea'
# Saved 'Around the World by Daft Punk'
# Saved 'My Way by Calvin Harris'
# Saved 'Scream by Michael Jackson (Ft. Janet Jackson)'
# Saved 'Complicated by Dimitri Vegas & Like Mike & David Guetta (Ft. Kiiara)'
# Saved 'Myself by Bazzi'
# Saved 'Hustle Bones by Death Grips'
# Saved 'Audio by LSD'
# Saved 'Only The Young by Taylor Swift'
# Saved 'Bring the Noize by M.I.A.'
# Saved 'Beyond by Daft Punk'
# Saved 'JE TE VOGLIO BENE ASSAJE by LIBERATO'
# Saved 'Left Brain, Right Brain by Bo Burnham'
# Saved 'Brain Power by NOMA (JPN)'
# Saved 'Jump by Rihanna (Ft. Kevin Cossom)'
# Saved '96 Fuckries by Jme'
# Saved 'I Just Had Sex by The Lonely Island (Ft. Akon)'
# Saved 'Busted and Blue by Gorillaz'
# Saved 'Antisocial 2 by ​tana (Ft. Slump6s, ​SSGKobe, Xhulooo & Yung Fazo)'
# Saved 'Location Unknown ◐ by HONNE (Ft. Georgia)'
# Saved 'Massive by Drake'
# Saved 'Out of Touch by Daryl Hall & John Oates'
# Saved 'Enigma by Lady Gaga'
# Saved 'I Really Like You by Carly Rae Jepsen'
# Saved 'Everybody's Free (To Wear Sunscreen) by Baz Luhrmann (Ft. Lee Perry (Narrator))'
# Saved 'NFS Underground by GSPD'
# Saved 'Just One Yesterday by Fall Out Boy (Ft. Foxes)'
# Saved 'The Run and Go by ​twenty one pilots'
# Saved 'Angel by Fifth Harmony'
# Saved 'This Town by Kygo (Ft. Sasha Alex Sloan)'
# Saved 'After The Afterparty by Charli XCX (Ft. Lil Yachty)'
# Saved 'Brain by BANKS'
# Saved 'Because by The Beatles'
# Saved 'Fearless, Pt. II by Lost Sky (Ft. Chris Linton)'
# Saved 'I Can't Give Everything Away by David Bowie'
# Saved 'A Tale By Quincy by The Weeknd'
# Saved 'Madness by Muse'
# Saved '불장난 (PLAYING WITH FIRE) by BLACKPINK'
# Saved '​mary magdalene by FKA twigs'
# Saved 'Baby, I'm Jealous by Bebe Rexha (Ft. Doja Cat)'
# Saved 'Be Together by Major Lazer (Ft. Wild Belle)'
# Saved 'And the Snakes Start to Sing by Bring Me The Horizon'
# Saved 'SUMMER RENAISSANCE by Beyoncé'
# Saved 'Someone That Loves You by HONNE & Izzy Bizu'
# Saved 'Shine by Olly Alexander'
# Saved 'Maniac by Michael Sembello'
# Saved 'Starry Eyes by The Weeknd'
# Saved 'Did Somebody Say (Just Eat) by Katy Perry'
# Saved 'Where Them Girls At by David Guetta (Ft. Flo Rida & Nicki Minaj)'
# Saved 'Life Round Here by James Blake'
# Saved '​disco tits by Tove Lo'
# Saved 'I'm The Best by Nicki Minaj'
# Saved 'Dreamer by Axwell Λ Ingrosso (Ft. Trevor Guthrie)'
# Saved 'Gone by Charli XCX & Christine and the Queens'
# Saved 'Save ME by BTS'
# Saved 'Good Things Fall Apart by ILLENIUM (Ft. Jon Bellion)'
# Saved 'LA Confidential by Tory Lanez'
# Saved 'BATTLE OF THE LARYNX by Melanie Martinez'
# Saved 'Остров (Island) by МЫ (WE) (Ft. Mirèle)'
# Saved 'Bad Decisions by ​benny blanco, BTS & Snoop Dogg'
# Saved 'Pagan Poetry by Björk'
# Saved 'Holy Ground by Davido (Ft. Nicki Minaj)'
# Saved 'Everybody Knows by Leonard Cohen'
# Saved 'Glory Box by Portishead'
# Saved 'Jenny (I Wanna Ruin Our Friendship) by Studio Killers'
# Saved '3-Way (The Golden Rule) by The Lonely Island (Ft. Justin Timberlake & Lady Gaga)'
# Saved 'Sing Me to Sleep by Alan Walker'
# Saved 'The National Anthem by Radiohead'
# Saved 'A Moment Apart by ODESZA'
# Saved '​holy terrain by FKA twigs (Ft. Future)'
# Saved 'Shit by Bo Burnham'
# Saved 'Jealous by Eyedress'
# Saved 'Frozen by Madonna'
# Saved 'Ruby by ​twenty one pilots'
# Saved 'Swing Lynn by Harmless'
# Saved 'Thief by Ansel Elgort'
# Saved 'No Excuses by Meghan Trainor'
# Saved 'Gimme More by Britney Spears'
# Saved 'Skin by Rihanna'
# Saved 'Nights With You by MØ'
# Saved 'Don't Stay in School by Boyinaband'
# Saved 'Revolution by Diplo (Ft. Faustix, Imanos & ​kai)'
# Saved '불타오르네 (Burning Up) (Fire) by BTS'
# Saved 'YOLO by The Lonely Island (Ft. Adam Levine & Kendrick Lamar)'
# Saved 'Integrity by Jme'
# Saved 'Check It Out by Nicki Minaj & will.i.am'
# Saved 'Both Ways by Liam Payne'
# Saved 'This is What It Feels Like by BANKS'
# Saved 'Dooo It! by Miley Cyrus'
# Saved '1x1 by Bring Me The Horizon (Ft. Nova Twins)'
# Saved 'Dirty Sexy Money by David Guetta & AFROJACK (Ft. Charli XCX & French Montana)'
# Saved 'Come Up and Get Me by Death Grips'
# Saved 'Crack Baby by Mitski'
# Saved 'Any Colour You Like by Pink Floyd'
# Saved 'Habits of My Heart by Jaymes Young'
# Saved '666 ʇ by Bon Iver'
# Saved 'Domino by Jessie J'
# Saved 'Y.A.L.A. by M.I.A.'
# Saved 'Pretty Cvnt by Sewerslvt'
# Saved 'Do My Thang by Miley Cyrus'
# Saved 'Glad You Came by The Wanted'
# Saved 'New Divide by Linkin Park'
# Saved '​stupid horse by 100 gecs'
# Saved 'Dorak Gai - دورك جي by Wegz - ويجز'
# Saved 'BLACKPINK - 아니길 (Hope Not) (Romanized) by Genius Romanizations'
# Saved 'Outside by Calvin Harris (Ft. Ellie Goulding)'
# Saved 'Dímelo by Snakehips & Tory Lanez'
# Saved 'Bang Bang by ​will.i.am'
# Saved 'Ameno by ERA'
# Saved '​sex money feelings die by Lykke Li'
# Saved 'A Keeper by Drake'
# Saved 'Miss You by Oliver Tree & Robin Schulz'
# Saved 'Flicker by Porter Robinson'
# Saved 'Lighter by Nathan Dawe (Ft. KSI)'
# Saved 'On the Run by Pink Floyd'
# Saved 'Head.Cars.Bending by The 1975'
# Saved 'Lotus Flower by Radiohead'
# Saved 'IN THE SUMMER by 嵐 (ARASHI)'
# Saved 'Lovely by ​twenty one pilots'
# Saved 'Big Enough by Kirin J Callinan (Ft. Alex Cameron, Jimmy Barnes & Molly Lewis)'
# Saved 'Watch This by Lil Uzi Vert'
# Saved 'SMOKE IT OFF! by Lumi Athena & jnhygs'
# Saved 'Someone New by BANKS'
# Saved 'Akasaka Sad by Rina Sawayama'
# Saved 'Break Up Song by Little Mix'
# Saved 'Play by K-391, Alan Walker & Martin Tungevaag (Ft. Mangoo)'
# Saved 'Cut My Hair by Mounika. (Ft. Cavetown)'
# Saved 'Die Trying by Michl'
# Saved 'Mitsubishi Sony by Frank Ocean'
# Saved 'Whip It by Nicki Minaj'
# Saved 'Save Me by Nicki Minaj'
# Saved 'Runaway (U & I) by Galantis'
# Saved 'You & Me (Flume Remix) by Disclosure (Ft. ELIZA)'
# Saved 'PLASTIC OFF THE SOFA by Beyoncé'
# Saved 'Goodnight Gotham by Rihanna'
# Saved 'Don't Play by Anne-Marie, KSI & Digital Farm Animals'
# Saved '​moment by Vierre Cloud'
# Saved 'Dawn Chorus by Thom Yorke'
# Saved 'Winaloto by Tommy Cash'
# Saved 'Then by Anne-Marie'
# Saved 'Can’t Get You Out Of My Head by Kylie Minogue'
# Saved 'Fashion! by Lady Gaga'
# Saved 'Make Me Fade by K.Flay'
# Saved 'BLACKPINK - Really (English Translation) by Genius English Translations'
# Saved 'West End Girls by Pet Shop Boys'
# Saved 'Don't Kill My Vibe by Sigrid'
# Saved 'Overgrown by James Blake'
# Saved '​psychofreak by Camila Cabello (Ft. WILLOW)'
# Saved 'These Girls by Why Don't We'
# Saved '​bitches by Tove Lo'
# Saved 'I Dare You by The xx'
# Saved 'All Of Me by Big Gigantic (Ft. Logic & ROZES)'
# Saved 'Supplies by Justin Timberlake'
# Saved 'Астронавт (Astronaut) by ATL'
# Saved 'No Drama by Tinashe (Ft. Offset)'
# Saved 'Summertime by Vince Staples'
# Saved 'Been You by Justin Bieber'
# Saved 'Content by Bo Burnham'
# Saved 'Poppin by Yeat'
# Saved 'In Here Somewhere by Frank Ocean'
# Saved 'Грустная сука (Sad Bitch) by IC3PEAK'
# Saved 'Love Is Gone by SLANDER (Ft. Dylan Matthew)'
# Succsefffully saved electronic songs
